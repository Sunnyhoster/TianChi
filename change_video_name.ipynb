# %%
import sys

# %%
i=0
id=0
data_list=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", [])
                elif i % 4 == 0:
                    data["answer"].append(word)
                    data_list.append(data)
                    data={}
                    answer=[]
                else:
                    data["answer"].append(word)
            else:
                video_id=word

# %%
import os

# %%
i=0
dict_video={}
path = '/disk/private-data/yy/TianChi/VQADatasetA_20180815/train/'         # 替换为你的路径
dir = os.listdir(path)                  # dir是目录下的全部文件
fopen = open('./data/video_name.txt', 'w') # 替换为你的路径
for d in dir:                        # d是每一个文件的文件名
    i+=1
    string = d   #拼接字符串并换行
    dict_video[d]=i
    fopen.write(string)             # 写入文件中
fopen.close()

# %%
dict_video
# Out:
# {'ZJL4004.mp4': 3223,
#  'ZJL752.mp4': 3120,
#  'ZJL246.mp4': 603,
#  'ZJL2756.mp4': 1415,
#  'ZJL79.mp4': 120,
#  'ZJL1480.mp4': 116,
#  'ZJL3740.mp4': 1069,
#  'ZJL1323.mp4': 886,
#  'ZJL3549.mp4': 2382,
#  'ZJL534.mp4': 1414,
#  'ZJL3980.mp4': 283,
#  'ZJL2563.mp4': 1773,
#  'ZJL3378.mp4': 2799,
#  'ZJL3128.mp4': 3278,
#  'ZJL2066.mp4': 83,
#  'ZJL4018.mp4': 3160,
#  'ZJL4091.mp4': 286,
#  'ZJL675.mp4': 2194,
#  'ZJL64.mp4': 1830,
#  'ZJL3248.mp4': 573,
#  'ZJL1834.mp4': 1571,
#  'ZJL2624.mp4': 1467,
#  'ZJL3754.mp4': 1120,
#  'ZJL3508.mp4': 711,
#  'ZJL2320.mp4': 3012,
#  'ZJL2213.mp4': 1437,
#  'ZJL83.mp4': 3011,
#  'ZJL2909.mp4': 10,
#  'ZJL3399.mp4': 2733,
#  'ZJL2519.mp4': 81,
#  'ZJL2938.mp4': 1452,
#  'ZJL478.mp4': 2298,
#  'ZJL653.mp4': 847,
#  'ZJL789.mp4': 3110,
#  'ZJL2674.mp4': 1102,
#  'ZJL4118.mp4': 1792,
#  'ZJL3282.mp4': 1738,
#  'ZJL4263.mp4': 198,
#  'ZJL3018.mp4': 732,
#  'ZJL1215.mp4': 2205,
#  'ZJL20.mp4': 3027,
#  'ZJL1452.mp4': 2640,
#  'ZJL1811.mp4': 1322,
# ...

# %%
import json

# %%
#new_dict = json.loads(data_list)
with open("./data/video_name_to_id.json","w") as f:
    json.dump(dict_video,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...
