# %%
import sys

# %% [markdown]
# f=open("./VQADatasetA_20180815/train.txt")
# for line in f.readlines():
#     print(line)

# %% [markdown]
# while line:
#     print(line,end=" ")
#     #line=f.readlines()
# f.close()

# %%
flag_line=0
with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        flag_line+=1
        words = line.split(',')
        flag_word=0
        for word in words:
            flag_word+=1
        if flag_word!=21:
            print(flag_line)

# %%
frequency_question = {}
frequency_answer={}
i=0

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    if word not in frequency_question:
                        frequency_question[word]=1
                    else:
                        frequency_question[word]+=1
                else:
                    if word not in frequency_answer:
                        frequency_answer[word]=1
                    else:
                        frequency_answer[word]+=1

# %%
frequency_question
# Out:
# {'where is the person in blue': 1,
#  'what does the man in the video shoot': 1,
#  'is the person in video sitting or standing before putting the computer on': 1,
#  'is the woman wearing white clothes in the video long hair or short hair': 1,
#  'what is the host in the video doing': 2,
#  "what color is the judge's clothes in the video": 1,
#  'what color of the jacket does the person wear in the video': 15,
#  'is the woman in video standing or lying down': 1,
#  'where is the person in black clothes': 1,
#  'is the person wearing glasses in the video standing or sitting': 3,
#  'was the man in the video sitting or standing at the beginning': 1,
#  'what is the person wearing red in the video doing': 1,
#  'what color pants does the people wearing a cowboy cap wear in video': 1,
#  'is the alpaca standing or sitting in video': 1,
#  'what is the mouse doing in the video': 1,
#  'what is the color of th boat in the video': 1,
#  'what is the color of the backpack in the video': 1,
#  "what is in the man's hand": 31,
#  "what is in the man's pocket": 1,
#  'how many people appear in the video': 5,
#  'what is the color of the pants does the man in yellow top wear': 1,
#  'what is the color of the chair': 2,
#  'what color is the gun in the video': 1,
#  'where is the cream in the video': 2,
#  'what are the children in the video doing': 1,
#  'what does the grandmother hold in hands in the video': 1,
#  'is the person a woman or a man in the video': 1,
#  'what is in the mouth of the person in the video': 1,
#  'why throwing smoke shell in the video': 1,
#  'where is the book': 19,
#  'where is the audience': 3,
#  'what color does the woman wear in the video': 1,
#  'is the person under the spotlight standing or sitting': 1,
#  "what is the color of the man's clothes at the beginning of the video": 2,
#  'what color does the man in the video wear': 2,
#  'what is on the table of the kitchen': 2,
#  'is the person wearing trousers or shorts': 1,
#  'what was girl doing at beginning of video': 1,
#  'what is the color of the wall in the video': 37,
#  'what is the color of the clothes on the bed in the video': 1,
#  'what image is played in the video': 1,
#  'what are the alpacas doing in video': 1,
#  'what color of the clothes does the girl wear at the beginning of the video': 1,
#  'where is the animated scene in the video': 1,
#  'is the person sitting in the video sitting or standing': 1,
#  'what is the person with a hat doing in the video': 1,
#  'what does the man in the video finally pick up': 1,
#  'what color pants does the standing man wear in the video': 1,
#  'where is the person': 19,
#  'what color is the pot in video': 1,
#  'what is the gender of the person wearing wings in the video': 1,
#  'is the man blinking or closing his eyes in the video': 1,
#  'where is the person driving car in the video': 1,
#  'is the person in the video sitting or walking': 1,
#  'is the text in the video english or chinese': 4,
#  'what is the color of the pants does the man wear': 6,
#  'what color is the grass in the video': 2,
#  'what color is the washer in the video': 1,
#  'what is on the road in the video': 2,
#  'where is the sofa in the video': 3,
#  'is the weather sunny or cloudy': 1,
#  'what does the person have on his body': 1,
#  'where is the cartoon in the video played': 1,
#  'what is the person kicking in the video': 1,
#  'what is the color of the socks does the man wear': 1,
#  'what is the weapon used to do in the video': 1,
#  'how many paper are folded in the video': 1,
#  'what color is the fire in the video': 1,
#  'what is the person in the water in video doing': 1,
#  'what is at the back of the person in video': 1,
#  'what is at the right side of the sofa': 1,
#  'where is the man lying on in the video': 2,
#  'where did the person in video put the medicine': 1,
#  'what is the shape of the tape in the video': 1,
#  'what is the person on the square in the video doing': 1,
#  'what is the woman wearing sunglasses doing in the video': 1,
#  'is the warship 3d or real in the video': 1,
#  'where is the washing machine': 2,
#  'what is the man squatting in the video doing': 1,
#  'what is the person at the beginning of the video doing': 1,
#  'is the person wearing the hat in the video sitting or standing': 2,
#  'is the boy in red standing or sitting': 1,
#  'is the person in the video sitting or standing after entering into the house': 1,
#  'what is the animal in the picture': 1,
#  'what happened after the person in the video kicked the ball': 1,
#  'is the person in the video sitting or lying while reading a book': 1,
#  'what is the woman with bag in her hand doing in video': 1,
#  'what is in front of the stairs': 1,
#  'what is the color of the car for the person in red': 1,
#  "what is on the girl's head": 2,
#  'where is the switch in the video': 1,
#  'what is the car doing': 1,
#  'is the boy sitting or kneeling in the video': 1,
#  'what is the grandmother doing in the video': 1,
#  'what color is the box on the left side of the man in white in the video': 1,
#  'is the person wearing sunglasses in the video male or female': 1,
#  'what color pants is the golden blonde person wearing in video': 1,
#  'is the basin in the video standing up or upside down': 1,
#  'where is the computer in the video': 15,
#  'what does the girl in video wear on her hand': 1,
#  'what is on the closet': 6,
#  'is the person in the video sitting or standing while eating': 2,
#  'is the person wearing red headscarf standing or sitting in the video': 1,
#  'is the person sitting or kneeling in the video': 1,
#  "what color is the person's hair in the video": 7,
#  'is the toilet paper in video upside down or standing': 1,
#  'what is on the stand': 2,
#  'where is the red color bottle': 1,
#  'where is the little parrot in the video at the beginning': 1,
#  'what is the shape of the starfish in the video': 1,
#  'where is the magazine thrown in the video': 1,
#  'what is the color of the clothes does the man brushing the basin wear': 1,
#  'what is the weather in the game': 1,
#  'what is the scene in the video': 1,
#  'where is the switch of the lamp in the video': 1,
#  'is the person drinking water in the video standing or lying': 1,
#  'what is the man in red doing in the video': 1,
#  'what is the man in grey pants doing': 1,
#  'what is on the window': 1,
#  'where is the person flying in the cartoon': 1,
#  'which hand of the woman with the bag in video holds the bag': 1,
#  'what color top does the woman wear in the video': 3,
#  'what color is the shoelace in the video': 1,
#  'what color is the clothes worn by the people in the barbecue': 1,
#  "what is the color of the person's clothes in video": 106,
#  'what is the color of clothes of the woman wearing glasses in the video': 1,
#  'what is between two sofas in the video': 1,
#  'is the guy in the plaid shirt sitting or standing in the video': 1,
#  'what is the color of the t-shirt the person is wearing': 1,
#  'what is the box in the video': 1,
#  'what is in front of the person with long hair in the video': 1,
#  'which hand does the person in the video use to get the tool': 1,
#  'what is the people circling in the middle around': 1,
#  "what is the color of women's clothes in the video": 2,
#  'what is the person in the video holding in their hands': 1,
#  'what is the color of the plastic bucket in the video': 2,
#  'what does the person with glasses in video have on his chest': 1,
#  'how many hands are in the video': 1,
#  'is the lens in the video moving upward or downward at last': 1,
#  'what color is the pen in video': 1,
#  'what tool is the person in the video wrapped in meat powder': 1,
#  'what is the background in video': 2,
#  'what is the purple light of the video reflected on': 1,
#  'where are the clothes hanging in the video': 1,
#  'where is the cartoon character in the video': 11,
#  'is the old man in video long hair or short hair': 1,
#  'what color is the tie of the man': 1,
#  'is the person wearing the hood in the video sitting or standing': 1,
#  'where is the car': 3,
#  'what is on the wall behind the girl in video': 1,
#  'is the person in the video walking or seated': 1,
#  'what color pants does the person with red plaid wear': 1,
#  'is the text in the video written in english or chinese': 4,
#  'where is the red 5': 1,
#  'is the bald in the video standing or sitting': 1,
#  'what is the last action of the person in the video': 1,
#  'what is the dog doing in the video': 2,
#  'is the person wearing pink in the video standing or sitting': 1,
#  'what is the plane doing in the video': 2,
#  'where is the person carrying a bag in the video': 1,
#  'what is the person holding a microphone in the video doing': 1,
#  'what color is the building in the video': 1,
#  'is the person wearing a white hat holding something a left hand or a right hand': 1,
#  'what is on the seaside in the video': 1,
#  'is the person in the video sitting or standing at rest': 1,
#  'where is the stool in the video': 1,
#  'what color is the dress of the woman dancing in video': 1,
#  'is the person in green in the video standing or sitting': 1,
#  'what is the color of the vacuum cleaner in video': 1,
#  'what do the women in video wear on their ears': 1,
#  'what is the color of the plate in the video': 1,
#  'what color of the clothes does the squidward tentacles wear in the video': 1,
#  "what is the color of the man's hat in the video": 1,
#  'what is on the tv stand': 1,
#  'what is the person is hand in the video': 1,
#  'what shoes does the person in video wear': 1,
#  'where is the tv in the video': 3,
#  'is the person wearing the earrings standing or sitting': 1,
#  'what does the man in the video eat': 1,
#  'is the person in the video sitting or standing while drinking': 1,
#  'what style of clothes does the person in video wear': 1,
#  'is the person in brown and white standing or sitting': 1,
#  'what is the man wearing on the head in the second photo in the video': 1,
#  'where did the person put the book in the video': 1,
#  'what is the in the scene': 1,
#  'where is the person in the hat': 1,
#  'is the person against the wall sitting or standing in the video': 1,
#  'is the word in the video english or chinese': 1,
#  'where is the floor lamp in the video': 4,
#  'where is switch': 2,
#  "what color are the man's clothes in the video": 1,
#  'what is hanging on the door behind the woman in the video': 1,
#  'which runway person in the video runs first': 1,
#  'what is the color of the clothes on the chair': 1,
#  'what is the person in the game holding': 1,
#  'what musical instruments is in the video': 1,
#  'what is the color of the trousers does the person wear while standing in video': 1,
#  'what is in the box': 2,
#  'what color is the phone in the video': 2,
#  "what is on the woman's ear": 2,
#  'what color is the plate of bread in the video': 1,
#  'what does the woman in video wear on her head': 1,
#  'where was the third photo taken in the video': 1,
#  'where is the person with a hat in the video': 1,
#  'what is the color of the soap in the video': 1,
#  'where is the child in green in video': 1,
#  'what does the man in video wear on his hand': 1,
#  'is the person wearing black clothes in the video standing or sitting': 2,
#  'what is the facial expression of the person in the first photo in the video': 1,
#  'does the person has long hair or short hair in the video': 1,
#  'what color socks does the girl in green skirts wear': 1,
#  'is the person in the video sitting or squatting': 2,
#  'what color is the object in video': 1,
#  'what color are the pants of the person with hair braiding in the video': 1,
#  'is the person wearing the purple tie standing or sitting': 1,
#  'what is the color of the hamster': 1,
#  'what is the hair color of people in video': 1,
#  'is there a woman wearing a hat in video': 1,
#  'is the person in the rose red dress standing or sitting': 1,
#  'where is the table lamp': 3,
#  'what is on the simple table in the video': 1,
#  'is the computer turned on or off': 1,
#  'what is the man in video doing': 4,
#  'where is the can in the video': 1,
#  'is the person in white sitting or standing in the video': 1,
#  'what color are the english letters in the left corner in the video': 1,
#  'what is next to the iron gauze in the video': 1,
#  'what is in the person is hand on the stage in the video': 1,
#  'is the man just sitting or kneeling at the beginning of the video': 1,
#  'what color is the hat of the man': 1,
#  'what is the clothes color of the person holding the cup': 1,
#  'is the woman in the video sitting or standing': 37,
#  'where is the closet in the video': 1,
#  'what color is the apron worn by the person in the video': 1,
#  'is the city gate in the video opening or closed': 1,
#  'what does the woman wear on her face in video': 2,
#  'what does the person hold in hands in the video': 3,
#  'what is on the ground in front of the cabinet': 1,
#  'is the man wearing green clothes standing or sitting in the video': 1,
#  'what color of the clothes does the cartoon child wear in the video': 1,
#  'what is the yacht doing': 1,
#  'where is the person fighting in the video': 1,
#  'are the eyes of the alpaca in video open or closed': 1,
#  'is the person in red sitting or standing': 1,
#  'what is the sport equipment next to the man': 1,
#  'what is in the cup in video': 1,
#  'what is in the neck of the person in the video': 1,
#  'what is the color of the clothes of the cartoon character in video': 1,
#  'is the woman with bag in her hand standing or sitting in video': 1,
#  'what color is the dresser in the video': 1,
#  'what color is the background of the picture in video': 1,
#  'what does the woman holding the broom in the video wear': 1,
#  'what color is the door': 4,
#  'is the glass bowl on or upside down': 1,
#  'is the boy standing or sitting in video': 2,
#  'what is on the table in front of the woman': 1,
#  "what is on policeman's head in video": 1,
#  'how many lines of bold english are there in the video': 1,
#  'is the hair of the man in the video straight or curly': 1,
#  'what is placed on the table in the video': 1,
#  'is the person sitting in the video or standing': 1,
#  'where did the person in the video get the milk': 1,
#  'how many kinds of food are there in the video': 1,
#  'what are on the bed': 1,
#  'where did the man in the video take the pillow': 1,
#  'what is on the shelf': 6,
#  'is the man wearing orange dress standing or sitting': 1,
#  'what color is the clothes of the man with red hair': 1,
#  "what is the color of the man in blue's hair": 1,
#  'what color clothes is the person with dirty braids wearing in the video': 1,
#  'is the toy standing or sitting in the video': 1,
#  'where is the second person in the video': 1,
#  'where is the watermelon in the video': 1,
#  'what is on the left side of the window': 1,
#  'is the host in the video standing or sitting': 2,
#  'is the game character standing or sitting in the video': 1,
#  'what color of the pants does the person wear in the video': 23,
#  'what is on the person is face who wears white clothes in the video': 1,
#  'what is on the toy car in the video': 1,
#  'what color is the dog in the video': 3,
#  'is the person in video in the living room or the bathroom': 1,
#  'where are the bottles in the video': 1,
#  'what is in the refrigerator': 3,
#  'what color is the cabinet': 8,
#  'where is the toy': 1,
#  'what is the first person in the video doing': 4,
#  'what are the youths in the video doing': 1,
#  'what color is the mat in the video': 1,
#  'is the person in red sitting or standing in the video': 3,
#  'is the adult sitting or standing while moving stuff in the video': 1,
#  'where is the motorbike parking in the video': 1,
#  'how many faces did the people in the video complete': 1,
#  'what is the color of the baby carriage in the video': 2,
#  'is the bareheaded person sitting or standing in the video': 1,
#  'which hand is the watch worn by the person in the video': 1,
#  'is the person wearing pink clothes in the video long hair or short hair': 1,
#  "where is the thing that's supposed to be placed": 1,
#  'what is the old lady doing in video': 1,
#  'is the person who plays the guitar in the video standing or sitting': 1,
#  'what does the person in the white coat wear around his neck in video': 1,
#  'is the kitten in the basket standing or lying down': 1,
#  'is the person with a pen in the video standing or sitting': 1,
#  'what color is the swimming pool in video': 1,
#  'is the man in the cowboy hat sitting or standing in the video': 1,
#  'what is the color of pants of the child in green in video': 1,
#  'what is the man sitting doing': 1,
#  'what color of the clothes does the person in the left side wear in the video': 1,
#  'what is the machine doing': 1,
#  'what is the person standing in the video doing': 2,
#  'what is the person doing at the beginning of the video': 2,
#  'what color of the hat does the person wear in the video': 1,
#  'what does the man have in the video': 1,
#  'what kind of the jacket does the person wear in the video': 2,
#  'what is the gender of the person wearing glasses in the video': 1,
#  'what is the color of the sheets in the video': 3,
#  'what color of clothes is the person wearing in the video': 1,
#  'what is the woman in the video doing': 88,
#  "what is the color of thr woman's glasses": 1,
#  'what is the game in the video called': 1,
#  'what is the person in the video taking': 1,
#  'is the girl standing or sitting in video': 7,
#  'where is man in video': 2,
#  'where is woman at the beginning of video': 1,
#  'is the person holding knife with right hand or left hand in the video': 1,
#  'what is the character doing in the video': 1,
#  'what is the man doing': 106,
#  'is the person sitting in the video long hair or short hair': 1,
#  'what firmed the things showed in the screen': 1,
#  'what color is the wall in video': 1,
#  'is the woman wearing glasses with the left hand or right hand': 1,
#  'where is the game character walking in': 1,
#  'where is the towel in the video': 2,
#  'what is the shape of the green figure in the video': 1,
#  'where is the person who appeared at the beginning of the video': 1,
#  "what is the color of the child's hat in the video": 1,
#  'what is the athlete doing in the video': 2,
#  'who is the person in the video': 1,
#  'is the person wearing plaid shirts in the video sitting or standing': 1,
#  'what color is the brand': 1,
#  'what is the person who wears the hat in the video doing': 1,
#  'what is the animal is at last in the video': 1,
#  'where does the boy in the video take books': 1,
#  'is the man playing the guitar standing or sitting in video': 1,
#  'what is the color of the clothes worn by the first person in the video': 1,
#  'is the person sitting or lying on his stomach in the beginning of the video': 1,
#  'is the water flowing or still in the video': 1,
#  "what color is the standing person's clothes in the video": 1,
#  'is the font moving in the video horizontal or vertical': 1,
#  'where is the quilt in the video': 1,
#  'what color is the font appear in the video': 1,
#  'is the man in green standing or sitting in the video': 1,
#  'what color clothes does the white-haired old person wear': 1,
#  'what is the woman with short hair doing': 2,
#  'which room did the person wearing the vest in the video come from': 1,
#  'where is the child in green in the video': 1,
#  'what color is the table tennis table in the video': 1,
#  'what is on the cabinet behind the man': 1,
#  'is the puppy in the video standing or crawling': 1,
#  'what color vest does the woman wearing vest in the video wear': 1,
#  'what is the gender of the person in the video': 53,
#  'what is the person on the ground doing': 1,
#  'what is on the countryard': 1,
#  'what is on the face of the person in the video': 33,
#  'where is the recycle bin in the video': 1,
#  'what are the two sides of the stairs in the video': 1,
#  'what is the material of the toy in the video': 1,
#  'what is the green wood doing': 1,
#  'is the cartoon character sitting or standing in the video': 4,
#  'what is the person in the plaid shirt doing in video': 1,
#  'is the person wearing black pants in the video standing or sitting': 1,
#  'is the person covered with a blanket sitting or standing in the video': 1,
#  'where are the shoes in the video': 5,
#  'where does the person put his clothes': 1,
#  "what is wearing on the woman's face in the video": 1,
#  'what is the color of the jacket the man wears in the video': 1,
#  'how many skulls are in the video': 1,
#  'what color are the pants of the person in the video': 2,
#  'what is the bucket doing in the cartoon video': 1,
#  'is the person applauding in the video sitting or standing': 2,
#  'where is the last person in the video': 1,
#  'what is the woman riding in the video': 1,
#  'is the girl standing or sitting in the video': 8,
#  'where does the person in the video put the case': 1,
#  'what is on the left of the door': 2,
#  'what is on the stone': 1,
#  'is the person holding a microphone in the video sitting or standing': 1,
#  'what is the design of the sticker in the video': 1,
#  'where is the cartoon child in the video': 1,
#  "what is the color of girl's coat in video": 1,
#  'where are the books in the video': 4,
#  'what does the person wear on his head': 3,
#  'what color is the clothes of the man with glasses': 1,
#  'what is the person with long hair in the video doing': 1,
#  'what is the man wearing a hat doing': 1,
#  'where is the beverage': 2,
#  'what is the english initials in video': 1,
#  'what is the robot doing in the video': 1,
#  'which team got the ball in the video': 1,
#  'what is the color of the helmet': 1,
#  'what is the person who is standing doing in the video': 1,
#  'which hand does the person with white hair use in the video to hold the hairdryer': 1,
#  'what is the person in red doing in the video': 2,
#  'is the person aimed at the video sitting or standing': 1,
#  'where did the person with glasses take beverage from in the video': 1,
#  'is the person in the video sitting or standing when sneezing': 1,
#  'what color is the toy in the video': 1,
#  'what is on the commodity shelf': 2,
#  'is the person lying or sitting in the video': 2,
#  'what is the color of the picture frame in the video': 1,
#  'what is the color of the sofa': 5,
#  'is the last person to go out in the video male or female': 1,
#  'what color is the helicopter in the video': 1,
#  "what color is the teacher's clothes": 1,
#  'what is on the selfie stick': 1,
#  'is the person in white pants sitting or standing': 1,
#  'is the model in the white clothes standing or sitting': 1,
#  'where is the clothes': 13,
#  'where is the bottle in the video': 7,
#  'what color of the clothes does the person with a hat wear in the video': 1,
#  'what is in the hands of the boy in white': 1,
#  'which country is the game in the video held in': 1,
#  'what does the person put on the table in the video': 1,
#  'what color do men wear in the video': 1,
#  'is the athlete standing or sitting in the video': 1,
#  'what does the man with shield do': 1,
#  'where is poker': 1,
#  'what did the people in the video do after knocking on the wall': 1,
#  'what is the color of the english font in video': 1,
#  'what is the person in white doing in video': 2,
#  'is the person in short black sleeves sitting or standing': 1,
#  'where is the camera': 1,
#  'is the woman wearing sunglasses in the video standing or sitting': 1,
#  'what is on the rugby spectators stand': 1,
#  'is the person sitting or standing in the vide': 1,
#  'which type is the car in the video': 1,
#  'what is the person wearing black clothes doing in the video': 4,
#  'what is the person wearing blue shorts doing in the video': 1,
#  'is the person wrestling in the video is a man or a woman': 1,
#  'how many blankets is the person in the video holding': 1,
#  'what is on the face of the red-haired person in the video': 1,
#  'what is the person in brown and white doing': 1,
#  'what is on the head of the person wearing police suit': 1,
#  "what is the color of the person's shoes in the video": 2,
#  'is the person wearing white clothes in the video standing or sitting': 2,
#  'what time is it in the video': 5,
#  'what is the man at the door doing': 1,
#  'what is the color of the coat the man wears': 1,
#  'what is in the hands of the person wearing rompers': 1,
#  "what color is the woman'hair in video": 4,
#  'how many brands are there': 1,
#  'what color socks does the goalkeeper wear': 1,
#  'where is the rice cooker': 1,
#  'what is the color of the pillow the man wears in the video': 1,
#  'what is the shape of the gold coin in the video': 1,
#  'where is the leopard': 1,
#  'what is in front of the person in gray pants': 1,
#  'what color is the bottle in the video': 1,
#  'where is the person in the video lying': 1,
#  'what is the girl doing at the end of the video': 1,
#  'what is the scene in video': 1,
#  'does the man in the video have hair or no hair': 1,
#  'what color is the cutting board in the video': 1,
#  'what color pants does the person in the video wear': 7,
#  'is the headlight in the video turned on or off': 1,
#  'what color clothes does the child answering the question': 1,
#  'is the model standing or sitting in the video': 1,
#  'what is the color of the cupboard': 1,
#  'what is the woman wearing on her ears': 1,
#  'what color is the handwritten text in the video': 1,
#  'what is around the game characters in the video': 1,
#  'what is the man in black in the video doing': 1,
#  'where is the game character in the video': 2,
#  'what does the woman wear around her neck in the video': 2,
#  'what color is the sword': 1,
#  'what is the person with white hair in the video doing': 1,
#  'what color is the hat that the computer player is wearing in the video': 1,
#  'what is the color of spongebob': 1,
#  'what are the two people in front of the microphone doing': 1,
#  'what does the man in the video hold': 6,
#  'what is in front of the car': 1,
#  'what pattern does the toy have': 1,
#  "what is in the person's hand in video": 1,
#  "what is in the person's hand in the video": 9,
#  'what color is the cloud in the video': 1,
#  'where is the person wearing orange pants in the video': 1,
#  'what brand is the car in the video': 1,
#  'what is the model in the video doing': 1,
#  'how many objects are there': 1,
#  'what does the person have on his left hand': 2,
#  'what does the person in video sleep on': 1,
#  'what is on the market table': 1,
#  'what color is the scene in the video': 1,
#  'is the person in the video sitting or standing after taking medicine': 1,
#  'is the woman in the video standing or sitting at the end': 1,
#  'where is the water bottle in the video': 3,
#  'where is the fan': 1,
#  'at what place': 1,
#  'what color jacket is the game character wearing in the video': 1,
#  'what is person doing in video': 1,
#  'where are the two people in video': 3,
#  'what can you see in video': 26,
#  'what is the color of the clothes of the person in the video': 74,
#  'what color clothes is the man wearing black shorts wearing in the video': 1,
#  'what is on the floor': 17,
#  'is there chinese or english on the computer screen': 1,
#  'what color is the letter of the web site in the video': 1,
#  'what color of clothes does the man on the stage wear in the video': 1,
#  'what is the person wearing a vest in the video doing': 1,
#  'what is in front of the bed': 1,
#  'what is the in the sea in the video': 1,
#  'what is the person with hair braiding in the video doing': 1,
#  'where is the role in the video': 1,
#  'what is introduced in the video': 1,
#  'what is the shape of the decorative ribbon in video': 1,
#  'where does the person in the video sit on': 1,
#  'what is on the chopping board': 2,
#  'are the letters in the video english or chinese': 1,
#  'is the man with glasses in the video sitting or lying': 1,
#  'what tool was the tool used in the video': 1,
#  "what is in the man in purple's hand": 1,
#  'what does the woman in video carry': 1,
#  'what color is the clothes in the video': 1,
#  'what is in the tvbench': 1,
#  'what is the color of the clothes of the man in the video': 9,
#  'is the woman in red in the video standing or sitting': 1,
#  'what is the person doing in the game': 1,
#  'what are the animals in video': 2,
#  'what color clothes does the person on the left wear in the video': 1,
#  'is the person in purple long hair or short hair': 1,
#  'what is the car doing in the video': 1,
#  'what is the white fish doing': 1,
#  'is the person in the video lying on his stomach or sitting': 1,
#  'what color of clothes does the man in the video wear': 28,
#  'what is at the back of the closet': 1,
#  'is the tv on or off': 3,
#  'how many singing person in the video': 1,
#  'is the person with glasses in the video standing or sitting': 2,
#  'is the person wearing in purple standing or sitting': 1,
#  'is the person in the knitted hat standing or sitting in the video': 1,
#  'is the woman standing or sitting in video': 15,
#  'what did the female warrior in video ride on': 1,
#  'which hand of the person in the video has the watch': 1,
#  'what is covered in the man in the video': 1,
#  "what is in the man's hands at the door": 1,
#  'what is the person who is eating in the video doing': 1,
#  'what is the person wearing yellow clothes in the video doing': 1,
#  'is the boxing man sitting or standing in the video': 1,
#  'is the person in black sitting or standing in the video': 3,
#  'where is the jacket on the person in the video from': 1,
#  'what is on the floor in the video': 3,
#  'is person in video standing or sitting': 1,
#  'what is the drone hanging in the video': 1,
#  'what is the color of the refrigerator in video': 1,
#  'what is the exercising projection in the second video': 1,
#  'where is the bolster': 2,
#  'what is on the column': 1,
#  'where is the muppet in the video': 1,
#  'what is the color of the socks the man wears': 1,
#  'what is in front of the woman': 1,
#  'is the hand in the video the left hand or right hand': 1,
#  'is the gray-haired person long hair or short hair': 1,
#  'what is the color of the pants of the person in the video': 20,
#  'does the crystal skull have head or not': 1,
#  'is headlight in video open or closed': 1,
#  'what is under the electronics in video': 1,
#  'what is the child in the video doing': 7,
#  'how many did the person in the video make': 1,
#  "what color is the woman's hair": 1,
#  'what color is the leading car in the video': 1,
#  'what are the small animals in the video': 1,
#  'what was in the video in the end': 1,
#  'is the person wearing a white shirt sitting or standing in the video': 1,
#  'is the person wearing black clothes sitting or standing': 1,
#  'what is the champion doing in the video': 1,
#  'what is on the wall in the video': 26,
#  'what is the man in black doing': 1,
#  'where is the english letters in the video': 1,
#  'is the woman wear earring': 1,
#  'is the person in blue clothes sitting or standing': 1,
#  'is the girl with long hair sitting or standing': 1,
#  'what is the text background color in the video': 1,
#  'where do the clothes in video hang': 1,
#  'what is the name of the film in the video': 1,
#  'what is the person in red doing': 2,
#  'what is the color of the clothes of the speaking woman in the video': 1,
#  'what is on the sink': 2,
#  'where is the tree in video': 1,
#  'what is the person wearing on his head in the video': 4,
#  'what is the color of the light in the video': 2,
#  'what is the person doing in the second video': 1,
#  'what is the person in white doing': 4,
#  'is the wood in the video placed horizontally or vertically in front of the tire': 1,
#  'what color is the clothes worn by the person in the video': 10,
#  'where does the man in the video enter': 1,
#  'is the person wearing khaki clothes in the video standing or squatting': 1,
#  'what is hanging on the roof': 1,
#  'where is the scarf': 2,
#  'is the person wearing hat standing or stitting in the video': 1,
#  'what is the man in gray holding in his hand in the video': 1,
#  'what color top does the person wearing hat in the video wear': 1,
#  'what is the color of the walls in the video': 1,
#  'what color clothes does the person wearing hat wear in the video': 1,
#  'is the man standing or sitting in the video': 28,
#  'what did the person in video take out from the refrigerator': 1,
#  'what color is the dress of the person who pushes the snowmobile in the video': 1,
#  'what color is the leaf in the video': 3,
#  'what is in front of the wind': 1,
#  'what is the color of the trousers the man wears': 8,
#  'what is the box in video on': 1,
#  "what is in the man's hand in the video": 2,
#  'where is the person in black pants in the video': 1,
#  'what is on the door': 4,
#  'where is the guitar in the video': 1,
#  'what does the man have on his shoulder': 1,
#  'what color shirt does the host wear in the video': 1,
#  'is the person in colorful trousers sitting or standing in the video': 1,
#  'what is on the bed after the person throwing clothes': 1,
#  'where does the woman in the video sit': 1,
#  "what is in the boy's hand in the video": 1,
#  'what did the woman in the video pick up from the couch': 1,
#  'what is the monster doing in the video': 2,
#  'what is the animal except cat in the video': 1,
#  'what is in the hands of the person in the last scene': 1,
#  'where are the plates': 1,
#  'is the text in the video screen horizontal or vertical': 1,
#  'what color clothes does man wear in the video': 1,
#  'what color is the headgear in the video': 1,
#  'is the man in the video is standing or sitting': 1,
#  'where is the horse in the video': 2,
#  'what is on the commode': 1,
#  'what is the color of the clothes does the girl with long hair wear': 1,
#  'is the person wearing a hat standing or sitting in the video': 1,
#  'what animals appear in the first picture of video': 1,
#  'is the woman in white standing or sitting in the video': 1,
#  'what is the shape of the dialog box in the video': 1,
#  'what is on the left hand side of the man in the video': 1,
#  'where is the person in blue in vodeo': 1,
#  'where is the person in white at the beginning of the video': 1,
#  'what color is the woman wearing in the video': 1,
#  'what does the man wear on head in the video': 7,
#  'where is the woman in the video': 50,
#  'what does the man in the video wear on his face': 3,
#  'what is the person wearing the hat doing in the video': 3,
#  'is the person with glasses in video standing or sitting': 2,
#  'what is next to the stairs': 1,
#  "what is the color of the person's hat in the video": 1,
#  'what color is the rubber band in the video': 1,
#  'where is the man in black pants': 2,
#  'is the deer in the video sitting or squatting': 1,
#  'where is the text in the video': 1,
#  'what color is the ribbon on the hat in the video': 1,
#  'what is the color of the door in the video': 12,
#  'what color is the box in video': 1,
#  'is the woman standing or sitting': 8,
#  'what is the picture of the video': 1,
#  'what is the color of the wooden case in the video': 1,
#  'where is the person wearing a black hat': 1,
#  'how many people appeared in the video': 5,
#  'what is the color of the closet': 2,
#  'is there a number in the video': 1,
#  'where does the mop lean on': 1,
#  'what are the two people in the fence doing in the video': 1,
#  'is the child with a necklace sitting or standing': 1,
#  'is the person wearing hat sitting or standing': 2,
#  'is the person standing or sitting whiling drinking water in the video': 1,
#  'where is the man taking off clothes': 1,
#  'what does the girl in video wear on her head': 3,
#  'what is the player in the video holding in their hands': 1,
#  'what is the hand doing in the video': 2,
#  'what is wearing on the head of the person in black in the video': 1,
#  'where are the things in the video': 1,
#  'what does the man in green in the video do after finishing shooting': 1,
#  'where is the room in the video': 2,
#  'what is the shape of dialog box in video': 1,
#  'what is the person sitting on in the video': 1,
#  'what material is the curtain in the video': 1,
#  'is the person raising his left hand or right hand': 1,
#  'where is the yoga mat in the video': 1,
#  'is the princess standing or sitting in the animation': 1,
#  'which hand does the person in the video use to wipe the mouth': 1,
#  "what is in the girl's arms": 1,
#  'how many lines of characters appeared in the video': 1,
#  'is the person standing or sitting while playing phone in the video': 1,
#  'what is the person in the video lock up': 1,
#  'what color shoes does the person in the video wear': 1,
#  'what is behind the chair': 3,
#  'where is the backpack in the video': 2,
#  'is the person in blue sitting or standing in the video': 1,
#  'what are the two people doing in the video': 1,
#  'what does the person in red wear on the head in the video': 1,
#  'is the font in english or chinese in the video': 1,
#  'where is the banana pattern in the video': 1,
#  'what is the color of the computer': 3,
#  'how many people are in video': 3,
#  'what is the snake doing in the video': 1,
#  "what color is the man's clothes in video": 1,
#  'how many hools are made': 1,
#  'what is the color of the subtitle in the first subtitle': 1,
#  'what is the color of the clothes of the white hair cartoon character': 1,
#  'what is the woman with glasses doing in video': 1,
#  'is the plane flying or stopping': 2,
#  'what color shoes does the person wear in the video': 4,
#  'where is the melon': 1,
#  'where does the man in the video put the book': 2,
#  'what color of sleeves of the clothes does the person wear in the video': 1,
#  'what is on the tv in the video': 1,
#  'what is the person doing on the stage': 1,
#  'what is in front of the person with glasses': 1,
#  'what color is the cupboard door next to the refrigerator': 1,
#  'what is the color of the bag on the back of the person in the video': 1,
#  'which hand does the person in the video hold the object': 1,
#  'what is under the kettle in the video': 1,
#  'what color do women wear in the video': 1,
#  'where is the black subtitle in the video': 1,
#  'what color clothes does the third person wear in the video': 1,
#  'what is woman doing at the beginning of video': 1,
#  'what color is the plate in the video': 2,
#  'what is the cursor doing in video': 1,
#  'what do people in video wear on their faces': 1,
#  'what color did the person in video dye the hair': 1,
#  'what is the yellow-haired man in the video doing': 1,
#  "what color is the girl'hair in video": 2,
#  'is the woman with glasses sitting or standing in the video': 1,
#  'is the man sitting on the bed or chair in the video': 1,
#  'what is james in the video doing': 1,
#  'what is the color of the coat the man wears in the video': 3,
#  'what color clothes do people wear in the video': 1,
#  'what did the person in video take': 1,
#  'what animal is there in the video': 1,
#  'is the person wrapped in a blanket sitting or standing': 1,
#  'where is the person making a phone call in the video': 1,
#  'what is the living room': 1,
#  'what is in the plate in the video': 1,
#  'was the man lying or sitting in the end': 1,
#  'what is on the right of the road': 1,
#  'where is the glasses in the video': 1,
#  'what is on the washbasin in the video': 1,
#  'is the yellow wooden man standing or sitting in video': 1,
#  'what is the person wearing a yellow clothes in the video doing': 1,
#  'what is the score of both sides in the video': 1,
#  'how many people in the video are singing': 1,
#  'what is on the bedside': 1,
#  'is the performing boy standing or sitting in the video': 1,
#  "what is the color of the person's skirt in the video": 1,
#  'why does the kid tie hair up in the video waving her hands': 1,
#  'what is surrounding the boxing stage': 1,
#  'where is the bike in the video': 1,
#  'is the is the person in the video dressed in long sleeve or short sleeve': 1,
#  'what is the color of the pants of the person in video': 1,
#  'what is in the cabinet': 9,
#  'what color is the background wall in the video': 3,
#  'what is in front of the cabinet': 2,
#  'what is in the plate': 1,
#  'is the person on the left in the video standing or sitting': 1,
#  'how many pictures are there in the video': 1,
#  'what is in front of the child in the video': 2,
#  'what is the color of the sauce': 1,
#  'where is the person in the plaid shirt in video': 1,
#  'where did the person in the video put the folded things': 1,
#  'what does the boy in the video wear on his face': 1,
#  'is it left hand or right hand in video': 1,
#  'how many cars are there in the video': 2,
#  'does the pen have cap in the video': 1,
#  'what is the black-haired person doing in the video': 1,
#  'what color is the wall space in video': 2,
#  'does the woman in video have straight hair or curly hair': 2,
#  'what are the person wearing in the video': 1,
#  'what is the person in white clothes doing': 3,
#  'where is the singing person in the video': 1,
#  'what appears after the text in the video': 1,
#  'what is the color of the pants does the boy wear': 1,
#  'is the man in red sitting or standing in the video': 1,
#  'how many puppies are there in the video': 1,
#  'what is on the corridor': 1,
#  'what is shown on the screen in the video': 2,
#  'what does the girl wear on head in the video': 3,
#  'what are on the face of the person wearing the hat in the video': 1,
#  'what does the person take off after coming in': 1,
#  'what is the color of the box in the video': 1,
#  'what color top does the person in the water wear in video': 1,
#  'what does the person in the video pull out from his pocket': 1,
#  'is the machine in the video placed horizontally or vertically': 1,
#  'what is the color of the tomato in the video': 1,
#  'what color of the clothes does the person wear at the beginning in the video': 1,
#  'where is the person in blue in video': 1,
#  'is the person in the video sitting or standing while writing': 1,
#  'what does the person take off in the video': 1,
#  'where is the girl singing at': 1,
#  'is the person sitting or standing while eating in the video': 2,
#  'what color does the men wear in the video': 1,
#  'what image is placed in the video': 1,
#  'what is on the sofa in the video': 2,
#  'what is in front of the closet': 1,
#  'what color is english in the video': 2,
#  'what is on the staircase': 1,
#  'what is the color of the window in the video': 1,
#  'is the man in white standing or sitting': 1,
#  'what is the color of the pattern behind the woman': 1,
#  'is the person in the video sitting ot standing': 1,
#  'is the person with glasses sitting or standing in the video': 1,
#  'where is the child in video': 1,
#  'what color shirt does the person wear in the video': 1,
#  'what is on the right side of the food rack': 1,
#  'what does the man in the video wear on his neck': 1,
#  'is the person in video sitting or standing before drinking': 1,
#  'what did the person in the video take at the beginning': 1,
#  'what is on the right of the wall': 1,
#  'is the person in the video standing or lying at last': 1,
#  'how is the rank of the person in the middle in the video': 1,
#  'what is the color of the hat the person wearing in the video': 1,
#  'what is behind the little boy in the video': 1,
#  'what color is the tank in the video': 1,
#  'what color is the clock': 1,
#  'what is in front of the locomotive': 1,
#  'how many tires are there in the video': 1,
#  'is the animal standing or sitting in the video': 1,
#  'where is the monster in the video': 2,
#  'how many objects are there in video': 1,
#  'what is the color of the clothes of the boy in the video': 1,
#  'where is the hamster': 1,
#  'what is the person in pink doing in video': 1,
#  'what is the person holding the right hand in the video': 1,
#  'what is the color of the person wearing the white hat': 1,
#  'in the community is the person standing or sitting in the video': 1,
#  'where is the newsstand in video': 1,
#  'what is the person doing at last': 1,
#  'what is the squidward tentacles doing in the video': 1,
#  'what is the gender of the person standing up in the video': 1,
#  'is the sealed tank in the video open or closed': 1,
#  'what is the person eating': 1,
#  'where is the box': 2,
#  'what electronics are shown in video': 1,
#  'is the police officer in the video standing or sitting': 1,
#  'what is on the countertop in the video': 1,
#  'what color is the barrier in the video': 1,
#  'what is the machine puppet doing in the video': 1,
#  'what is behind the car': 1,
#  'does the person in the last photo having curly or straight hair': 1,
#  'what is on the face of the person wearing a red headscarf': 1,
#  'what is the color of the person wearing a hat in the video': 1,
#  'where is the hat': 1,
#  'where are the clothes in the video': 1,
#  'what color is the dress worn by the princess in the video': 1,
#  'where is the plant': 1,
#  'is the person wearing white clothes in the video sitting or standing': 3,
#  'what is on the sofa': 11,
#  'what do the person in the video have in his hand': 1,
#  'what is the color of the english alphabet in the video': 1,
#  'is the grandmother standing or sitting in the video': 1,
#  'which hand of the person in the video holds the fruit': 1,
#  'what is in the hands before the person in the video puts the blanket': 1,
#  'what is on the window sill': 2,
#  'what is the color of the ball in the video': 1,
#  'where is the camera in the video': 1,
#  'where did the person put the clothes he took off': 1,
#  'what color is the clothes of the boy in video': 1,
#  'what is the boy doing in the video': 5,
#  'what is the old man doing in video': 1,
#  'is the old man in the video sitting or standing': 1,
#  'what is the color of the hammer in video': 1,
#  'what is the second brand': 1,
#  'what are the men sitting on the bed': 1,
#  'where is the chair in the video': 7,
#  'where does the person sit in the video': 2,
#  'where is the person sitting in the video': 8,
#  'what is the person in video holding in his hands': 4,
#  'where is the bowl before opening the carton': 1,
#  'what color clothes does the person wear in the video': 121,
#  'was the man standing or sitting in the end': 2,
#  'where is the orange': 2,
#  'is the computer on or off': 1,
#  'what color is the grass': 1,
#  "what is in the man's pocket in video": 1,
#  'is the person in suit in the video standing or sitting': 1,
#  'what does the police officer in the video hold in his right hand': 1,
#  'what is on the face of the man in the video': 8,
#  'where is the computer in video': 3,
#  'where does the man in the video put the sheet': 1,
#  'what is on the left side of the road': 1,
#  'where is the mural': 9,
#  'is the person in light-purple shirt sitting or standing in the video': 1,
#  'where is the fireworks in the video': 1,
#  'which hand did the person use to hold things': 1,
#  'what is worn on the bald face in the video': 1,
#  'what is man doing in cartoon': 1,
#  'what color of the clothes does the boy wear in the video': 3,
#  'what color car does the person in video drive': 1,
#  'is the girl standing or sitting in the latter half of the video': 1,
#  'what is the color of the wardrobe': 1,
#  'what color is the hair of the person in the video': 1,
#  'what does the sitting person in video have on their face': 1,
#  'what color of the dress does the person wear in the video': 4,
#  'what is mario in green doing in the video': 1,
#  'what color clothes does the front person in the video wear': 1,
#  'what are the masses holding in the video': 1,
#  'where did the woman in green and man lie in the video': 1,
#  'what is the person holding in the video': 4,
#  'what is the color of the hat of the person in the video': 3,
#  'what color top does the man holding a woman in white in the video wear': 1,
#  "what is on the woman's legs in the video": 1,
#  'what is the person wearing the hat doing': 1,
#  'where do the man and woman in the video sit': 1,
#  'what is on the black board': 1,
#  'is the monkey standing or sitting in the video': 1,
#  'what does the man have to do when entering the room': 1,
#  'where does the person in blue lean': 1,
#  'what is the color of the motorbike in the video': 1,
#  'where is the pet food container in the video': 1,
#  'what is on the ground in the video': 18,
#  'which hand does the person in the video use to take the kettle': 1,
#  'where do people in the video type': 1,
#  "what is the color of the woman's clothes in the video": 13,
#  'what color is the cat in the video': 2,
#  'is the animal that appears in the video a cat or a dog': 1,
#  'what is the color of the pillow in video': 1,
#  'what did you see after the arrow appeared in the phone in the video': 1,
#  'what is worn on the head of the person in the video': 1,
#  "what are on the wrestler's ears": 1,
#  'what is in the bed': 1,
#  'how many computer are in the video': 1,
#  'what does the woman in the video hold in her hand': 4,
#  'is the cartoon character in video a wolf or a horse': 1,
#  'is the person in the video wearing a glasses or not': 1,
#  'what color is the clothes worn by the little boy in the video': 1,
#  'what does the person in the video take': 1,
#  'what fruit is put behind the person in the video': 1,
#  "what is on the person's legs in the video": 1,
#  'what color clothes does the person without glasses wear': 1,
#  'what is in the bar': 1,
#  'does the person in the video sit or stand while using the vacuum cleaner': 1,
#  'is the person sitting or lying in the video': 8,
#  'what color clothes does the person opening the door wear in the video': 1,
#  'is it child or old man in video': 1,
#  'what is the second picture of video computer on': 1,
#  'where is the room in video': 1,
#  "what is in the person's hands in the video": 1,
#  'what does the person wearing orange pants wear on face in the video': 1,
#  'what is the woman in dress doing': 1,
#  'what is at the back of the car': 1,
#  'what is the adult doing at the beginning of the video': 1,
#  "what color is the dog's tooth in the video": 1,
#  'where is the boy in video': 2,
#  'what is she doing': 1,
#  'is the dish in the video hot or cold': 1,
#  'what is the person competing about': 1,
#  'is the person in the video sitting or standing while undressing': 1,
#  'what color is the pot in the video': 6,
#  'what color is the pattern in the bowl made of': 1,
#  'where is the person wearing hat in the video': 1,
#  'what is the color of the kerchief the man wears in the video': 1,
#  'what color is the headset worn by the woman in the video': 1,
#  'where is the desk in the video': 1,
#  'where is the television in the video': 2,
#  'how many doors of the closet in the video': 1,
#  'where did the video last appear': 1,
#  'how many famous paintings are shown in video': 1,
#  'what is the men doing in video': 2,
#  'what is the person in striped clothes doing': 1,
#  'is the man standing or sitting in video': 8,
#  "what is the color of the man's tie": 1,
#  "what is the color of the person's hair": 2,
#  'where are those two people': 1,
#  'what did the person in the video take': 1,
#  'where is the plate': 1,
#  'where is the person holding the microphone in the video': 1,
#  'is the car singer door or double door': 1,
#  'how many images are there in video': 1,
#  'where is the sitting person in the video': 1,
#  'what is the color of the floor in the video': 4,
#  'how many machines are there in the video': 1,
#  'what color coat is the man wearing in the video': 1,
#  'what is the color of the microphone in the video': 1,
#  'where is the goblet': 2,
#  'how many people in the cartoon': 1,
#  'is the man in video standing or lying down': 1,
#  'is the person in the white coat standing or sitting in the video': 1,
#  'what is the color of the top does the man in yellow pants wear': 1,
#  'what coat is the man wearing': 1,
#  'what is on the table which beneath the mirror': 1,
#  'where is the coat': 2,
#  "is the person's hair in the video long or short": 1,
#  'is the person in the video standing orsquatting': 1,
#  'what color is the clothes of the man running in video': 1,
#  'what color clothes is the person wearing blue shorts wearing in the video': 1,
#  'where is the low table in video': 1,
#  'what is the english letter doing': 1,
#  'where does the person lean in the video': 1,
#  'where is the refrigerator': 2,
#  'where is the photo frame in video': 1,
#  'where is the judgment in the video': 1,
#  'what is on the plate in the video': 1,
#  'what color is the clothes of the woman who smokes in the video': 1,
#  'is the person playing instrument wearing a watch': 1,
#  'is the person in the air or on land in the video': 1,
#  'where is the globe in the video': 2,
#  'where is the person holding the broom': 2,
#  'what color is the hat worn by people wearing purple clothes in the video': 1,
#  'what is the weapon shooting in the video': 1,
#  'what color pants does the last person wear': 1,
#  'what happened': 1,
#  ...}

# %%
sort_answer=sorted(frequency_answer.items(),key=lambda e:e[1],reverse=True)
sort_question=sorted(frequency_question.items(),key=lambda e:e[1],reverse=True)

# %%
frequency_answer
# Out:
# {'spinning web': 3,
#  'mesuring': 3,
#  'medicine bottle': 3,
#  'egg': 11,
#  'wooden frame': 1,
#  'ice chest': 1,
#  'taking photos with phone': 1,
#  'brown-black': 6,
#  'picking up water cup': 2,
#  'glass bowl': 1,
#  'throwing quilt': 3,
#  'poster': 20,
#  'branch': 3,
#  'opening gas tank': 1,
#  'man': 103,
#  'sitting on table': 1,
#  'orange red': 16,
#  'stooping': 1,
#  'making research': 2,
#  'playing plants vs zombies': 2,
#  'wiping hands': 5,
#  'crawling': 3,
#  'opening window': 8,
#  'brand': 3,
#  'fruits': 9,
#  'making up': 14,
#  'dark gray': 38,
#  'sound': 3,
#  'on computer desktop': 3,
#  'throwing pillow': 21,
#  'on leg': 3,
#  'lying down': 65,
#  'racing track': 3,
#  'walking up to table': 1,
#  'silver-gray': 3,
#  'sword': 9,
#  'drawing curtain': 6,
#  'in waiting area': 1,
#  'behind iron net': 3,
#  'virisdis': 1,
#  'oil drum': 1,
#  'pizza': 2,
#  'taking out bag': 1,
#  'tunnel': 1,
#  'handkerchief': 1,
#  'holding pen': 3,
#  'catching cat tail': 1,
#  'bottle-green': 1,
#  'taking lid': 1,
#  'making hamburger': 1,
#  'painting': 76,
#  'faint grey': 1,
#  'yelling': 1,
#  'lipstick': 1,
#  'dark blue': 194,
#  'purple and black': 1,
#  'table tennis bat': 4,
#  'taking up plates': 1,
#  'grazing': 1,
#  'animal': 14,
#  'tidying clothes': 8,
#  'taking computer': 8,
#  'shaking hands': 6,
#  'player': 5,
#  'watching fireworks': 3,
#  'books': 7,
#  'wipe': 2,
#  'potato': 6,
#  'putting away clothes': 6,
#  'breadmaker': 1,
#  'typing on computer': 1,
#  'preparing to fishing': 1,
#  'brown red': 4,
#  'crisper': 1,
#  'in midpoint': 2,
#  'touching nose': 1,
#  'under table': 3,
#  'taking spoon': 2,
#  'closet': 72,
#  'taking blankets': 2,
#  'applying face film': 1,
#  'cloakroom': 19,
#  'fixing lock': 1,
#  'controlling items': 1,
#  'buggy bag': 1,
#  'drying her hair': 2,
#  'monitor': 2,
#  'driving spacecraft': 3,
#  'cleaning toy': 1,
#  'watching cartoon': 3,
#  'taking towel to wipe cup': 1,
#  'flag': 1,
#  'broken': 3,
#  'greyish white': 1,
#  'large building': 1,
#  'raising picture frame': 1,
#  'glass bottle': 5,
#  'carrying box': 2,
#  'hovel': 4,
#  'cake': 3,
#  'seated': 3,
#  'light switch': 3,
#  'cooking dishes': 2,
#  'soap box': 3,
#  'test paper': 1,
#  'brushing his teeth': 1,
#  'playing musical instruments': 1,
#  'answering question': 3,
#  'going to cave': 1,
#  'in room': 124,
#  'introducing product': 6,
#  'reading messages': 5,
#  'leather handbag': 1,
#  'raising her hand': 1,
#  'rose red': 29,
#  'wiping chair': 2,
#  'lifting cup': 7,
#  'water bottle': 5,
#  'sailing': 4,
#  'cut things': 1,
#  'verdancy': 1,
#  'rag': 5,
#  'brown': 182,
#  'wiping hair': 3,
#  'wheel': 2,
#  'monster': 8,
#  'wiping articles': 1,
#  'pulling door': 1,
#  'getting box': 1,
#  'setting cup': 1,
#  'brick red': 1,
#  'plastic bags': 5,
#  'rolling up sleeves': 1,
#  'pointing to toy': 1,
#  'putting computer in bed': 1,
#  'veil': 3,
#  'picking up cloth': 1,
#  'fetching things': 26,
#  'outdoors': 19,
#  'spice bottle': 1,
#  'having beard': 6,
#  'portrait': 3,
#  'knapsack': 2,
#  'sweeping': 7,
#  'purple-blue': 1,
#  'tie': 23,
#  'telestudio': 4,
#  'arrange shelf': 1,
#  'walking into door': 2,
#  'light-green': 6,
#  'hair clasp': 3,
#  'in hall': 1,
#  'putting on hat': 1,
#  'picking up things': 3,
#  'holding knife': 1,
#  'hanging on rope': 3,
#  'taking oatmeal': 1,
#  'holding bag': 2,
#  'table tennis table': 1,
#  'excavator': 3,
#  'opening box': 11,
#  'sculpture': 1,
#  'shaking basin': 1,
#  'on water': 4,
#  'kneading face': 1,
#  'playing pull piece': 3,
#  'on balcony': 4,
#  'placing phone': 3,
#  'booting': 1,
#  'pure red': 2,
#  'placing box': 2,
#  'iron gate': 2,
#  'stepping in front of desk': 1,
#  'embracing each other': 1,
#  'riding roller coaster': 3,
#  'mopping mirror': 1,
#  'handrail': 6,
#  'midwinter phenomenon': 1,
#  'pink bear': 1,
#  'taking off vest': 1,
#  'on refrigerator': 12,
#  'finishing room': 1,
#  'next to man': 3,
#  'baby-blue': 5,
#  'seabed': 3,
#  'lifting quilt': 2,
#  'corner': 12,
#  'dining': 6,
#  'placing back cushion': 1,
#  'pulling towel': 1,
#  'accepting interview': 1,
#  'cups': 6,
#  'picking up goods': 1,
#  'listening to headset': 1,
#  'checking car': 3,
#  'incarnadine': 2,
#  'playing and fighting': 1,
#  'counting eggs': 1,
#  'touching camel': 1,
#  'showing car': 1,
#  'meatball': 3,
#  'playing tablet': 4,
#  'tube': 3,
#  'showing': 4,
#  'displaying clothes': 1,
#  'watching photo': 2,
#  'pot culture': 1,
#  'stretching out hand': 1,
#  'firing': 2,
#  'finding clothes': 2,
#  'stadium': 9,
#  "employee's card": 3,
#  'having meeting': 3,
#  'in cabin': 3,
#  'stickers': 2,
#  'on toilet tank': 3,
#  'getting washed': 1,
#  'observing item': 1,
#  'turning on computer': 10,
#  'square cloth': 1,
#  'coffee machine': 1,
#  'giving lecture': 5,
#  'instructions': 1,
#  'shooting arrow': 3,
#  'ancient blue': 1,
#  'autumn and winter': 3,
#  'european futures table': 3,
#  'teacup': 1,
#  'silvery white': 7,
#  'twenty three': 3,
#  'opening paper box': 1,
#  'yellowish brown': 1,
#  'sink': 1,
#  'smelling flowers': 1,
#  'having meal': 10,
#  'flashlight': 8,
#  'on sport court': 6,
#  "closing washing machine's door": 1,
#  'sitting down': 23,
#  'moving tv': 1,
#  'in living room': 189,
#  'canary yellow': 2,
#  'toothbrush': 6,
#  'land': 3,
#  'long jump': 4,
#  'go up stairs': 1,
#  'fireworks': 1,
#  'putting on socks': 3,
#  'taking picture': 3,
#  'washing pool': 2,
#  'referee': 2,
#  'mopping': 1,
#  'arranging table': 3,
#  'pouring into food': 1,
#  'mess tin': 2,
#  'cartoon painting': 3,
#  'placing plates': 4,
#  'taking stairs': 1,
#  'dark purple': 26,
#  'turning over handbags': 1,
#  'in concert hall': 1,
#  'mark cups': 1,
#  'taking stuffs': 1,
#  'football field': 16,
#  'singing': 120,
#  'lunch box': 4,
#  'guitarist bass': 1,
#  'tying shoe laces': 4,
#  'enjoying program': 1,
#  'looking at shoe size': 1,
#  'viewing car button': 1,
#  'switching off tv': 3,
#  'pink red': 5,
#  'curtain': 37,
#  'picking up cup': 3,
#  'roads': 1,
#  'pants': 7,
#  'on door': 21,
#  'wooden shelves': 1,
#  'wearing jacket': 1,
#  'by stand': 3,
#  'bookshelves': 1,
#  'lightyellow': 1,
#  'cartoon plane': 3,
#  'stirring ingredients': 1,
#  'taking paper': 2,
#  'plastic can': 1,
#  'looking at food': 1,
#  'pouring detergent': 1,
#  'washer': 4,
#  'water bucket': 2,
#  'greyish-green': 1,
#  'adjusting frame': 1,
#  'watching matches': 1,
#  'control panel': 1,
#  'having meals': 1,
#  'placing stuff': 4,
#  'french light': 1,
#  'getting food': 1,
#  'character suit': 1,
#  'lemon': 3,
#  'square': 16,
#  'stationary': 6,
#  'gmc': 3,
#  'turning off lamp': 1,
#  'modern fancywork': 4,
#  'three': 85,
#  'military uniform': 1,
#  'ferris wheel': 3,
#  'wiping table top': 1,
#  'looking at pictures': 3,
#  'teasing dog': 2,
#  'sliding door bolt': 2,
#  'raising his head': 1,
#  'pentagram': 3,
#  'golden': 24,
#  'taking mirror': 2,
#  'closing cabinet': 3,
#  'grayish yellow': 1,
#  'protective earphone': 3,
#  'pressing pillow': 1,
#  'on door knock': 3,
#  'closestools': 1,
#  'video': 3,
#  'fruit plate': 1,
#  'taking wrench': 6,
#  'steering wheel': 17,
#  'chandelier': 1,
#  'cambridge blue': 1,
#  'presiding over': 1,
#  'opening refrigerator door': 7,
#  'putting on performance': 1,
#  'fixing car': 4,
#  'big red': 11,
#  'putting dishes': 1,
#  'looking at shoes': 2,
#  'stand': 3,
#  'at auditorium': 3,
#  'pulling curtain': 1,
#  'long sleeve': 6,
#  'standing in bird cage': 1,
#  'covering ears': 3,
#  'on highway': 5,
#  'picking up bolster': 1,
#  'sun yellow': 1,
#  'dark blur': 1,
#  'azure blue': 18,
#  'wiping tv': 3,
#  'american flag': 1,
#  'moving back and forth': 3,
#  'in bed': 1,
#  'lightblue': 1,
#  'sepia': 4,
#  'in middle of stage': 3,
#  'moving stuff': 1,
#  'blue and green': 1,
#  'electric guitar': 3,
#  'broth boils': 1,
#  'out door': 3,
#  'ivory': 4,
#  'soft red': 7,
#  'light-yellow': 9,
#  'farthest to right': 3,
#  'on washing sink': 6,
#  'marine blue': 19,
#  'on hearth': 9,
#  'attacking': 4,
#  'mazda': 3,
#  'water plastic': 1,
#  'shaking': 6,
#  'bullet': 1,
#  'bar': 1,
#  'picking up photo frame': 1,
#  'in front of table tennis table': 3,
#  'tangerine': 9,
#  'carrying paper': 1,
#  'writing': 58,
#  'turning cap': 1,
#  'removing bottle': 1,
#  'placing cell phone': 1,
#  'pedestrian': 1,
#  'riverside': 3,
#  'racing car': 1,
#  'taking out some snacks': 1,
#  'stroking his beard': 1,
#  'chopping block': 1,
#  'chewing things': 1,
#  'hammer': 2,
#  'tachometer': 1,
#  'dusk': 3,
#  'ice tray': 1,
#  'parking lot': 4,
#  'stirring paste': 1,
#  'stroller': 9,
#  'long hair': 234,
#  'electricity': 1,
#  'gloves': 12,
#  'arranging hair': 3,
#  'dustbin': 1,
#  'sweeping trash': 3,
#  'beside tv': 3,
#  'in air': 9,
#  'lamps': 2,
#  'launching': 3,
#  'small tree': 4,
#  'throwing cushions': 1,
#  'placing vacuum cleaner': 1,
#  'sorting out clothes': 2,
#  'akimbo': 1,
#  'lawn': 25,
#  'competition terrain': 2,
#  'handle': 5,
#  'hugging people': 1,
#  'repairing door': 2,
#  'rice cooker': 2,
#  'hanger': 22,
#  'gray-black': 7,
#  'near staircase': 3,
#  'taking pillow': 17,
#  'repairing goods': 1,
#  'closing fridge door': 1,
#  'throwing bolster': 2,
#  'dart board': 2,
#  'putting on lipsticks': 1,
#  'gas cooker': 1,
#  'tooth cup': 2,
#  'on washbasin': 9,
#  'little yellow dog': 1,
#  'taking jar': 1,
#  'forward': 7,
#  'navy': 1,
#  'wiping items': 1,
#  'three groups': 3,
#  'folding towels': 7,
#  'laundry': 1,
#  'wiping desk': 4,
#  'hot': 6,
#  'selfie': 2,
#  'hugging child': 1,
#  'rugby': 6,
#  'eating': 292,
#  'typing': 13,
#  'hand': 5,
#  'dark red': 64,
#  'holding bottle': 2,
#  'raising bag': 1,
#  'in bottom of sea': 3,
#  'holding broom': 2,
#  'runway': 3,
#  'eating grapes': 1,
#  'crossing arms': 1,
#  'pigment': 5,
#  'bring plastic bag': 1,
#  'slipper': 4,
#  'choosing tools': 1,
#  'ride motorcycle': 5,
#  'taking microphone': 1,
#  'rolling eyes': 1,
#  'back cushion': 7,
#  'placing sundries': 1,
#  'judgment': 2,
#  'blanket': 74,
#  'taking plastic bag': 1,
#  'moving out items': 1,
#  'going outdoors': 1,
#  'back bag': 1,
#  'apricot red': 4,
#  'morning': 4,
#  'wrestling': 26,
#  'weapon': 4,
#  'taking game pad': 1,
#  'set fire': 1,
#  'basketball hoop': 4,
#  'throwing cushion': 1,
#  'at sea': 1,
#  'trash can chair': 1,
#  'lifting plate': 1,
#  'snowy white': 1,
#  'microwave oven': 16,
#  'jar': 26,
#  'performance': 1,
#  'pictures': 6,
#  'saucer': 4,
#  'playing cup': 3,
#  'showing items': 2,
#  'watch': 43,
#  'arctic': 1,
#  'looking up': 2,
#  'throwing rag': 1,
#  'cutting green vegetable': 1,
#  'bathing animal': 1,
#  'fishing gear': 1,
#  'socket': 21,
#  'lifting water cup': 1,
#  'having medication': 1,
#  'wobbling': 1,
#  'taking things': 56,
#  'taking off pants': 1,
#  'sliver grey': 4,
#  'tank': 1,
#  'national flag': 7,
#  'in classroom': 1,
#  'putting down lid': 1,
#  'headphones': 3,
#  'flour': 6,
#  'in corner of room': 3,
#  'building': 3,
#  'putting plate': 1,
#  'on runway': 7,
#  'in middle of interface': 1,
#  'tool': 11,
#  'portrayal': 1,
#  'frying beef steak': 1,
#  'juicer': 3,
#  'game handle': 3,
#  'cap': 33,
#  'star photos': 1,
#  'looking at photos': 6,
#  'saluting': 1,
#  'purse': 3,
#  'wiping nose': 12,
#  'drinking milktea': 1,
#  'observing good or bad': 3,
#  'sponge': 4,
#  'camel': 1,
#  'smoke blue': 1,
#  'card': 5,
#  'face cream': 1,
#  'cleaning up': 28,
#  'looking computer': 4,
#  'placing stuffs': 1,
#  'windows': 2,
#  'ashtray': 2,
#  'blue and gray': 1,
#  'putting back cabinet': 1,
#  'taking book': 16,
#  'eggs': 2,
#  'refreshing': 3,
#  'taking ingredients': 1,
#  'playing football': 10,
#  'round earrings': 2,
#  'taking bag': 12,
#  'playing computers': 3,
#  'volleyball court': 1,
#  'looking for something': 26,
#  'using calculator': 1,
#  'making paper airplane': 2,
#  'packing phone': 1,
#  'lighting light': 1,
#  'backpack': 20,
#  'tap': 4,
#  'pavement': 3,
#  'picking up towels': 1,
#  'opening medicine bottles': 1,
#  'outlet': 1,
#  'light red': 28,
#  'taking shovel': 1,
#  'drinking things': 3,
#  'pan': 11,
#  'looking at photo': 7,
#  'grabbing food': 3,
#  'water dispenser': 1,
#  'cosmetics': 3,
#  'night': 3,
#  'jade green': 4,
#  'helicopter': 3,
#  'washing ball': 1,
#  'dining room': 1,
#  'watching information': 1,
#  'sliding door': 2,
#  'taking interview': 1,
#  'electric wire': 9,
#  'picking up dishes': 1,
#  'opening cupboard door': 3,
#  'igniting hearth': 1,
#  'pulling something': 1,
#  'putting down': 2,
#  'taking out boxes': 1,
#  'pouring beverage': 2,
#  'wrist watch': 10,
#  'cap pistol': 1,
#  'not': 3,
#  'pressing neck': 1,
#  'playing table tennis': 7,
#  'being in daze': 3,
#  'purple red': 6,
#  'landscape': 3,
#  'grey-white': 3,
#  'in meeting room': 1,
#  'sun': 2,
#  'playing stage play': 1,
#  'taking something': 16,
#  'photos of beautiful women': 1,
#  'coriander': 4,
#  'rehearsing show': 1,
#  'on floor': 69,
#  'checking out snacks': 1,
#  'on shoes': 6,
#  'rubbing plasticene': 1,
#  'taking newspaper': 1,
#  'blue-black': 10,
#  'wheelchair': 1,
#  'green vegetable': 3,
#  'laundry detergent': 24,
#  'hair-drying cap': 1,
#  'car door': 1,
#  'reddish orange': 2,
#  'taking bottle': 9,
#  'cleaning up shelf': 1,
#  'touching jaw': 1,
#  'taking pics': 1,
#  'wiping bottle': 4,
#  'basketball': 6,
#  'tiles': 1,
#  'pour water': 2,
#  'magenta pink': 1,
#  'tiptoeing': 1,
#  'on face': 6,
#  'crying': 4,
#  'machine part': 3,
#  'dashboard': 1,
#  'climbing snow mountain': 3,
#  'bending': 1,
#  'placing things': 5,
#  'taking umbrella': 1,
#  'sky': 6,
#  'raise sail': 3,
#  'piazza': 1,
#  'stroking hair': 1,
#  'uniform': 1,
#  'pouring juice': 1,
#  'installing equipment': 2,
#  'in storage room': 2,
#  'crab': 4,
#  'speaking': 264,
#  'shelter': 6,
#  'touching grass': 3,
#  'wireless-voice tube': 1,
#  'detergent': 6,
#  'taking photo for car': 3,
#  'measuring ruler': 1,
#  'yawning': 3,
#  'pouring out': 1,
#  'badminton court': 3,
#  'bin': 1,
#  'tidying table': 2,
#  'on oven': 1,
#  'in engine room': 3,
#  'beside car': 3,
#  'placing besom': 1,
#  'playing his cellphone': 1,
#  'birdcage': 1,
#  'trucks': 3,
#  'throwing duster cloth': 1,
#  'carrying': 1,
#  'putting on another table': 1,
#  'looking at others': 1,
#  'doing some cleaning': 7,
#  'on grasslands': 1,
#  'getting milk': 1,
#  'drying sweat': 1,
#  'operating': 1,
#  'covering clothes': 1,
#  'compere': 1,
#  'purple blue': 2,
#  'cleaning cloth': 4,
#  'watching': 2,
#  'setting backpack': 1,
#  'putting hand on closet': 1,
#  'brownish black': 6,
#  'magic stick': 3,
#  'blasket': 1,
#  'reach out hand': 1,
#  'art painting': 1,
#  'working': 4,
#  'on desktop': 3,
#  'throwing clothes': 22,
#  'twisting himself': 1,
#  'magic cube': 3,
#  'playing field': 11,
#  'platform': 3,
#  'sweeping something': 1,
#  'sorting up': 1,
#  'flute': 3,
#  'trotting': 2,
#  'hanging picture': 1,
#  'spider net': 2,
#  'discharging baby carriage': 1,
#  'protective cover': 1,
#  'using cleaning fluid': 1,
#  'fire hydrant cabinet': 1,
#  'in stairwell': 9,
#  'preparing': 1,
#  'weight lifting': 3,
#  'entering text': 2,
#  'dusty gray': 3,
#  'glove': 7,
#  'taking plates': 6,
#  'watching mobile phone': 1,
#  'moving item': 1,
#  'little bird': 1,
#  'plating': 3,
#  'game characters': 2,
#  'sitting on sofa': 2,
#  'emerald green': 5,
#  'flip food': 1,
#  'traninng animal': 1,
#  'testing stadium': 1,
#  'bath chair': 1,
#  'moving table': 2,
#  'sorting clothes': 3,
#  'dresser': 3,
#  'burgandy': 4,
#  'earphone': 27,
#  'tidying up': 1,
#  'pouring water to another cup': 3,
#  'observing fan': 1,
#  'putting telecontroller': 1,
#  'bright yellow': 3,
#  'cloth': 12,
#  'painting eye makeup': 1,
#  'turning up light': 2,
#  'washing hands': 13,
#  'picking up broom': 2,
#  'desk lamp': 8,
#  'finishing': 3,
#  'communicating': 1,
#  'organizing items': 4,
#  'uncover pot': 1,
#  'violet': 37,
#  'turning on cellphone': 1,
#  'recording news live': 1,
#  'repairing machine': 1,
#  'playing poker': 3,
#  'in cloakroom': 2,
#  'eyeglasses': 33,
#  'participating in competition': 1,
#  'knives': 1,
#  'computer': 258,
#  'sit': 3,
#  'by river': 12,
#  'in spacecraft': 1,
#  'unsnaping': 1,
#  'kicking door': 1,
#  'true-black': 1,
#  'turning off hearth': 1,
#  'dark coffee': 2,
#  'performing': 33,
#  'in great hall': 3,
#  'making telephone calls': 4,
#  'ofo': 1,
#  'data': 1,
#  'parked': 3,
#  'puffed food': 1,
#  'basketball player': 1,
#  'taking out bread': 1,
#  'closing refrigerator': 10,
#  'rope': 4,
#  'cage': 5,
#  'preparing truck': 1,
#  'organizing sofa': 1,
#  'getting bag': 3,
#  'light yellow': 44,
#  'searching refrigerator': 1,
#  'columns': 1,
#  'beside sound': 2,
#  'removing lamp cover': 1,
#  'lightg-purple': 1,
#  'toweling': 1,
#  'cartoon child': 1,
#  'mountain': 3,
#  'putting condiment': 3,
#  'cleaning up thoroughly': 1,
#  'electromobile': 2,
#  'taking tissue': 1,
#  'royal blue': 32,
#  'taking out goods': 1,
#  'darkish red': 1,
#  'powder cake': 1,
#  'in front': 3,
#  'butterfly': 3,
#  'dull-red': 1,
#  'packing laptop bag': 1,
#  'against wall': 7,
#  'magazines': 3,
#  'dessert': 5,
#  'looking at camera': 5,
#  'astronaut': 1,
#  'carrying bags': 1,
#  'match': 6,
#  'tv box': 1,
#  'taking face film': 1,
#  'atropurpureus': 1,
#  'looking at wall': 1,
#  'in washingroom': 2,
#  'broadcasting station': 1,
#  'throwing food': 1,
#  'drink water': 2,
#  'closing door refrigerator': 1,
#  'cape': 1,
#  'taking two bowls': 1,
#  'spoons': 1,
#  'artificial flower': 1,
#  'snapping fingers': 1,
#  'computer image': 3,
#  'deep red': 1,
#  'taking duster cloth': 1,
#  'fishing net': 3,
#  'blue azure': 1,
#  'by lake': 3,
#  'earth yellow': 5,
#  'plum red': 1,
#  'eating bread': 34,
#  'eating snacks': 6,
#  'on pole': 3,
#  'stepping on pillow': 1,
#  'throwing out pillow': 1,
#  'on blanket': 3,
#  'throwing towel': 4,
#  'in city': 1,
#  'wrapping powder': 1,
#  'screwdriver': 8,
#  'bluish white': 1,
#  'putting away dishes': 1,
#  'organizing clothes': 3,
#  'closing paper box': 1,
#  'bright blue': 2,
#  'playing game': 10,
#  'drying hair': 1,
#  'fish': 9,
#  'looking at cellphone': 5,
#  'plastic cup': 1,
#  'juicing': 1,
#  'five hundred and twenty eight': 1,
#  'beige color': 3,
#  'leaning against wall': 1,
#  'flipping pages': 1,
#  'beer': 3,
#  'in carport': 1,
#  'fixing up things': 1,
#  'shampoo': 7,
#  'getting blanket': 2,
#  'riding horse': 6,
#  'turning off fire': 1,
#  'sneeze': 2,
#  'round': 16,
#  'opening bag': 4,
#  'on playground': 7,
#  'reading': 72,
#  'cleaning up goods': 1,
#  'eyes': 3,
#  'armrests': 4,
#  'driving racing car': 3,
#  'bouncing basketball': 1,
#  'putting computer on table': 1,
#  'furvous': 72,
#  'cutting food material': 1,
#  'white plaid': 2,
#  'grubbing': 3,
#  'company': 3,
#  'in washer': 3,
#  'dumbbell': 8,
#  'olive green': 1,
#  'carrying items': 1,
#  'station caption': 1,
#  'deep blue': 2,
#  'sauce purple': 1,
#  'placing ingredients': 1,
#  'on stairs': 131,
#  'repairing computer': 1,
#  'folding things': 3,
#  'emerald': 1,
#  'net pocket': 1,
#  'piano': 9,
#  'dark-brown': 2,
#  'reddish brown': 1,
#  'photo frames': 3,
#  'balls': 1,
#  'brown green': 7,
#  'putting off clothes': 1,
#  'washing things': 2,
#  'pale green': 12,
#  'carrying goods': 1,
#  'one five': 1,
#  'putting bottle': 1,
#  'seeing program': 1,
#  'looking for things': 3,
#  'plastic box': 6,
#  'peach red': 8,
#  'walking toward door': 1,
#  'putting items': 3,
#  'throwing up towels': 1,
#  'dating bread': 1,
#  'plastic': 6,
#  'inside room': 1,
#  'fence': 6,
#  'upstairs': 3,
#  'seawater': 2,
#  'opening up files': 1,
#  'residential': 2,
#  'wathet blue': 1,
#  'light black': 11,
#  'residence': 384,
#  'in dish': 3,
#  'hand on shoulder': 1,
#  'rosy': 2,
#  'putting pillow': 3,
#  'throwing trash': 2,
#  'green and blue': 2,
#  'photographing': 2,
#  'crossing street': 3,
#  'wing': 6,
#  'stb': 1,
#  'computer parts': 1,
#  'trash can': 6,
#  'picking materials': 1,
#  'twisting things': 1,
#  'shaking camera arm': 1,
#  'mario': 1,
#  'tv set': 15,
#  'hollow earrings': 1,
#  'purple sauce': 2,
#  'out of room': 1,
#  'router': 2,
#  'pale purple': 3,
#  'athletes': 1,
#  'picking up juicer': 3,
#  'electronic screen': 3,
#  'diyworks': 1,
#  'liquid': 3,
#  'putting down cloth bag': 1,
#  'folding silk scarves': 1,
#  'fashion show': 10,
#  'black red': 2,
#  'dog house': 1,
#  'cycling': 3,
#  'feeding': 1,
#  'pulling cord': 1,
#  'in hallway': 11,
#  'opening notebook': 1,
#  'day': 3,
#  'taking off clothes': 67,
#  'dull gray': 3,
#  'dark-yellow': 3,
#  'eating popcorn': 1,
#  'in gymnasium': 6,
#  'stick': 4,
#  'studios': 9,
#  'turning lights off': 1,
#  'music score': 5,
#  'rectangle': 30,
#  'playing phones': 1,
#  'tearing off paper': 1,
#  'fire red': 1,
#  'peachblossom': 4,
#  'light-purple': 3,
#  'pouring back to plate': 1,
#  'fat': 6,
#  'beard': 3,
#  'playing rugby': 3,
#  'snowmobile': 1,
#  'taking medication': 1,
#  'sealing tank': 1,
#  'sliver': 2,
#  'bright-red': 6,
#  'jeans': 3,
#  'wiping toy': 1,
#  'purply': 2,
#  'wooden door': 2,
#  'fire truck': 3,
#  'lying down under covers': 1,
#  'billboard': 1,
#  'water tap': 4,
#  'placing computer': 3,
#  'approaching door': 1,
#  'coffee color': 1,
#  'flushing plate': 1,
#  'snow': 1,
#  'taking seat cushion': 1,
#  'rising head': 1,
#  'peachpuff': 1,
#  'whistle': 1,
#  'cooking bench': 1,
#  'street light': 2,
#  'light pink': 25,
#  'washing powder': 1,
#  'putting down brooms': 1,
#  'washing spoon': 1,
#  'looking through bags': 1,
#  'moving': 18,
#  'pressing remote controller': 1,
#  'mobile phone': 26,
#  'motorbike': 4,
#  'in locker room': 1,
#  'touching hair': 6,
#  'red brown': 1,
#  'walking dog': 3,
#  'seat cushion': 2,
#  'on hand': 4,
#  'reading newspaper': 5,
#  ...}

# %%
sort_answer
# Out:
# [('standing', 6344),
#  ('sitting', 2440),
#  ('black', 1824),
#  ('white', 1338),
#  ('indoor', 1155),
#  ('blue', 707),
#  ('red', 563),
#  ('on table', 492),
#  ('in house', 450),
#  ('kitchen', 433),
#  ('residence', 384),
#  ('drinking water', 373),
#  ('green', 364),
#  ('living room', 336),
#  ('glasses', 329),
#  ('cup', 304),
#  ('yellow', 297),
#  ('eating', 292),
#  ('short hair', 288),
#  ('chair', 270),
#  ('clothes', 269),
#  ('speaking', 264),
#  ('talking', 263),
#  ('computer', 258),
#  ('bedroom', 256),
#  ('lying', 248),
#  ('hat', 246),
#  ('long hair', 234),
#  ('table', 222),
#  ('grey', 206),
#  ('walking', 204),
#  ('book', 198),
#  ('in door', 195),
#  ('dark blue', 194),
#  ('in living room', 189),
#  ('on wall', 188),
#  ('two', 186),
#  ('brown', 182),
#  ('gray', 175),
#  ('on ground', 167),
#  ('purple', 164),
#  ('pink', 156),
#  ('pillow', 155),
#  ('milk white', 153),
#  ('in kitchen', 152),
#  ('creamy white', 149),
#  ('outdoor', 145),
#  ('male', 142),
#  ('chatting', 139),
#  ('in bedroom', 136),
#  ('on stairs', 131),
#  ('in room', 124),
#  ('singing', 120),
#  ('inside house', 120),
#  ('mirror', 119),
#  ('dancing', 114),
#  ('pot', 114),
#  ('sneezing', 113),
#  ('sofa', 113),
#  ('light blue', 109),
#  ('on bed', 108),
#  ('bottle', 108),
#  ('room', 105),
#  ('cooking', 104),
#  ('on sofa', 104),
#  ('man', 103),
#  ('phone', 102),
#  ('bed', 99),
#  ('cabinet', 97),
#  ('opening door', 97),
#  ('orange', 97),
#  ('playing computer', 97),
#  ('indoors', 95),
#  ('desk', 94),
#  ('watching tv', 93),
#  ('tidying', 91),
#  ('bright red', 90),
#  ('car', 89),
#  ('aterrimus', 89),
#  ('three', 85),
#  ('in car', 84),
#  ('running', 82),
#  ('english', 82),
#  ('mustache', 81),
#  ('playing cell phone', 81),
#  ('cell phone', 79),
#  ('plate', 79),
#  ('bathroom', 79),
#  ('on desk', 78),
#  ('house', 78),
#  ('dark black', 77),
#  ('resting', 77),
#  ('dark grey', 77),
#  ('painting', 76),
#  ('female', 76),
#  ('left hand', 75),
#  ('yes', 75),
#  ('shoes', 75),
#  ('microphone', 75),
#  ('blanket', 74),
#  ('dog', 74),
#  ('refrigerator', 74),
#  ('sleeping', 73),
#  ('closet', 72),
#  ('reading', 72),
#  ('furvous', 72),
#  ('bag', 72),
#  ('dark green', 71),
#  ('towel', 70),
#  ('on floor', 69),
#  ('on stage', 68),
#  ('taking off clothes', 67),
#  ('on chair', 67),
#  ('woman', 67),
#  ('right hand', 66),
#  ('lying down', 65),
#  ('door', 65),
#  ('tv', 65),
#  ('playing phone', 65),
#  ('dark red', 64),
#  ('closing door', 64),
#  ('light gray', 62),
#  ('clearing up', 60),
#  ('reading book', 59),
#  ('writing', 58),
#  ('sweeping floor', 58),
#  ('squatting', 57),
#  ('taking things', 56),
#  ('box', 56),
#  ('tree', 55),
#  ('on shelf', 54),
#  ('open', 54),
#  ('on cabinet', 54),
#  ('light grey', 54),
#  ('on', 54),
#  ('bowl', 54),
#  ('light green', 54),
#  ('in studio', 54),
#  ('taking off shoes', 53),
#  ('corridor', 53),
#  ('paper', 52),
#  ('off-white', 52),
#  ('looking into mirror', 51),
#  ('driving', 51),
#  ('shelf', 50),
#  ('crimson', 50),
#  ('studio', 50),
#  ('looking in mirror', 50),
#  ('laptop', 48),
#  ('lamp', 48),
#  ('in bathroom', 47),
#  ('broom', 47),
#  ('guitar', 46),
#  ('helmet', 46),
#  ('photo frame', 46),
#  ('playing games', 46),
#  ('playing mobile phone', 45),
#  ('four', 45),
#  ('light yellow', 44),
#  ('on road', 44),
#  ('toilet', 44),
#  ('dark brown', 44),
#  ('watch', 43),
#  ('pouring water', 43),
#  ('carton', 43),
#  ('pure black', 43),
#  ('sky blue', 42),
#  ('grass green', 42),
#  ('cleaning', 41),
#  ('mouse', 41),
#  ('stairs', 40),
#  ('beige', 40),
#  ('one', 39),
#  ('on street', 39),
#  ('dark gray', 38),
#  ('opening refrigerator', 38),
#  ('television', 38),
#  ('water cup', 38),
#  ('curtain', 37),
#  ('violet', 37),
#  ('people', 37),
#  ('ring', 37),
#  ('dark-blue', 37),
#  ('washing machine', 36),
#  ('food', 36),
#  ('milky white', 36),
#  ('looking at computer', 36),
#  ('switch', 36),
#  ('pool', 35),
#  ('photo', 35),
#  ('eating things', 35),
#  ('navy blue', 35),
#  ('eating bread', 34),
#  ('camera', 34),
#  ('cyan', 34),
#  ('laughing', 34),
#  ('doorway', 34),
#  ('taking clothes', 34),
#  ('cap', 33),
#  ('eyeglasses', 33),
#  ('performing', 33),
#  ('reading books', 33),
#  ('no', 33),
#  ('necklace', 33),
#  ('hanging on wall', 33),
#  ('royal blue', 32),
#  ('playing guitar', 32),
#  ('gray white', 32),
#  ('quilt', 32),
#  ('vacuum cleaner', 31),
#  ('taking photos', 31),
#  ('putting on shoes', 31),
#  ('azure', 31),
#  ('water', 31),
#  ('rectangle', 30),
#  ('light-blue', 30),
#  ('putting on clothes', 30),
#  ('drinking', 30),
#  ('left', 30),
#  ('pen', 30),
#  ('rose red', 29),
#  ('in hands', 29),
#  ('cleaning up', 28),
#  ('light red', 28),
#  ('bucket', 28),
#  ('cartoon', 28),
#  ('in cabinet', 28),
#  ('in water', 28),
#  ('earphone', 27),
#  ('turning on light', 27),
#  ('light', 27),
#  ('horizontal', 27),
#  ('carpet', 27),
#  ('wearing shoes', 27),
#  ('bread', 27),
#  ('taking cup', 27),
#  ('right', 27),
#  ('fetching things', 26),
#  ('dark purple', 26),
#  ('wrestling', 26),
#  ('jar', 26),
#  ('looking for something', 26),
#  ('mobile phone', 26),
#  ('silver', 26),
#  ('window', 26),
#  ('snacks', 26),
#  ('taking shoes', 26),
#  ('exercising', 26),
#  ('explaining', 26),
#  ('lawn', 25),
#  ('light pink', 25),
#  ('wearing clothes', 25),
#  ('behind door', 25),
#  ('in hand', 25),
#  ('smalt', 25),
#  ('beige white', 25),
#  ('putting things', 25),
#  ('golden', 24),
#  ('laundry detergent', 24),
#  ('curly hair', 24),
#  ('gun', 24),
#  ('on washing machine', 24),
#  ('on lawn', 24),
#  ('person', 24),
#  ('closed', 24),
#  ('clock', 24),
#  ('horse', 24),
#  ('stage', 24),
#  ('tie', 23),
#  ('sitting down', 23),
#  ('court', 23),
#  ('hearth', 23),
#  ('calling', 23),
#  ('remote control', 23),
#  ('public place', 23),
#  ('cat', 23),
#  ('plastic bag', 23),
#  ('beverage', 23),
#  ('watching computer', 23),
#  ('hanger', 22),
#  ('throwing clothes', 22),
#  ('light white', 22),
#  ('having rest', 22),
#  ('light purple', 22),
#  ('six', 22),
#  ('paper box', 22),
#  ('opening', 22),
#  ('sky-blue', 22),
#  ('throwing pillow', 21),
#  ('on door', 21),
#  ('socket', 21),
#  ('baby blue', 21),
#  ('stool', 21),
#  ('in closet', 21),
#  ('khaki', 21),
#  ('on stool', 21),
#  ('poster', 20),
#  ('backpack', 20),
#  ('holding pillow', 20),
#  ('notebook', 20),
#  ('atrovirens', 20),
#  ('placing items', 20),
#  ('deep purple', 20),
#  ('cloakroom', 19),
#  ('outdoors', 19),
#  ('marine blue', 19),
#  ('flower', 19),
#  ('on grass', 19),
#  ('playing basketball', 19),
#  ('knife', 19),
#  ('case', 19),
#  ('fighting', 19),
#  ('dark yellow', 19),
#  ('doll', 19),
#  ('taking off coat', 19),
#  ('lake blue', 19),
#  ('azure blue', 18),
#  ('moving', 18),
#  ('posing', 18),
#  ('curly', 18),
#  ('in corridor', 18),
#  ('brownish yellow', 18),
#  ('lavender', 18),
#  ('couch', 18),
#  ('dark-red', 18),
#  ('taking photo', 18),
#  ('hands', 18),
#  ('washing clothes', 18),
#  ('kneeling', 18),
#  ('shooting', 18),
#  ('making call', 18),
#  ('black blue', 18),
#  ('steering wheel', 17),
#  ('taking pillow', 17),
#  ('staircase', 17),
#  ('cellphone', 17),
#  ('basket', 17),
#  ('basketball court', 17),
#  ('drinking beverage', 17),
#  ('child', 17),
#  ('looking at mirror', 17),
#  ('auditorium', 17),
#  ('ash black', 17),
#  ('taking phone', 17),
#  ('keyboard', 17),
#  ('wiping table', 17),
#  ('orange red', 16),
#  ('football field', 16),
#  ('square', 16),
#  ('microwave oven', 16),
#  ('taking book', 16),
#  ('taking something', 16),
#  ('round', 16),
#  ('opening cabinet', 16),
#  ('taking towel', 16),
#  ('competing', 16),
#  ('skyblue', 16),
#  ('vase', 16),
#  ('smiling', 16),
#  ('ball', 16),
#  ('jumping', 16),
#  ('wall', 16),
#  ('spoon', 16),
#  ('getting up', 16),
#  ('taking pictures', 16),
#  ('taking medicine', 16),
#  ('at table', 16),
#  ('newspaper', 16),
#  ('light brown', 16),
#  ('on cupboard', 16),
#  ('tv set', 15),
#  ('toilets', 15),
#  ('rose', 15),
#  ('daytime', 15),
#  ('next to car', 15),
#  ('playing', 15),
#  ('black and white', 15),
#  ('pale pink', 15),
#  ('flying', 15),
#  ('magazine', 15),
#  ('off white', 15),
#  ('glass', 15),
#  ('watching video', 15),
#  ('skirt', 15),
#  ('calendar', 15),
#  ('in cupboard', 15),
#  ('in corner', 15),
#  ('display', 15),
#  ('climbing stairs', 15),
#  ('on cooktop', 15),
#  ('horizontally', 15),
#  ('shirt', 15),
#  ('in game', 15),
#  ('toy', 15),
#  ('game scene', 15),
#  ('grey white', 15),
#  ('eating something', 15),
#  ('wardrobe', 15),
#  ('making up', 14),
#  ('animal', 14),
#  ('clothing', 14),
#  ('gray black', 14),
#  ('tan', 14),
#  ('field', 14),
#  ('claybank', 14),
#  ('audience', 14),
#  ('beach', 14),
#  ('turquoise', 14),
#  ('earphones', 14),
#  ('fan', 14),
#  ('modena', 14),
#  ('pumpkin', 14),
#  ('typing', 13),
#  ('washing hands', 13),
#  ('stairwell', 13),
#  ('swimming', 13),
#  ('turning on lights', 13),
#  ('putting away things', 13),
#  ('earrings', 13),
#  ('sheet', 13),
#  ('dark-grey', 13),
#  ('game', 13),
#  ('kettle', 13),
#  ('basin', 13),
#  ('pure white', 13),
#  ('in sky', 13),
#  ('taking blanket', 13),
#  ('looking at phone', 13),
#  ('watching videos', 13),
#  ('putting cup', 13),
#  ('ocean blue', 13),
#  ('silver grey', 13),
#  ('on refrigerator', 12),
#  ('corner', 12),
#  ('gloves', 12),
#  ('wiping nose', 12),
#  ('taking bag', 12),
#  ('cloth', 12),
#  ('by river', 12),
#  ('pale green', 12),
#  ('true red', 12),
#  ('coffee', 12),
#  ('skiing', 12),
#  ('storage room', 12),
#  ('meat', 12),
#  ('tablecloth', 12),
#  ('grey black', 12),
#  ('warehouse', 12),
#  ('stopped', 12),
#  ('watching phone', 12),
#  ('playing piano', 12),
#  ('oven', 12),
#  ('circle', 12),
#  ('lights', 12),
#  ('making phone call', 12),
#  ('stirring', 12),
#  ('medium yellow', 12),
#  ('interviewing', 12),
#  ('closing window', 12),
#  ('grass', 12),
#  ('scarf', 12),
#  ('on court', 12),
#  ('bicycle', 12),
#  ('seven', 12),
#  ('off', 12),
#  ('cushion', 12),
#  ('egg', 11),
#  ('opening box', 11),
#  ('big red', 11),
#  ('tool', 11),
#  ('pan', 11),
#  ('playing field', 11),
#  ('light black', 11),
#  ('in hallway', 11),
#  ('going upstairs', 11),
#  ('drawing', 11),
#  ('eating food', 11),
#  ('athlete', 11),
#  ('turning off light', 11),
#  ('road', 11),
#  ('changing clothes', 11),
#  ('table lamp', 11),
#  ('turning off lights', 11),
#  ('electric fan', 11),
#  ('taking food', 11),
#  ('five', 11),
#  ('utility room', 11),
#  ('rice white', 11),
#  ('orange yellow', 11),
#  ('pale yellow', 11),
#  ('having match', 11),
#  ('dishes', 11),
#  ('making speech', 11),
#  ('gymnasium', 11),
#  ('plastic bottle', 11),
#  ('cartoon character', 11),
#  ('drinking milk', 11),
#  ('grey and white', 11),
#  ('on steps', 11),
#  ('bottle green', 11),
#  ('dressing up', 11),
#  ('frame', 11),
#  ('turning on computer', 10),
#  ('having meal', 10),
#  ('playing football', 10),
#  ('wrist watch', 10),
#  ('blue-black', 10),
#  ('closing refrigerator', 10),
#  ('playing game', 10),
#  ('fashion show', 10),
#  ('folding paper', 10),
#  ('in washing room', 10),
#  ('opening closet', 10),
#  ('getting dressed', 10),
#  ('creamy-white', 10),
#  ('mural', 10),
#  ('putting down something', 10),
#  ('folding clothes', 10),
#  ('going downstairs', 10),
#  ('laundry room', 10),
#  ('introducing car', 10),
#  ('grayish white', 10),
#  ('apron', 10),
#  ('undressing', 10),
#  ('pure-black', 10),
#  ('corner of wall', 10),
#  ('turning around', 10),
#  ('studying', 10),
#  ('trousers', 10),
#  ('light-grey', 10),
#  ('brush', 10),
#  ('army green', 10),
#  ('taking selfie', 10),
#  ('shovel', 10),
#  ('faint yellow', 10),
#  ('on snow mountain', 10),
#  ('cupboard', 10),
#  ('fruits', 9),
#  ('sword', 9),
#  ('stadium', 9),
#  ('light-yellow', 9),
#  ('on hearth', 9),
#  ('tangerine', 9),
#  ('stroller', 9),
#  ('in air', 9),
#  ('on washbasin', 9),
#  ('electric wire', 9),
#  ('taking bottle', 9),
#  ('in stairwell', 9),
#  ('fish', 9),
#  ('piano', 9),
#  ('studios', 9),
#  ('garland', 9),
#  ('blue and black', 9),
#  ('on beach', 9),
#  ('on hanger', 9),
#  ('chicken', 9),
#  ('sapphire blue', 9),
#  ('seat', 9),
#  ('headset', 9),
#  ('opening cabinet door', 9),
#  ('vacuum machine', 9),
#  ('banana', 9),
#  ('introducing', 9),
#  ('black grey', 9),
#  ('simple', 9),
#  ('on screen', 9),
#  ('cleaning window', 9),
#  ('on carpet', 9),
#  ('sheets', 9),
#  ('standing up', 9),
#  ('riding motorcycle', 9),
#  ('electronic guitar', 9),
#  ('brownish red', 9),
#  ('magenta', 9),
#  ('decorative painting', 9),
#  ('fresco', 9),
#  ('milk-white', 9),
#  ('handbag', 9),
#  ('mop', 9),
#  ('putting down cup', 9),
#  ('catwalk show', 9),
#  ('sunglasses', 9),
#  ('playground', 9),
#  ('stone', 9),
#  ('in cup', 9),
#  ('in front of table', 9),
#  ('in refrigerator', 9),
#  ('in drawer', 9),
#  ('driving car', 9),
#  ('jacinth', 9),
#  ('lakeside', 9),
#  ('human', 9),
#  ('on tv bench', 9),
#  ('on window sill', 9),
#  ('earthy yellow', 9),
#  ('can', 9),
#  ('relaxing', 9),
#  ('in wardrobe', 9),
#  ('putting clothes', 9),
#  ('above ground', 9),
#  ('word', 9),
#  ('opening window', 8),
#  ('tidying clothes', 8),
#  ('taking computer', 8),
#  ('monster', 8),
#  ('flashlight', 8),
#  ('desk lamp', 8),
#  ('screwdriver', 8),
#  ('dumbbell', 8),
#  ('peach red', 8),
#  ('walking around', 8),
#  ('picking up pillow', 8),
#  ('bowel', 8),
#  ('throwing things', 8),
#  ('wathet', 8),
#  ('hugging', 8),
#  ('putting shoes', 8),
#  ('restaurant', 8),
#  ('pale grey', 8),
#  ('vegetables', 8),
#  ('bolster', 8),
#  ('bosom', 8),
#  ('at corner', 8),
#  ('curtains', 8),
#  ('besom', 8),
#  ('watching television', 8),
#  ('picture', 8),
#  ('machine', 8),
#  ('snow mountain', 8),
#  ('golden yellow', 8),
#  ('lemon yellow', 8),
#  ('doing cleaning', 8),
#  ('pale blue', 8),
#  ('putting on coat', 8),
#  ('boat', 8),
#  ('clapping', 8),
#  ('placing clothes', 8),
#  ('slivery', 8),
#  ('light cyan', 8),
#  ('bike', 8),
#  ('next to door', 8),
#  ('books', 7),
#  ('lifting cup', 7),
#  ('sweeping', 7),
#  ('silvery white', 7),
#  ('pants', 7),
#  ('opening refrigerator door', 7),
#  ('soft red', 7),
#  ('gray-black', 7),
#  ('forward', 7),
#  ('folding towels', 7),
#  ('back cushion', 7),
#  ('national flag', 7),
#  ('on runway', 7),
#  ('looking at photo', 7),
#  ('playing table tennis', 7),
#  ('doing some cleaning', 7),
#  ('glove', 7),
#  ('against wall', 7),
#  ('shampoo', 7),
#  ('on playground', 7),
#  ('brown green', 7),
#  ('classroom', 7),
#  ('earring', 7),
#  ('cleaning table', 7),
#  ('doing chores', 7),
#  ('in toilet', 7),
#  ('clapping hands', 7),
#  ('armrest', 7),
#  ('filming', 7),
#  ('cleaner', 7),
#  ('skeleton', 7),
#  ('laboratory', 7),
#  ('medal', 7),
#  ('hair clip', 7),
#  ('silver gray', 7),
#  ('dark-black', 7),
#  ('boy', 7),
#  ('in pot', 7),
#  ('silvery gray', 7),
#  ('on sea', 7),
#  ('model', 7),
#  ('washing cup', 7),
#  ('plant', 7),
#  ('screwing cap', 7),
#  ('in river', 7),
#  ('taking rest', 7),
#  ('blankets', 7),
#  ('stairway', 7),
#  ('in pool', 7),
#  ('picking up clothes', 7),
#  ('telephone', 7),
#  ('plates', 7),
#  ('triangle', 7),
#  ('on closet', 7),
#  ('throwing book', 7),
#  ('hangers', 7),
#  ('brushing plate', 7),
#  ('cooking meal', 7),
#  ('puppy', 7),
#  ('hanging clothes', 7),
#  ('hall', 7),
#  ('screen', 7),
#  ('ivory-white', 7),
#  ('river', 7),
#  ('fuchsia', 7),
#  ('suit', 7),
#  ('golden-yellow', 7),
#  ('pea green', 7),
#  ('bracelet', 7),
#  ('turning off computer', 7),
#  ('magnet', 7),
#  ('washroom', 7),
#  ('table tennis', 7),
#  ('scarlet', 7),
#  ('on tea table', 7),
#  ('black-blue', 7),
#  ('brown-black', 6),
#  ('drawing curtain', 6),
#  ('shaking hands', 6),
#  ('potato', 6),
#  ('putting away clothes', 6),
#  ('introducing product', 6),
#  ('having beard', 6),
#  ('light-green', 6),
#  ('handrail', 6),
#  ('dining', 6),
#  ('cups', 6),
#  ('on sport court', 6),
#  ('toothbrush', 6),
#  ('stationary', 6),
#  ('taking wrench', 6),
#  ('long sleeve', 6),
#  ('on washing sink', 6),
#  ('shaking', 6),
#  ('hot', 6),
#  ('rugby', 6),
#  ('pictures', 6),
#  ('flour', 6),
#  ('looking at photos', 6),
#  ('purple red', 6),
#  ('on shoes', 6),
#  ('basketball', 6),
#  ('on face', 6),
#  ('sky', 6),
#  ('shelter', 6),
#  ('detergent', 6),
#  ('brownish black', 6),
#  ('taking plates', 6),
#  ('match', 6),
#  ('eating snacks', 6),
#  ('riding horse', 6),
#  ('plastic box', 6),
#  ('plastic', 6),
#  ('fence', 6),
#  ('wing', 6),
#  ('trash can', 6),
#  ('in gymnasium', 6),
#  ('fat', 6),
#  ('bright-red', 6),
#  ('touching hair', 6),
#  ('comic', 6),
#  ('lying on his stomach', 6),
#  ('holding dog', 6),
#  ('looking outside window', 6),
#  ('moving chair', 6),
#  ('on carton', 6),
#  ('pushing car', 6),
#  ('lobby', 6),
#  ('having conversation', 6),
#  ('racing', 6),
#  ('mopping floor', 6),
#  ('by sea', 6),
#  ('hair band', 6),
#  ('beside sofa', 6),
#  ('watching game', 6),
#  ('alpaca', 6),
#  ('by wall', 6),
#  ('using vacuum cleaner', 6),
#  ('chopping board', 6),
#  ('on rope', 6),
#  ('cleaning mirror', 6),
#  ('transparent', 6),
#  ('in washing machine', 6),
#  ('in front of closet', 6),
#  ('throwing shoes', 6),
#  ('blue white', 6),
#  ('hamster', 6),
#  ('in sea', 6),
#  ('sea blue', 6),
#  ('t-shirts', 6),
#  ('brown yellow', 6),
#  ('in cinema', 6),
#  ('at stair hall', 6),
#  ('english letter', 6),
#  ('vehicle', 6),
#  ('baby', 6),
#  ('forest', 6),
#  ('screwing bottle cap', 6),
#  ('fruit', 6),
#  ('pouring laundry detergent', 6),
#  ('playing ball', 6),
#  ('dialog box', 6),
#  ('hospital', 6),
#  ('reseda', 6),
#  ('ring finger', 6),
#  ('on chopping board', 6),
#  ('looking at things', 6),
#  ('massaging', 6),
#  ('tattoo', 6),
#  ('doing experiment', 6),
#  ('in front of mirror', 6),
#  ('taking broom', 6),
#  ('on ice', 6),
#  ('selfie stick', 6),
#  ('jasper', 6),
#  ('park', 6),
#  ('home', 6),
#  ('suburb', 6),
#  ('on bus', 6),
#  ('repairing', 6),
#  ('rabbit', 6),
#  ('in box', 6),
#  ('jacket', 6),
#  ('shorts', 6),
#  ('rose-bengal', 6),
#  ('near table', 6),
#  ('sports center', 6),
#  ('covering blanket', 6),
#  ('taking out items', 6),
#  ('hair braiding', 6),
#  ('motorcycle', 6),
#  ('giving speech', 6),
#  ('bookcase', 6),
#  ('moving boxes', 6),
#  ('bed sheet', 6),
#  ('on tv cabinet', 6),
#  ('playing baseball', 6),
#  ('sliver white', 6),
#  ('beside door', 6),
#  ('playing video', 6),
#  ('minecraft', 6),
#  ('in carton', 6),
#  ('ball park', 6),
#  ('taking books', 6),
#  ('bracers', 6),
#  ('repairing car', 6),
#  ('putting away stuff', 6),
#  ('taking plate', 6),
#  ('rolling', 6),
#  ('bbc', 6),
#  ('placing cup', 6),
#  ('croci', 6),
#  ('blackboard', 6),
#  ('on board', 6),
#  ('key', 6),
#  ('wiping face', 6),
#  ('cow', 6),
#  ('playing cellphone', 6),
#  ('groveling', 6),
#  ('vegetable', 6),
#  ('on head', 6),
#  ('waving', 6),
#  ('putting down clothes', 6),
#  ('amaranth', 6),
#  ('broadcasting', 6),
#  ('photograph', 6),
#  ('on plane', 6),
#  ('in front of door', 6),
#  ('drinking juice', 6),
#  ('snowfield', 6),
#  ('on counter', 6),
#  ('stretching arms', 6),
#  ('on snowfield', 6),
#  ('nodding', 6),
#  ('putting food', 6),
#  ('operating computer', 6),
#  ('third', 6),
#  ('in stairs', 6),
#  ('stirring food', 6),
#  ('wiping glasses', 6),
#  ('watching photos', 6),
#  ('medicine', 6),
#  ('mat', 6),
#  ('hair', 6),
#  ('wiping hands', 5),
#  ('player', 5),
#  ('glass bottle', 5),
#  ('reading messages', 5),
#  ('water bottle', 5),
#  ('rag', 5),
#  ('plastic bags', 5),
#  ('baby-blue', 5),
#  ('giving lecture', 5),
#  ('pink red', 5),
#  ('on highway', 5),
#  ('handle', 5),
#  ('hand', 5),
#  ('pigment', 5),
#  ('ride motorcycle', 5),
#  ('card', 5),
#  ('placing things', 5),
#  ('emerald green', 5),
#  ('cage', 5),
#  ('dessert', 5),
#  ('looking at camera', 5),
#  ('earth yellow', 5),
#  ('looking at cellphone', 5),
#  ('music score', 5),
#  ('reading newspaper', 5),
#  ('operating phone', 5),
#  ('taking box', 5),
#  ('taking magazine', 5),
#  ('going up stairs', 5),
#  ('doing exercise', 5),
#  ('leopard', 5),
#  ('balloon', 5),
#  ('bridge', 5),
#  ('black gray', 5),
#  ('cabinet door', 5),
#  ('denim blue', 5),
#  ('monkey', 5),
#  ('at door', 5),
#  ('button', 5),
#  ('milk', 5),
#  ('vacuum', 5),
#  ('ater', 5),
#  ('closing refrigerator door', 5),
#  ('statue', 5),
#  ('blue purple', 5),
#  ('oil painting', 5),
#  ('talking on phone', 5),
#  ('saffron', 5),
#  ('closing closet', 5),
#  ('acting', 5),
#  ('doing laundry', 5),
#  ('seasoning', 5),
#  ('umbrella', 5),
#  ('seeing information', 5),
#  ('paper folding', 5),
#  ('putting towel', 5),
#  ('swinging', 5),
#  ('outside house', 5),
#  ('reaching out', 5),
#  ('putting on blanket', 5),
#  ('cooking things', 5),
#  ('mattress', 5),
#  ('visiting', 5),
#  ('swimming pool', 5),
#  ('number', 5),
#  ('under stairs', 5),
#  ('boxing', 5),
#  ('boating', 5),
#  ('vermilion', 5),
#  ('waste container', 5),
#  ('taking out clothes', 5),
#  ('kissing', 5),
#  ('ash gray', 5),
#  ('tibetain blue', 5),
#  ('picking up book', 5),
#  ('sewing machine', 5),
#  ('candle', 5),
#  ('document', 5),
#  ('snake', 5),
#  ('in glass bowl', 5),
#  ('taking off his clothes', 5),
#  ('peak green', 5),
#  ('washing dishes', 5),
#  ('plastic bucket', 5),
#  ('holding cup', 5),
#  ('purplish red', 5),
#  ('fork', 5),
#  ('narrating', 5),
#  ('arrow', 5),
#  ('taking on his coat', 5),
#  ('microwave', 5),
#  ('wiping mirror', 5),
#  ('playing computer games', 5),
#  ('peach', 5),
#  ('opening computer', 5),
#  ('folding towel', 5),
#  ('purplish blue', 5),
#  ('3d', 5),
#  ('washbasin', 5),
#  ('subtitle', 5),
#  ('falling down', 5),
#  ('recording', 5),
#  ('light-red', 5),
#  ('table tennis bat', 4),
#  ('brown red', 4),
#  ('hovel', 4),
#  ('sailing', 4),
#  ('telestudio', 4),
#  ('on water', 4),
#  ('on balcony', 4),
#  ('playing tablet', 4),
#  ('showing', 4),
#  ('long jump', 4),
#  ('placing plates', 4),
#  ...]

# %%
sort_question
# Out:
# [('where is the person in the video', 1266),
#  ('what is the person in the video doing', 933),
#  ('what is the person doing in the video', 794),
#  ('is the person in the video standing or sitting', 546),
#  ('is the person in the video sitting or standing', 507),
#  ('is the person sitting or standing in the video', 450),
#  ('what is in the video', 316),
#  ('what is on the table', 224),
#  ('where is the person in video', 194),
#  ('what is in the room', 182),
#  ('what can you see in the video', 163),
#  ('what color of the clothes does the person wear in the video', 162),
#  ('what is the man in the video doing', 137),
#  ('what is the man doing in the video', 132),
#  ('is the person standing or sitting in the video', 131),
#  ('what is in front of the person in the video', 130),
#  ('what color clothes does the person wear in the video', 121),
#  ('what is the person in video doing', 121),
#  ('where is the man', 108),
#  ('what is the person doing in video', 108),
#  ("what is the color of the person's clothes in video", 106),
#  ('what is the man doing', 106),
#  ('is the man in the video standing or sitting', 105),
#  ('where is the man in the video', 96),
#  ("what is the color of the person's clothes in the video", 94),
#  ('what color clothes does the person in the video wear', 90),
#  ("what color is the person's clothes in the video", 89),
#  ('what is the woman in the video doing', 88),
#  ('what is the color of the wall', 85),
#  ('is the man standing or sitting', 84),
#  ('what is the color of the clothes of the person in the video', 74),
#  ('what is on the table in the video', 71),
#  ('what color pants does the person wear in the video', 65),
#  ('what is in the living room', 58),
#  ('is the man sitting or standing in the video', 58),
#  ('what is on the wall', 57),
#  ('what is the woman doing in the video', 56),
#  ('is the person in video sitting or standing', 56),
#  ('what color does the person wear in the video', 55),
#  ('what is the gender of the person in the video', 53),
#  ('where is the woman in the video', 50),
#  ('what color is the wall', 50),
#  ('what is on the bed', 50),
#  ('is the woman in the video standing or sitting', 49),
#  ("what color are the person's clothes in the video", 46),
#  ('what is in front of the wall', 39),
#  ('what is the color of the wall in the video', 37),
#  ('is the woman in the video sitting or standing', 37),
#  ('what is the color of the clothes the man wears', 37),
#  ('what is the woman doing', 37),
#  ('is the person in the video long hair or short hair', 37),
#  ("what is in the man's hands", 36),
#  ('what is the color of the clothes in the video', 36),
#  ('what color clothes does the man wear in the video', 36),
#  ('what is the color of the clothes does the man wear', 36),
#  ('what is the person doing', 36),
#  ('where is the cup', 36),
#  ('what color clothes does the woman wear in the video', 35),
#  ('where is the woman', 35),
#  ('what is on the face of the person in the video', 33),
#  ('is the person in video standing or sitting', 33),
#  ("what is in the man's hand", 31),
#  ('is the person in the video standing or lying', 31),
#  ('is the man in the video sitting or standing', 31),
#  ('what is in the kitchen', 30),
#  ('what is on the desk', 29),
#  ('what color of clothes does the man in the video wear', 28),
#  ('is the man standing or sitting in the video', 28),
#  ('what is the color of the clothes the man wears in the video', 28),
#  ('what can you see in video', 26),
#  ('what is on the wall in the video', 26),
#  ('is the woman standing or sitting in the video', 26),
#  ('what color of the clothes does the man wear in the video', 26),
#  ('what is in the hand of the person in the video', 25),
#  ('what color is the wall in the video', 25),
#  ('what does the man in the video hold in his hand', 25),
#  ('what is in front of the window', 24),
#  ('what color clothes does person in the video wear', 24),
#  ('is the woman sitting or standing', 24),
#  ('what color of the pants does the person wear in the video', 23),
#  ("what is on the person's face in the video", 23),
#  ('what color of the clothes does the woman wear in the video', 22),
#  ('does the person have long hair or short hair', 22),
#  ('where is the computer', 21),
#  ('what color top does the person wear in the video', 21),
#  ('what is the color of the pants of the person in the video', 20),
#  ('what is the color of the clothes does the person wear in video', 20),
#  ('where is the book', 19),
#  ('where is the person', 19),
#  ('what color clothes is the person wearing in the video', 19),
#  ('what is on the ground', 19),
#  ('what color does the person wear', 19),
#  ('what is behind the person in the video', 19),
#  ('what is on the ground in the video', 18),
#  ('does the person have long hair or short hair in the video', 18),
#  ('what color does the man wear in the video', 18),
#  ('is the person standing or sitting in video', 18),
#  ('what is on the floor', 17),
#  ('what is on the table in video', 17),
#  ("what is the color of the person's trousers in video", 17),
#  ('is the woman in the video long hair or short hair', 17),
#  ('what color of the jacket does the person wear in the video', 15),
#  ('where is the computer in the video', 15),
#  ('is the woman standing or sitting in video', 15),
#  ('what is the color of the trousers does the person wear in video', 15),
#  ('what color of upper outer garment does the person in the video wear', 15),
#  ("what is the color of the person's hair in the video", 15),
#  ("what color is the person's coat in video", 15),
#  ("what is in the woman's hands", 15),
#  ('what is on the right of the person in the video', 15),
#  ('what is the woman doing in video', 15),
#  ('is the person in the video sitting or lying', 14),
#  ('where is the mirror in the video', 14),
#  ('where is the clothes', 13),
#  ("what is the color of the woman's clothes in the video", 13),
#  ('what color of clothes does the woman in the video wear', 13),
#  ('is the person in the video sitting or standing at first', 13),
#  ('what color coat does the person wear in the video', 13),
#  ('where is the car in the video', 13),
#  ('what is on the cabinet', 13),
#  ('what is the color of the door in the video', 12),
#  ('what does the person wear on head in the video', 12),
#  ('what is the color of the table in the video', 12),
#  ('where is the bottle', 12),
#  ('what is the color of the car in the video', 12),
#  ('what is the cartoon character doing in the video', 12),
#  ('what is the color of the clothes the woman wears', 12),
#  ('is the person in the video sitting or standing at the beginning', 12),
#  ('where is the mirror', 12),
#  ('what is the man doing in video', 12),
#  ('what is on the cooktop', 12),
#  ('what is the color of the clothes does the woman wear', 12),
#  ('where is the cartoon character in the video', 11),
#  ('what is on the sofa', 11),
#  ("what is in the person's hand", 11),
#  ("what is the color of the person's pants in the video", 11),
#  ('is the person standing or sitting in the beginning of the video', 11),
#  ('what color is the car in the video', 11),
#  ('where is the woman in video', 11),
#  ('is the woman sitting or standing in the video', 11),
#  ('what color is the clothes worn by the person in the video', 10),
#  ('what is the girl doing in the video', 10),
#  ('what color is the chair in the video', 10),
#  ('is the person in video sitting or standing at the beginning', 10),
#  ('how many people are there in the video', 10),
#  ("what color is the man's clothes in the video", 10),
#  ('where is the tv', 10),
#  ('what is on the washing machine', 10),
#  ("what is in the woman's hand", 10),
#  ('where is the cup in the video', 10),
#  ('what is the color of the wall in video', 10),
#  ('what does the person wear on face in the video', 10),
#  ('is the man in the video long hair or short hair', 10),
#  ('where is the laptop', 10),
#  ('what is the color of the coat does the person wear in video', 10),
#  ("what is in the person's hand in the video", 9),
#  ('what is the color of the clothes of the man in the video', 9),
#  ('what is in the cabinet', 9),
#  ('where is the mural', 9),
#  ("what is the color of the woman's clothes", 9),
#  ('what is the woman holding in the video', 9),
#  ('where is the man in video', 9),
#  ('what is in the closet', 9),
#  ("what is on the man's face in the video", 9),
#  ('is the person in the video short hair or long hair', 9),
#  ('what color is the cabinet', 8),
#  ('is the girl standing or sitting in the video', 8),
#  ('what is the color of the trousers the man wears', 8),
#  ('is the woman standing or sitting', 8),
#  ('where is the person sitting in the video', 8),
#  ('what is on the face of the man in the video', 8),
#  ('is the person sitting or lying in the video', 8),
#  ('is the man standing or sitting in video', 8),
#  ('what is the color of the sofa in the video', 8),
#  ("what is on the person's head in the video", 8),
#  ('what is in front of the door in the video', 8),
#  ('what is the color of the chair in the video', 8),
#  ('what is the color of the clothes of the woman in the video', 8),
#  ('what is the color of the cabinet in the video', 8),
#  ('what is in the corridor', 8),
#  ('what does the man in the video wear on his head', 8),
#  ('what is on the left of the person in the video', 8),
#  ('is the person in the video sitting or lying down', 8),
#  ('where is the towel', 8),
#  ('where is the pillow', 8),
#  ('how many people are in the video', 8),
#  ('what is the girl doing in video', 8),
#  ('what color is the sofa in the video', 8),
#  ('what is the color of the blanket in the video', 8),
#  ("what color is the person's hair in the video", 7),
#  ('is the girl standing or sitting in video', 7),
#  ('where is the bottle in the video', 7),
#  ('what color pants does the person in the video wear', 7),
#  ('what is the child in the video doing', 7),
#  ('what does the man wear on head in the video', 7),
#  ('where is the chair in the video', 7),
#  ('is the door in the video open or closed', 7),
#  ('where is the animal in the video', 7),
#  ('what is on the stage', 7),
#  ('what is on the stairs', 7),
#  ('what color of the coat does the person wear in the video', 7),
#  ('what is the color of the curtain in the video', 7),
#  ('what is the color of the car', 7),
#  ('what is hanging on the wall in the video', 7),
#  ('where are the clothes', 7),
#  ('what is the color of the refrigerator in the video', 7),
#  ('is the man standing or sitting at last', 7),
#  ('what is the color of the pants does the man wear', 6),
#  ('what is on the closet', 6),
#  ('what is on the shelf', 6),
#  ('what does the man in the video hold', 6),
#  ('what color is the pot in the video', 6),
#  ('what is on the hearth', 6),
#  ('where is the child in the video', 6),
#  ('what are the people doing in video', 6),
#  ('what color dress does the person wear in the video', 6),
#  ('where is the chair', 6),
#  ('is the man in the video standing or sitting at the beginning', 6),
#  ('what color pants does the man wear in the video', 6),
#  ("what is the color of the man's clothes in the video", 6),
#  ('what color top does the person in the video wear', 6),
#  ('what is on the storage rack', 6),
#  ("what color is the person's top in the video", 6),
#  ('is the boy in the video standing or sitting', 6),
#  ('what is in front of the door', 6),
#  ('what does the person in video wear on his head', 6),
#  ("what color is the person's pants in the video", 6),
#  ('what animal is in the video', 6),
#  ('what is in the person is hand in the video', 6),
#  ('what does the person in video have on their face', 6),
#  ('is the person in video in the living room or in the kitchen', 6),
#  ('what color is the refrigerator', 6),
#  ('what does the man in the video sit on', 6),
#  ('what is the person in the video', 6),
#  ("what is the color of the living room's wall", 6),
#  ('how many people appear in the video', 5),
#  ('where are the shoes in the video', 5),
#  ('what is the color of the sofa', 5),
#  ('what time is it in the video', 5),
#  ('how many people appeared in the video', 5),
#  ('what is the boy doing in the video', 5),
#  ('what color is the hat in the video', 5),
#  ('what is the color of the trousers the man wears in the video', 5),
#  ('what is in video', 5),
#  ('what color of clothes does the person in the video wear', 5),
#  ('what is at the back of the door', 5),
#  ('is the person lying or sitting in the beginning of the video', 5),
#  ('where is the pen in the video', 5),
#  ('is the man sitting or standing', 5),
#  ('where is the audience in the video', 5),
#  ('where is the boy in the video', 5),
#  ('what is the person wearing glasses in the video doing', 5),
#  ('what is the person holding in his hand in the video', 5),
#  ('where is the man sitting in the video', 5),
#  ('is the person standing or sitting at the beginning of the video', 5),
#  ('what is on the head of the person in the video', 5),
#  ("what is the color of woman's clothes in video", 5),
#  ('where are the people in video', 5),
#  ('what color coat does the person in the video wear', 5),
#  ('what does the man wear on face in the video', 5),
#  ('what is in front of the woman in the video', 5),
#  ('where are the shoes', 5),
#  ('what is the man holding in the video', 5),
#  ('is the text in the video horizontal or vertical', 5),
#  ("what is the color of person's coat in video", 5),
#  ('where is the plate in the video', 5),
#  ('where is the pillow in the video', 5),
#  ('is the cartoon character in the video sitting or standing', 5),
#  ('where is the book in the video', 5),
#  ('what is the animal in the video', 5),
#  ('what is on the cabinet in the video', 5),
#  ('what is the man wearing on the head in the video', 5),
#  ("what is the color of man's clothes in video", 5),
#  ('what is the man in the video', 5),
#  ('where is the girl in the video', 5),
#  ('what is in the bathroom', 5),
#  ("what is on the person's hand in the video", 5),
#  ('where is the carton', 5),
#  ('is the television turned on or off in the video', 5),
#  ('how many people have appeared in the video', 5),
#  ('what color of the clothes does the person wear at the beginning of the video',
#   5),
#  ('are the people standing or sitting in video', 5),
#  ('what is on the wall in video', 5),
#  ('what sports have appeared in video', 5),
#  ('what is on the countertop', 5),
#  ('what does the person open in the video', 5),
#  ('what color is the door in the video', 5),
#  ('what does the person in the video hold', 5),
#  ('is the person sitting or standing at the beginning of the video', 5),
#  ('what is in the toilet', 5),
#  ('is the text in the video english or chinese', 4),
#  ('is the text in the video written in english or chinese', 4),
#  ('where is the floor lamp in the video', 4),
#  ('what is the man in video doing', 4),
#  ('what color is the door', 4),
#  ('what is the first person in the video doing', 4),
#  ('is the cartoon character sitting or standing in the video', 4),
#  ('where are the books in the video', 4),
#  ('what is the person wearing black clothes doing in the video', 4),
#  ("what color is the woman'hair in video", 4),
#  ('what is the person wearing on his head in the video', 4),
#  ('what is the person in white doing', 4),
#  ('what is on the door', 4),
#  ('what color shoes does the person wear in the video', 4),
#  ('what is the person in video holding in his hands', 4),
#  ('what color of the dress does the person wear in the video', 4),
#  ('what is the person holding in the video', 4),
#  ('what does the woman in the video hold in her hand', 4),
#  ('what is the color of the floor in the video', 4),
#  ('what does the woman wear on head in the video', 4),
#  ('what is in the washing room', 4),
#  ('where is the toy in the video', 4),
#  ("what color is the girl's hair in the video", 4),
#  ('what does the woman in the video hold', 4),
#  ('what is the color of the cat in the video', 4),
#  ('what color is the woman is hair in the video', 4),
#  ('what color hat does the man wear in the video', 4),
#  ("what is on the woman's face in the video", 4),
#  ('where is the guitar', 4),
#  ('where is the water glass in the video', 4),
#  ('what color is the background in video', 4),
#  ('what color of the pants does the man wear in the video', 4),
#  ('what does the person hold in hand in the video', 4),
#  ('what is the person in the video holding', 4),
#  ('what is in front of the person in video', 4),
#  ('where is the photo', 4),
#  ('is the audience standing or sitting', 4),
#  ('where are the people in the video', 4),
#  ('is the girl in the video standing or sitting', 4),
#  ('what does the person in video wear on his face', 4),
#  ('what is the person in the video sitting on', 4),
#  ("what is the color of woman's coat in video", 4),
#  ('what is on the refrigerator', 4),
#  ('what does the person turn on in the video', 4),
#  ('what is in the car', 4),
#  ("what is the color of person's clothes in video", 4),
#  ('what color is the floor in the video', 4),
#  ('what is the girl in the video doing', 4),
#  ('what is wearing on the head of the person in the video', 4),
#  ('what does the woman in the video wear on her face', 4),
#  ('what is the person in stripe shirt doing in the video', 4),
#  ('where is the table in the video', 4),
#  ('where is the television', 4),
#  ('where is the switch', 4),
#  ('what is on the bed in video', 4),
#  ('what is on the right of the door', 4),
#  ('where is the paper box', 4),
#  ('is the person in video a man or a woman', 4),
#  ('where is the person in white', 4),
#  ('what is the child doing in the video', 4),
#  ('what does the person in video have in his hand', 4),
#  ('what color top does the person wearing glasses in the video wear', 4),
#  ('is the man in video sitting or standing', 4),
#  ('what color of the pants does the woman wear in the video', 4),
#  ('is the person holding the broom sitting or standing', 4),
#  ('where is the box in the video', 4),
#  ('what color is the carpet in the video', 4),
#  ('what is the boy in the video doing', 4),
#  ('is the light turned on or off in the video', 4),
#  ('what is on the stool', 4),
#  ('what is on the table in the kitchen', 4),
#  ('where is the person standing in the video', 4),
#  ('what color is the table in the video', 4),
#  ('is the person in the video standing or squatting', 4),
#  ('is the person singing in the video sitting or standing', 4),
#  ('what is the color of the refrigerator', 4),
#  ('where is the refrigerator in the video', 4),
#  ('where is the blanket in the video', 4),
#  ('what is the animal doing in the video', 4),
#  ('what is behind the door', 4),
#  ("what color is the woman's hair in the video", 4),
#  ('what is in the hands of the person in the video', 4),
#  ('what is the kid doing in the video', 4),
#  ('what is the person in white doing in the video', 4),
#  ('is the person wearing glasses in the video standing or sitting', 3),
#  ('where is the audience', 3),
#  ('where is the sofa in the video', 3),
#  ('what color top does the woman wear in the video', 3),
#  ('where is the car', 3),
#  ('where is the tv in the video', 3),
#  ('where is the table lamp', 3),
#  ('what does the person hold in hands in the video', 3),
#  ('what color is the dog in the video', 3),
#  ('what is in the refrigerator', 3),
#  ('is the person in red sitting or standing in the video', 3),
#  ('what is the color of the sheets in the video', 3),
#  ('what does the person wear on his head', 3),
#  ('where is the water bottle in the video', 3),
#  ('where are the two people in video', 3),
#  ('is the tv on or off', 3),
#  ('is the person in black sitting or standing in the video', 3),
#  ('what is on the floor in the video', 3),
#  ('what color is the leaf in the video', 3),
#  ('what does the man in the video wear on his face', 3),
#  ('what is the person wearing the hat doing in the video', 3),
#  ('what does the girl in video wear on her head', 3),
#  ('what is behind the chair', 3),
#  ('what is the color of the computer', 3),
#  ('how many people are in video', 3),
#  ('what is the color of the coat the man wears in the video', 3),
#  ('what color is the background wall in the video', 3),
#  ('what is the person in white clothes doing', 3),
#  ('what does the girl wear on head in the video', 3),
#  ('is the person wearing white clothes in the video sitting or standing', 3),
#  ('where is the computer in video', 3),
#  ('what color of the clothes does the boy wear in the video', 3),
#  ('what is the color of the hat of the person in the video', 3),
#  ('what does the person in video hold', 3),
#  ('what is in front of the table', 3),
#  ('what is the color of the broom in the video', 3),
#  ('what is on the lawn', 3),
#  ("what is on the man's head in the video", 3),
#  ('what happens in video', 3),
#  ('what does the woman in video wear on her face', 3),
#  ('what color of the t-shirt does the person wear in the video', 3),
#  ("what color is the man's hair in the video", 3),
#  ('is the person wearing glasses standing or sitting in the video', 3),
#  ('what is the athlete in the video doing', 3),
#  ('what is the adult doing in the video', 3),
#  ('is the person in glasses sitting or standing', 3),
#  ('is the animal appearing in the video a cat or a dog', 3),
#  ('where is the mirror placed in the video', 3),
#  ('what is the person wearing black pants doing', 3),
#  ('what color is the table', 3),
#  ('what color is the refrigerator in the video', 3),
#  ('what is the animal that appears in the video', 3),
#  ('is the person sitting or standing at the beginning in the video', 3),
#  ('what is the color of the clothes of the person sitting in the video', 3),
#  ('does the woman have long hair or short hair in the video', 3),
#  ('what color is the dress of the person in the video', 3),
#  ('is the person in video have short hair or long hair', 3),
#  ('what is the person with glasses doing in the video', 3),
#  ('what is the color of the sheet in the video', 3),
#  ('what is behind the refrigerator', 3),
#  ('does the woman in the video have long hair or short hair', 3),
#  ('what does the man in video wear on his head', 3),
#  ('is the boy standing or sitting in the video', 3),
#  ('what is behind the person', 3),
#  ('what does the man wear around his neck in the video', 3),
#  ("what color are the woman's clothes in the video", 3),
#  ('what color is the horse in the video', 3),
#  ('what is on the glass table', 3),
#  ('is the woman in video sitting or standing', 3),
#  ('is the person in the video man or woman', 3),
#  ('what is the background color in the video', 3),
#  ('what color is the chair', 3),
#  ('is the text in the video chinese or english', 3),
#  ('what is in front of the man', 3),
#  ('where is the person at the beginning of the video', 3),
#  ('what is the wall full of in the video', 3),
#  ('what is the person doing in the first video', 3),
#  ('is the person standing or lying in the video', 3),
#  ('what is the man wearing on the neck in the video', 3),
#  ('what color of the clothes does the girl wear in the video', 3),
#  ('what are the men in the video doing', 3),
#  ('what is on video', 3),
#  ('where is the person in red', 3),
#  ('what is hanging on the wall', 3),
#  ('what is the color of the table', 3),
#  ('what is on the tea table', 3),
#  ('where is the phone in the video', 3),
#  ('what is the person wearing glasses doing in the video', 3),
#  ('what color is the sheet', 3),
#  ('what is the game character doing in the video', 3),
#  ('what color is the cup', 3),
#  ('what is behind the people in the video', 3),
#  ('what is in the room in the video', 3),
#  ('what is the color of the computer in the video', 3),
#  ('what is the person wearing pink in the video doing', 3),
#  ('is the man in the video straight or curly', 3),
#  ('what is the color of the washing machine', 3),
#  ('what is the person in blue doing in the video', 3),
#  ('what color dress does the girl wear in the video', 3),
#  ("what is in the woman's hand in the video", 3),
#  ('is the window in the video open or closed', 3),
#  ('where does the man in the video sit', 3),
#  ('what is in the bedroom', 3),
#  ('what is in front of the chair', 3),
#  ('what color is the desk in the video', 3),
#  ('what color is the light in the video', 3),
#  ('what is the baby doing in the video', 3),
#  ('what color is the sky in video', 3),
#  ('are people standing or sitting in the video', 3),
#  ('what is on the bed in the video', 3),
#  ('is the person in black sitting or standing', 3),
#  ('what does the man in video wear on his face', 3),
#  ('what does the person in the video hold in the hands', 3),
#  ('where is the table', 3),
#  ('is the person wearing black pants standing or sitting', 3),
#  ('what color is the chair in video', 3),
#  ('what color is the cabinet in the video', 3),
#  ('is the child in the video sitting or standing', 3),
#  ('what is on the chair', 3),
#  ('what is in front of the sofa', 3),
#  ('where is the person in the video at the beginning', 3),
#  ('what is worn on the hand of the person in the video', 3),
#  ('what is the person wearing the video', 3),
#  ('what is the woman in black doing', 3),
#  ('where is the painting', 3),
#  ('what is on the pool table', 3),
#  ('what is the color of the towel in the video', 3),
#  ('what color clothes is the woman wearing in the video', 3),
#  ('what color hair does the person have in the video', 3),
#  ('what are the hands doing in the video', 3),
#  ('is the man in purple standing or sitting', 3),
#  ("what is the color of the child's clothes in the video", 3),
#  ('where is the laundry detergent', 3),
#  ('what is the person sitting in the video doing', 3),
#  ('what color does the boy wear in the video', 3),
#  ('what is the color of the dress does the woman wear', 3),
#  ('is the person wearing a hat in the video long hair or short hair', 3),
#  ('what does the man hold in hands in the video', 3),
#  ('is the man standing or sitting at the beginning', 3),
#  ('what is at the back of the person in the video', 3),
#  ('is the woman in the video straight or curly', 3),
#  ('what is the occupation of the person in the video', 3),
#  ('what is the color of the pillow in the video', 3),
#  ('where is the cat in the video', 3),
#  ('is the person in the video sitting or lying at first', 3),
#  ('what is in front of the mirror', 3),
#  ('what is on the person in the video', 3),
#  ('what color is the subtitle in the video', 3),
#  ('is the person in pink sitting or standing in the video', 3),
#  ('what is the color of the cup', 3),
#  ('what is the host in the video doing', 2),
#  ('what is the color of the chair', 2),
#  ('where is the cream in the video', 2),
#  ("what is the color of the man's clothes at the beginning of the video", 2),
#  ('what color does the man in the video wear', 2),
#  ('what is on the table of the kitchen', 2),
#  ('what color is the grass in the video', 2),
#  ('what is on the road in the video', 2),
#  ('where is the man lying on in the video', 2),
#  ('where is the washing machine', 2),
#  ('is the person wearing the hat in the video sitting or standing', 2),
#  ("what is on the girl's head", 2),
#  ('is the person in the video sitting or standing while eating', 2),
#  ('what is on the stand', 2),
#  ("what is the color of women's clothes in the video", 2),
#  ('what is the color of the plastic bucket in the video', 2),
#  ('what is the background in video', 2),
#  ('what is the dog doing in the video', 2),
#  ('what is the plane doing in the video', 2),
#  ('where is switch', 2),
#  ('what is in the box', 2),
#  ('what color is the phone in the video', 2),
#  ("what is on the woman's ear", 2),
#  ('is the person wearing black clothes in the video standing or sitting', 2),
#  ('is the person in the video sitting or squatting', 2),
#  ('what does the woman wear on her face in video', 2),
#  ('is the boy standing or sitting in video', 2),
#  ('is the host in the video standing or sitting', 2),
#  ('what is the color of the baby carriage in the video', 2),
#  ('what is the person standing in the video doing', 2),
#  ('what is the person doing at the beginning of the video', 2),
#  ('what kind of the jacket does the person wear in the video', 2),
#  ('where is man in video', 2),
#  ('where is the towel in the video', 2),
#  ('what is the athlete doing in the video', 2),
#  ('what is the woman with short hair doing', 2),
#  ('what color are the pants of the person in the video', 2),
#  ('is the person applauding in the video sitting or standing', 2),
#  ('what is on the left of the door', 2),
#  ('where is the beverage', 2),
#  ('what is the person in red doing in the video', 2),
#  ('what is on the commodity shelf', 2),
#  ('is the person lying or sitting in the video', 2),
#  ('what is the person in white doing in video', 2),
#  ("what is the color of the person's shoes in the video", 2),
#  ('is the person wearing white clothes in the video standing or sitting', 2),
#  ('where is the game character in the video', 2),
#  ('what does the woman wear around her neck in the video', 2),
#  ('what does the person have on his left hand', 2),
#  ('what is on the chopping board', 2),
#  ('what are the animals in video', 2),
#  ('is the person with glasses in the video standing or sitting', 2),
#  ('where is the bolster', 2),
#  ('what is the person in red doing', 2),
#  ('what is on the sink', 2),
#  ('what is the color of the light in the video', 2),
#  ('where is the scarf', 2),
#  ("what is in the man's hand in the video", 2),
#  ('what is the monster doing in the video', 2),
#  ('where is the horse in the video', 2),
#  ('is the person with glasses in video standing or sitting', 2),
#  ('where is the man in black pants', 2),
#  ('what is the color of the closet', 2),
#  ('is the person wearing hat sitting or standing', 2),
#  ('what is the hand doing in the video', 2),
#  ('where is the room in the video', 2),
#  ('where is the backpack in the video', 2),
#  ('is the plane flying or stopping', 2),
#  ('where does the man in the video put the book', 2),
#  ('what color is the plate in the video', 2),
#  ("what color is the girl'hair in video", 2),
#  ('what is in front of the cabinet', 2),
#  ('what is in front of the child in the video', 2),
#  ('how many cars are there in the video', 2),
#  ('what color is the wall space in video', 2),
#  ('does the woman in video have straight hair or curly hair', 2),
#  ('what is shown on the screen in the video', 2),
#  ('is the person sitting or standing while eating in the video', 2),
#  ('what is on the sofa in the video', 2),
#  ('what color is english in the video', 2),
#  ('where is the monster in the video', 2),
#  ('where is the box', 2),
#  ('what is on the window sill', 2),
#  ('where does the person sit in the video', 2),
#  ('was the man standing or sitting in the end', 2),
#  ('where is the orange', 2),
#  ('what color is the cat in the video', 2),
#  ('where is the boy in video', 2),
#  ('where is the television in the video', 2),
#  ('what is the men doing in video', 2),
#  ("what is the color of the person's hair", 2),
#  ('where is the goblet', 2),
#  ('where is the coat', 2),
#  ('where is the refrigerator', 2),
#  ('where is the globe in the video', 2),
#  ('where is the person holding the broom', 2),
#  ('what color is the car', 2),
#  ('what is the princess in the video doing', 2),
#  ('what is the color of the shoes in the video', 2),
#  ('is the character in the video standing or sitting', 2),
#  ('what color hair does the woman have in the video', 2),
#  ('what color shoes does the woman wear in the video', 2),
#  ('what is the color of the boat in the video', 2),
#  ('what is on the couch', 2),
#  ('what is the color of the tree in the video', 2),
#  ('is the lamp on or off', 2),
#  ("what is the color of women's clothes in video", 2),
#  ('what did the person in the video open', 2),
#  ('what is the color of the computer desktop in the video', 2),
#  ('is the man wearing a pair of pants or a skirt', 2),
#  ('where is the plant in the video', 2),
#  ('what is the color of the bag in the video', 2),
#  ('what color is the woman wearing the jacket', 2),
#  ('where is the frame', 2),
#  ('what color is the candle in the video', 2),
#  ('is the picture in video stationary or moving', 2),
#  ('what is in the hand of the girl in the video', 2),
#  ('what is the color of the hat in the video', 2),
#  ('what does the person have in his hand', 2),
#  ('is the woman sitting or standing in video', 2),
#  ('what does the man carry on his back in the video', 2),
#  ('what is the person in blue doing', 2),
#  ('what is the last thing in the video', 2),
#  ('what color clothes is the baby wearing in the video', 2),
#  ('is the person wearing blue clothes standing or sitting', 2),
#  ('where is the medicine bottle', 2),
#  ('what is the color of the pillows in the video', 2),
#  ('what are the athletes in the video doing', 2),
#  ('what color is the blanket in video', 2),
#  ('what color of the clothes does the cartoon character wear in the video', 2),
#  ('what is the color of the hair of the person in the video', 2),
#  ('what color is the font in the video', 2),
#  ('what is on the vacant lot', 2),
#  ('what does the person in pink doing in the video', 2),
#  ('what is behind the woman', 2),
#  ('what is playing in video', 2),
#  ('where are the two people in the video', 2),
#  ('what is the person wearing white clothes in the video doing', 2),
#  ('where is the model in the video', 2),
#  ('what does the woman in the video hold in her right hand', 2),
#  ('where is the number plate in the video', 2),
#  ('what is the color of the clothes does the person wear while eating in video',
#   2),
#  ('what is the color of the hearth', 2),
#  ('is the character standing or sitting in video', 2),
#  ('where is the electric fan in the video', 2),
#  ('does the person wear pants or shorts', 2),
#  ('what is the girl in black in video holding in her hand', 2),
#  ('is the boy standing or sitting', 2),
#  ('is the man standing or sitting in the end', 2),
#  ('what color is the bowl in the video', 2),
#  ('is the person lying or seated in the video', 2),
#  ('is the person on the stage standing or sitting in the video', 2),
#  ('what is on the wardrobe', 2),
#  ('what color is the floor', 2),
#  ('what is man doing in video', 2),
#  ('what color is the basin in video', 2),
#  ('what color is the car in video', 2),
#  ('what color clothes do people in the video wear', 2),
#  ('does the man in the video have long or short hair', 2),
#  ('what is the boy doing', 2),
#  ('is the animal in the video sitting or standing', 2),
#  ('what is the man with glasses doing', 2),
#  ('which hand of the person in the video holds the cup', 2),
#  ('are the audience standing or sitting', 2),
#  ('is the woman standing or lying in the video', 2),
#  ('what is in the hand of the woman in the video', 2),
#  ('what color is the background in the video', 2),
#  ('what color is the roof in the video', 2),
#  ('what is the sport in the video', 2),
#  ('is the person sitting or squatting', 2),
#  ('does the person have short hair or long hair in the video', 2),
#  ('what color is the fence in the video', 2),
#  ('what is the picture in video', 2),
#  ('where is the boy', 2),
#  ('what is the color of the piano in the video', 2),
#  ("what is the color of girl's clothes in video", 2),
#  ('what color is the bowl', 2),
#  ('how many kids are there in the video', 2),
#  ('where is the vase', 2),
#  ('how many person showed in the video', 2),
#  ('what is the person wearing a hat doing in the video', 2),
#  ('what is the person playing in the video', 2),
#  ('what does the man wear on his wrist in the video', 2),
#  ('where are the cups in the video', 2),
#  ('is the cartoon character standing or sitting in video', 2),
#  ("what color is the woman's clothes in the video", 2),
#  ('where is the ball in the video', 2),
#  ('where is the phone', 2),
#  ('what is the color of the pants does the boy in white top wear', 2),
#  ('is the man in the video standing or sitting at the end', 2),
#  ('what color of clothes does the man squatting in the video wear', 2),
#  ('what is on the roof in the video', 2),
#  ('what color clothes does the man in the video wear', 2),
#  ('where is the person in the second video', 2),
#  ('where is the person at last in the video', 2),
#  ('is the person in the video standing or lying down', 2),
#  ('what color clothes does the cartoon character wear in the video', 2),
#  ('where is the lamp in video', 2),
#  ('what is the color of the pan in the video', 2),
#  ('is the game character in the video standing or sitting', 2),
#  ('what is on the chair in the video', 2),
#  ('where is the bag in the video', 2),
#  ('is the referee in the video standing or sitting', 2),
#  ('where is the broom in the video', 2),
#  ('in which hand does the person hold the cellphone in the video', 2),
#  ('what color of the clothes does the child wear in the video', 2),
#  ('what is the computer doing in the video', 2),
#  ('what is the color of the hair of the person in green in the video', 2),
#  ('what is the color of the horse in the video', 2),
#  ('which hand of the person in the video holds the food', 2),
#  ('what is the color of the bolster in the video', 2),
#  ('are the two men in the video standing or sitting', 2),
#  ('what is the color of the words in the video', 2),
#  ("what color is the person's hair", 2),
#  ("what is the color of the women's clothes in the video", 2),
#  ('is the woman in the video lying down or sitting', 2),
#  ('what color is the tire in the video', 2),
#  ('where is the clothes in the video', 2),
#  ('what color is the ground in the video', 2),
#  ('what color is the number in the video', 2),
#  ('what does the person have', 2),
#  ('what is on the left side of the chair', 2),
#  ('what is the person doing with his hands in the video', 2),
#  ('is the person sitting or standing on the stage', 2),
#  ('where is the food', 2),
#  ('what is the color of the cabinet', 2),
#  ('is woman in video standing or sitting', 2),
#  ('is the woman in red sitting or standing', 2),
#  ('what is the color of the light', 2),
#  ('where is the cup in video', 2),
#  ('what is the color of the stairs in the video', 2),
#  ('which hand of the man in video holds the script', 2),
#  ('what is the little boy in the video doing', 2),
#  ('what is in the right hand of the person in the video', 2),
#  ('what is in the dishes', 2),
#  ('is the child sitting or standing in the video', 2),
#  ("what is the color of the person's pants in video", 2),
#  ('what is the color of the hat', 2),
#  ('what is the man in the video holding in his arms', 2),
#  ('what is in the hand of the man in the video', 2),
#  ('is the singing person standing or sitting in the video', 2),
#  ('what is person in video doing', 2),
#  ('what color is the steering wheel in the video', 2),
#  ('what is on the beach', 2),
#  ('is the woman in white standing or sitting in video', 2),
#  ('where is the pan in the video', 2),
#  ('what is the color of the hair of the woman in the video', 2),
#  ('is the last person in the video standing or sitting', 2),
#  ("what is the color of the woman's hair", 2),
#  ('what is in the bag', 2),
#  ('where does the person lie', 2),
#  ('what appeared in the video', 2),
#  ('what color clothes does the person in the first scene wear', 2),
#  ('where is the doll in the video', 2),
#  ('is the curtain in the video open or closed', 2),
#  ('what is the person wearing glasses doing', 2),
#  ('what is the white thing in the video', 2),
#  ('what color is the plant in the video', 2),
#  ('what is behind the person standing in video', 2),
#  ('what is the color of the background in the video', 2),
#  ('what is on the cabinet in video', 2),
#  ('what is the color of the clothes of the person with glasses in the video',
#   2),
#  ('what is in the fridge in the video', 2),
#  ("what color is the chef's hat in the video", 2),
#  ('is the person sitting or standing while drinking water in the video', 2),
#  ('what color are the shoes', 2),
#  ('what color is the cover in the video', 2),
#  ('is the person wearing white clothes in the video long hair or short hair',
#   2),
#  ('what is the person in video doing after getting up', 2),
#  ('where is the clock', 2),
#  ('what is the person in green clothes doing', 2),
#  ('how many game figures are in the video', 2),
#  ('what is on the table in front of the man', 2),
#  ('is the lamp opening or closed in the video', 2),
#  ('what color top does the little girl wear in the video', 2),
#  ('in which room is the man in the video', 2),
#  ('what color of skirt does the woman in the video wear', 2),
#  ('what is the color of the balloon in the video', 2),
#  ('where is the decorative painting in the video', 2),
#  ('what does the person in the video doing', 2),
#  ('what color of clothes does the boy in the video wear', 2),
#  ('what color is the tie in the video', 2),
#  ('what vehicle is in the video', 2),
#  ('what is the woman wearing on the head in the video', 2),
#  ('what is on the refrigerator in the video', 2),
#  ('does the singing person have long hair or short hair in the video', 2),
#  ('what is the color of the flower in the video', 2),
#  ('what is the shape of the paper in the video', 2),
#  ('is the singing person sitting or standing in the video', 2),
#  ('is the person in the video a boy or a girl', 2),
#  ('what is the alphabet at the left corner of the video', 2),
#  ('what is the person with glasses doing', 2),
#  ('what color shorts does the man wear in the video', 2),
#  ('what kind of transportation does video have', 2),
#  ('what color is the curtain in the video', 2),
#  ('what is on the left of the wall', 2),
#  ('where is the man at the beginning of the video', 2),
#  ('what color is the nail in the video', 2),
#  ('is the cartoon character in the video standing or sitting', 2),
#  ('where is the adult in the video', 2),
#  ('what color is the seat in the video', 2),
#  ('does the person in video have a beard on their face', 2),
#  ('is the person in the video lying or standing', 2),
#  ('where is the hanger in the video', 2),
#  ('what is on the back of the person in the video', 2),
#  ('where is the gun in the video', 2),
#  ('is the person with glasses in the video sitting or standing', 2),
#  ('where is the person wearing hat', 2),
#  ('what is the color of the pants of the person with glasses', 2),
#  ('what are the women doing in video', 2),
#  ('what color of clothes does the girl in the video wear', 2),
#  ('is the man in the video sitting or squatting', 2),
#  ('what color is the cartoon character in the video', 2),
#  ('what is in front of the man in the video', 2),
#  ('what is the man wearing', 2),
#  ('is the person in white standing or sitting', 2),
#  ('what does the person hold in the video', 2),
#  ('where is the poster', 2),
#  ('where does the woman in the video put her clothes', 2),
#  ('is the door open or closed in the video', 2),
#  ('what is the horse doing in video', 2),
#  ('where is the vase in the video', 2),
#  ('what color is the laptop in the video', 2),
#  ('is the person wearing black clothes in the video long hair or short hair',
#   2),
#  ('what can be seen in video', 2),
#  ('is the person in white in the video standing or sitting', 2),
#  ('what is on the front of the door', 2),
#  ('what is the brand of the car', 2),
#  ('what is the color of the pants of the man in the video', 2),
#  ('what is the cat doing in the video', 2),
#  ('what is the color of the washing machine in the video', 2),
#  ('what is in the basin in the video', 2),
#  ('where is the mirror in the video hanging', 2),
#  ('what is the person in green doing in the video', 2),
#  ('where is the kettle', 2),
#  ('is the phone in the video horizontal or vertical', 2),
#  ('where is the drink', 2),
#  ('what color is the english in the video', 2),
#  ('is the person wearing glasses', 2),
#  ('what is the person pushing in the video', 2),
#  ('is the person with glasses standing or sitting in video', 2),
#  ('what is the color of the hair of the person in blue', 2),
#  ('where is the person singing in the video', 2),
#  ('where is the fish in the video', 2),
#  ('where is the snake in the video', 2),
#  ('what is the color of the bottle', 2),
#  ('what color is the pants worn by the person in the video', 2),
#  ('what color pants does the woman wear in the video', 2),
#  ('where is the cabinet', 2),
#  ('what color is the microphone in the video', 2),
#  ('is the person standing or sitting on the stage in the video', 2),
#  ('what is in the hallway', 2),
#  ('is the person in the video walking or sitting', 2),
#  ('what is the man in blue doing', 2),
#  ('what is the person with red hair doing', 2),
#  ("what is the color of the woman's hair in the video", 2),
#  ('where does the man in the video put the clothes', 2),
#  ('where is the remote control', 2),
#  ('is the woman in video standing or sitting', 2),
#  ("what is the color of the man's pants in the video", 2),
#  ('what is the color of the curtain', 2),
#  ('is the person in white standing or sitting in the video', 2),
#  ('what color t-shirt does the person wear in the video', 2),
#  ('where is the picture frame in the video', 2),
#  ('where is sofa in video', 2),
#  ('what is the color of the stool', 2),
#  ('what is the adult in the video doing', 2),
#  ('what does the person wear in the video', 2),
#  ('what is the old man in the video doing', 2),
#  ('what color is the dress worn by the woman in the video', 2),
#  ('what is the women doing in the video', 2),
#  ('is the person in pink in the video sitting or standing', 2),
#  ('what color is the glove in the video', 2),
#  ('what color of pants does the man in the video wear', 2),
#  ('what are the men doing in video', 2),
#  ('what does the person drink', 2),
#  ('where is the calendar', 2),
#  ('what does the girl hold in hand in the video', 2),
#  ('what is hanging on the window in the video', 2),
#  ('what color is the sofa', 2),
#  ('is the woman in the video lying or sitting', 2),
#  ('what is the green stuff in video', 2),
#  ('what is the color of the clothes of the adult in the video', 2),
#  ('where does the person enter in the video', 2),
#  ('is the referee in the video sitting or standing', 2),
#  ('what does the person have in the video', 2),
#  ('where is the machine in the video', 2),
#  ('what is the person in black doing', 2),
#  ("what is the color of the man's hair", 2),
#  ('what is on the door of the refrigerator', 2),
#  ('what is the color of the blanket in video', 2),
#  ('is the person in the video a man or a woman', 2),
#  ('what is the color of the pot in the video', 2),
#  ('what color are the numbers in video', 2),
#  ('what is the person in orange doing in video', 2),
#  ('what is on the shelf in video', 2),
#  ('what is the person standing in video doing', 2),
#  ('is the man with white hair in the video standing or sitting', 2),
#  ('where is the bowl in the video', 2),
#  ('what does the person in the video wear', 2),
#  ('where is the person in the first video', 2),
#  ('what is the animal in video', 2),
#  ('what is on the sofa in video', 2),
#  ('is the person wearing the trousers or shorts in the video', 2),
#  ('is the cursor in video moving', 2),
#  ('what is in front of the adult in the video', 2),
#  ('what color clothes does the person with white hair wear in the video', 2),
#  ('what is at the back of the chair', 2),
#  ('what color is the sky in the video', 2),
#  ('where is the person in blue', 1),
#  ('what does the man in the video shoot', 1),
#  ('is the person in video sitting or standing before putting the computer on',
#   1),
#  ('is the woman wearing white clothes in the video long hair or short hair',
#   1),
#  ("what color is the judge's clothes in the video", 1),
#  ('is the woman in video standing or lying down', 1),
#  ('where is the person in black clothes', 1),
#  ('was the man in the video sitting or standing at the beginning', 1),
#  ('what is the person wearing red in the video doing', 1),
#  ('what color pants does the people wearing a cowboy cap wear in video', 1),
#  ('is the alpaca standing or sitting in video', 1),
#  ('what is the mouse doing in the video', 1),
#  ('what is the color of th boat in the video', 1),
#  ('what is the color of the backpack in the video', 1),
#  ("what is in the man's pocket", 1),
#  ('what is the color of the pants does the man in yellow top wear', 1),
#  ('what color is the gun in the video', 1),
#  ('what are the children in the video doing', 1),
#  ('what does the grandmother hold in hands in the video', 1),
#  ('is the person a woman or a man in the video', 1),
#  ('what is in the mouth of the person in the video', 1),
#  ('why throwing smoke shell in the video', 1),
#  ('what color does the woman wear in the video', 1),
#  ('is the person under the spotlight standing or sitting', 1),
#  ('is the person wearing trousers or shorts', 1),
#  ('what was girl doing at beginning of video', 1),
#  ('what is the color of the clothes on the bed in the video', 1),
#  ('what image is played in the video', 1),
#  ('what are the alpacas doing in video', 1),
#  ('what color of the clothes does the girl wear at the beginning of the video',
#   1),
#  ('where is the animated scene in the video', 1),
#  ('is the person sitting in the video sitting or standing', 1),
#  ('what is the person with a hat doing in the video', 1),
#  ('what does the man in the video finally pick up', 1),
#  ('what color pants does the standing man wear in the video', 1),
#  ('what color is the pot in video', 1),
#  ('what is the gender of the person wearing wings in the video', 1),
#  ('is the man blinking or closing his eyes in the video', 1),
#  ('where is the person driving car in the video', 1),
#  ('is the person in the video sitting or walking', 1),
#  ('what color is the washer in the video', 1),
#  ('is the weather sunny or cloudy', 1),
#  ('what does the person have on his body', 1),
#  ('where is the cartoon in the video played', 1),
#  ('what is the person kicking in the video', 1),
#  ('what is the color of the socks does the man wear', 1),
#  ('what is the weapon used to do in the video', 1),
#  ('how many paper are folded in the video', 1),
#  ('what color is the fire in the video', 1),
#  ('what is the person in the water in video doing', 1),
#  ('what is at the back of the person in video', 1),
#  ('what is at the right side of the sofa', 1),
#  ('where did the person in video put the medicine', 1),
#  ('what is the shape of the tape in the video', 1),
#  ('what is the person on the square in the video doing', 1),
#  ('what is the woman wearing sunglasses doing in the video', 1),
#  ('is the warship 3d or real in the video', 1),
#  ('what is the man squatting in the video doing', 1),
#  ('what is the person at the beginning of the video doing', 1),
#  ('is the boy in red standing or sitting', 1),
#  ('is the person in the video sitting or standing after entering into the house',
#   1),
#  ('what is the animal in the picture', 1),
#  ('what happened after the person in the video kicked the ball', 1),
#  ('is the person in the video sitting or lying while reading a book', 1),
#  ('what is the woman with bag in her hand doing in video', 1),
#  ('what is in front of the stairs', 1),
#  ('what is the color of the car for the person in red', 1),
#  ...]

# %%
for question,times in frequency_question.items():
    #print(answer)
    num_word=0
    words = question.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word<=3:
        print(question,times)
# Out:
# where is switch 2
# where is poker 1
# at what place 1
# what happened 1
# where is magnet 1

# %%
num_word_dict={}
for answer,times in frequency_answer.items():
    #print(answer)
    num_word=0
    words = answer.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times
# Out:
# taking towel to wipe cup 1
# stepping in front of desk 1
# pouring water to another cup 3
# five hundred and twenty eight 1
# right hand to do operation 1
# playing with rubik is cube 3
# right hand pointing at sky 3
# looking at outside of window 1
# in front of rear tire 1
# pouring it into washing machine 1
# closing door of washing machine 1
# putting them in another bowl 1
# year two zero zero eight 1
# taking part in variety competition 1
# year two thousand and eight 1
# opening door of washing machine 1
# putting cup on right hand 1
# looking at things in hands 1
# taking things out from refrigerator 3
# getting up to go out 1
# taking apart of baby carriage 1
# putting clothes on his body 1

# %%
num_word_dict
# Out:
# {1: 32978, 2: 14291, 3: 2319, 4: 248, 5: 30, 6: 8, 8: 1}

# %%
num_word_dict={}
for answer,times in frequency_question.items():
    #print(answer)
    num_word=0
    words = answer.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times
# Out:
# where is the washing machine 2
# what is the car doing 1
# what is on the closet 6
# what is on the stand 2
# what is on the window 1
# where is the red 5 1
# what is in the box 2
# where is the table lamp 3
# what is the yacht doing 1
# what color is the door 4
# what are on the bed 1
# what is on the shelf 6
# what is in the refrigerator 3
# what color is the cabinet 8
# what is the machine doing 1
# where is man in video 2
# what is the man doing 106
# what color is the brand 1
# what is on the countryard 1
# what is on the stone 1
# how many brands are there 1
# where is the rice cooker 1
# what color is the sword 1
# how many objects are there 1
# what is on the floor 17
# what is in the tvbench 1
# what is on the column 1
# is the woman wear earring 1
# what is on the sink 2
# what is on the door 4
# what is on the commode 1
# what is behind the chair 3
# how many hools are made 1
# what is the living room 1
# what is on the bedside 1
# what is in the cabinet 9
# what is in the plate 1
# what is on the corridor 1
# what is on the staircase 1
# what color is the clock 1
# what is the person eating 1
# what is behind the car 1
# what is on the sofa 11
# what is the second brand 1
# what color is the grass 1
# what is in the bed 1
# what is in the bar 1
# where are those two people 1
# what color is the car 2
# what is on the couch 2
# what is on the ceiling 1
# what are on the table 1
# where is the tissue box 1
# what color is the computer 1
# what is on the lawn 3
# what is on the washbasin 1
# where is the cartoon character 1
# what color is the crayon 1
# what is behind the reporter 1
# what is on the pool 1
# where is the person dancing 1
# what is introduced in video 1
# where is the medicine bottle 2
# where is the green planting 1
# where is person in video 1
# what is on the table-board 1
# what is behind the woman 2
# what color is the television 1
# what is playing in video 2
# what are the audience doing 1
# what is on the hearth 6
# what is on the wall 57
# what is on the stage 7
# what are three aliens doing 1
# what is on the wardrobe 2
# what is on the screen 1
# what is on the stairs 7
# what color is the floor 2
# where does the person enter 1
# what does the person wear 1
# what is on the roof 1
# on what sits the person 1
# what is the boy doing 2
# what color is the table 3
# what color is the wall 50
# what is surrounding the house 1
# where is he water bottle 1
# what is in the closet 9
# what is on the table 224
# what color is the bowl 2
# where is the tv hanging 1
# what is the audience doing 1
# what is behind the refrigerator 3
# what is on the paper 1
# what is the kid doing 1
# what is behind the person 3
# what is on the aisle 1
# where is the bath ball 1
# what color is the chair 3
# where does the person sit 1
# what is on the refrigerator 4
# what is in the car 4
# what is on the track 1
# where is the water bucket 1
# what is in the video 316
# where are the clothes hanging 1
# what color is the earring 1
# what does the person have 2
# what is behind the lake 1
# is the person wearing tie 1
# what is on the stake 1
# what is in the corridor 8
# what is in the kitchen 30
# what is in the dishes 2
# what color is the alpaca 1
# what is on the bed 50
# where is the girl drawing 1
# what is on the beach 2
# where is the tooth patient 1
# what are the man doing 1
# what is near the woman 1
# where is the water cup 1
# what is in the bag 2
# where does the person lie 2
# what appeared in the video 2
# where is the towel ring 1
# what color is the sheet 3
# what color is the dish 1
# what does the person lock 1
# what is in the microwave 1
# where is the flower pot 1
# where is the electric fan 1
# is the person wearing watch 1
# what color is the cup 3
# what are on the roof 1
# what color is the flute 1
# what color is the pillow 1
# where are the two men 1
# what is following the player 1
# what is under the computer 1
# what color is the roof 1
# what color are the shoes 2
# what is onn the chair 1
# what is on the grassland 1
# what color is the bed 1
# what is the policeman wearing 1
# what is in the bedroom 3
# what is on the ground 19
# what color is the tv 1
# is the person wearing shirt 1
# where is the paper box 4
# what is the woman doing 37
# what is in the room 182
# what is the leopard doing 1
# what is on the desk 29
# what is in the park 1
# where is the tooth cup 1
# where is on the ground 1
# what is outside the house 1
# what color is the subtitle 1
# what are in the closet 1
# what is the man wearing 2
# what is on the worktop 1
# what is on the stove 1
# where does the people sit 1
# where is the photo frame 1
# what is behind the table 1
# what is in the pot 1
# what color is the towel 1
# what is on the chair 3
# what color is the tablecloth 1
# what color is the helicopter 1
# what is in the hand 1
# where is the blue blanket 1
# where is the towel thrown 1
# what is the video about 1
# is the person wearing glasses 2
# what is behind the kids 1
# what is in the bathroom 5
# what is the hamster doing 1
# what is on the stool 4
# is the woman wearing necklace 1
# what are on the steps 1
# what is on the piano 1
# what is in the carton 1
# what color is the paper 1
# where are these shoes from 1
# is mario standing or sitting 1
# what is on the seat 1
# where is the toy shelf 1
# what is in the hallway 2
# where is the mineral water 1
# where is the gas tank 1
# what is on the cabinet 13
# is the selfie stick flexible 1
# where are the two boys 1
# where is the laundry detergent 3
# where is the remote control 2
# where is sofa in video 2
# where is the computer host 1
# what color is the refrigerator 6
# how many person is there 1
# what is near the tv 1
# what does the person drink 2
# what is on the plate 1
# what is on the website 1
# what color is the starfish 1
# what is on the cooktop 12
# what type is the cartoo 1
# what color is the sofa 2
# where is the desk lamp 1
# what color is the scarf 1
# what is the person doing 36
# what color is the stone 1
# what is on the countertop 5
# what color is the cooktop 1
# what is behind the computer 1
# what is behind the door 4
# what is under the tv 1
# what is on the street 1
# what is behind the man 1
# what is in the corner 1
# what is in the toilet 5
# what is in the cupboard 1
# where are those two men 1
# where is the seat cushion 1
# what color is the wardrobe 1

# %%
num_word_dict
# Out:
# {2: 1,
#  3: 5,
#  4: 481,
#  5: 1549,
#  6: 852,
#  7: 2790,
#  8: 3536,
#  9: 3174,
#  10: 1755,
#  11: 1089,
#  12: 759,
#  13: 426,
#  14: 112,
#  15: 60,
#  16: 24,
#  17: 9,
#  18: 2,
#  19: 1}

# %%
num_word_dict={}
have_and=0
have_of=0
have_in=0
have_from=0
have_ing=0
have_at=0
have_to=0
have_pronouns=0 #代词
for answer,times in frequency_answer.items():
    #print(answer)
    num_word=0
    if "and" in answer:
        have_and+=1
    if "of" in answer:
        have_of+=1
    if "in" in answer:
        have_in+=1
    if "ing" in answer:
        have_ing+=1
    if "from" in answer:
        have_from+=1
    if "at" in answer:
        have_at+=1
    if "to" in answer:
        have_to+=1
    if "it" in answer or "his" in answer or "her" in answer or "them" in answer:
        have_pronouns+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times

# %%
have_and,have_of,have_in,have_ing,have_from,have_at,have_to,have_pronouns
# Out:
# (158, 132, 2603, 2293, 3, 446, 347, 311)

# %%
num_word_dict={}
have_what=0
have_how=0
have_is=0
have_on=0
have_in=0
have_many=0
have_where=0
have_color=0 
have_does=0
have_do=0
have_person=0
for answer,times in frequency_question.items():
    #print(answer)
    num_word=0
    if "what" in answer:
        have_what+=1
    if "how" in answer:
        have_how+=1
    if "is" in answer:
        have_is+=1
    if "on" in answer:
        have_on+=1
    if "in" in answer:
        have_in+=1
    if "many" in answer:
        have_many+=1
    if "where" in answer:
        have_where+=1
    if "color" in answer:
        have_color+=1
    if "does" in answer:
        have_does+=1
    if "do" in answer:
        have_do+=1
    if "person" in answer:
        have_person+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times

# %%
have_what,have_how,have_is,have_on,have_in,have_many,have_where,have_color,have_does,have_do,have_person
# Out:
# (2684, 110, 3564, 2103, 3869, 98, 682, 1128, 579, 1156, 1421)
