# %%
import sys

# %% [markdown]
# f=open("./VQADatasetA_20180815/train.txt")
# for line in f.readlines():
#     print(line)

# %% [markdown]
# while line:
#     print(line,end=" ")
#     #line=f.readlines()
# f.close()

# %%
flag_line=0
with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        flag_line+=1
        words = line.split(',')
        flag_word=0
        for word in words:
            flag_word+=1
        if flag_word!=21:
            print(flag_line)

# %%
frequency_question = {}
frequency_answer={}
i=0

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    if word not in frequency_question:
                        frequency_question[word]=1
                    else:
                        frequency_question[word]+=1
                else:
                    if word not in frequency_answer:
                        frequency_answer[word]=1
                    else:
                        frequency_answer[word]+=1

# %%
frequency_question
# Out:
# {'what is the color of the heart in the video': 1,
#  'what is color of trousers of man in video': 1,
#  'how many characters appear in video': 1,
#  'what is the person holding the broom doing': 1,
#  'is the person in colorful trousers sitting or standing in the video': 1,
#  'what is on the countertop': 5,
#  'what color is the hair of the person wearing rose red dress': 1,
#  'what is the shape of the bricks in the video': 1,
#  'is the person in the white coat standing or sitting in the video': 1,
#  'what is the color of the clothes on the bed in the video': 1,
#  'what instrument is in the video': 1,
#  'what color is the floor tile in the video': 1,
#  'where did the person in the video going to': 1,
#  'what is the color of the pants does the man sitting wear': 1,
#  'what is in the hands before the person in the video dumps things': 1,
#  'is the text on the nail polish written in english or chinese in the video': 1,
#  'what color of the clothes does the man wear in the video': 26,
#  'is the hair-tied person in the video standing or sitting': 1,
#  'what is the color of the closet which is behind the man': 1,
#  'is the woman in the video lying down or sitting': 2,
#  'what is the person wearing white pants doing': 1,
#  'what is the round doing in the video': 1,
#  'what color is the carpet in the video': 4,
#  'where do the people in video play football': 1,
#  'is the guitar player standing or sitting in the video': 1,
#  'where does the person put the handbag': 1,
#  'where is the color paper in the video': 1,
#  'where is the television': 4,
#  'where is sofa in video': 2,
#  'what is put in the right of the person in the video': 1,
#  'is the referee in the video sitting or standing': 2,
#  'what is on the left side of the fridge': 1,
#  'where is the number plate in the video': 2,
#  'where is the person wearing the hat': 1,
#  'what are the animals in video': 2,
#  'what is the color of the bag in the video': 2,
#  'what is on the corridor': 1,
#  'is the person in the viedo sitting or standing': 1,
#  'is the boy with green hair sitting or standing in the video': 1,
#  'what color is the brand': 1,
#  'where is the person in red in the video': 1,
#  'what is the person with white hair in the video doing': 1,
#  "what is on the man's legs in the video": 1,
#  "what is the color of the woman's hair": 2,
#  'what is the sport in the video': 2,
#  'what is on the front of the door': 2,
#  'is the person in the last scene standing or sitting': 1,
#  'what color does the woman wear': 1,
#  'what kind of the jacket does the person tying hair up wear in the video': 1,
#  'what did the character drive to the river in video': 1,
#  'where does the man in the video sit': 3,
#  'what is behind the refrigerator': 3,
#  'what is the person wearing a vest in the video doing': 1,
#  'is the person in the video long hair or short hair': 37,
#  'which hand of the man holds the bag': 1,
#  'where is the leopard': 1,
#  'does the person wear pants or shorts': 2,
#  'where does the man in the video put what he has on his hand': 1,
#  'is the animal appearing in the video a dog or a cat': 1,
#  'where is the person with golden hair': 1,
#  'is the man in purple standing or sitting': 3,
#  'where is the person wearing earrings': 1,
#  'is the person in video sitting or lying down': 1,
#  'is the man in red sitting or standing in the video': 1,
#  'what does the man wear on head in the video': 7,
#  "what is color of man's hair in cartoon": 1,
#  'what is the color of the wooden cabinet in the video': 1,
#  'what does the person have in his hand': 2,
#  'which number of the player in the video scored the ball': 1,
#  'what is on the aisle': 1,
#  'is the person lying or seated in the video': 2,
#  'what is the person holding in his hand in the video': 5,
#  'what is the fish that is moving its mouth': 1,
#  'where is the camera': 1,
#  'what type is the yellow car': 1,
#  'where does the people sit': 1,
#  'what color is the t-shirt the person wears': 1,
#  'what color of the team uniform does the person wear in the video': 1,
#  'where is the two girls dancing together in the video': 1,
#  'is the man sitting or standing in the cartoon': 1,
#  'what is in the toilet': 5,
#  "what is the color of the man's clothes in the video": 6,
#  'what color are the clothes of the person who sits in the middle in the video': 1,
#  'what is on the face of the man in the video': 8,
#  'which season is the model showing in the video': 1,
#  'is the kid wearing a glasses sitting or standing in the video': 1,
#  'what does the boy wear on head in the video': 1,
#  'what is hanging next to the mirror in video': 1,
#  'what does the person have on his body': 1,
#  'what is the color of the trousers of the person in a striped shirt in video': 1,
#  'what time is it in the video': 5,
#  'what is the person playing the guitar in the video doing': 1,
#  'is the athlete in the video standing or sitting': 1,
#  'is the person wearing shirt': 1,
#  'what color hair does the man wearing orange dress have': 1,
#  'what color clothes do the boy in the video wear': 1,
#  'is the person in the video standing or sitting': 546,
#  'what is the person who take the microphone doing in the video': 1,
#  'where is the skeleton in the video': 1,
#  'what color pants does the man with black hair wear in the video': 1,
#  'is the woman standing or sitting in video': 15,
#  'where is the animated scene in the video': 1,
#  'how is the sky in the video': 1,
#  'what is being played in the video': 1,
#  'what is the girl doing in video': 8,
#  'what is on the market table': 1,
#  'is the woman in blue long hair or short hair': 1,
#  'what is in the hand the person in the video': 1,
#  'what is on the cupboard in video': 1,
#  'which line is the red font in the video': 1,
#  'what is the wall full of in the video': 3,
#  'where is the person in the second video': 2,
#  'what color is the chair in video': 3,
#  'is the person sitting or lying in the video': 8,
#  'is the cook in the video sitting or standing': 1,
#  'what is the color of the car for the person in red': 1,
#  'what is the color of the clothes does the person wear in video': 20,
#  'where is the tissue box': 1,
#  'what color is the desk lamp on the table in the video': 1,
#  'what is the person in video sitting on': 1,
#  'where is the tree in the video': 1,
#  'what color is the microphone in the video': 2,
#  'what is the person wearing white shirts in the video doing': 1,
#  'what is the cartoon character sitting on the boat doing': 1,
#  'what is the shape of the gold coin in the video': 1,
#  'what is the color of the washing machine in video': 1,
#  'where is switch': 2,
#  'where is the white kitten in the video': 1,
#  'what is the color of the hat the person wearing in the video': 1,
#  'is the dog in the video sitting or standing': 1,
#  'is the wolf standing or sitting in video': 1,
#  'what is following the player': 1,
#  'is the person in video in the living room or the bathroom': 1,
#  'where is the water cup': 1,
#  'what color is the gold coin in the video': 1,
#  'what is the cartoon character in the video doing': 1,
#  'what is the color of wall at the beginning of the video': 1,
#  'is the person in video sitting or standing before putting the pillow': 1,
#  'what is the person wearing on his head in the video': 4,
#  'what is the person in the left side of the video doing': 1,
#  'is the person in the video sitting or standing before putting books': 1,
#  "what is the color of woman's clothes in video": 5,
#  "what is the color of the woman's clothes who is sitted on the sofa in the video": 1,
#  'what is on the stool': 4,
#  'where is the paper box': 4,
#  'what color clothes does the second person wear in the video': 1,
#  'what color is the dress worn by the woman in the video': 2,
#  'is the kid standing or sitting': 1,
#  'what does the man in video wear on his head': 3,
#  'how many game figures are in the video': 2,
#  'is the lamp on or off': 2,
#  'what color of the clothes does the girl wear in the video': 3,
#  'what are the numbers in video': 1,
#  'what is the name of the game in the video': 1,
#  'what color police uniform does the person wear in the video': 1,
#  "what is on the man's legs": 1,
#  "what color are the woman's clothes in the video": 3,
#  'what is placed in the pot in the video': 1,
#  'what is on the floor in th video': 1,
#  'what is the boy doing in video': 1,
#  'what is the person carry a bag in the video doing': 1,
#  'what is on the bed in the video': 3,
#  "what color is the child'skin in video": 1,
#  'is the woman in red in the video standing or sitting': 1,
#  'was the person in the video standing or sitting at first': 1,
#  'what color clothes is the person wearing red scarves wearing in the video': 1,
#  'is the woman in the video just lying down or standing': 1,
#  'what color is the roof': 1,
#  'what is in the room in the video': 3,
#  'what color shoes does the person wear in the video': 4,
#  'what is the woman doing in video': 15,
#  'what does the person with glasses hold in his hand': 1,
#  'where is the goblet': 2,
#  'what color shoes does the woman wear in the video': 2,
#  'where is the jar placed in the video': 1,
#  'what is the exercising projection in the third video': 1,
#  'what is the clothes color of the person holding the cup': 1,
#  'which hand of the person in the video holds the fruit': 1,
#  'what color of the clothes does the cartoon child wear in the video': 1,
#  "what is on the man's arm in the video": 1,
#  'what are the audience in the video doing': 1,
#  'how many people appeared in the video': 5,
#  'is the person in black clothes sitting or standing': 1,
#  'is the person in striped clothes sitting or lying': 1,
#  'where is the child in green in the video': 1,
#  'where is the person with the dirty braid in the video': 1,
#  'what color of the clothes does the person wear in the video': 162,
#  'what color clothes does the person without glasses wear': 1,
#  'where was the computer before the person getting up': 1,
#  'are the letters in video english or chinese': 1,
#  'what is the animal': 1,
#  'what is on the machine in the video': 1,
#  'what color top does the woman wear in the video': 3,
#  'where does the person in the first picture of video put the computer': 1,
#  'what is the gender of the child at the beginning of the video': 1,
#  'what is on the left hand side of the man in the video': 1,
#  'what did the person turn off in the video': 1,
#  'what color clothes does the person wearing the bag in the video': 1,
#  "what is in the boy's hand in the video": 1,
#  'what is the man in green doing in the video': 1,
#  'what is the man wearing a hat in the video doing': 1,
#  'what is the gender of the person wearing glasses in the video': 1,
#  'what is the color of the washing machine': 3,
#  'which side does the light in video revolve around': 1,
#  'what do the person in the video have in his hand': 1,
#  'is the plasticine doll in the video sitting or lying down': 1,
#  'is the cartoon child sitting or standing in the video': 1,
#  'what color clothes does the man without a hat in the video wear': 1,
#  'where is the clothes': 13,
#  'what is the color of the clothes of the person carrying the bag': 1,
#  'what is the person in the right side doing in the video': 1,
#  'what color is the cup': 3,
#  'what is the color of the plastic case in the video': 1,
#  'does the person in the last photo having curly or straight hair': 1,
#  'does the man in black have moustache': 1,
#  'what does the person in the video wear on his neck': 1,
#  'is the blonde in the video standing or sitting': 1,
#  'what color is the phone in the video': 2,
#  'what does the person in video wear on his head': 6,
#  'where is the wrench in the video': 1,
#  'what color pants does man with a hat wear in the video': 1,
#  'where is the man who lifts the sail': 1,
#  'what is the color of the closet in the video': 1,
#  'what is the color of the hair of the girl': 1,
#  'what is in the plate': 1,
#  'is the person with the paper in the video standing or lying': 1,
#  'what did the person in video do after putting the pillow': 1,
#  'what color is the car seat in video': 1,
#  'where is the cartoon child in the video': 1,
#  'where is the motorcycle in the video': 1,
#  'who is the person in the video': 1,
#  'where is the pan in the video': 2,
#  'what sports items are on the cartoon in video': 1,
#  'what is beside the closet in the video': 1,
#  'what is the man dong in the video': 1,
#  'what is the color of the dishes in the video': 1,
#  'what color clothes is the person in the video wear': 1,
#  'what is the color of the pancake in the video': 1,
#  'on what sits the person': 1,
#  'what is the computer in the video doing': 1,
#  'is the man eating bread in the video sitting or standing': 1,
#  'what is in the bag in the video': 1,
#  'what color is the woman wearing the video': 1,
#  'what is the color of the sheets': 1,
#  'what is the person wearing on the knee in the video': 1,
#  "what is the color of the child's clothes in the video": 3,
#  'where is the person in the video indoors': 1,
#  'what is the color of the carpet in the video': 1,
#  'what is outside in the video': 1,
#  'what color clothes does the person take off in the video': 1,
#  'where is the bike in the video': 1,
#  "where is the person's right hand put in the videos": 1,
#  'where is the laundry detergent': 3,
#  'what color of the coat does the person wear in the video': 7,
#  'where does the man in the video put the book': 2,
#  'where is the knife': 1,
#  'what color is the grass in video': 1,
#  'what is the color of the helmet': 1,
#  'what is the person wearing striped shirts in the video doing': 1,
#  'is the man wearing red clothes in the video long hair or short hair': 1,
#  'what is the animal except cat in the video': 1,
#  'is the person in the video sitting or standing': 507,
#  'what is the person in video standing under': 1,
#  'is the person in blue clothes sitting or standing': 1,
#  'what is in front of the person in gray pants': 1,
#  'what color of clothes does the person in the video wear': 5,
#  'what color hair is the person in the video': 1,
#  'what does the woman in video wear around her neck': 1,
#  'what is the person wearing helmets in the video doing': 1,
#  'what is the color of the clothes of the person wearing black pants in video': 1,
#  'where is the pancake in the video': 1,
#  'where is the bottle': 12,
#  'is the spongebob walking or standing in the video': 1,
#  'what does the person in the video wear on his left wrist': 1,
#  'what is the color of the clothes does the man standing on the stool wear': 1,
#  'what is the picture of the video': 1,
#  'what is the woman wearing on her left hand': 1,
#  'what color of the pants does the person with red lattices wear': 1,
#  'what is the color of the grapes': 1,
#  'where are those two men': 1,
#  "what is the color of thr woman's glasses": 1,
#  'is the person who wears a horse maskin the video standing or sitting': 1,
#  'how many people are on the boat in the video': 1,
#  'what is the soldier doing in the video': 1,
#  'what is the color of the pattern behind the woman': 1,
#  'what is the purple light of the video reflected on': 1,
#  'what does the person in video have on their face': 6,
#  'where is the person wearing hat in the video': 1,
#  "what is on the woman with short hair's ears": 1,
#  'what is the person in gray pants doing': 1,
#  'what did the sitting man put on his face': 1,
#  'is the person wearing the white hat in the video standing or sitting': 1,
#  'is the adult in the video sitting or standing': 1,
#  'where is the computer in the video': 15,
#  'what is the gender of the person who opened the box in the video': 1,
#  'where is the pot': 1,
#  'what color is the nail in the video': 2,
#  "what is the color of the girl's hair in the cartoon": 1,
#  'what color clothes does the woman in the video wear': 1,
#  'what is behind the lake': 1,
#  'what is the color of the bin in video': 1,
#  'where is the hanger in the video hanging': 1,
#  'is the person in video sitting or standing after pouring something down': 1,
#  'what is the person wearing a black shirt doing in the video': 1,
#  'what numbers appear in the picture in video': 1,
#  'are the two men in the video standing or sitting': 2,
#  'is the image in video colorful or black and white': 1,
#  'what is the color of the clothes does the man brushing the basin wear': 1,
#  'what is in front of the man in the video': 2,
#  'what color clothes does the person with white hair wear in the video': 2,
#  'what is in the corner of the video': 1,
#  'are most people in video standing or sitting': 1,
#  'what is the color of the clothes does the man wear': 36,
#  'what is the person in purple clothes doing': 1,
#  'what is in the right hand of the person in the video': 2,
#  'where is the brick in the video': 1,
#  'does the text written in english or chinese in the video': 1,
#  'which hand of the person in the video puts on the mouth': 1,
#  'what is the person wearing blue shorts doing in the video': 1,
#  'what color of the clothes does the child wear in the video': 2,
#  'what does the girl wear on head in the video': 3,
#  'what is the sport event in the video': 1,
#  'what is the person in the video': 6,
#  'what color pants does the referee wear in the video': 1,
#  'is the person in brown white clothes sitting or standing': 1,
#  'what color is the building in the video': 1,
#  'what is the facial expression of the person in the first photo in the video': 1,
#  'is the door of the yellow car in the video opening or closed': 1,
#  'what is the person on the stage doing in the video': 1,
#  'what color is the dish': 1,
#  'is the man in video sitting or standing': 4,
#  'is the person in black t-shirts sitting or standing in the video': 1,
#  'what is the deer doing in the video': 1,
#  'what is on the pool table': 3,
#  'what color is the bed': 1,
#  'what is the color of the cabinet': 2,
#  'where is the squidward tentacles in the video': 1,
#  'what color is the pen in video': 1,
#  'what is the person in striped clothes doing': 1,
#  'is the person in video standing or sitting at the end': 1,
#  'what is the color of the clothes of the person eating things in the video': 1,
#  'what are the man doing': 1,
#  'what is the man in the video wearing on his head': 1,
#  'what is the pattern of the box in the video': 1,
#  'what is the cartoon character doing at last in the video': 1,
#  'what is playing in video': 2,
#  'what color of the clothes does the person in the left side wear in the video': 1,
#  'how many kitchen knives are there in the video': 1,
#  'what is the person holding at the beginning in the video': 1,
#  'what is the person in white doing at the beginning of the video': 1,
#  'what color of hat does the man in the video wear': 1,
#  'is the person in the rose red dress standing or sitting': 1,
#  'is the person wearing red clothes standing or sitting': 1,
#  'is the person with glasses in video standing or sitting': 2,
#  'where did the person put the book in the video': 1,
#  'how many kids are there in the video': 2,
#  'what color is the character picture in the video': 1,
#  "what is in the woman's hand in the video": 3,
#  'what is the color of the hair of the person in green in the video': 2,
#  'where is the cutting board in the video': 1,
#  'what is the bareheaded person doing in the video': 1,
#  'what is in the hands of the person in the video': 4,
#  'what did the person in video do when the opened the door': 1,
#  'what is the person in black t-shirt doing in video': 1,
#  'what color top does the person running wear in the video': 1,
#  'what color does the squatting person wear': 1,
#  'how many cars are there in the video': 2,
#  'what does the man in the video wear on his neck': 1,
#  'where is the board in the video': 1,
#  'what color of the clothes is the referee wearing in the video': 1,
#  'how many lights are shining on the school bus': 1,
#  'is the background in video green mountains or green trees': 1,
#  'what is the color of the pants of the person wearing hat': 1,
#  'where is the person who appeared at the beginning of the video': 1,
#  'what color clothes does person in the video wear': 24,
#  'where is the musical instrument in the video': 1,
#  'what color are the pants worn by glasses wearer in the video': 1,
#  'is the man in the video fat or thin': 1,
#  'what is the box in the video': 1,
#  'how many person is there': 1,
#  "what color is the man's clothes in the video": 10,
#  "what is on the woman's face in the video": 4,
#  'where is the ball in the video': 2,
#  'what color is the bottle in the video': 1,
#  'what is the color of the helmet of the woman in the video': 1,
#  'what is the color of the bread in the video': 1,
#  'what image is placed in the video': 1,
#  'where is the blue fist in the barrel-shape house': 1,
#  'what color is the clothes worn by the person who take a baseball bat in the video': 1,
#  'what kind of car does the person in the video enter': 1,
#  'is the computer turned on or off': 1,
#  'what is the character doing in the video': 1,
#  'is the person with red hair sitting or standing': 1,
#  'is the television turned on or off in the video': 5,
#  'what is the woman warrior in video holding in her left hand': 1,
#  'is the cartoon character in the video standing or sitting': 2,
#  'is james in the video standing or sitting': 1,
#  'what color is the person standing in the video': 1,
#  'what do the first row of people do in the video': 1,
#  'where does the person put the books': 1,
#  'is the person in red sitting or standing in video': 1,
#  'what is the girl wearing the sneakers in the video doing': 1,
#  'are the children standing or sitting in the video': 1,
#  'what does the woman wear on head in the video': 4,
#  'what does the woman in the video wear on her neck': 1,
#  'where is the sheep in the video': 1,
#  'what is on the storage rack': 6,
#  'is the game window open or closed': 1,
#  'which hand does the person in the video use to take the kettle': 1,
#  'what does the man wear on his wrist in the video': 2,
#  "what is on the man's leg": 1,
#  'what is the man doing with the woman': 1,
#  'what did the man wearing the dress in the video take': 1,
#  'what color is the basin in the video': 1,
#  'is the person in the video wearing glasses': 1,
#  'what kind of animal is in the video': 1,
#  'what is the person with the pen in the video doing': 1,
#  'what color is the bowl in the video': 2,
#  'what animal is in the video': 6,
#  'what appeared at the beginning of the video': 1,
#  'where is the man in black pants': 2,
#  'what is in the tvbench': 1,
#  'what is the person in black pants doing in the video': 1,
#  'is the person wearing khaki clothes in the video standing or squatting': 1,
#  'what color is the towel': 1,
#  'what are the two people doing in the video': 1,
#  'where is the child in the video': 6,
#  'what is the person in the game holding': 1,
#  'what is on the left side of the refrigerator': 1,
#  'where was the man at the beginning': 1,
#  'is the man in green standing or sitting in the video': 1,
#  'is the person wearing blue clothes standing or sitting': 2,
#  'what does the person wear in hand in the video': 1,
#  'what color of the clothes does the girl wear at the beginning of the video': 1,
#  'what is the person showing at first in the video doing': 1,
#  'here is the person in the video': 1,
#  'what is on the side of the sink in the video': 1,
#  'what does the person having yellow hair have in his hand': 1,
#  'what is the person with red plaid doing': 1,
#  'what is hanging on the wall in the video': 7,
#  "what color is the man's wall in the video": 1,
#  'where is the man in black with short sleeves in video': 1,
#  'what is the color of the sausage in the video': 1,
#  'where is the person singing in the video': 2,
#  'what is the color of the pillow in video': 1,
#  'is the woman in video standing or sitting': 2,
#  'what is the woman in the video doing': 88,
#  'where is the chair in the video': 7,
#  "what is on the girl's neck in the first picture": 1,
#  'what happens in video': 3,
#  'what color is the pants that the first person wears in the video': 1,
#  'where is the other helmet in the video': 1,
#  'where is the robot in the video': 1,
#  'what is on the left of the door in the video': 1,
#  'is the person sitting or standing while answering the phone in the video': 1,
#  'what is the girl doing in the cartoon': 1,
#  'what is on the left of the person in the video': 8,
#  'are people standing or sitting in the last picture': 1,
#  'where is the light in video': 1,
#  'what color is the box filled with water': 1,
#  'what color of pants does the man in the video wear': 2,
#  'what is the color of the door in the video': 12,
#  'what color is the ship in the video': 1,
#  'is the cat in the cartoon reading a newspaper or a book in the video': 1,
#  'what color does the person in video wear': 1,
#  'what is the color of the pendant lamp in the video': 1,
#  'what is the background color of the second picture in the video': 1,
#  'what is on the wooden closet in the video': 1,
#  'is the man just sitting or kneeling at the beginning of the video': 1,
#  "what is the color of the smiling face in the woman in black'sclothes": 1,
#  'is the person wearing white clothes in the video standing or sitting': 2,
#  'is the machine in the video placed horizontally or vertically': 1,
#  'where is the person in the first video': 2,
#  'where does the person enter': 1,
#  'where is the street lamp in video': 1,
#  'is the person in the video standing or sitting at the end': 1,
#  'what is on the left of the stairs': 1,
#  'is the person lying or sitting in the beginning of the video': 5,
#  'is the person wearing orange pants sitting or standing in the video': 1,
#  'does the person in the video wear shoes': 1,
#  'what does the person wear on head in the video': 12,
#  'what color is the headset worn by the woman in the video': 1,
#  'what is the person in the game doing': 1,
#  'what is the last person holding in the video': 1,
#  'what is in front of the washing room': 1,
#  "what color is the dog's tooth in the video": 1,
#  'how many pearl magnets are there in the video': 1,
#  'what is the person doing at last': 1,
#  'what is in the woman is hand in the video': 1,
#  'what is in the bag': 2,
#  'where is the quilt in the video': 1,
#  'what is the living room': 1,
#  'what are the masses holding in the video': 1,
#  'was the man in the video sitting or standing at the beginning': 1,
#  'what color is the cupboard door next to the refrigerator': 1,
#  'is it the daytime or night in the video': 1,
#  'where is the towel in the video': 2,
#  'is the person wearing black clothes sitting or standing': 1,
#  'is the person in white sitting or standing': 1,
#  'what is in front of the person with glasses': 1,
#  'what color is the table': 3,
#  'where are the clothes': 7,
#  'what is outside the room in the video': 1,
#  'is the woman with bun standing or sitting in video': 1,
#  'what is the woman in the video': 1,
#  'is the character in video a man or a baby': 1,
#  'what is the last action of the person in the video': 1,
#  'is the man with white hair in the video standing or sitting': 2,
#  'what is the girl in the video doing after opening the window': 1,
#  'what color clothes does the last person appear in the video': 1,
#  'what is the characteristic of the animal in the video': 1,
#  'what is the color of the quilt': 1,
#  'where is the bamboo hat in the video': 1,
#  'what is on the cabinet on the left side of the bed': 1,
#  'on what does the person with a pen write': 1,
#  'what color suit does the person wear in the video': 1,
#  'is the person wearing police uniform a man or a woman': 1,
#  "what is in the person's hand in the game": 1,
#  'what is on the shelf': 6,
#  'what color is the cabinet in video': 1,
#  'what are the men doing in video': 2,
#  'what is the color of the hat of the person wearing a hat in video': 1,
#  'what is on the right side of the chair': 1,
#  'which team got the ball in the video': 1,
#  'what color skirt is the model wearing in the video': 1,
#  'what is the color of the alphabet in the school bus': 1,
#  'what is on the left of the door': 2,
#  "what is the color of the woman's clothes at the beginning of the video": 1,
#  'what did the person holding the football in the video do': 1,
#  'where is the architectural model in the video': 1,
#  'what are the people wearing rompers in the video doing': 1,
#  'what did the person put down in the video': 1,
#  'what is the color of the wall': 85,
#  'what is the person covered with a blanket doing': 1,
#  'what is under the table in the video': 1,
#  'is the judge sitting or standing in the video': 1,
#  'is the person in the video sitting or standing at the beginning': 12,
#  'what does the bespectacled black man in video hold': 1,
#  'what is the boy in the video seeing': 1,
#  'where is the person in purple': 1,
#  'where did the person get the cup': 1,
#  'what is the gender of the person on the sports field in the video': 1,
#  'what is the person holding in the hands': 1,
#  'where did the person with glasses take beverage from in the video': 1,
#  'where does the boy in the video take books': 1,
#  'what is the gender of the person playing tennis in the video': 1,
#  'what is in the fence in the video': 1,
#  'what does the man have in the video': 1,
#  'what color is the washing machine': 1,
#  'what is the person with white hair doing': 1,
#  'where does the person in the video play': 1,
#  'where is the person playing football in the video': 1,
#  'what color clothes is the girl wearing in the video': 1,
#  'what is the color of the clothes the woman wears': 12,
#  'where is the brush in the video': 1,
#  'is the person playing the piano in the video standing or sitting': 1,
#  'what is the color of the pants does the man in yellow top wear': 1,
#  'what is on the piano in the video': 1,
#  'what color does the thinner man wear in the video': 1,
#  'what is the color of the pants of the person in white clothes': 1,
#  'what is the person wearing long hair doing in the video': 1,
#  'what is on the left of the refrigerator': 1,
#  'which hand of the person in the video holds the tie': 1,
#  'what is the color of the clothes of the adult in the video': 2,
#  'what is the person on the second picture of video doing': 1,
#  'what color does the woman wear in the video': 1,
#  'is the stake in video placed forward or sideways': 1,
#  'is the person holding the knife in the video standing or sitting': 1,
#  'what is the person standing doing in the video': 1,
#  'what are the fingers doing in the video': 1,
#  'what is on the countertop in the video': 1,
#  'what color is the door': 4,
#  'what color is the refrigerator in the video': 3,
#  'what is the color of the wall in the video': 37,
#  'what is at the back of the chair': 2,
#  'what is the man wearing on the face in the video': 1,
#  'where is the person holding the umbrella': 1,
#  'what color clothes does the person wearing red pants wear': 1,
#  'what color of the pants does the person wear in the video': 23,
#  'where is the plant': 1,
#  'what is on the left side of the bed': 1,
#  'what is in front of the door in the video': 8,
#  'what is the person in glasses doing': 1,
#  'what is the crowd doing in the video': 1,
#  "what color are the girl's clothes in the video": 1,
#  "what is in the man's mouth in video": 1,
#  'what color battle dress does the female warrior in video wear': 1,
#  'how many people are flying in the cartoon': 1,
#  'what is worn on the person is face of video': 1,
#  'is the person in the right side sitting or standing in the video': 1,
#  'what is the color of the clothes of the person wearing glasses': 1,
#  'where is the man lying on in the video': 2,
#  'what does the woman in the video hold in her hand': 4,
#  'which pattern is the first program to click on in the video': 1,
#  'where is the calendar in the video': 1,
#  'is the city gate in the video opening or closed': 1,
#  'what color pants does the people wearing a cowboy cap wear in video': 1,
#  'what are the characters of the game in the video doing': 1,
#  'what is the puppy in the video doing': 1,
#  'what is on the hanger in the room': 1,
#  'what is the person drawing in the video': 1,
#  'what did the woman in the video throw on the ground': 1,
#  'what does the person in the video wear on the head': 1,
#  'what color is the sailboard in video': 1,
#  'where is the flower in the video': 1,
#  'what is the person wearing orange pants doing in the video': 1,
#  'how many fingers can be seen in the video': 1,
#  'what is on the plate in the video': 1,
#  'what is the person wearing a yellow clothes in the video doing': 1,
#  'what is the color of the hair of the person in the video': 2,
#  'what is the arrow in the video pointing to': 1,
#  'what color is the hair of the woman wearing red rose dress': 1,
#  'is the person in the video walking or seated': 1,
#  'what is on the chest of the person in the video': 1,
#  'where is the palm in the video': 1,
#  'what color top does person running first in the video wear': 1,
#  'is the athlete in the video a man or a woman': 1,
#  'is the person wearing sky blue clothes standing or sitting in the video': 1,
#  'what is the person with the microphone doing': 1,
#  'is the audience in the video is sitting or standing': 1,
#  'where is the person standing in video': 1,
#  'what did the girl wearing the red boots in the video feed the horse': 1,
#  'what is woman doing at the beginning of video': 1,
#  'where is the woman in the video putting the clothes': 1,
#  'is the door the person pull in the video open or closed': 1,
#  'where is the cook in the video': 1,
#  'are the eyes of the alpaca in video open or closed': 1,
#  'what color is the clothes of the referee in video': 1,
#  'what fruit is put behind the person in the video': 1,
#  'what is the person wearing on ears at the commentary table in the video': 1,
#  'is the cartoon character standing or sitting in video': 2,
#  'is the boy in the video standing or sitting at the beginning': 1,
#  'what color is the hair clip on the head of the person in the video': 1,
#  'what is on the front of the window': 1,
#  'is the boy in white standing or sitting': 1,
#  'is the person tying hair up sitting or standing in the video': 1,
#  'what is the score of both sides in the video': 1,
#  'what does the person wear around the neck in the video': 1,
#  'what is the cut in the video': 1,
#  'where is the stool in the video': 1,
#  'is the person wearing a glasses in the video sitting or standing': 1,
#  'what did the man in the video take': 1,
#  'is the person sitting or lying on his stomach in the beginning of the video': 1,
#  'is the basin in the video standing up or upside down': 1,
#  'what is the gender of the person with red hair': 1,
#  'is the text in the video chinese or english': 3,
#  'is the person holding the bag in the video standing or sitting': 1,
#  'what is the yacht doing': 1,
#  'what does the right pattern at the beginning of the video look like': 1,
#  'what is the woman wearing a vest in the video doing': 1,
#  'is the player at the end of the video standing or lying on stomach': 1,
#  'what is on the staircase': 1,
#  "what color is the first monster's cloak in the video": 1,
#  'what is on the table in the table': 1,
#  'what color is the pot in video': 1,
#  'what color is the hair of the first person in the video': 1,
#  'is the person in the video squatting or standing': 1,
#  'what is the color of the car in the video': 12,
#  'what is the person in black trousers with white stripes in video doing': 1,
#  'what color is the cover in the video': 2,
#  'what color of the pants does the person with long hair wear in the video': 1,
#  'where is the photo frame in the video': 1,
#  'what is the shape of the container in the video': 1,
#  'where is the person in the black trousers': 1,
#  'what happened to the plane in the video': 1,
#  'what is in front of the person wearing blue trousers': 1,
#  'is the woman holding the broom in the video standing or sitting': 1,
#  'why throwing smoke shell in the video': 1,
#  'what color of clothes does the person on the stage wear in the video': 1,
#  'what color is the camera in the video': 1,
#  'what color do women wear in the video': 1,
#  'where are the flowerpots in the video': 1,
#  'what is the color of the english alphabet in the video': 1,
#  'does the person has long hair or short hair in the video': 1,
#  'what does the black-haired man in the video hold in his hand': 1,
#  'is the first box in the video open or closed': 1,
#  'is the water flowing or still in the video': 1,
#  'where are the people in video': 5,
#  'which hand does the person in the video use to get the tool': 1,
#  'what color is the barrier in the video': 1,
#  'where is the fan': 1,
#  'what does the person in orange in video have on their face': 1,
#  'what is the color of the pot in the video': 2,
#  'where are the two woman in the end': 1,
#  "what color is the person's hat in the video": 1,
#  'what is in the cabinet in the video': 1,
#  'where is the woman in the blue dress in video': 1,
#  'how many images are there in video': 1,
#  'what is the color of the clothes of the interviewee': 1,
#  'what color is on the ground in video': 1,
#  'what color is the handle on the door': 1,
#  'what is the man wearing on the neck in the video': 3,
#  'what is the shape of the tape in the video': 1,
#  'does the crystal skull have head or not': 1,
#  'what color is the paper in the video': 1,
#  'what is on the ground in the repair video': 1,
#  'is the sealed tank in the video open or closed': 1,
#  'is the girl with long hair sitting or standing': 1,
#  'where does the person in the video sit on': 1,
#  'is the woman in video standing or lying down': 1,
#  'what is the color of the book in the video': 1,
#  'where is the horse': 1,
#  'what color is the collar of the person in the video': 1,
#  'how many did the person in the video make': 1,
#  'where is the mural': 9,
#  'where does the woman take out the white clothes': 1,
#  'where is the person at the beginning in the video': 1,
#  'is the person on the left in the video standing or sitting': 1,
#  'where is the person in glasses': 1,
#  'is the man in the video standing or sitting at the beginning': 6,
#  'what is the person wearing glasses in the video doing': 5,
#  'what color is the plate of bread in the video': 1,
#  'what is on the tv in the video': 1,
#  'is the person in suit in the video standing or sitting': 1,
#  "what color hat is worn on the man's head in the video": 1,
#  'where is the pillow in the video': 5,
#  'is the person in the first picture standing sitting in the video': 1,
#  'what color is the wooden man ttanding in video': 1,
#  'what are on the person is hands in the video': 1,
#  'what color is the shoes in the video': 1,
#  'what color is the pants of the backpacker in the video': 1,
#  'is the person in video sitting or standing before lying on bed': 1,
#  'where is the baby stroller in the video': 1,
#  'is the person in red sitting or standing': 1,
#  'what is the person eating': 1,
#  'what color dress does the woman sitting in the video wear': 1,
#  'what is the trousers color of the person in the white clothes in video': 1,
#  'is the person in white in the video standing or sitting': 2,
#  'what is the color of the microphone in the video': 1,
#  'what is the color of the phone': 1,
#  'what color pants does the last person wear': 1,
#  'where is man in video': 2,
#  'where is the magazine thrown in the video': 1,
#  'what is in front of the person in red': 1,
#  'where does the person in the video go in': 1,
#  'what is the boy in the video doing': 4,
#  'what is the car hit in the video': 1,
#  'what did the woman in the video pick up from the couch': 1,
#  'is the car stopped or moving': 1,
#  'is the person in video sitting or standing after throwing the pillow': 1,
#  'what are on the steps': 1,
#  'what is the clothes color of the person in the black trousers': 1,
#  'where is packaging milk': 1,
#  'what is the animal that appears in the video': 3,
#  "what color is the kid's dress": 1,
#  'what is the color of the paper plane in the video': 1,
#  'what color is the onion in video': 1,
#  'is the person writing on the blackboard a man or a woman': 1,
#  'which hand did the person use to carry shoes': 1,
#  "what is on the person's finger in the video": 1,
#  'is the person holding a microphone in the video sitting or standing': 1,
#  'what are the people in the video doing': 1,
#  'where is the beverage': 2,
#  'what color is the wolf in video': 1,
#  'what do people in the video hold': 1,
#  'what are on the table': 1,
#  'where is the table lamp placed in the video': 1,
#  'what is the color of the trousers the woman wears': 1,
#  'what does the woman wear on face in the video': 1,
#  'what is on either side of the street in video': 1,
#  'is the person standing or sitting in the beginning of the video': 11,
#  'what color is the pigment on the table': 1,
#  'what is the gender of the person singing in the video': 1,
#  'what vehicle is in the video': 2,
#  'what color is the wall space in video': 2,
#  'what is the shape of the desk in the video': 1,
#  "what is on the person's hands in the video": 1,
#  'is the person in the video reaching out with the right hand or the left hand': 1,
#  'is the person in the video sitting or standing at rest': 1,
#  'what color clothes does the person in the video wear': 90,
#  'what is the person wearing black clothes doing in the video': 4,
#  'is the audience standing or sitting in video': 1,
#  'is the person wearing black clothes in the video long hair or short hair': 2,
#  'what is the person doing in the cartoon': 1,
#  'where is the athlete in red': 1,
#  'what color is the eye shadow of the woman in the video': 1,
#  'what is the person who is eating in the video doing': 1,
#  'is the last two woman in the video standing or sitting': 1,
#  'what color is the dress of the person in the video': 3,
#  'why is the person turning back': 1,
#  'what is on the right of the person in the video': 15,
#  'what is the woman taking in the video': 1,
#  'what is the mickey mouse doing': 1,
#  'what is in the hands of the person standing on the ground': 1,
#  'where does the person in the video throw clothes to': 1,
#  'what color is the light in the first scene': 1,
#  'what is the closet full of in the video': 1,
#  'where is the child in green in video': 1,
#  'is the person doing the exercise in the video standing or sitting': 1,
#  'what does the man in the video shoot': 1,
#  'where does the person sit in the video': 2,
#  'what is behind the woman': 2,
#  'what is the boy in red sitting on': 1,
#  'what color is the pram in the video': 1,
#  'what is the person firming about': 1,
#  'what color is the laptop in the video': 2,
#  'what is the player in yellow doing in the video': 1,
#  'where does the man in the video hang the blanket': 1,
#  'where is the poster': 2,
#  'where is the person sneezing in the video': 1,
#  'what is the color of the subtitle in the first subtitle': 1,
#  'where is the pillows': 1,
#  'where did the man in the video take the pillow': 1,
#  'what does the man have to do when entering the room': 1,
#  'is the boy standing or sitting in video': 2,
#  'what color do men wear in the video': 1,
#  'is the basin round or square': 1,
#  'what does the person hold in his left hand in the video': 1,
#  'what is on the track': 1,
#  'what is the black-haired person doing in the video': 1,
#  "what color is the singing people's clothes": 1,
#  'what is in the microwave': 1,
#  'is the soup in the video hot or cold later': 1,
#  'what color pants does the person in red wear': 1,
#  'what is the woman in white doing': 1,
#  'whether the english letters in the video are horizontal or vertical': 1,
#  'does the woman have long hair or short hair in the video': 3,
#  'what is the gender of the character in the video': 1,
#  'what is on the ground in front of the cabinet': 1,
#  'what is in front of the wall': 39,
#  'is the person playing badminton in the video standing or sitting': 1,
#  'is the person dancing in the video a man or a woman': 1,
#  'where is the kettle in the video': 1,
#  'what is the shape of the table in video': 1,
#  'is the video ending up with left hand or right hand': 1,
#  'what is the background in video': 2,
#  'where does the person wearing yellow clothes sit in the video': 1,
#  'is the person in the video sitting or standing when playing the cell phone': 1,
#  'what are the women doing in video': 2,
#  "what color is the girl's hair in the video": 4,
#  'what is the person wearing white pants doing in the video': 1,
#  'what is the person in the video doing': 933,
#  'is the pipe in video straight or curved': 1,
#  'is the person in the video sitting or standing after getting up': 1,
#  'what is the color of the bear in the video': 1,
#  'where is the woman in green standing': 1,
#  'what color clothes is the person wearing blue shorts wearing in the video': 1,
#  'what color is the clip of the black man with the microphone': 1,
#  'what is the color of the trousers the man in orange': 1,
#  'is the person with glasses in the video long hair or short hair': 1,
#  'where does the woman in the video jump': 1,
#  'what color of clothes does the boy in the video wear': 2,
#  'what is the shape of the food in video': 1,
#  'where are the two people in the video': 2,
#  'what is the color of the electric light in the video': 1,
#  'what is the person in purple doing': 1,
#  'where is the man in purple': 1,
#  'where is the swim ring in the video': 1,
#  'what is at the right side of the stairs': 1,
#  "what is the color of the person's coat in video": 1,
#  'is the woman in white standing or sitting in the video': 1,
#  'is the character standing or sitting in video': 2,
#  'what is the color of the refrigerator in video': 1,
#  'what is the person in red in the video doing': 1,
#  'where does the person put the food': 1,
#  'what color is the coat of the woman with glasses in video': 1,
#  'where is the speech draft in the video': 1,
#  'what is on the computer screen': 1,
#  'is the person in video sitting or standing before turning on the light': 1,
#  'where is the girl': 1,
#  'what is the english alphabet in the logo of the car': 1,
#  'what is in the closet': 9,
#  'how many foods are in the pot in video': 1,
#  'is the person wearing hat sitting or standing': 2,
#  'what is the color of the table in the video': 12,
#  'what is the person in black holding in his hand in the video': 1,
#  "what is the color of woman's coat in video": 4,
#  "what is the color of the standing person's clothes in video": 1,
#  'what is the man in blue doing': 2,
#  'where is the toy shelf': 1,
#  'where is the light in the video': 1,
#  'what does the girl in video hold': 1,
#  'where is the man sitting in the video': 5,
#  'where is the person with glasses in video': 1,
#  "what is the color of the man's trousers in video": 1,
#  'where is the person in red in video': 1,
#  'what are in the closet': 1,
#  'what color is the tank in the video': 1,
#  'what is in front of the window': 24,
#  'where are the people holding the parade at': 1,
#  'was the man lying or sitting in the end': 1,
#  'what is the player in the video holding in their hands': 1,
#  'what is on the head of the person sitting in the video': 1,
#  'where is the head image in the video': 1,
#  'is the person standing in the video or sitting': 1,
#  'what is the man testing in the video': 1,
#  'where is the person wearing blue shorts in the video': 1,
#  'how many oranges are there in the video': 1,
#  'what is the person in video doing after getting up': 2,
#  'what is on the cooktop in the video': 1,
#  'where is the person carrying a bag in the video': 1,
#  'what is onn the chair': 1,
#  'what is the girl doing at the end of the video': 1,
#  'what is in front of the adult in the video': 2,
#  'what is on the tv cabinet': 1,
#  'where was the third photo taken in the video': 1,
#  'what is the child doing in video': 1,
#  'which animal in the video is sprawling upstairs': 1,
#  'what is the girl in the video doing': 4,
#  'what color of the clothes does the person wear at the beginning of the video': 5,
#  'the person sitting in the chair is a man or a woman': 1,
#  'what color is the dress of the woman dancing in video': 1,
#  'where is the man in video': 9,
#  'is the screen on the computer in the video bright or not': 1,
#  'what is the person with hair braiding in the video doing': 1,
#  'what is the gender of the person who is opening the door in the video': 1,
#  'what is the person standing in the scene in the video': 1,
#  'what is the person in white clothes doing in the video': 1,
#  'is the person wearing the purple dress standing or sitting': 1,
#  'what is in the corridor': 8,
#  'where does the man in the video put his clothes': 1,
#  "what is the color of the person's shoes in the video": 2,
#  'what is on the bedside table': 1,
#  'where is the person with hair braiding in the video': 1,
#  'what color is the wall': 50,
#  'what color t-shirt does the person wear in the video': 2,
#  'how many people are singing in the video': 1,
#  'where are those two people': 1,
#  'which of the hands holds the phone': 1,
#  'what color is the leading car in the video': 1,
#  'what is the backpacker in the video doing': 1,
#  'is the person playing baseball in the video sitting or standing': 1,
#  'where is the person in the beginning of the video': 1,
#  'what is the little girl doing in the video': 1,
#  'is it competing or training in the video': 1,
#  'what is under the electronics in video': 1,
#  'what color hair does the person have in the video': 3,
#  'what is on the car monitor in video': 1,
#  'what graphics are the people in the video': 1,
#  'is the tire standing or sideways in the video': 1,
#  'what is on the ground in the video': 18,
#  'what is placed on the table in the video': 1,
#  'is the person in the video looking in the mirror sitting or standing': 1,
#  'where is the chair': 6,
#  "what is on the person's head in the second video": 1,
#  'is the person against the wall sitting or standing in the video': 1,
#  'is the person holding the umbrella in the video sitting or standing': 1,
#  'is the person in short black sleeves sitting or standing': 1,
#  'what is the background color of the third picture in the video': 1,
#  'where does the woman in the video put her clothes': 2,
#  'what color are the shoes of the person wearing white pants': 1,
#  'what is on the face of the person wearing rosy red dress': 1,
#  'what color is the butterfly sticker in the video': 1,
#  'where does the woman in the video sit': 1,
#  'what is the old man doing in video': 1,
#  'is man standing or sitting in video': 1,
#  'what are the people doing in video': 6,
#  "what is the shape of rubik's cube in video": 1,
#  'where is the water bucket': 1,
#  'where is the bolster': 2,
#  'what is the cursor doing in video': 1,
#  'where is the animal in the video': 7,
#  "what color is the person's clothes who is eating in the video": 1,
#  'is the typing method in the video simple or difficult': 1,
#  'what is the cat in video on': 1,
#  "what is the color of the person's skirt in the video": 1,
#  'what is introduced in the video': 1,
#  'is the child with a necklace sitting or standing': 1,
#  'what color is the tool for loading flour': 1,
#  'does the man in the video have long or short hair': 2,
#  'what is on the right of the bed': 1,
#  "what is on the person's hand": 1,
#  'what is in video': 5,
#  'is the person wearing glasses in the video standing or sitting': 3,
#  "what is on the person's head in the first video": 1,
#  'what is the bald head in the video doing': 1,
#  'is the person wearing plaid shirt in the video sitting or standing': 1,
#  'is the car singer door or double door': 1,
#  'what does the person put in the box in the video': 1,
#  'where is the person in the video at the beginning': 3,
#  'where is the vase in the video': 2,
#  'what color is the dinosaur in the video': 1,
#  "what color is the man's top in the video": 1,
#  'what is the person in the video sitting on': 4,
#  'what is in front of the person in striped clothes': 1,
#  'where is the woman with short hair': 1,
#  'what is wearing on the head in the video': 1,
#  'what is the boy doing': 2,
#  'where is the tv hanging on': 1,
#  'is the person sitting or standing on the stage': 2,
#  'where is the fruit in the video': 1,
#  'what color top does the person wearing hat in the video wear': 1,
#  'where is the person wearing a red headscarf': 1,
#  'what is on the table-board': 1,
#  'where is the person in black trousers with white stripes in video': 1,
#  'is the person singing in the video long hair or short hair': 1,
#  'is the person sitting or standing while putting down books in the video': 1,
#  'where is the plant in the video': 2,
#  'what is on the food in video': 1,
#  'what color is the basin in video': 2,
#  "what is the color of the person's hair in the video": 15,
#  'what is on the stake': 1,
#  'what is placed on the right side of the person in the video': 1,
#  'where is the flower pot': 1,
#  'what is the man wearing a hat doing': 1,
#  "is it men's or women's volleyball in video": 1,
#  'what is the person holding a cup doing in the video': 1,
#  'where is the bike': 1,
#  'what color of clothes does the woman in the video wear': 13,
#  'where is the man taking off clothes': 1,
#  ...}

# %%
len(frequency_question)
# Out:
# 4447

# %%
sort_answer=sorted(frequency_answer.items(),key=lambda e:e[1],reverse=True)
sort_question=sorted(frequency_question.items(),key=lambda e:e[1],reverse=True)

# %%
len(frequency_answer)
# Out:
# 4730

# %%
len(sort_answer)
# Out:
# 4730

# %%
sort_question
# Out:
# [('where is the person in the video', 1266),
#  ('what is the person in the video doing', 933),
#  ('what is the person doing in the video', 794),
#  ('is the person in the video standing or sitting', 546),
#  ('is the person in the video sitting or standing', 507),
#  ('is the person sitting or standing in the video', 450),
#  ('what is in the video', 316),
#  ('what is on the table', 224),
#  ('where is the person in video', 194),
#  ('what is in the room', 182),
#  ('what can you see in the video', 163),
#  ('what color of the clothes does the person wear in the video', 162),
#  ('what is the man in the video doing', 137),
#  ('what is the man doing in the video', 132),
#  ('is the person standing or sitting in the video', 131),
#  ('what is in front of the person in the video', 130),
#  ('what is the person in video doing', 121),
#  ('what color clothes does the person wear in the video', 121),
#  ('what is the person doing in video', 108),
#  ('where is the man', 108),
#  ("what is the color of the person's clothes in video", 106),
#  ('what is the man doing', 106),
#  ('is the man in the video standing or sitting', 105),
#  ('where is the man in the video', 96),
#  ("what is the color of the person's clothes in the video", 94),
#  ('what color clothes does the person in the video wear', 90),
#  ("what color is the person's clothes in the video", 89),
#  ('what is the woman in the video doing', 88),
#  ('what is the color of the wall', 85),
#  ('is the man standing or sitting', 84),
#  ('what is the color of the clothes of the person in the video', 74),
#  ('what is on the table in the video', 71),
#  ('what color pants does the person wear in the video', 65),
#  ('what is in the living room', 58),
#  ('is the man sitting or standing in the video', 58),
#  ('what is on the wall', 57),
#  ('what is the woman doing in the video', 56),
#  ('is the person in video sitting or standing', 56),
#  ('what color does the person wear in the video', 55),
#  ('what is the gender of the person in the video', 53),
#  ('what color is the wall', 50),
#  ('where is the woman in the video', 50),
#  ('what is on the bed', 50),
#  ('is the woman in the video standing or sitting', 49),
#  ("what color are the person's clothes in the video", 46),
#  ('what is in front of the wall', 39),
#  ('is the person in the video long hair or short hair', 37),
#  ('what is the color of the wall in the video', 37),
#  ('what is the color of the clothes the man wears', 37),
#  ('is the woman in the video sitting or standing', 37),
#  ('what is the woman doing', 37),
#  ('what is the color of the clothes does the man wear', 36),
#  ('what color clothes does the man wear in the video', 36),
#  ('what is the person doing', 36),
#  ('what is the color of the clothes in the video', 36),
#  ("what is in the man's hands", 36),
#  ('where is the cup', 36),
#  ('where is the woman', 35),
#  ('what color clothes does the woman wear in the video', 35),
#  ('what is on the face of the person in the video', 33),
#  ('is the person in video standing or sitting', 33),
#  ("what is in the man's hand", 31),
#  ('is the man in the video sitting or standing', 31),
#  ('is the person in the video standing or lying', 31),
#  ('what is in the kitchen', 30),
#  ('what is on the desk', 29),
#  ('is the man standing or sitting in the video', 28),
#  ('what is the color of the clothes the man wears in the video', 28),
#  ('what color of clothes does the man in the video wear', 28),
#  ('what color of the clothes does the man wear in the video', 26),
#  ('is the woman standing or sitting in the video', 26),
#  ('what can you see in video', 26),
#  ('what is on the wall in the video', 26),
#  ('what color is the wall in the video', 25),
#  ('what does the man in the video hold in his hand', 25),
#  ('what is in the hand of the person in the video', 25),
#  ('what color clothes does person in the video wear', 24),
#  ('what is in front of the window', 24),
#  ('is the woman sitting or standing', 24),
#  ('what color of the pants does the person wear in the video', 23),
#  ("what is on the person's face in the video", 23),
#  ('does the person have long hair or short hair', 22),
#  ('what color of the clothes does the woman wear in the video', 22),
#  ('where is the computer', 21),
#  ('what color top does the person wear in the video', 21),
#  ('what is the color of the clothes does the person wear in video', 20),
#  ('what is the color of the pants of the person in the video', 20),
#  ('where is the book', 19),
#  ('where is the person', 19),
#  ('what color clothes is the person wearing in the video', 19),
#  ('what is behind the person in the video', 19),
#  ('what is on the ground', 19),
#  ('what color does the person wear', 19),
#  ('what is on the ground in the video', 18),
#  ('does the person have long hair or short hair in the video', 18),
#  ('is the person standing or sitting in video', 18),
#  ('what color does the man wear in the video', 18),
#  ('is the woman in the video long hair or short hair', 17),
#  ('what is on the floor', 17),
#  ('what is on the table in video', 17),
#  ("what is the color of the person's trousers in video", 17),
#  ('is the woman standing or sitting in video', 15),
#  ('what is the woman doing in video', 15),
#  ('where is the computer in the video', 15),
#  ('what is on the right of the person in the video', 15),
#  ("what is the color of the person's hair in the video", 15),
#  ("what color is the person's coat in video", 15),
#  ('what is the color of the trousers does the person wear in video', 15),
#  ('what color of the jacket does the person wear in the video', 15),
#  ('what color of upper outer garment does the person in the video wear', 15),
#  ("what is in the woman's hands", 15),
#  ('where is the mirror in the video', 14),
#  ('is the person in the video sitting or lying', 14),
#  ('where is the clothes', 13),
#  ('what color of clothes does the woman in the video wear', 13),
#  ('is the person in the video sitting or standing at first', 13),
#  ("what is the color of the woman's clothes in the video", 13),
#  ('what is on the cabinet', 13),
#  ('where is the car in the video', 13),
#  ('what color coat does the person wear in the video', 13),
#  ('where is the bottle', 12),
#  ('what is the color of the door in the video', 12),
#  ('what does the person wear on head in the video', 12),
#  ('is the person in the video sitting or standing at the beginning', 12),
#  ('what is the color of the clothes the woman wears', 12),
#  ('what is the color of the car in the video', 12),
#  ('what is the color of the table in the video', 12),
#  ('what is the color of the clothes does the woman wear', 12),
#  ('what is on the cooktop', 12),
#  ('what is the cartoon character doing in the video', 12),
#  ('what is the man doing in video', 12),
#  ('where is the mirror', 12),
#  ('is the person standing or sitting in the beginning of the video', 11),
#  ('is the woman sitting or standing in the video', 11),
#  ('where is the cartoon character in the video', 11),
#  ("what is in the person's hand", 11),
#  ('where is the woman in video', 11),
#  ('what color is the car in the video', 11),
#  ('what is on the sofa', 11),
#  ("what is the color of the person's pants in the video", 11),
#  ("what color is the man's clothes in the video", 10),
#  ('is the person in video sitting or standing at the beginning', 10),
#  ('what is on the washing machine', 10),
#  ("what is in the woman's hand", 10),
#  ('where is the cup in the video', 10),
#  ('what color is the chair in the video', 10),
#  ('where is the laptop', 10),
#  ('what is the color of the coat does the person wear in video', 10),
#  ('what does the person wear on face in the video', 10),
#  ('what is the girl doing in the video', 10),
#  ('what color is the clothes worn by the person in the video', 10),
#  ('is the man in the video long hair or short hair', 10),
#  ('where is the tv', 10),
#  ('what is the color of the wall in video', 10),
#  ('how many people are there in the video', 10),
#  ('where is the mural', 9),
#  ('what is in the closet', 9),
#  ('where is the man in video', 9),
#  ("what is on the man's face in the video", 9),
#  ("what is the color of the woman's clothes", 9),
#  ('what is in the cabinet', 9),
#  ('what is the color of the clothes of the man in the video', 9),
#  ('what is the woman holding in the video', 9),
#  ("what is in the person's hand in the video", 9),
#  ('is the person in the video short hair or long hair', 9),
#  ('what is on the face of the man in the video', 8),
#  ('what is the girl doing in video', 8),
#  ('is the person sitting or lying in the video', 8),
#  ('what is on the left of the person in the video', 8),
#  ('what is in front of the door in the video', 8),
#  ('what is in the corridor', 8),
#  ('is the man standing or sitting in video', 8),
#  ("what is on the person's head in the video", 8),
#  ('where is the person sitting in the video', 8),
#  ('is the person in the video sitting or lying down', 8),
#  ('what is the color of the chair in the video', 8),
#  ('what color is the sofa in the video', 8),
#  ('is the girl standing or sitting in the video', 8),
#  ('what is the color of the sofa in the video', 8),
#  ('what is the color of the clothes of the woman in the video', 8),
#  ('what color is the cabinet', 8),
#  ('what is the color of the cabinet in the video', 8),
#  ('where is the towel', 8),
#  ('what does the man in the video wear on his head', 8),
#  ('is the woman standing or sitting', 8),
#  ('where is the pillow', 8),
#  ('what is the color of the blanket in the video', 8),
#  ('what is the color of the trousers the man wears', 8),
#  ('how many people are in the video', 8),
#  ('what does the man wear on head in the video', 7),
#  ('what color of the coat does the person wear in the video', 7),
#  ('what is hanging on the wall in the video', 7),
#  ('where is the chair in the video', 7),
#  ('where are the clothes', 7),
#  ('where is the animal in the video', 7),
#  ('what is on the stairs', 7),
#  ("what color is the person's hair in the video", 7),
#  ('where is the bottle in the video', 7),
#  ('is the man standing or sitting at last', 7),
#  ('what is the color of the refrigerator in the video', 7),
#  ('what is the child in the video doing', 7),
#  ('is the girl standing or sitting in video', 7),
#  ('what is the color of the car', 7),
#  ('what color pants does the person in the video wear', 7),
#  ('what is on the stage', 7),
#  ('is the door in the video open or closed', 7),
#  ('what is the color of the curtain in the video', 7),
#  ("what is the color of the man's clothes in the video", 6),
#  ('what does the person in video wear on his head', 6),
#  ('what does the person in video have on their face', 6),
#  ('what is the person in the video', 6),
#  ('what is on the storage rack', 6),
#  ('what animal is in the video', 6),
#  ('where is the child in the video', 6),
#  ('what is on the shelf', 6),
#  ('is the man in the video standing or sitting at the beginning', 6),
#  ('where is the chair', 6),
#  ('what are the people doing in video', 6),
#  ('what color pants does the man wear in the video', 6),
#  ('what is in front of the door', 6),
#  ('what color is the refrigerator', 6),
#  ('what is on the closet', 6),
#  ('what color top does the person in the video wear', 6),
#  ("what color is the person's top in the video", 6),
#  ('what color dress does the person wear in the video', 6),
#  ('is the boy in the video standing or sitting', 6),
#  ('what is in the person is hand in the video', 6),
#  ('what does the man in the video hold', 6),
#  ('what is the color of the pants does the man wear', 6),
#  ('what is on the hearth', 6),
#  ('what does the man in the video sit on', 6),
#  ("what color is the person's pants in the video", 6),
#  ('is the person in video in the living room or in the kitchen', 6),
#  ('what color is the pot in the video', 6),
#  ("what is the color of the living room's wall", 6),
#  ('what is on the countertop', 5),
#  ('what is the person holding in his hand in the video', 5),
#  ('what is in the toilet', 5),
#  ('what time is it in the video', 5),
#  ("what is the color of woman's clothes in video", 5),
#  ('how many people appeared in the video', 5),
#  ('what color of clothes does the person in the video wear', 5),
#  ('is the television turned on or off in the video', 5),
#  ('is the person lying or sitting in the beginning of the video', 5),
#  ('where are the people in video', 5),
#  ('what is the person wearing glasses in the video doing', 5),
#  ('where is the pillow in the video', 5),
#  ('where is the man sitting in the video', 5),
#  ('what color of the clothes does the person wear at the beginning of the video',
#   5),
#  ('what is in video', 5),
#  ('where is the book in the video', 5),
#  ('where is the pen in the video', 5),
#  ('how many people appear in the video', 5),
#  ('what color is the hat in the video', 5),
#  ('where is the boy in the video', 5),
#  ('what is at the back of the door', 5),
#  ('is the text in the video horizontal or vertical', 5),
#  ('what does the person in the video hold', 5),
#  ('what is on the cabinet in the video', 5),
#  ('what is the animal in the video', 5),
#  ("what is the color of person's coat in video", 5),
#  ('what does the man wear on face in the video', 5),
#  ('where is the girl in the video', 5),
#  ('what is on the wall in video', 5),
#  ('what is the man wearing on the head in the video', 5),
#  ('what is in the bathroom', 5),
#  ('what color is the door in the video', 5),
#  ('what is in front of the woman in the video', 5),
#  ('what is the color of the trousers the man wears in the video', 5),
#  ('what is the man in the video', 5),
#  ('is the cartoon character in the video sitting or standing', 5),
#  ("what is the color of man's clothes in video", 5),
#  ('what does the person open in the video', 5),
#  ('is the man sitting or standing', 5),
#  ("what is on the person's hand in the video", 5),
#  ('is the person standing or sitting at the beginning of the video', 5),
#  ('where is the audience in the video', 5),
#  ('what is the boy doing in the video', 5),
#  ('what is on the head of the person in the video', 5),
#  ('where are the shoes', 5),
#  ('where are the shoes in the video', 5),
#  ('is the person sitting or standing at the beginning of the video', 5),
#  ('what color coat does the person in the video wear', 5),
#  ('what is the color of the sofa', 5),
#  ('are the people standing or sitting in video', 5),
#  ('what sports have appeared in video', 5),
#  ('where is the plate in the video', 5),
#  ('what is the man holding in the video', 5),
#  ('where is the carton', 5),
#  ('how many people have appeared in the video', 5),
#  ('what color is the carpet in the video', 4),
#  ('where is the television', 4),
#  ('what is the person wearing on his head in the video', 4),
#  ('what is on the stool', 4),
#  ('where is the paper box', 4),
#  ('what color shoes does the person wear in the video', 4),
#  ('is the man in video sitting or standing', 4),
#  ('what is in the hands of the person in the video', 4),
#  ("what is on the woman's face in the video", 4),
#  ('what does the woman wear on head in the video', 4),
#  ('what color is the door', 4),
#  ('what does the woman in the video hold in her hand', 4),
#  ('what is the boy in the video doing', 4),
#  ('what is the person wearing black clothes doing in the video', 4),
#  ("what color is the girl's hair in the video", 4),
#  ("what is the color of woman's coat in video", 4),
#  ('what is the girl in the video doing', 4),
#  ('what is the person in the video sitting on', 4),
#  ("what is the color of person's clothes in video", 4),
#  ('what does the person hold in hand in the video', 4),
#  ('is the girl in the video standing or sitting', 4),
#  ('is the person in video a man or a woman', 4),
#  ('what is the kid doing in the video', 4),
#  ('what is in the car', 4),
#  ("what color is the woman'hair in video", 4),
#  ('what is the child doing in the video', 4),
#  ('what color of the pants does the woman wear in the video', 4),
#  ('what color is the floor in the video', 4),
#  ('what is the color of the refrigerator', 4),
#  ('where are the people in the video', 4),
#  ('what does the person in video have in his hand', 4),
#  ('is the text in the video english or chinese', 4),
#  ('where is the person standing in the video', 4),
#  ('where is the photo', 4),
#  ('what color hat does the man wear in the video', 4),
#  ("what color is the woman's hair in the video", 4),
#  ('what color is the woman is hair in the video', 4),
#  ('where is the toy in the video', 4),
#  ('what is the animal doing in the video', 4),
#  ('what is wearing on the head of the person in the video', 4),
#  ('what is the person holding in the video', 4),
#  ('what color of the pants does the man wear in the video', 4),
#  ('what does the woman in the video hold', 4),
#  ('is the audience standing or sitting', 4),
#  ('where is the water glass in the video', 4),
#  ('where is the refrigerator in the video', 4),
#  ('what color is the table in the video', 4),
#  ('what is the person in video holding in his hands', 4),
#  ('what is the man in video doing', 4),
#  ('what is on the right of the door', 4),
#  ('what is in the washing room', 4),
#  ('is the person singing in the video sitting or standing', 4),
#  ('what is on the table in the kitchen', 4),
#  ('is the person holding the broom sitting or standing', 4),
#  ('what is on the bed in video', 4),
#  ('what color is the background in video', 4),
#  ('where is the blanket in the video', 4),
#  ('what does the person in video wear on his face', 4),
#  ('what is in front of the person in video', 4),
#  ('where is the box in the video', 4),
#  ('where is the person in white', 4),
#  ('where is the floor lamp in the video', 4),
#  ('what color top does the person wearing glasses in the video wear', 4),
#  ('what does the person turn on in the video', 4),
#  ('what is the person in stripe shirt doing in the video', 4),
#  ('what is the person in white doing in the video', 4),
#  ('what is behind the door', 4),
#  ('where is the switch', 4),
#  ('is the person in the video standing or squatting', 4),
#  ('what is the person in white doing', 4),
#  ('where are the books in the video', 4),
#  ('where is the table in the video', 4),
#  ('is the light turned on or off in the video', 4),
#  ('what is the first person in the video doing', 4),
#  ('where is the guitar', 4),
#  ('what color of the dress does the person wear in the video', 4),
#  ('what is the person in the video holding', 4),
#  ('what is on the door', 4),
#  ('what does the woman in the video wear on her face', 4),
#  ('is the cartoon character sitting or standing in the video', 4),
#  ('what is the color of the floor in the video', 4),
#  ('what is the color of the cat in the video', 4),
#  ('what is on the refrigerator', 4),
#  ('is the text in the video written in english or chinese', 4),
#  ('where does the man in the video sit', 3),
#  ('what is behind the refrigerator', 3),
#  ('is the man in purple standing or sitting', 3),
#  ('what is the wall full of in the video', 3),
#  ('what color is the chair in video', 3),
#  ('what does the man in video wear on his head', 3),
#  ('what color of the clothes does the girl wear in the video', 3),
#  ("what color are the woman's clothes in the video", 3),
#  ('what is on the bed in the video', 3),
#  ('what is in the room in the video', 3),
#  ('what color top does the woman wear in the video', 3),
#  ('what is the color of the washing machine', 3),
#  ('what color is the cup', 3),
#  ("what is the color of the child's clothes in the video", 3),
#  ('where is the laundry detergent', 3),
#  ('what does the girl wear on head in the video', 3),
#  ('what is on the pool table', 3),
#  ("what is in the woman's hand in the video", 3),
#  ('what happens in video', 3),
#  ('what color is the table', 3),
#  ('what color is the refrigerator in the video', 3),
#  ('is the text in the video chinese or english', 3),
#  ('what is the man wearing on the neck in the video', 3),
#  ('what is the animal that appears in the video', 3),
#  ('what color is the dress of the person in the video', 3),
#  ('does the woman have long hair or short hair in the video', 3),
#  ('what color hair does the person have in the video', 3),
#  ('is the person wearing glasses in the video standing or sitting', 3),
#  ('where is the person in the video at the beginning', 3),
#  ('is the man standing or sitting at the beginning', 3),
#  ('what is the woman in black doing', 3),
#  ('what is the person wearing pink in the video doing', 3),
#  ('what does the man wear around his neck in the video', 3),
#  ('what color is the chair', 3),
#  ('what is hanging on the wall', 3),
#  ('what is the adult doing in the video', 3),
#  ('what color is the horse in the video', 3),
#  ('are people standing or sitting in the video', 3),
#  ('what is the occupation of the person in the video', 3),
#  ('where is the tv in the video', 3),
#  ('what is behind the chair', 3),
#  ('what is on the lawn', 3),
#  ('is the person in red sitting or standing in the video', 3),
#  ('what is the person wearing glasses doing in the video', 3),
#  ('what color is the dog in the video', 3),
#  ('what color is the desk in the video', 3),
#  ('what is the color of the hat of the person in the video', 3),
#  ('what color of the t-shirt does the person wear in the video', 3),
#  ('what does the man hold in hands in the video', 3),
#  ('is the person wearing white clothes in the video sitting or standing', 3),
#  ('what color dress does the girl wear in the video', 3),
#  ('where is the computer in video', 3),
#  ('what color is the subtitle in the video', 3),
#  ('where is the sofa in the video', 3),
#  ('is the person wearing black pants standing or sitting', 3),
#  ('is the person in the video man or woman', 3),
#  ('where is the mirror placed in the video', 3),
#  ('what color does the boy wear in the video', 3),
#  ('is the animal appearing in the video a cat or a dog', 3),
#  ('what is the game character doing in the video', 3),
#  ('what is the color of the broom in the video', 3),
#  ('where is the phone in the video', 3),
#  ('what does the man in video wear on his face', 3),
#  ('where is the audience', 3),
#  ('where is the person in red', 3),
#  ('is the person wearing a hat in the video long hair or short hair', 3),
#  ('what is the color of the towel in the video', 3),
#  ('where is the person at the beginning of the video', 3),
#  ('is the person in pink sitting or standing in the video', 3),
#  ('what are the hands doing in the video', 3),
#  ('is the person in black sitting or standing in the video', 3),
#  ('what is on the floor in the video', 3),
#  ("what is on the man's head in the video", 3),
#  ('where is the table', 3),
#  ('where is the water bottle in the video', 3),
#  ('is the person in the video sitting or lying at first', 3),
#  ('is the person in video have short hair or long hair', 3),
#  ('what is the color of the cup', 3),
#  ('what is the color of the coat the man wears in the video', 3),
#  ('what is the color of the table', 3),
#  ('is the tv on or off', 3),
#  ('where are the two people in video', 3),
#  ('what does the girl in video wear on her head', 3),
#  ('is the child in the video sitting or standing', 3),
#  ('what is the person wearing black pants doing', 3),
#  ('what is behind the people in the video', 3),
#  ('what is the color of the sheet in the video', 3),
#  ('what is the color of the computer', 3),
#  ('what is the color of the computer in the video', 3),
#  ('what color clothes is the woman wearing in the video', 3),
#  ('what is in front of the chair', 3),
#  ('what is on the glass table', 3),
#  ('what is on the person in the video', 3),
#  ("what color is the man's hair in the video", 3),
#  ('what does the person hold in hands in the video', 3),
#  ('where is the cat in the video', 3),
#  ('what is on the chair', 3),
#  ('what does the person wear on his head', 3),
#  ('what is behind the person', 3),
#  ('what is in front of the sofa', 3),
#  ('what are the men in the video doing', 3),
#  ('where is the table lamp', 3),
#  ('what is in front of the mirror', 3),
#  ('what is at the back of the person in the video', 3),
#  ('what is on video', 3),
#  ('what is the person sitting in the video doing', 3),
#  ('is the woman in the video straight or curly', 3),
#  ('what is the background color in the video', 3),
#  ('what color is the background wall in the video', 3),
#  ('how many people are in video', 3),
#  ('what is worn on the hand of the person in the video', 3),
#  ('what is in the refrigerator', 3),
#  ('what is the color of the clothes of the person sitting in the video', 3),
#  ('what is the person doing in the first video', 3),
#  ('is the person in glasses sitting or standing', 3),
#  ('what is the person wearing the hat doing in the video', 3),
#  ('what color is the sky in video', 3),
#  ('is the woman in video sitting or standing', 3),
#  ('what color is the leaf in the video', 3),
#  ('is the person standing or lying in the video', 3),
#  ('is the window in the video open or closed', 3),
#  ('what color of the clothes does the boy wear in the video', 3),
#  ('where is the painting', 3),
#  ('what does the man in the video wear on his face', 3),
#  ('what is in front of the man', 3),
#  ('what is the person wearing the video', 3),
#  ('is the person sitting or standing at the beginning in the video', 3),
#  ('what is the color of the dress does the woman wear', 3),
#  ('is the person in black sitting or standing', 3),
#  ('what color is the light in the video', 3),
#  ('what is the athlete in the video doing', 3),
#  ('what is the color of the sheets in the video', 3),
#  ('what is the person in white clothes doing', 3),
#  ('what does the woman in video wear on her face', 3),
#  ('what is in the bedroom', 3),
#  ('what is in front of the table', 3),
#  ('is the person wearing glasses standing or sitting in the video', 3),
#  ('what is on the tea table', 3),
#  ('what is the color of the pillow in the video', 3),
#  ('what is the person with glasses doing in the video', 3),
#  ('what does the person in the video hold in the hands', 3),
#  ('what does the person in video hold', 3),
#  ('what color is the cabinet in the video', 3),
#  ('is the boy standing or sitting in the video', 3),
#  ('what is the baby doing in the video', 3),
#  ('is the man in the video straight or curly', 3),
#  ('where is the car', 3),
#  ('what color is the sheet', 3),
#  ('does the woman in the video have long hair or short hair', 3),
#  ('what is the person in blue doing in the video', 3),
#  ('is the woman in the video lying down or sitting', 2),
#  ('where is sofa in video', 2),
#  ('is the referee in the video sitting or standing', 2),
#  ('where is the number plate in the video', 2),
#  ('what are the animals in video', 2),
#  ('what is the color of the bag in the video', 2),
#  ("what is the color of the woman's hair", 2),
#  ('what is the sport in the video', 2),
#  ('what is on the front of the door', 2),
#  ('does the person wear pants or shorts', 2),
#  ('what does the person have in his hand', 2),
#  ('is the person lying or seated in the video', 2),
#  ('where is the person in the second video', 2),
#  ('what color is the microphone in the video', 2),
#  ('where is switch', 2),
#  ('what color is the dress worn by the woman in the video', 2),
#  ('how many game figures are in the video', 2),
#  ('is the lamp on or off', 2),
#  ('where is the goblet', 2),
#  ('what color shoes does the woman wear in the video', 2),
#  ('what color is the phone in the video', 2),
#  ('where is the pan in the video', 2),
#  ('where does the man in the video put the book', 2),
#  ('what color is the nail in the video', 2),
#  ('are the two men in the video standing or sitting', 2),
#  ('what is in front of the man in the video', 2),
#  ('what color clothes does the person with white hair wear in the video', 2),
#  ('what is in the right hand of the person in the video', 2),
#  ('what color of the clothes does the child wear in the video', 2),
#  ('what is the color of the cabinet', 2),
#  ('what is playing in video', 2),
#  ('is the person with glasses in video standing or sitting', 2),
#  ('how many kids are there in the video', 2),
#  ('what is the color of the hair of the person in green in the video', 2),
#  ('how many cars are there in the video', 2),
#  ('where is the ball in the video', 2),
#  ('is the cartoon character in the video standing or sitting', 2),
#  ('what does the man wear on his wrist in the video', 2),
#  ('what color is the bowl in the video', 2),
#  ('where is the man in black pants', 2),
#  ('is the person wearing blue clothes standing or sitting', 2),
#  ('where is the person singing in the video', 2),
#  ('is the woman in video standing or sitting', 2),
#  ('what color of pants does the man in the video wear', 2),
#  ('is the person wearing white clothes in the video standing or sitting', 2),
#  ('where is the person in the first video', 2),
#  ('what is in the bag', 2),
#  ('where is the towel in the video', 2),
#  ('is the man with white hair in the video standing or sitting', 2),
#  ('what are the men doing in video', 2),
#  ('what is on the left of the door', 2),
#  ('what is the color of the clothes of the adult in the video', 2),
#  ('what is at the back of the chair', 2),
#  ('where is the man lying on in the video', 2),
#  ('what is the color of the hair of the person in the video', 2),
#  ('is the cartoon character standing or sitting in video', 2),
#  ('what color is the cover in the video', 2),
#  ('what is the color of the pot in the video', 2),
#  ('is the person in white in the video standing or sitting', 2),
#  ('where is man in video', 2),
#  ('where is the beverage', 2),
#  ('what vehicle is in the video', 2),
#  ('what color is the wall space in video', 2),
#  ('is the person wearing black clothes in the video long hair or short hair',
#   2),
#  ('where does the person sit in the video', 2),
#  ('what is behind the woman', 2),
#  ('what color is the laptop in the video', 2),
#  ('where is the poster', 2),
#  ('is the boy standing or sitting in video', 2),
#  ('what is the background in video', 2),
#  ('what are the women doing in video', 2),
#  ('what color of clothes does the boy in the video wear', 2),
#  ('where are the two people in the video', 2),
#  ('is the character standing or sitting in video', 2),
#  ('is the person wearing hat sitting or standing', 2),
#  ('what is the man in blue doing', 2),
#  ('what is the person in video doing after getting up', 2),
#  ('what is in front of the adult in the video', 2),
#  ("what is the color of the person's shoes in the video", 2),
#  ('what color t-shirt does the person wear in the video', 2),
#  ('where does the woman in the video put her clothes', 2),
#  ('where is the bolster', 2),
#  ('does the man in the video have long or short hair', 2),
#  ('where is the vase in the video', 2),
#  ('what is the boy doing', 2),
#  ('is the person sitting or standing on the stage', 2),
#  ('where is the plant in the video', 2),
#  ('what color is the basin in video', 2),
#  ('what is the horse doing in video', 2),
#  ('what is the color of the clothes of the person with glasses in the video',
#   2),
#  ('where is the monster in the video', 2),
#  ('in which room is the man in the video', 2),
#  ('what is on the refrigerator in the video', 2),
#  ('what is the color of the computer desktop in the video', 2),
#  ("what is the color of the man's clothes at the beginning of the video", 2),
#  ('what color is the number in the video', 2),
#  ('where is the remote control', 2),
#  ('what is on the left of the wall', 2),
#  ('what is in front of the child in the video', 2),
#  ('what is the color of the clothes does the person wear while eating in video',
#   2),
#  ("what color is the woman's clothes in the video", 2),
#  ('what color of skirt does the woman in the video wear', 2),
#  ('where does the person enter in the video', 2),
#  ('what color is the blanket in video', 2),
#  ('where is the doll in the video', 2),
#  ('what color is the cartoon character in the video', 2),
#  ('what does the girl hold in hand in the video', 2),
#  ('what is on the shelf in video', 2),
#  ('what is on the sofa in video', 2),
#  ('what did the person in the video open', 2),
#  ('what is the color of the blanket in video', 2),
#  ('is the lamp opening or closed in the video', 2),
#  ('where is the backpack in the video', 2),
#  ('what is in the hand of the man in the video', 2),
#  ("what is on the woman's ear", 2),
#  ('what is hanging on the window in the video', 2),
#  ('what color is the floor', 2),
#  ('what is on the back of the person in the video', 2),
#  ('what does the woman in the video hold in her right hand', 2),
#  ('is the person sitting or standing while eating in the video', 2),
#  ('where is the person at last in the video', 2),
#  ("what is the color of the person's hair", 2),
#  ('what is in the basin in the video', 2),
#  ('what is the hand doing in the video', 2),
#  ('what is the green stuff in video', 2),
#  ('where is the scarf', 2),
#  ('what color is english in the video', 2),
#  ('is the person in the video sitting or squatting', 2),
#  ('where is the refrigerator', 2),
#  ('where does the person lie', 2),
#  ('what is the adult in the video doing', 2),
#  ('what color are the numbers in video', 2),
#  ('what is the person in green doing in the video', 2),
#  ('what does the person have on his left hand', 2),
#  ('where is the phone', 2),
#  ('is the person applauding in the video sitting or standing', 2),
#  ("what color is the girl'hair in video", 2),
#  ('what is the color of the stool', 2),
#  ('what is the color of the bolster in the video', 2),
#  ('where is the coat', 2),
#  ('what color is the roof in the video', 2),
#  ('what is on the window sill', 2),
#  ('where is the kettle', 2),
#  ('what is the computer doing in the video', 2),
#  ('is the cursor in video moving', 2),
#  ('was the man standing or sitting in the end', 2),
#  ('is the person wearing glasses', 2),
#  ('is the curtain in the video open or closed', 2),
#  ('what is the girl in black in video holding in her hand', 2),
#  ('what color is the curtain in the video', 2),
#  ('what is in the hand of the girl in the video', 2),
#  ('what color clothes does the person in the first scene wear', 2),
#  ('what is the little boy in the video doing', 2),
#  ('does the woman in video have straight hair or curly hair', 2),
#  ('what color hair does the woman have in the video', 2),
#  ('what does the person drink', 2),
#  ('where is the washing machine', 2),
#  ('where is the horse in the video', 2),
#  ('what is the person doing with his hands in the video', 2),
#  ('what is the color of the bottle', 2),
#  ('is the person in white standing or sitting in the video', 2),
#  ('what color of clothes does the man squatting in the video wear', 2),
#  ('what is in the hallway', 2),
#  ('what kind of transportation does video have', 2),
#  ('what is the woman with short hair doing', 2),
#  ('what is the color of the closet', 2),
#  ('is the person in the video standing or lying down', 2),
#  ('does the person in video have a beard on their face', 2),
#  ('where is the room in the video', 2),
#  ('is the referee in the video standing or sitting', 2),
#  ('what is on the table of the kitchen', 2),
#  ('what color of the clothes does the cartoon character wear in the video', 2),
#  ('what is the color of the balloon in the video', 2),
#  ('what is on the table in front of the man', 2),
#  ('where is the television in the video', 2),
#  ('is the singing person sitting or standing in the video', 2),
#  ('what is the plane doing in the video', 2),
#  ('what is the men doing in video', 2),
#  ('what is the person in red doing', 2),
#  ('is the person on the stage standing or sitting in the video', 2),
#  ('what is in the dishes', 2),
#  ('what are the athletes in the video doing', 2),
#  ('what is in the box', 2),
#  ('where is the hanger in the video', 2),
#  ('what is in the fridge in the video', 2),
#  ('is the door open or closed in the video', 2),
#  ('what does the person wear in the video', 2),
#  ('where is the boy', 2),
#  ('what is in front of the cabinet', 2),
#  ('is the last person in the video standing or sitting', 2),
#  ('what color is the bowl', 2),
#  ('is the woman in red sitting or standing', 2),
#  ('where is the food', 2),
#  ('what does the woman wear on her face in video', 2),
#  ('what color is the plate in the video', 2),
#  ('where is the picture frame in the video', 2),
#  ('is the woman in the video lying or sitting', 2),
#  ('what is on the door of the refrigerator', 2),
#  ('what is on the sofa in the video', 2),
#  ('what is the person in green clothes doing', 2),
#  ('what is the person with red hair doing', 2),
#  ('what is the person pushing in the video', 2),
#  ('is the animal in the video sitting or standing', 2),
#  ('what is the person wearing a hat doing in the video', 2),
#  ('what is the color of the chair', 2),
#  ('is the character in the video standing or sitting', 2),
#  ('what is the cat doing in the video', 2),
#  ('what is the old man in the video doing', 2),
#  ('what is the color of the pants does the boy in white top wear', 2),
#  ('what is on the roof in the video', 2),
#  ('what is the color of the pants of the man in the video', 2),
#  ('what is on the road in the video', 2),
#  ("what is the color of the woman's hair in the video", 2),
#  ('is the person in the video a man or a woman', 2),
#  ('what color is the ground in the video', 2),
#  ('how many person showed in the video', 2),
#  ('is the child sitting or standing in the video', 2),
#  ('where is the frame', 2),
#  ('what is shown on the screen in the video', 2),
#  ('what color are the shoes', 2),
#  ('where is the clothes in the video', 2),
#  ('what is the shape of the paper in the video', 2),
#  ('is the game character in the video standing or sitting', 2),
#  ('is the man wearing a pair of pants or a skirt', 2),
#  ('what is the host in the video doing', 2),
#  ('where is the box', 2),
#  ('what is man doing in video', 2),
#  ('what is the color of the light in the video', 2),
#  ('where is the mirror in the video hanging', 2),
#  ('where is the calendar', 2),
#  ('is the woman in white standing or sitting in video', 2),
#  ('is the person in the video a boy or a girl', 2),
#  ('is the person in the video sitting or standing while eating', 2),
#  ('what is the person in orange doing in video', 2),
#  ('what color is the plant in the video', 2),
#  ('what color does the man in the video wear', 2),
#  ('what is the last thing in the video', 2),
#  ('what is on the wardrobe', 2),
#  ('what is the picture in video', 2),
#  ('what is the person doing at the beginning of the video', 2),
#  ('is the person with glasses in the video standing or sitting', 2),
#  ('is the person wearing the trousers or shorts in the video', 2),
#  ('is the woman sitting or standing in video', 2),
#  ('does the singing person have long hair or short hair in the video', 2),
#  ('what is the color of the background in the video', 2),
#  ('what does the woman wear around her neck in the video', 2),
#  ('what color pants does the woman wear in the video', 2),
#  ('what color is the pants worn by the person in the video', 2),
#  ('what is on the cabinet in video', 2),
#  ('where is the medicine bottle', 2),
#  ('where is the bowl in the video', 2),
#  ('what appeared in the video', 2),
#  ('what is the animal in video', 2),
#  ("what is in the man's hand in the video", 2),
#  ('is the man in the video sitting or squatting', 2),
#  ('is the person standing or sitting on the stage in the video', 2),
#  ('what is the color of the light', 2),
#  ('is the host in the video standing or sitting', 2),
#  ('is the person with glasses standing or sitting in video', 2),
#  ('is the man standing or sitting in the end', 2),
#  ('what is the color of the curtain', 2),
#  ('which hand of the person in the video holds the food', 2),
#  ('is the person wearing black clothes in the video standing or sitting', 2),
#  ('is the picture in video stationary or moving', 2),
#  ('what color is the sky in the video', 2),
#  ('what is on the vacant lot', 2),
#  ('where does the man in the video put the clothes', 2),
#  ('what is the color of the words in the video', 2),
#  ('what is the person in red doing in the video', 2),
#  ('what does the person in pink doing in the video', 2),
#  ('what is the princess in the video doing', 2),
#  ("what is the color of women's clothes in the video", 2),
#  ('what is the brand of the car', 2),
#  ('what is the color of the boat in the video', 2),
#  ('what is on the beach', 2),
#  ('what is the color of the pan in the video', 2),
#  ('is the person with glasses in the video sitting or standing', 2),
#  ('is the plane flying or stopping', 2),
#  ('is the person in the video walking or sitting', 2),
#  ('what is the person standing in the video doing', 2),
#  ('where is the clock', 2),
#  ('what is the athlete doing in the video', 2),
#  ('what is the color of the hat', 2),
#  ("what is the color of the man's hair", 2),
#  ('what is the monster doing in the video', 2),
#  ('where is the drink', 2),
#  ('where is the broom in the video', 2),
#  ('is the person in the video lying or standing', 2),
#  ('what is the man wearing', 2),
#  ('what does the person have in the video', 2),
#  ('what color is the tie in the video', 2),
#  ('where is the gun in the video', 2),
#  ('what is the person in black doing', 2),
#  ('which hand of the person in the video holds the cup', 2),
#  ("what is the color of women's clothes in video", 2),
#  ("what is the color of the women's clothes in the video", 2),
#  ('what is the person wearing white clothes in the video doing', 2),
#  ('where is the person holding the broom', 2),
#  ('what color is the grass in the video', 2),
#  ('what color is the woman wearing the jacket', 2),
#  ('what does the person hold in the video', 2),
#  ('what color clothes does the man in the video wear', 2),
#  ('what is on the commodity shelf', 2),
#  ('what is in the hand of the woman in the video', 2),
#  ('what color is the candle in the video', 2),
#  ('what color is the font in the video', 2),
#  ('what color clothes does the cartoon character wear in the video', 2),
#  ('what does the man carry on his back in the video', 2),
#  ('where is the game character in the video', 2),
#  ('where is the snake in the video', 2),
#  ('does the person have short hair or long hair in the video', 2),
#  ('where is the decorative painting in the video', 2),
#  ('what color clothes do people in the video wear', 2),
#  ('what is person in video doing', 2),
#  ('is the person sitting or squatting', 2),
#  ('what is on the stand', 2),
#  ('what is the white thing in the video', 2),
#  ('where is the globe in the video', 2),
#  ('what is the dog doing in the video', 2),
#  ('what is the color of the horse in the video', 2),
#  ("what color is the chef's hat in the video", 2),
#  ("what is the color of girl's clothes in video", 2),
#  ('where is the cream in the video', 2),
#  ('is the woman standing or lying in the video', 2),
#  ('are the audience standing or sitting', 2),
#  ('where are the cups in the video', 2),
#  ('where is the cabinet', 2),
#  ('where is the machine in the video', 2),
#  ('what is on the sink', 2),
#  ('is the singing person standing or sitting in the video', 2),
#  ('what is the person standing in video doing', 2),
#  ('where is the adult in the video', 2),
#  ('what is the man in the video holding in his arms', 2),
#  ("what color is the person's hair", 2),
#  ('is the person sitting or standing while drinking water in the video', 2),
#  ('what is on the chair in the video', 2),
#  ('what color is the car', 2),
#  ('what is the color of the hair of the woman in the video', 2),
#  ('is the person wearing the hat in the video sitting or standing', 2),
#  ('what is on the chopping board', 2),
#  ('where is the model in the video', 2),
#  ('is the person in pink in the video sitting or standing', 2),
#  ('what can be seen in video', 2),
#  ('is the man in the video standing or sitting at the end', 2),
#  ('where is the vase', 2),
#  ('what is the color of the stairs in the video', 2),
#  ('what is the color of the hair of the person in blue', 2),
#  ('is the person in white standing or sitting', 2),
#  ("what is the color of the person's pants in video", 2),
#  ('is woman in video standing or sitting', 2),
#  ('what is the person with glasses doing', 2),
#  ('what color clothes is the baby wearing in the video', 2),
#  ('what is the color of the pillows in the video', 2),
#  ('what color is the fence in the video', 2),
#  ('in which hand does the person hold the cellphone in the video', 2),
#  ('what is the color of the shoes in the video', 2),
#  ('what is the person playing in the video', 2),
#  ('where is the boy in video', 2),
#  ('where is the person wearing hat', 2),
#  ('what is the color of the plastic bucket in the video', 2),
#  ('what does the person in the video wear', 2),
#  ('what is the person in blue doing', 2),
#  ('is the person lying or sitting in the video', 2),
#  ('what color is the tire in the video', 2),
#  ('where is the fish in the video', 2),
#  ('what color shorts does the man wear in the video', 2),
#  ('what is the color of the flower in the video', 2),
#  ('what is on the left side of the chair', 2),
#  ('what color is the background in the video', 2),
#  ('what color is the steering wheel in the video', 2),
#  ('which hand of the man in video holds the script', 2),
#  ('what does the person in the video doing', 2),
#  ('what color of clothes does the girl in the video wear', 2),
#  ('what color is the car in video', 2),
#  ('what color is the cat in the video', 2),
#  ('where is the bag in the video', 2),
#  ('where is the orange', 2),
#  ('what is the woman wearing on the head in the video', 2),
#  ('what is the color of the tree in the video', 2),
#  ('where is the lamp in video', 2),
#  ("what is on the girl's head", 2),
#  ('what is the person wearing glasses doing', 2),
#  ('what color is the sofa', 2),
#  ('what is on the couch', 2),
#  ('what color is the english in the video', 2),
#  ('what kind of the jacket does the person wear in the video', 2),
#  ('is the boy standing or sitting', 2),
#  ('what color top does the little girl wear in the video', 2),
#  ('what is the color of the piano in the video', 2),
#  ('what is the color of the pants of the person with glasses', 2),
#  ('what is the person in white doing in video', 2),
#  ('is the phone in the video horizontal or vertical', 2),
#  ('what is the alphabet at the left corner of the video', 2),
#  ('what is the man with glasses doing', 2),
#  ('is the person wearing white clothes in the video long hair or short hair',
#   2),
#  ('what is behind the person standing in video', 2),
#  ('where is the cup in video', 2),
#  ('what color is the glove in the video', 2),
#  ('what is the color of the hat in the video', 2),
#  ('what is the color of the baby carriage in the video', 2),
#  ('what is the women doing in the video', 2),
#  ('what does the person have', 2),
#  ('what is the color of the hearth', 2),
#  ('what is the color of the washing machine in the video', 2),
#  ('where is the man at the beginning of the video', 2),
#  ("what is the color of the man's pants in the video", 2),
#  ('what color are the pants of the person in the video', 2),
#  ('what color is the seat in the video', 2),
#  ('where is the electric fan in the video', 2),
#  ('what is the color of the heart in the video', 1),
#  ('what is color of trousers of man in video', 1),
#  ('how many characters appear in video', 1),
#  ('what is the person holding the broom doing', 1),
#  ('is the person in colorful trousers sitting or standing in the video', 1),
#  ('what color is the hair of the person wearing rose red dress', 1),
#  ('what is the shape of the bricks in the video', 1),
#  ('is the person in the white coat standing or sitting in the video', 1),
#  ('what is the color of the clothes on the bed in the video', 1),
#  ('what instrument is in the video', 1),
#  ('what color is the floor tile in the video', 1),
#  ('where did the person in the video going to', 1),
#  ('what is the color of the pants does the man sitting wear', 1),
#  ('what is in the hands before the person in the video dumps things', 1),
#  ('is the text on the nail polish written in english or chinese in the video',
#   1),
#  ('is the hair-tied person in the video standing or sitting', 1),
#  ('what is the color of the closet which is behind the man', 1),
#  ('what is the person wearing white pants doing', 1),
#  ('what is the round doing in the video', 1),
#  ('where do the people in video play football', 1),
#  ('is the guitar player standing or sitting in the video', 1),
#  ('where does the person put the handbag', 1),
#  ('where is the color paper in the video', 1),
#  ('what is put in the right of the person in the video', 1),
#  ('what is on the left side of the fridge', 1),
#  ('where is the person wearing the hat', 1),
#  ('what is on the corridor', 1),
#  ('is the person in the viedo sitting or standing', 1),
#  ('is the boy with green hair sitting or standing in the video', 1),
#  ('what color is the brand', 1),
#  ('where is the person in red in the video', 1),
#  ('what is the person with white hair in the video doing', 1),
#  ("what is on the man's legs in the video", 1),
#  ('is the person in the last scene standing or sitting', 1),
#  ('what color does the woman wear', 1),
#  ('what kind of the jacket does the person tying hair up wear in the video',
#   1),
#  ('what did the character drive to the river in video', 1),
#  ('what is the person wearing a vest in the video doing', 1),
#  ('which hand of the man holds the bag', 1),
#  ('where is the leopard', 1),
#  ('where does the man in the video put what he has on his hand', 1),
#  ('is the animal appearing in the video a dog or a cat', 1),
#  ('where is the person with golden hair', 1),
#  ('where is the person wearing earrings', 1),
#  ('is the person in video sitting or lying down', 1),
#  ('is the man in red sitting or standing in the video', 1),
#  ("what is color of man's hair in cartoon", 1),
#  ('what is the color of the wooden cabinet in the video', 1),
#  ('which number of the player in the video scored the ball', 1),
#  ('what is on the aisle', 1),
#  ('what is the fish that is moving its mouth', 1),
#  ('where is the camera', 1),
#  ('what type is the yellow car', 1),
#  ('where does the people sit', 1),
#  ('what color is the t-shirt the person wears', 1),
#  ('what color of the team uniform does the person wear in the video', 1),
#  ('where is the two girls dancing together in the video', 1),
#  ('is the man sitting or standing in the cartoon', 1),
#  ('what color are the clothes of the person who sits in the middle in the video',
#   1),
#  ('which season is the model showing in the video', 1),
#  ('is the kid wearing a glasses sitting or standing in the video', 1),
#  ('what does the boy wear on head in the video', 1),
#  ('what is hanging next to the mirror in video', 1),
#  ('what does the person have on his body', 1),
#  ('what is the color of the trousers of the person in a striped shirt in video',
#   1),
#  ('what is the person playing the guitar in the video doing', 1),
#  ('is the athlete in the video standing or sitting', 1),
#  ...]

# %%
for question,times in frequency_question.items():
    #print(answer)
    num_word=0
    words = question.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word<=3:
        print(question,times)
# Out:
# where is switch 2
# what happened 1
# where is poker 1
# where is magnet 1
# at what place 1

# %%
num_word_dict_answer={}
for answer,times in frequency_answer.items():
    #print(answer)
    num_word=0
    words = answer.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict_answer:
        num_word_dict_answer[num_word]=times
    else:
        num_word_dict_answer[num_word]+=times
# Out:
# pouring it into washing machine 1
# pouring water to another cup 3
# putting clothes on his body 1
# getting up to go out 1
# taking part in variety competition 1
# five hundred and twenty eight 1
# opening door of washing machine 1
# right hand pointing at sky 3
# putting cup on right hand 1
# putting them in another bowl 1
# looking at things in hands 1
# taking apart of baby carriage 1
# right hand to do operation 1
# year two zero zero eight 1
# looking at outside of window 1
# taking towel to wipe cup 1
# playing with rubik is cube 3
# taking things out from refrigerator 3
# year two thousand and eight 1
# stepping in front of desk 1
# closing door of washing machine 1
# in front of rear tire 1

# %%
num_word_dict_answer
# Out:
# {1: 32978, 2: 14291, 3: 2319, 4: 248, 5: 30, 6: 8, 8: 1}

# %%
num_word_dict_question={}
for answer,times in frequency_question.items():
    #print(answer)
    num_word=0
    words = answer.split(' ')
    for word in words:
        num_word+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict_question:
        num_word_dict_question[num_word]=times
    else:
        num_word_dict_question[num_word]+=times
# Out:
# what is on the countertop 5
# where is sofa in video 2
# what is on the corridor 1
# what color is the brand 1
# what is behind the refrigerator 3
# what is on the aisle 1
# where does the people sit 1
# what is in the toilet 5
# is the person wearing shirt 1
# where is the tissue box 1
# what is following the player 1
# where is the water cup 1
# what is on the stool 4
# where is the paper box 4
# what color is the roof 1
# what color is the cup 3
# what is in the plate 1
# on what sits the person 1
# where is the laundry detergent 3
# where are those two men 1
# what is behind the lake 1
# what color is the dish 1
# what color is the bed 1
# what are the man doing 1
# what is playing in video 2
# how many person is there 1
# what is in the tvbench 1
# what color is the towel 1
# where does the person enter 1
# what is in the bag 2
# what is the living room 1
# what color is the table 3
# what is on the shelf 6
# what color is the door 4
# what is the yacht doing 1
# what is on the staircase 1
# what is the person eating 1
# where is man in video 2
# what are on the steps 1
# what are on the table 1
# what is behind the woman 2
# what is on the track 1
# what is in the microwave 1
# what is in the closet 9
# where is the toy shelf 1
# what are in the closet 1
# what is onn the chair 1
# what is in the corridor 8
# what color is the wall 50
# where are those two people 1
# where is the water bucket 1
# what is the boy doing 2
# what is on the table-board 1
# what is on the stake 1
# where is the flower pot 1
# what is behind the man 1
# what is on the website 1
# what is in the cupboard 1
# what color is the chair 3
# where are the two men 1
# where is the remote control 2
# what color is the alpaca 1
# what is on the street 1
# what is behind the chair 3
# what is on the countryard 1
# what color is the floor 2
# what is in the car 4
# what is on the lawn 3
# what is the kid doing 1
# is the person wearing watch 1
# what is behind the kids 1
# what is on the stone 1
# how many objects are there 1
# what is on the bedside 1
# where is the blue blanket 1
# what is on the stairs 7
# is the person wearing tie 1
# where does the person lie 2
# what is the second brand 1
# where is the photo frame 1
# where is the tooth patient 1
# where is the towel ring 1
# what is behind the computer 1
# is the person wearing glasses 2
# what color is the starfish 1
# what is on the floor 17
# what does the person drink 2
# where is the washing machine 2
# how many brands are there 1
# where is the person dancing 1
# what is in the hallway 2
# where is the tv hanging 1
# what color is the scarf 1
# what color is the tablecloth 1
# what is near the tv 1
# what is on the wall 57
# what color is the flute 1
# is the selfie stick flexible 1
# what are three aliens doing 1
# what is the person doing 36
# what is in the dishes 2
# what is on the worktop 1
# what is in the box 2
# what is in the bathroom 5
# what color is the refrigerator 6
# what is on the closet 6
# what is the car doing 1
# where is the green planting 1
# what are on the bed 1
# what is in the pot 1
# what color is the bowl 2
# what is the video about 1
# what color is the wardrobe 1
# what is in the cabinet 9
# where are the two boys 1
# what are on the roof 1
# where is the gas tank 1
# where are these shoes from 1
# is the woman wearing necklace 1
# what is on the plate 1
# what are the audience doing 1
# what color is the grass 1
# what color is the crayon 1
# what is behind the table 1
# where is person in video 1
# what color are the shoes 2
# what is in the room 182
# how many hools are made 1
# where is the seat cushion 1
# what color is the tv 1
# what is outside the house 1
# what is on the wardrobe 2
# what is the leopard doing 1
# what color is the pillow 1
# what is on the commode 1
# what is the policeman wearing 1
# where is on the ground 1
# where is the medicine bottle 2
# what appeared in the video 2
# where is the mineral water 1
# what is on the stove 1
# where is the red 5 1
# what does the person wear 1
# what is behind the car 1
# what does the person lock 1
# what is on the chair 3
# what is on the beach 2
# where is the rice cooker 1
# where is the computer host 1
# where is he water bottle 1
# what is in the video 316
# what is behind the person 3
# is the woman wear earring 1
# is mario standing or sitting 1
# what color is the subtitle 1
# where is the bath ball 1
# what is in the bar 1
# where is the table lamp 3
# what is the man wearing 2
# what is the audience doing 1
# what color is the clock 1
# what is on the cooktop 12
# what is on the table 224
# what is on the cabinet 13
# what is on the window 1
# what color is the helicopter 1
# where are the clothes hanging 1
# what is under the computer 1
# what color is the cabinet 8
# what is on the hearth 6
# what is behind the door 4
# what is on the column 1
# what is in the refrigerator 3
# what is on the seat 1
# what is on the ceiling 1
# what is on the washbasin 1
# what is on the stand 2
# where is the electric fan 1
# what is in the hand 1
# what is on the sofa 11
# where does the person sit 1
# what type is the cartoo 1
# what is the man doing 106
# where is the girl drawing 1
# what is on the roof 1
# what is on the bed 50
# what is behind the reporter 1
# what is on the sink 2
# what color is the television 1
# what color is the paper 1
# what color is the stone 1
# what color is the car 2
# what color is the earring 1
# what is on the grassland 1
# what is on the pool 1
# what is on the screen 1
# what is on the door 4
# what is on the stage 7
# what is on the piano 1
# what is on the paper 1
# what is on the desk 29
# what is under the tv 1
# what is in the bed 1
# what color is the computer 1
# what is in the park 1
# what is introduced in video 1
# what is near the woman 1
# what is on the refrigerator 4
# where is the desk lamp 1
# what is in the bedroom 3
# where is the towel thrown 1
# what is surrounding the house 1
# what is on the ground 19
# where is the tooth cup 1
# what is the hamster doing 1
# where is the cartoon character 1
# what is in the corner 1
# what color is the sofa 2
# what is on the couch 2
# what is in the kitchen 30
# what color is the cooktop 1
# what color is the sword 1
# what is in the carton 1
# what is the machine doing 1
# what does the person have 2
# what color is the sheet 3
# what is the woman doing 37

# %%
num_word_dict_question
# Out:
# {2: 1,
#  3: 5,
#  4: 481,
#  5: 1549,
#  6: 852,
#  7: 2790,
#  8: 3536,
#  9: 3174,
#  10: 1755,
#  11: 1089,
#  12: 759,
#  13: 426,
#  14: 112,
#  15: 60,
#  16: 24,
#  17: 9,
#  18: 2,
#  19: 1}

# %%
num_word_dict={}
have_and=0
have_of=0
have_in=0
have_from=0
have_ing=0
have_at=0
have_to=0
have_pronouns=0 #代词
for answer,times in frequency_answer.items():
    #print(answer)
    num_word=0
    if "and" in answer:
        have_and+=1
    if "of" in answer:
        have_of+=1
    if "in" in answer:
        have_in+=1
    if "ing" in answer:
        have_ing+=1
    if "from" in answer:
        have_from+=1
    if "at" in answer:
        have_at+=1
    if "to" in answer:
        have_to+=1
    if "it" in answer or "his" in answer or "her" in answer or "them" in answer:
        have_pronouns+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times

# %%
have_and,have_of,have_in,have_ing,have_from,have_at,have_to,have_pronouns
# Out:
# (158, 132, 2603, 2293, 3, 446, 347, 311)

# %%
num_word_dict={}
have_what=0
have_how=0
have_is=0
have_on=0
have_in=0
have_many=0
have_where=0
have_color=0 
have_does=0
have_do=0
have_person=0
for answer,times in frequency_question.items():
    #print(answer)
    num_word=0
    if "what" in answer:
        have_what+=1
    if "how" in answer:
        have_how+=1
    if "is" in answer:
        have_is+=1
    if "on" in answer:
        have_on+=1
    if "in" in answer:
        have_in+=1
    if "many" in answer:
        have_many+=1
    if "where" in answer:
        have_where+=1
    if "color" in answer:
        have_color+=1
    if "does" in answer:
        have_does+=1
    if "do" in answer:
        have_do+=1
    if "person" in answer:
        have_person+=1
#     frequency_answer.get('Age')
#     frequency_answer[answer].append(num_word)
    if num_word==5:
        print(answer,times)
    if num_word not in num_word_dict:
        num_word_dict[num_word]=times
    else:
        num_word_dict[num_word]+=times

# %%
have_what,have_how,have_is,have_on,have_in,have_many,have_where,have_color,have_does,have_do,have_person
# Out:
# (2684, 110, 3564, 2103, 3869, 98, 682, 1128, 579, 1156, 1421)

# %%
sort_answer
# Out:
# [('standing', 6344),
#  ('sitting', 2440),
#  ('black', 1824),
#  ('white', 1338),
#  ('indoor', 1155),
#  ('blue', 707),
#  ('red', 563),
#  ('on table', 492),
#  ('in house', 450),
#  ('kitchen', 433),
#  ('residence', 384),
#  ('drinking water', 373),
#  ('green', 364),
#  ('living room', 336),
#  ('glasses', 329),
#  ('cup', 304),
#  ('yellow', 297),
#  ('eating', 292),
#  ('short hair', 288),
#  ('chair', 270),
#  ('clothes', 269),
#  ('speaking', 264),
#  ('talking', 263),
#  ('computer', 258),
#  ('bedroom', 256),
#  ('lying', 248),
#  ('hat', 246),
#  ('long hair', 234),
#  ('table', 222),
#  ('grey', 206),
#  ('walking', 204),
#  ('book', 198),
#  ('in door', 195),
#  ('dark blue', 194),
#  ('in living room', 189),
#  ('on wall', 188),
#  ('two', 186),
#  ('brown', 182),
#  ('gray', 175),
#  ('on ground', 167),
#  ('purple', 164),
#  ('pink', 156),
#  ('pillow', 155),
#  ('milk white', 153),
#  ('in kitchen', 152),
#  ('creamy white', 149),
#  ('outdoor', 145),
#  ('male', 142),
#  ('chatting', 139),
#  ('in bedroom', 136),
#  ('on stairs', 131),
#  ('in room', 124),
#  ('singing', 120),
#  ('inside house', 120),
#  ('mirror', 119),
#  ('pot', 114),
#  ('dancing', 114),
#  ('sneezing', 113),
#  ('sofa', 113),
#  ('light blue', 109),
#  ('on bed', 108),
#  ('bottle', 108),
#  ('room', 105),
#  ('cooking', 104),
#  ('on sofa', 104),
#  ('man', 103),
#  ('phone', 102),
#  ('bed', 99),
#  ('playing computer', 97),
#  ('opening door', 97),
#  ('cabinet', 97),
#  ('orange', 97),
#  ('indoors', 95),
#  ('desk', 94),
#  ('watching tv', 93),
#  ('tidying', 91),
#  ('bright red', 90),
#  ('aterrimus', 89),
#  ('car', 89),
#  ('three', 85),
#  ('in car', 84),
#  ('english', 82),
#  ('running', 82),
#  ('mustache', 81),
#  ('playing cell phone', 81),
#  ('plate', 79),
#  ('cell phone', 79),
#  ('bathroom', 79),
#  ('on desk', 78),
#  ('house', 78),
#  ('dark grey', 77),
#  ('resting', 77),
#  ('dark black', 77),
#  ('female', 76),
#  ('painting', 76),
#  ('shoes', 75),
#  ('microphone', 75),
#  ('left hand', 75),
#  ('yes', 75),
#  ('refrigerator', 74),
#  ('blanket', 74),
#  ('dog', 74),
#  ('sleeping', 73),
#  ('reading', 72),
#  ('furvous', 72),
#  ('closet', 72),
#  ('bag', 72),
#  ('dark green', 71),
#  ('towel', 70),
#  ('on floor', 69),
#  ('on stage', 68),
#  ('woman', 67),
#  ('on chair', 67),
#  ('taking off clothes', 67),
#  ('right hand', 66),
#  ('lying down', 65),
#  ('playing phone', 65),
#  ('tv', 65),
#  ('door', 65),
#  ('closing door', 64),
#  ('dark red', 64),
#  ('light gray', 62),
#  ('clearing up', 60),
#  ('reading book', 59),
#  ('writing', 58),
#  ('sweeping floor', 58),
#  ('squatting', 57),
#  ('taking things', 56),
#  ('box', 56),
#  ('tree', 55),
#  ('on cabinet', 54),
#  ('on shelf', 54),
#  ('open', 54),
#  ('bowl', 54),
#  ('on', 54),
#  ('in studio', 54),
#  ('light green', 54),
#  ('light grey', 54),
#  ('corridor', 53),
#  ('taking off shoes', 53),
#  ('paper', 52),
#  ('off-white', 52),
#  ('driving', 51),
#  ('looking into mirror', 51),
#  ('looking in mirror', 50),
#  ('studio', 50),
#  ('shelf', 50),
#  ('crimson', 50),
#  ('laptop', 48),
#  ('lamp', 48),
#  ('broom', 47),
#  ('in bathroom', 47),
#  ('photo frame', 46),
#  ('helmet', 46),
#  ('playing games', 46),
#  ('guitar', 46),
#  ('playing mobile phone', 45),
#  ('four', 45),
#  ('on road', 44),
#  ('toilet', 44),
#  ('light yellow', 44),
#  ('dark brown', 44),
#  ('pouring water', 43),
#  ('pure black', 43),
#  ('carton', 43),
#  ('watch', 43),
#  ('grass green', 42),
#  ('sky blue', 42),
#  ('mouse', 41),
#  ('cleaning', 41),
#  ('stairs', 40),
#  ('beige', 40),
#  ('on street', 39),
#  ('one', 39),
#  ('television', 38),
#  ('opening refrigerator', 38),
#  ('water cup', 38),
#  ('dark gray', 38),
#  ('violet', 37),
#  ('people', 37),
#  ('dark-blue', 37),
#  ('curtain', 37),
#  ('ring', 37),
#  ('looking at computer', 36),
#  ('milky white', 36),
#  ('washing machine', 36),
#  ('food', 36),
#  ('switch', 36),
#  ('navy blue', 35),
#  ('eating things', 35),
#  ('pool', 35),
#  ('photo', 35),
#  ('laughing', 34),
#  ('doorway', 34),
#  ('cyan', 34),
#  ('eating bread', 34),
#  ('taking clothes', 34),
#  ('camera', 34),
#  ('hanging on wall', 33),
#  ('cap', 33),
#  ('performing', 33),
#  ('no', 33),
#  ('reading books', 33),
#  ('necklace', 33),
#  ('eyeglasses', 33),
#  ('royal blue', 32),
#  ('quilt', 32),
#  ('gray white', 32),
#  ('playing guitar', 32),
#  ('azure', 31),
#  ('taking photos', 31),
#  ('putting on shoes', 31),
#  ('vacuum cleaner', 31),
#  ('water', 31),
#  ('pen', 30),
#  ('light-blue', 30),
#  ('drinking', 30),
#  ('left', 30),
#  ('rectangle', 30),
#  ('putting on clothes', 30),
#  ('in hands', 29),
#  ('rose red', 29),
#  ('bucket', 28),
#  ('light red', 28),
#  ('in cabinet', 28),
#  ('in water', 28),
#  ('cleaning up', 28),
#  ('cartoon', 28),
#  ('wearing shoes', 27),
#  ('earphone', 27),
#  ('carpet', 27),
#  ('horizontal', 27),
#  ('right', 27),
#  ('bread', 27),
#  ('turning on light', 27),
#  ('light', 27),
#  ('taking cup', 27),
#  ('fetching things', 26),
#  ('mobile phone', 26),
#  ('dark purple', 26),
#  ('wrestling', 26),
#  ('looking for something', 26),
#  ('snacks', 26),
#  ('exercising', 26),
#  ('taking shoes', 26),
#  ('silver', 26),
#  ('explaining', 26),
#  ('window', 26),
#  ('jar', 26),
#  ('lawn', 25),
#  ('light pink', 25),
#  ('wearing clothes', 25),
#  ('behind door', 25),
#  ('smalt', 25),
#  ('putting things', 25),
#  ('beige white', 25),
#  ('in hand', 25),
#  ('clock', 24),
#  ('golden', 24),
#  ('on lawn', 24),
#  ('laundry detergent', 24),
#  ('curly hair', 24),
#  ('gun', 24),
#  ('person', 24),
#  ('closed', 24),
#  ('on washing machine', 24),
#  ('stage', 24),
#  ('horse', 24),
#  ('plastic bag', 23),
#  ('remote control', 23),
#  ('calling', 23),
#  ('tie', 23),
#  ('watching computer', 23),
#  ('sitting down', 23),
#  ('beverage', 23),
#  ('public place', 23),
#  ('cat', 23),
#  ('hearth', 23),
#  ('court', 23),
#  ('throwing clothes', 22),
#  ('paper box', 22),
#  ('hanger', 22),
#  ('sky-blue', 22),
#  ('having rest', 22),
#  ('opening', 22),
#  ('six', 22),
#  ('light white', 22),
#  ('light purple', 22),
#  ('on stool', 21),
#  ('baby blue', 21),
#  ('khaki', 21),
#  ('in closet', 21),
#  ('on door', 21),
#  ('throwing pillow', 21),
#  ('socket', 21),
#  ('stool', 21),
#  ('notebook', 20),
#  ('poster', 20),
#  ('holding pillow', 20),
#  ('deep purple', 20),
#  ('placing items', 20),
#  ('backpack', 20),
#  ('atrovirens', 20),
#  ('marine blue', 19),
#  ('outdoors', 19),
#  ('playing basketball', 19),
#  ('fighting', 19),
#  ('case', 19),
#  ('doll', 19),
#  ('taking off coat', 19),
#  ('lake blue', 19),
#  ('knife', 19),
#  ('dark yellow', 19),
#  ('cloakroom', 19),
#  ('on grass', 19),
#  ('flower', 19),
#  ('in corridor', 18),
#  ('dark-red', 18),
#  ('lavender', 18),
#  ('washing clothes', 18),
#  ('curly', 18),
#  ('taking photo', 18),
#  ('brownish yellow', 18),
#  ('posing', 18),
#  ('moving', 18),
#  ('kneeling', 18),
#  ('hands', 18),
#  ('shooting', 18),
#  ('making call', 18),
#  ('couch', 18),
#  ('black blue', 18),
#  ('azure blue', 18),
#  ('taking phone', 17),
#  ('keyboard', 17),
#  ('taking pillow', 17),
#  ('child', 17),
#  ('basketball court', 17),
#  ('staircase', 17),
#  ('steering wheel', 17),
#  ('wiping table', 17),
#  ('drinking beverage', 17),
#  ('ash black', 17),
#  ('basket', 17),
#  ('cellphone', 17),
#  ('auditorium', 17),
#  ('looking at mirror', 17),
#  ('opening cabinet', 16),
#  ('smiling', 16),
#  ('jumping', 16),
#  ('taking book', 16),
#  ('taking something', 16),
#  ('round', 16),
#  ('taking pictures', 16),
#  ('competing', 16),
#  ('orange red', 16),
#  ('taking medicine', 16),
#  ('on cupboard', 16),
#  ('newspaper', 16),
#  ('spoon', 16),
#  ('ball', 16),
#  ('square', 16),
#  ('vase', 16),
#  ('football field', 16),
#  ('wall', 16),
#  ('light brown', 16),
#  ('getting up', 16),
#  ('microwave oven', 16),
#  ('at table', 16),
#  ('taking towel', 16),
#  ('skyblue', 16),
#  ('toy', 15),
#  ('calendar', 15),
#  ('in corner', 15),
#  ('skirt', 15),
#  ('daytime', 15),
#  ('wardrobe', 15),
#  ('display', 15),
#  ('glass', 15),
#  ('in game', 15),
#  ('rose', 15),
#  ('black and white', 15),
#  ('watching video', 15),
#  ('shirt', 15),
#  ('flying', 15),
#  ('magazine', 15),
#  ('next to car', 15),
#  ('pale pink', 15),
#  ('climbing stairs', 15),
#  ('off white', 15),
#  ('grey white', 15),
#  ('eating something', 15),
#  ('playing', 15),
#  ('tv set', 15),
#  ('horizontally', 15),
#  ('in cupboard', 15),
#  ('game scene', 15),
#  ('toilets', 15),
#  ('on cooktop', 15),
#  ('gray black', 14),
#  ('modena', 14),
#  ('animal', 14),
#  ('tan', 14),
#  ('turquoise', 14),
#  ('making up', 14),
#  ('pumpkin', 14),
#  ('audience', 14),
#  ('clothing', 14),
#  ('earphones', 14),
#  ('fan', 14),
#  ('claybank', 14),
#  ('field', 14),
#  ('beach', 14),
#  ('earrings', 13),
#  ('typing', 13),
#  ('turning on lights', 13),
#  ('looking at phone', 13),
#  ('basin', 13),
#  ('washing hands', 13),
#  ('swimming', 13),
#  ('putting away things', 13),
#  ('in sky', 13),
#  ('pure white', 13),
#  ('sheet', 13),
#  ('silver grey', 13),
#  ('watching videos', 13),
#  ('stairwell', 13),
#  ('putting cup', 13),
#  ('dark-grey', 13),
#  ('taking blanket', 13),
#  ('kettle', 13),
#  ('ocean blue', 13),
#  ('game', 13),
#  ('stirring', 12),
#  ('off', 12),
#  ('on court', 12),
#  ('making phone call', 12),
#  ('seven', 12),
#  ('cushion', 12),
#  ('taking bag', 12),
#  ('gloves', 12),
#  ('wiping nose', 12),
#  ('corner', 12),
#  ('true red', 12),
#  ('warehouse', 12),
#  ('circle', 12),
#  ('stopped', 12),
#  ('skiing', 12),
#  ('pale green', 12),
#  ('on refrigerator', 12),
#  ('by river', 12),
#  ('storage room', 12),
#  ('watching phone', 12),
#  ('grey black', 12),
#  ('bicycle', 12),
#  ('meat', 12),
#  ('grass', 12),
#  ('closing window', 12),
#  ('oven', 12),
#  ('playing piano', 12),
#  ('interviewing', 12),
#  ('tablecloth', 12),
#  ('medium yellow', 12),
#  ('cloth', 12),
#  ('coffee', 12),
#  ('lights', 12),
#  ('scarf', 12),
#  ('grey and white', 11),
#  ('having match', 11),
#  ('in hallway', 11),
#  ('electric fan', 11),
#  ('eating food', 11),
#  ('frame', 11),
#  ('drawing', 11),
#  ('going upstairs', 11),
#  ('utility room', 11),
#  ('pale yellow', 11),
#  ('rice white', 11),
#  ('table lamp', 11),
#  ('taking food', 11),
#  ('pan', 11),
#  ('plastic bottle', 11),
#  ('athlete', 11),
#  ('road', 11),
#  ('on steps', 11),
#  ('five', 11),
#  ('changing clothes', 11),
#  ('egg', 11),
#  ('turning off light', 11),
#  ('dressing up', 11),
#  ('gymnasium', 11),
#  ('big red', 11),
#  ('orange yellow', 11),
#  ('playing field', 11),
#  ('dishes', 11),
#  ('drinking milk', 11),
#  ('bottle green', 11),
#  ('tool', 11),
#  ('opening box', 11),
#  ('turning off lights', 11),
#  ('cartoon character', 11),
#  ('light black', 11),
#  ('making speech', 11),
#  ('playing football', 10),
#  ('apron', 10),
#  ('trousers', 10),
#  ('closing refrigerator', 10),
#  ('grayish white', 10),
#  ('creamy-white', 10),
#  ('wrist watch', 10),
#  ('brush', 10),
#  ('turning around', 10),
#  ('fashion show', 10),
#  ('army green', 10),
#  ('pure-black', 10),
#  ('folding clothes', 10),
#  ('going downstairs', 10),
#  ('playing game', 10),
#  ('introducing car', 10),
#  ('blue-black', 10),
#  ('faint yellow', 10),
#  ('studying', 10),
#  ('getting dressed', 10),
#  ('mural', 10),
#  ('cupboard', 10),
#  ('putting down something', 10),
#  ('on snow mountain', 10),
#  ('folding paper', 10),
#  ('laundry room', 10),
#  ('in washing room', 10),
#  ('corner of wall', 10),
#  ('light-grey', 10),
#  ('having meal', 10),
#  ('turning on computer', 10),
#  ('taking selfie', 10),
#  ('shovel', 10),
#  ('opening closet', 10),
#  ('undressing', 10),
#  ('in air', 9),
#  ('playground', 9),
#  ('decorative painting', 9),
#  ('handbag', 9),
#  ('headset', 9),
#  ('in drawer', 9),
#  ('in wardrobe', 9),
#  ('mop', 9),
#  ('garland', 9),
#  ('putting clothes', 9),
#  ('fresco', 9),
#  ('tangerine', 9),
#  ('sapphire blue', 9),
#  ('electronic guitar', 9),
#  ('catwalk show', 9),
#  ('driving car', 9),
#  ('electric wire', 9),
#  ('on carpet', 9),
#  ('on window sill', 9),
#  ('stroller', 9),
#  ('in stairwell', 9),
#  ('in refrigerator', 9),
#  ('lakeside', 9),
#  ('word', 9),
#  ('on washbasin', 9),
#  ('on hanger', 9),
#  ('chicken', 9),
#  ('studios', 9),
#  ('on screen', 9),
#  ('fish', 9),
#  ('sunglasses', 9),
#  ('standing up', 9),
#  ('fruits', 9),
#  ('simple', 9),
#  ('piano', 9),
#  ('riding motorcycle', 9),
#  ('putting down cup', 9),
#  ('opening cabinet door', 9),
#  ('on hearth', 9),
#  ('above ground', 9),
#  ('earthy yellow', 9),
#  ('magenta', 9),
#  ('black grey', 9),
#  ('in front of table', 9),
#  ('stone', 9),
#  ('milk-white', 9),
#  ('sheets', 9),
#  ('brownish red', 9),
#  ('on beach', 9),
#  ('cleaning window', 9),
#  ('can', 9),
#  ('sword', 9),
#  ('blue and black', 9),
#  ('in cup', 9),
#  ('light-yellow', 9),
#  ('vacuum machine', 9),
#  ('banana', 9),
#  ('human', 9),
#  ('on tv bench', 9),
#  ('seat', 9),
#  ('stadium', 9),
#  ('relaxing', 9),
#  ('jacinth', 9),
#  ('taking bottle', 9),
#  ('introducing', 9),
#  ('slivery', 8),
#  ('bosom', 8),
#  ('next to door', 8),
#  ('hugging', 8),
#  ('clapping', 8),
#  ('vegetables', 8),
#  ('putting shoes', 8),
#  ('opening window', 8),
#  ('light cyan', 8),
#  ('putting on coat', 8),
#  ('bolster', 8),
#  ('watching television', 8),
#  ('at corner', 8),
#  ('monster', 8),
#  ('flashlight', 8),
#  ('tidying clothes', 8),
#  ('besom', 8),
#  ('doing cleaning', 8),
#  ('curtains', 8),
#  ('screwdriver', 8),
#  ('pale blue', 8),
#  ('dumbbell', 8),
#  ('desk lamp', 8),
#  ('wathet', 8),
#  ('walking around', 8),
#  ('placing clothes', 8),
#  ('bowel', 8),
#  ('snow mountain', 8),
#  ('picking up pillow', 8),
#  ('picture', 8),
#  ('golden yellow', 8),
#  ('lemon yellow', 8),
#  ('machine', 8),
#  ('pale grey', 8),
#  ('boat', 8),
#  ('peach red', 8),
#  ('throwing things', 8),
#  ('taking computer', 8),
#  ('bike', 8),
#  ('restaurant', 8),
#  ('hall', 7),
#  ('brown green', 7),
#  ('screwing cap', 7),
#  ('plant', 7),
#  ('sweeping', 7),
#  ('forward', 7),
#  ('taking rest', 7),
#  ('model', 7),
#  ('scarlet', 7),
#  ('suit', 7),
#  ('triangle', 7),
#  ('telephone', 7),
#  ('gray-black', 7),
#  ('pants', 7),
#  ('silvery gray', 7),
#  ('clapping hands', 7),
#  ('glove', 7),
#  ('opening refrigerator door', 7),
#  ('cooking meal', 7),
#  ('in pool', 7),
#  ('table tennis', 7),
#  ('on runway', 7),
#  ('in toilet', 7),
#  ('silver gray', 7),
#  ('doing chores', 7),
#  ('screen', 7),
#  ('classroom', 7),
#  ('brushing plate', 7),
#  ('looking at photo', 7),
#  ('hangers', 7),
#  ('boy', 7),
#  ('stairway', 7),
#  ('cleaner', 7),
#  ('books', 7),
#  ('on tea table', 7),
#  ('hair clip', 7),
#  ('river', 7),
#  ('shampoo', 7),
#  ('ivory-white', 7),
#  ('back cushion', 7),
#  ('dark-black', 7),
#  ('turning off computer', 7),
#  ('fuchsia', 7),
#  ('washroom', 7),
#  ('puppy', 7),
#  ('national flag', 7),
#  ('throwing book', 7),
#  ('on closet', 7),
#  ('hanging clothes', 7),
#  ('on playground', 7),
#  ('in pot', 7),
#  ('bracelet', 7),
#  ('silvery white', 7),
#  ('against wall', 7),
#  ('golden-yellow', 7),
#  ('skeleton', 7),
#  ('armrest', 7),
#  ('magnet', 7),
#  ('earring', 7),
#  ('on sea', 7),
#  ('plates', 7),
#  ('picking up clothes', 7),
#  ('blankets', 7),
#  ('folding towels', 7),
#  ('medal', 7),
#  ('filming', 7),
#  ('lifting cup', 7),
#  ('playing table tennis', 7),
#  ('cleaning table', 7),
#  ('laboratory', 7),
#  ('pea green', 7),
#  ('black-blue', 7),
#  ('in river', 7),
#  ('soft red', 7),
#  ('doing some cleaning', 7),
#  ('washing cup', 7),
#  ('wiping glasses', 6),
#  ('sky', 6),
#  ('jacket', 6),
#  ('in sea', 6),
#  ('plastic box', 6),
#  ('purple red', 6),
#  ('forest', 6),
#  ('third', 6),
#  ('on snowfield', 6),
#  ('repairing', 6),
#  ('on shoes', 6),
#  ('doing experiment', 6),
#  ('rolling', 6),
#  ('alpaca', 6),
#  ('toothbrush', 6),
#  ('fruit', 6),
#  ('dining', 6),
#  ('vegetable', 6),
#  ('selfie stick', 6),
#  ('shaking', 6),
#  ('hair band', 6),
#  ('throwing shoes', 6),
#  ('putting food', 6),
#  ('in carton', 6),
#  ('wing', 6),
#  ('amaranth', 6),
#  ('on bus', 6),
#  ('in front of mirror', 6),
#  ('home', 6),
#  ('on tv cabinet', 6),
#  ('on head', 6),
#  ('bookcase', 6),
#  ('ring finger', 6),
#  ('in washing machine', 6),
#  ('fat', 6),
#  ('handrail', 6),
#  ('on washing sink', 6),
#  ('minecraft', 6),
#  ('beside sofa', 6),
#  ('in box', 6),
#  ('brown yellow', 6),
#  ('holding dog', 6),
#  ('key', 6),
#  ('potato', 6),
#  ('waving', 6),
#  ('broadcasting', 6),
#  ('match', 6),
#  ('cups', 6),
#  ('having beard', 6),
#  ('bracers', 6),
#  ('putting down clothes', 6),
#  ('repairing car', 6),
#  ('introducing product', 6),
#  ('watching photos', 6),
#  ('on carton', 6),
#  ('brown-black', 6),
#  ('sports center', 6),
#  ('operating computer', 6),
#  ('fence', 6),
#  ('on ice', 6),
#  ('taking plates', 6),
#  ('drawing curtain', 6),
#  ('taking plate', 6),
#  ('pushing car', 6),
#  ('cleaning mirror', 6),
#  ('looking at things', 6),
#  ('jasper', 6),
#  ('hamster', 6),
#  ('brownish black', 6),
#  ('rose-bengal', 6),
#  ('on chopping board', 6),
#  ('screwing bottle cap', 6),
#  ('on counter', 6),
#  ('pouring laundry detergent', 6),
#  ('rabbit', 6),
#  ('on plane', 6),
#  ('in front of door', 6),
#  ('shaking hands', 6),
#  ('transparent', 6),
#  ('hospital', 6),
#  ('stationary', 6),
#  ('using vacuum cleaner', 6),
#  ('taking broom', 6),
#  ('sliver white', 6),
#  ('placing cup', 6),
#  ('taking out items', 6),
#  ('by wall', 6),
#  ('cow', 6),
#  ('tattoo', 6),
#  ('moving chair', 6),
#  ('on sport court', 6),
#  ('touching hair', 6),
#  ('pictures', 6),
#  ('vehicle', 6),
#  ('on face', 6),
#  ('photograph', 6),
#  ('blackboard', 6),
#  ('sea blue', 6),
#  ('on board', 6),
#  ('on rope', 6),
#  ('putting away stuff', 6),
#  ('lying on his stomach', 6),
#  ('stirring food', 6),
#  ('riding horse', 6),
#  ('bbc', 6),
#  ('bright-red', 6),
#  ('mopping floor', 6),
#  ('t-shirts', 6),
#  ('at stair hall', 6),
#  ('eating snacks', 6),
#  ('croci', 6),
#  ('reseda', 6),
#  ('bed sheet', 6),
#  ('shorts', 6),
#  ('park', 6),
#  ('in stairs', 6),
#  ('moving boxes', 6),
#  ('covering blanket', 6),
#  ('looking outside window', 6),
#  ('trash can', 6),
#  ('beside door', 6),
#  ('looking at photos', 6),
#  ('in gymnasium', 6),
#  ('lobby', 6),
#  ('groveling', 6),
#  ('in front of closet', 6),
#  ('drinking juice', 6),
#  ('nodding', 6),
#  ('baby', 6),
#  ('taking wrench', 6),
#  ('snowfield', 6),
#  ('english letter', 6),
#  ('shelter', 6),
#  ('playing video', 6),
#  ('watching game', 6),
#  ('comic', 6),
#  ('near table', 6),
#  ('taking books', 6),
#  ('chopping board', 6),
#  ('racing', 6),
#  ('motorcycle', 6),
#  ('medicine', 6),
#  ('stretching arms', 6),
#  ('by sea', 6),
#  ('plastic', 6),
#  ('hair braiding', 6),
#  ('long sleeve', 6),
#  ('rugby', 6),
#  ('giving speech', 6),
#  ('hot', 6),
#  ('putting away clothes', 6),
#  ('dialog box', 6),
#  ('having conversation', 6),
#  ('mat', 6),
#  ('in cinema', 6),
#  ('wiping face', 6),
#  ('playing cellphone', 6),
#  ('blue white', 6),
#  ('playing baseball', 6),
#  ('detergent', 6),
#  ('ball park', 6),
#  ('massaging', 6),
#  ('playing ball', 6),
#  ('hair', 6),
#  ('suburb', 6),
#  ('flour', 6),
#  ('basketball', 6),
#  ('light-green', 6),
#  ('oil painting', 5),
#  ('black gray', 5),
#  ('picking up book', 5),
#  ('taking magazine', 5),
#  ('wiping hands', 5),
#  ('arrow', 5),
#  ('baby-blue', 5),
#  ('outside house', 5),
#  ('holding cup', 5),
#  ('seasoning', 5),
#  ('sewing machine', 5),
#  ('talking on phone', 5),
#  ('tibetain blue', 5),
#  ('mattress', 5),
#  ('at door', 5),
#  ('blue purple', 5),
#  ('peach', 5),
#  ('snake', 5),
#  ('washing dishes', 5),
#  ('3d', 5),
#  ('dessert', 5),
#  ('kissing', 5),
#  ('peak green', 5),
#  ('going up stairs', 5),
#  ('purplish red', 5),
#  ('looking at cellphone', 5),
#  ('card', 5),
#  ('doing exercise', 5),
#  ('milk', 5),
#  ('taking out clothes', 5),
#  ('taking box', 5),
#  ('folding towel', 5),
#  ('seeing information', 5),
#  ('closing refrigerator door', 5),
#  ('visiting', 5),
#  ('closing closet', 5),
#  ('monkey', 5),
#  ('under stairs', 5),
#  ('vermilion', 5),
#  ('document', 5),
#  ('taking off his clothes', 5),
#  ('water bottle', 5),
#  ('putting on blanket', 5),
#  ('fork', 5),
#  ('purplish blue', 5),
#  ('leopard', 5),
#  ('denim blue', 5),
#  ('ash gray', 5),
#  ('plastic bags', 5),
#  ('glass bottle', 5),
#  ('recording', 5),
#  ('giving lecture', 5),
#  ('umbrella', 5),
#  ('hand', 5),
#  ('ater', 5),
#  ('placing things', 5),
#  ('music score', 5),
#  ('swimming pool', 5),
#  ('rag', 5),
#  ('operating phone', 5),
#  ('opening computer', 5),
#  ('putting towel', 5),
#  ('falling down', 5),
#  ('balloon', 5),
#  ('cage', 5),
#  ('saffron', 5),
#  ('button', 5),
#  ('doing laundry', 5),
#  ('paper folding', 5),
#  ('ride motorcycle', 5),
#  ('in glass bowl', 5),
#  ('narrating', 5),
#  ('candle', 5),
#  ('acting', 5),
#  ('looking at camera', 5),
#  ('microwave', 5),
#  ('reaching out', 5),
#  ('reading messages', 5),
#  ('cooking things', 5),
#  ('statue', 5),
#  ('cabinet door', 5),
#  ('earth yellow', 5),
#  ('boating', 5),
#  ('on highway', 5),
#  ('subtitle', 5),
#  ('number', 5),
#  ('bridge', 5),
#  ('light-red', 5),
#  ('emerald green', 5),
#  ('reading newspaper', 5),
#  ('waste container', 5),
#  ('pigment', 5),
#  ('plastic bucket', 5),
#  ('vacuum', 5),
#  ('washbasin', 5),
#  ('boxing', 5),
#  ('wiping mirror', 5),
#  ('player', 5),
#  ('handle', 5),
#  ('taking on his coat', 5),
#  ('swinging', 5),
#  ('pink red', 5),
#  ('playing computer games', 5),
#  ('black green', 4),
#  ('firming', 4),
#  ('ruler', 4),
#  ('tire', 4),
#  ('buff', 4),
#  ('water tap', 4),
#  ('tidying up things', 4),
#  ('tray', 4),
#  ('stools', 4),
#  ('by road', 4),
#  ('cleaning up dust', 4),
#  ...]

# %%
sort_question
# Out:
# [('where is the person in the video', 1266),
#  ('what is the person in the video doing', 933),
#  ('what is the person doing in the video', 794),
#  ('is the person in the video standing or sitting', 546),
#  ('is the person in the video sitting or standing', 507),
#  ('is the person sitting or standing in the video', 450),
#  ('what is in the video', 316),
#  ('what is on the table', 224),
#  ('where is the person in video', 194),
#  ('what is in the room', 182),
#  ('what can you see in the video', 163),
#  ('what color of the clothes does the person wear in the video', 162),
#  ('what is the man in the video doing', 137),
#  ('what is the man doing in the video', 132),
#  ('is the person standing or sitting in the video', 131),
#  ('what is in front of the person in the video', 130),
#  ('what is the person in video doing', 121),
#  ('what color clothes does the person wear in the video', 121),
#  ('what is the person doing in video', 108),
#  ('where is the man', 108),
#  ("what is the color of the person's clothes in video", 106),
#  ('what is the man doing', 106),
#  ('is the man in the video standing or sitting', 105),
#  ('where is the man in the video', 96),
#  ("what is the color of the person's clothes in the video", 94),
#  ('what color clothes does the person in the video wear', 90),
#  ("what color is the person's clothes in the video", 89),
#  ('what is the woman in the video doing', 88),
#  ('what is the color of the wall', 85),
#  ('is the man standing or sitting', 84),
#  ('what is the color of the clothes of the person in the video', 74),
#  ('what is on the table in the video', 71),
#  ('what color pants does the person wear in the video', 65),
#  ('what is in the living room', 58),
#  ('is the man sitting or standing in the video', 58),
#  ('what is on the wall', 57),
#  ('what is the woman doing in the video', 56),
#  ('is the person in video sitting or standing', 56),
#  ('what color does the person wear in the video', 55),
#  ('what is the gender of the person in the video', 53),
#  ('what color is the wall', 50),
#  ('where is the woman in the video', 50),
#  ('what is on the bed', 50),
#  ('is the woman in the video standing or sitting', 49),
#  ("what color are the person's clothes in the video", 46),
#  ('what is in front of the wall', 39),
#  ('is the person in the video long hair or short hair', 37),
#  ('what is the color of the wall in the video', 37),
#  ('what is the color of the clothes the man wears', 37),
#  ('is the woman in the video sitting or standing', 37),
#  ('what is the woman doing', 37),
#  ('what is the color of the clothes does the man wear', 36),
#  ('what color clothes does the man wear in the video', 36),
#  ('what is the person doing', 36),
#  ('what is the color of the clothes in the video', 36),
#  ("what is in the man's hands", 36),
#  ('where is the cup', 36),
#  ('where is the woman', 35),
#  ('what color clothes does the woman wear in the video', 35),
#  ('what is on the face of the person in the video', 33),
#  ('is the person in video standing or sitting', 33),
#  ("what is in the man's hand", 31),
#  ('is the man in the video sitting or standing', 31),
#  ('is the person in the video standing or lying', 31),
#  ('what is in the kitchen', 30),
#  ('what is on the desk', 29),
#  ('is the man standing or sitting in the video', 28),
#  ('what is the color of the clothes the man wears in the video', 28),
#  ('what color of clothes does the man in the video wear', 28),
#  ('what color of the clothes does the man wear in the video', 26),
#  ('is the woman standing or sitting in the video', 26),
#  ('what can you see in video', 26),
#  ('what is on the wall in the video', 26),
#  ('what color is the wall in the video', 25),
#  ('what does the man in the video hold in his hand', 25),
#  ('what is in the hand of the person in the video', 25),
#  ('what color clothes does person in the video wear', 24),
#  ('what is in front of the window', 24),
#  ('is the woman sitting or standing', 24),
#  ('what color of the pants does the person wear in the video', 23),
#  ("what is on the person's face in the video", 23),
#  ('does the person have long hair or short hair', 22),
#  ('what color of the clothes does the woman wear in the video', 22),
#  ('where is the computer', 21),
#  ('what color top does the person wear in the video', 21),
#  ('what is the color of the clothes does the person wear in video', 20),
#  ('what is the color of the pants of the person in the video', 20),
#  ('where is the book', 19),
#  ('where is the person', 19),
#  ('what color clothes is the person wearing in the video', 19),
#  ('what is behind the person in the video', 19),
#  ('what is on the ground', 19),
#  ('what color does the person wear', 19),
#  ('what is on the ground in the video', 18),
#  ('does the person have long hair or short hair in the video', 18),
#  ('is the person standing or sitting in video', 18),
#  ('what color does the man wear in the video', 18),
#  ('is the woman in the video long hair or short hair', 17),
#  ('what is on the floor', 17),
#  ('what is on the table in video', 17),
#  ("what is the color of the person's trousers in video", 17),
#  ('is the woman standing or sitting in video', 15),
#  ('what is the woman doing in video', 15),
#  ('where is the computer in the video', 15),
#  ('what is on the right of the person in the video', 15),
#  ("what is the color of the person's hair in the video", 15),
#  ("what color is the person's coat in video", 15),
#  ('what is the color of the trousers does the person wear in video', 15),
#  ('what color of the jacket does the person wear in the video', 15),
#  ('what color of upper outer garment does the person in the video wear', 15),
#  ("what is in the woman's hands", 15),
#  ('where is the mirror in the video', 14),
#  ('is the person in the video sitting or lying', 14),
#  ('where is the clothes', 13),
#  ('what color of clothes does the woman in the video wear', 13),
#  ('is the person in the video sitting or standing at first', 13),
#  ("what is the color of the woman's clothes in the video", 13),
#  ('what is on the cabinet', 13),
#  ('where is the car in the video', 13),
#  ('what color coat does the person wear in the video', 13),
#  ('where is the bottle', 12),
#  ('what is the color of the door in the video', 12),
#  ('what does the person wear on head in the video', 12),
#  ('is the person in the video sitting or standing at the beginning', 12),
#  ('what is the color of the clothes the woman wears', 12),
#  ('what is the color of the car in the video', 12),
#  ('what is the color of the table in the video', 12),
#  ('what is the color of the clothes does the woman wear', 12),
#  ('what is on the cooktop', 12),
#  ('what is the cartoon character doing in the video', 12),
#  ('what is the man doing in video', 12),
#  ('where is the mirror', 12),
#  ('is the person standing or sitting in the beginning of the video', 11),
#  ('is the woman sitting or standing in the video', 11),
#  ('where is the cartoon character in the video', 11),
#  ("what is in the person's hand", 11),
#  ('where is the woman in video', 11),
#  ('what color is the car in the video', 11),
#  ('what is on the sofa', 11),
#  ("what is the color of the person's pants in the video", 11),
#  ("what color is the man's clothes in the video", 10),
#  ('is the person in video sitting or standing at the beginning', 10),
#  ('what is on the washing machine', 10),
#  ("what is in the woman's hand", 10),
#  ('where is the cup in the video', 10),
#  ('what color is the chair in the video', 10),
#  ('where is the laptop', 10),
#  ('what is the color of the coat does the person wear in video', 10),
#  ('what does the person wear on face in the video', 10),
#  ('what is the girl doing in the video', 10),
#  ('what color is the clothes worn by the person in the video', 10),
#  ('is the man in the video long hair or short hair', 10),
#  ('where is the tv', 10),
#  ('what is the color of the wall in video', 10),
#  ('how many people are there in the video', 10),
#  ('where is the mural', 9),
#  ('what is in the closet', 9),
#  ('where is the man in video', 9),
#  ("what is on the man's face in the video", 9),
#  ("what is the color of the woman's clothes", 9),
#  ('what is in the cabinet', 9),
#  ('what is the color of the clothes of the man in the video', 9),
#  ('what is the woman holding in the video', 9),
#  ("what is in the person's hand in the video", 9),
#  ('is the person in the video short hair or long hair', 9),
#  ('what is on the face of the man in the video', 8),
#  ('what is the girl doing in video', 8),
#  ('is the person sitting or lying in the video', 8),
#  ('what is on the left of the person in the video', 8),
#  ('what is in front of the door in the video', 8),
#  ('what is in the corridor', 8),
#  ('is the man standing or sitting in video', 8),
#  ("what is on the person's head in the video", 8),
#  ('where is the person sitting in the video', 8),
#  ('is the person in the video sitting or lying down', 8),
#  ('what is the color of the chair in the video', 8),
#  ('what color is the sofa in the video', 8),
#  ('is the girl standing or sitting in the video', 8),
#  ('what is the color of the sofa in the video', 8),
#  ('what is the color of the clothes of the woman in the video', 8),
#  ('what color is the cabinet', 8),
#  ('what is the color of the cabinet in the video', 8),
#  ('where is the towel', 8),
#  ('what does the man in the video wear on his head', 8),
#  ('is the woman standing or sitting', 8),
#  ('where is the pillow', 8),
#  ('what is the color of the blanket in the video', 8),
#  ('what is the color of the trousers the man wears', 8),
#  ('how many people are in the video', 8),
#  ('what does the man wear on head in the video', 7),
#  ('what color of the coat does the person wear in the video', 7),
#  ('what is hanging on the wall in the video', 7),
#  ('where is the chair in the video', 7),
#  ('where are the clothes', 7),
#  ('where is the animal in the video', 7),
#  ('what is on the stairs', 7),
#  ("what color is the person's hair in the video", 7),
#  ('where is the bottle in the video', 7),
#  ('is the man standing or sitting at last', 7),
#  ('what is the color of the refrigerator in the video', 7),
#  ('what is the child in the video doing', 7),
#  ('is the girl standing or sitting in video', 7),
#  ('what is the color of the car', 7),
#  ('what color pants does the person in the video wear', 7),
#  ('what is on the stage', 7),
#  ('is the door in the video open or closed', 7),
#  ('what is the color of the curtain in the video', 7),
#  ("what is the color of the man's clothes in the video", 6),
#  ('what does the person in video wear on his head', 6),
#  ('what does the person in video have on their face', 6),
#  ('what is the person in the video', 6),
#  ('what is on the storage rack', 6),
#  ('what animal is in the video', 6),
#  ('where is the child in the video', 6),
#  ('what is on the shelf', 6),
#  ('is the man in the video standing or sitting at the beginning', 6),
#  ('where is the chair', 6),
#  ('what are the people doing in video', 6),
#  ('what color pants does the man wear in the video', 6),
#  ('what is in front of the door', 6),
#  ('what color is the refrigerator', 6),
#  ('what is on the closet', 6),
#  ('what color top does the person in the video wear', 6),
#  ("what color is the person's top in the video", 6),
#  ('what color dress does the person wear in the video', 6),
#  ('is the boy in the video standing or sitting', 6),
#  ('what is in the person is hand in the video', 6),
#  ('what does the man in the video hold', 6),
#  ('what is the color of the pants does the man wear', 6),
#  ('what is on the hearth', 6),
#  ('what does the man in the video sit on', 6),
#  ("what color is the person's pants in the video", 6),
#  ('is the person in video in the living room or in the kitchen', 6),
#  ('what color is the pot in the video', 6),
#  ("what is the color of the living room's wall", 6),
#  ('what is on the countertop', 5),
#  ('what is the person holding in his hand in the video', 5),
#  ('what is in the toilet', 5),
#  ('what time is it in the video', 5),
#  ("what is the color of woman's clothes in video", 5),
#  ('how many people appeared in the video', 5),
#  ('what color of clothes does the person in the video wear', 5),
#  ('is the television turned on or off in the video', 5),
#  ('is the person lying or sitting in the beginning of the video', 5),
#  ('where are the people in video', 5),
#  ('what is the person wearing glasses in the video doing', 5),
#  ('where is the pillow in the video', 5),
#  ('where is the man sitting in the video', 5),
#  ('what color of the clothes does the person wear at the beginning of the video',
#   5),
#  ('what is in video', 5),
#  ('where is the book in the video', 5),
#  ('where is the pen in the video', 5),
#  ('how many people appear in the video', 5),
#  ('what color is the hat in the video', 5),
#  ('where is the boy in the video', 5),
#  ('what is at the back of the door', 5),
#  ('is the text in the video horizontal or vertical', 5),
#  ('what does the person in the video hold', 5),
#  ('what is on the cabinet in the video', 5),
#  ('what is the animal in the video', 5),
#  ("what is the color of person's coat in video", 5),
#  ('what does the man wear on face in the video', 5),
#  ('where is the girl in the video', 5),
#  ('what is on the wall in video', 5),
#  ('what is the man wearing on the head in the video', 5),
#  ('what is in the bathroom', 5),
#  ('what color is the door in the video', 5),
#  ('what is in front of the woman in the video', 5),
#  ('what is the color of the trousers the man wears in the video', 5),
#  ('what is the man in the video', 5),
#  ('is the cartoon character in the video sitting or standing', 5),
#  ("what is the color of man's clothes in video", 5),
#  ('what does the person open in the video', 5),
#  ('is the man sitting or standing', 5),
#  ("what is on the person's hand in the video", 5),
#  ('is the person standing or sitting at the beginning of the video', 5),
#  ('where is the audience in the video', 5),
#  ('what is the boy doing in the video', 5),
#  ('what is on the head of the person in the video', 5),
#  ('where are the shoes', 5),
#  ('where are the shoes in the video', 5),
#  ('is the person sitting or standing at the beginning of the video', 5),
#  ('what color coat does the person in the video wear', 5),
#  ('what is the color of the sofa', 5),
#  ('are the people standing or sitting in video', 5),
#  ('what sports have appeared in video', 5),
#  ('where is the plate in the video', 5),
#  ('what is the man holding in the video', 5),
#  ('where is the carton', 5),
#  ('how many people have appeared in the video', 5),
#  ('what color is the carpet in the video', 4),
#  ('where is the television', 4),
#  ('what is the person wearing on his head in the video', 4),
#  ('what is on the stool', 4),
#  ('where is the paper box', 4),
#  ('what color shoes does the person wear in the video', 4),
#  ('is the man in video sitting or standing', 4),
#  ('what is in the hands of the person in the video', 4),
#  ("what is on the woman's face in the video", 4),
#  ('what does the woman wear on head in the video', 4),
#  ('what color is the door', 4),
#  ('what does the woman in the video hold in her hand', 4),
#  ('what is the boy in the video doing', 4),
#  ('what is the person wearing black clothes doing in the video', 4),
#  ("what color is the girl's hair in the video", 4),
#  ("what is the color of woman's coat in video", 4),
#  ('what is the girl in the video doing', 4),
#  ('what is the person in the video sitting on', 4),
#  ("what is the color of person's clothes in video", 4),
#  ('what does the person hold in hand in the video', 4),
#  ('is the girl in the video standing or sitting', 4),
#  ('is the person in video a man or a woman', 4),
#  ('what is the kid doing in the video', 4),
#  ('what is in the car', 4),
#  ("what color is the woman'hair in video", 4),
#  ('what is the child doing in the video', 4),
#  ('what color of the pants does the woman wear in the video', 4),
#  ('what color is the floor in the video', 4),
#  ('what is the color of the refrigerator', 4),
#  ('where are the people in the video', 4),
#  ('what does the person in video have in his hand', 4),
#  ('is the text in the video english or chinese', 4),
#  ('where is the person standing in the video', 4),
#  ('where is the photo', 4),
#  ('what color hat does the man wear in the video', 4),
#  ("what color is the woman's hair in the video", 4),
#  ('what color is the woman is hair in the video', 4),
#  ('where is the toy in the video', 4),
#  ('what is the animal doing in the video', 4),
#  ('what is wearing on the head of the person in the video', 4),
#  ('what is the person holding in the video', 4),
#  ('what color of the pants does the man wear in the video', 4),
#  ('what does the woman in the video hold', 4),
#  ('is the audience standing or sitting', 4),
#  ('where is the water glass in the video', 4),
#  ('where is the refrigerator in the video', 4),
#  ('what color is the table in the video', 4),
#  ('what is the person in video holding in his hands', 4),
#  ('what is the man in video doing', 4),
#  ('what is on the right of the door', 4),
#  ('what is in the washing room', 4),
#  ('is the person singing in the video sitting or standing', 4),
#  ('what is on the table in the kitchen', 4),
#  ('is the person holding the broom sitting or standing', 4),
#  ('what is on the bed in video', 4),
#  ('what color is the background in video', 4),
#  ('where is the blanket in the video', 4),
#  ('what does the person in video wear on his face', 4),
#  ('what is in front of the person in video', 4),
#  ('where is the box in the video', 4),
#  ('where is the person in white', 4),
#  ('where is the floor lamp in the video', 4),
#  ('what color top does the person wearing glasses in the video wear', 4),
#  ('what does the person turn on in the video', 4),
#  ('what is the person in stripe shirt doing in the video', 4),
#  ('what is the person in white doing in the video', 4),
#  ('what is behind the door', 4),
#  ('where is the switch', 4),
#  ('is the person in the video standing or squatting', 4),
#  ('what is the person in white doing', 4),
#  ('where are the books in the video', 4),
#  ('where is the table in the video', 4),
#  ('is the light turned on or off in the video', 4),
#  ('what is the first person in the video doing', 4),
#  ('where is the guitar', 4),
#  ('what color of the dress does the person wear in the video', 4),
#  ('what is the person in the video holding', 4),
#  ('what is on the door', 4),
#  ('what does the woman in the video wear on her face', 4),
#  ('is the cartoon character sitting or standing in the video', 4),
#  ('what is the color of the floor in the video', 4),
#  ('what is the color of the cat in the video', 4),
#  ('what is on the refrigerator', 4),
#  ('is the text in the video written in english or chinese', 4),
#  ('where does the man in the video sit', 3),
#  ('what is behind the refrigerator', 3),
#  ('is the man in purple standing or sitting', 3),
#  ('what is the wall full of in the video', 3),
#  ('what color is the chair in video', 3),
#  ('what does the man in video wear on his head', 3),
#  ('what color of the clothes does the girl wear in the video', 3),
#  ("what color are the woman's clothes in the video", 3),
#  ('what is on the bed in the video', 3),
#  ('what is in the room in the video', 3),
#  ('what color top does the woman wear in the video', 3),
#  ('what is the color of the washing machine', 3),
#  ('what color is the cup', 3),
#  ("what is the color of the child's clothes in the video", 3),
#  ('where is the laundry detergent', 3),
#  ('what does the girl wear on head in the video', 3),
#  ('what is on the pool table', 3),
#  ("what is in the woman's hand in the video", 3),
#  ('what happens in video', 3),
#  ('what color is the table', 3),
#  ('what color is the refrigerator in the video', 3),
#  ('is the text in the video chinese or english', 3),
#  ('what is the man wearing on the neck in the video', 3),
#  ('what is the animal that appears in the video', 3),
#  ('what color is the dress of the person in the video', 3),
#  ('does the woman have long hair or short hair in the video', 3),
#  ('what color hair does the person have in the video', 3),
#  ('is the person wearing glasses in the video standing or sitting', 3),
#  ('where is the person in the video at the beginning', 3),
#  ('is the man standing or sitting at the beginning', 3),
#  ('what is the woman in black doing', 3),
#  ('what is the person wearing pink in the video doing', 3),
#  ('what does the man wear around his neck in the video', 3),
#  ('what color is the chair', 3),
#  ('what is hanging on the wall', 3),
#  ('what is the adult doing in the video', 3),
#  ('what color is the horse in the video', 3),
#  ('are people standing or sitting in the video', 3),
#  ('what is the occupation of the person in the video', 3),
#  ('where is the tv in the video', 3),
#  ('what is behind the chair', 3),
#  ('what is on the lawn', 3),
#  ('is the person in red sitting or standing in the video', 3),
#  ('what is the person wearing glasses doing in the video', 3),
#  ('what color is the dog in the video', 3),
#  ('what color is the desk in the video', 3),
#  ('what is the color of the hat of the person in the video', 3),
#  ('what color of the t-shirt does the person wear in the video', 3),
#  ('what does the man hold in hands in the video', 3),
#  ('is the person wearing white clothes in the video sitting or standing', 3),
#  ('what color dress does the girl wear in the video', 3),
#  ('where is the computer in video', 3),
#  ('what color is the subtitle in the video', 3),
#  ('where is the sofa in the video', 3),
#  ('is the person wearing black pants standing or sitting', 3),
#  ('is the person in the video man or woman', 3),
#  ('where is the mirror placed in the video', 3),
#  ('what color does the boy wear in the video', 3),
#  ('is the animal appearing in the video a cat or a dog', 3),
#  ('what is the game character doing in the video', 3),
#  ('what is the color of the broom in the video', 3),
#  ('where is the phone in the video', 3),
#  ('what does the man in video wear on his face', 3),
#  ('where is the audience', 3),
#  ('where is the person in red', 3),
#  ('is the person wearing a hat in the video long hair or short hair', 3),
#  ('what is the color of the towel in the video', 3),
#  ('where is the person at the beginning of the video', 3),
#  ('is the person in pink sitting or standing in the video', 3),
#  ('what are the hands doing in the video', 3),
#  ('is the person in black sitting or standing in the video', 3),
#  ('what is on the floor in the video', 3),
#  ("what is on the man's head in the video", 3),
#  ('where is the table', 3),
#  ('where is the water bottle in the video', 3),
#  ('is the person in the video sitting or lying at first', 3),
#  ('is the person in video have short hair or long hair', 3),
#  ('what is the color of the cup', 3),
#  ('what is the color of the coat the man wears in the video', 3),
#  ('what is the color of the table', 3),
#  ('is the tv on or off', 3),
#  ('where are the two people in video', 3),
#  ('what does the girl in video wear on her head', 3),
#  ('is the child in the video sitting or standing', 3),
#  ('what is the person wearing black pants doing', 3),
#  ('what is behind the people in the video', 3),
#  ('what is the color of the sheet in the video', 3),
#  ('what is the color of the computer', 3),
#  ('what is the color of the computer in the video', 3),
#  ('what color clothes is the woman wearing in the video', 3),
#  ('what is in front of the chair', 3),
#  ('what is on the glass table', 3),
#  ('what is on the person in the video', 3),
#  ("what color is the man's hair in the video", 3),
#  ('what does the person hold in hands in the video', 3),
#  ('where is the cat in the video', 3),
#  ('what is on the chair', 3),
#  ('what does the person wear on his head', 3),
#  ('what is behind the person', 3),
#  ('what is in front of the sofa', 3),
#  ('what are the men in the video doing', 3),
#  ('where is the table lamp', 3),
#  ('what is in front of the mirror', 3),
#  ('what is at the back of the person in the video', 3),
#  ('what is on video', 3),
#  ('what is the person sitting in the video doing', 3),
#  ('is the woman in the video straight or curly', 3),
#  ('what is the background color in the video', 3),
#  ('what color is the background wall in the video', 3),
#  ('how many people are in video', 3),
#  ('what is worn on the hand of the person in the video', 3),
#  ('what is in the refrigerator', 3),
#  ('what is the color of the clothes of the person sitting in the video', 3),
#  ('what is the person doing in the first video', 3),
#  ('is the person in glasses sitting or standing', 3),
#  ('what is the person wearing the hat doing in the video', 3),
#  ('what color is the sky in video', 3),
#  ('is the woman in video sitting or standing', 3),
#  ('what color is the leaf in the video', 3),
#  ('is the person standing or lying in the video', 3),
#  ('is the window in the video open or closed', 3),
#  ('what color of the clothes does the boy wear in the video', 3),
#  ('where is the painting', 3),
#  ('what does the man in the video wear on his face', 3),
#  ('what is in front of the man', 3),
#  ('what is the person wearing the video', 3),
#  ('is the person sitting or standing at the beginning in the video', 3),
#  ('what is the color of the dress does the woman wear', 3),
#  ('is the person in black sitting or standing', 3),
#  ('what color is the light in the video', 3),
#  ('what is the athlete in the video doing', 3),
#  ('what is the color of the sheets in the video', 3),
#  ('what is the person in white clothes doing', 3),
#  ('what does the woman in video wear on her face', 3),
#  ('what is in the bedroom', 3),
#  ('what is in front of the table', 3),
#  ('is the person wearing glasses standing or sitting in the video', 3),
#  ('what is on the tea table', 3),
#  ('what is the color of the pillow in the video', 3),
#  ('what is the person with glasses doing in the video', 3),
#  ('what does the person in the video hold in the hands', 3),
#  ('what does the person in video hold', 3),
#  ('what color is the cabinet in the video', 3),
#  ('is the boy standing or sitting in the video', 3),
#  ('what is the baby doing in the video', 3),
#  ('is the man in the video straight or curly', 3),
#  ('where is the car', 3),
#  ('what color is the sheet', 3),
#  ('does the woman in the video have long hair or short hair', 3),
#  ('what is the person in blue doing in the video', 3),
#  ('is the woman in the video lying down or sitting', 2),
#  ('where is sofa in video', 2),
#  ('is the referee in the video sitting or standing', 2),
#  ('where is the number plate in the video', 2),
#  ('what are the animals in video', 2),
#  ('what is the color of the bag in the video', 2),
#  ("what is the color of the woman's hair", 2),
#  ('what is the sport in the video', 2),
#  ('what is on the front of the door', 2),
#  ('does the person wear pants or shorts', 2),
#  ('what does the person have in his hand', 2),
#  ('is the person lying or seated in the video', 2),
#  ('where is the person in the second video', 2),
#  ('what color is the microphone in the video', 2),
#  ('where is switch', 2),
#  ('what color is the dress worn by the woman in the video', 2),
#  ('how many game figures are in the video', 2),
#  ('is the lamp on or off', 2),
#  ('where is the goblet', 2),
#  ('what color shoes does the woman wear in the video', 2),
#  ('what color is the phone in the video', 2),
#  ('where is the pan in the video', 2),
#  ('where does the man in the video put the book', 2),
#  ('what color is the nail in the video', 2),
#  ('are the two men in the video standing or sitting', 2),
#  ('what is in front of the man in the video', 2),
#  ('what color clothes does the person with white hair wear in the video', 2),
#  ('what is in the right hand of the person in the video', 2),
#  ('what color of the clothes does the child wear in the video', 2),
#  ('what is the color of the cabinet', 2),
#  ('what is playing in video', 2),
#  ('is the person with glasses in video standing or sitting', 2),
#  ('how many kids are there in the video', 2),
#  ('what is the color of the hair of the person in green in the video', 2),
#  ('how many cars are there in the video', 2),
#  ('where is the ball in the video', 2),
#  ('is the cartoon character in the video standing or sitting', 2),
#  ('what does the man wear on his wrist in the video', 2),
#  ('what color is the bowl in the video', 2),
#  ('where is the man in black pants', 2),
#  ('is the person wearing blue clothes standing or sitting', 2),
#  ('where is the person singing in the video', 2),
#  ('is the woman in video standing or sitting', 2),
#  ('what color of pants does the man in the video wear', 2),
#  ('is the person wearing white clothes in the video standing or sitting', 2),
#  ('where is the person in the first video', 2),
#  ('what is in the bag', 2),
#  ('where is the towel in the video', 2),
#  ('is the man with white hair in the video standing or sitting', 2),
#  ('what are the men doing in video', 2),
#  ('what is on the left of the door', 2),
#  ('what is the color of the clothes of the adult in the video', 2),
#  ('what is at the back of the chair', 2),
#  ('where is the man lying on in the video', 2),
#  ('what is the color of the hair of the person in the video', 2),
#  ('is the cartoon character standing or sitting in video', 2),
#  ('what color is the cover in the video', 2),
#  ('what is the color of the pot in the video', 2),
#  ('is the person in white in the video standing or sitting', 2),
#  ('where is man in video', 2),
#  ('where is the beverage', 2),
#  ('what vehicle is in the video', 2),
#  ('what color is the wall space in video', 2),
#  ('is the person wearing black clothes in the video long hair or short hair',
#   2),
#  ('where does the person sit in the video', 2),
#  ('what is behind the woman', 2),
#  ('what color is the laptop in the video', 2),
#  ('where is the poster', 2),
#  ('is the boy standing or sitting in video', 2),
#  ('what is the background in video', 2),
#  ('what are the women doing in video', 2),
#  ('what color of clothes does the boy in the video wear', 2),
#  ('where are the two people in the video', 2),
#  ('is the character standing or sitting in video', 2),
#  ('is the person wearing hat sitting or standing', 2),
#  ('what is the man in blue doing', 2),
#  ('what is the person in video doing after getting up', 2),
#  ('what is in front of the adult in the video', 2),
#  ("what is the color of the person's shoes in the video", 2),
#  ('what color t-shirt does the person wear in the video', 2),
#  ('where does the woman in the video put her clothes', 2),
#  ('where is the bolster', 2),
#  ('does the man in the video have long or short hair', 2),
#  ('where is the vase in the video', 2),
#  ('what is the boy doing', 2),
#  ('is the person sitting or standing on the stage', 2),
#  ('where is the plant in the video', 2),
#  ('what color is the basin in video', 2),
#  ('what is the horse doing in video', 2),
#  ('what is the color of the clothes of the person with glasses in the video',
#   2),
#  ('where is the monster in the video', 2),
#  ('in which room is the man in the video', 2),
#  ('what is on the refrigerator in the video', 2),
#  ('what is the color of the computer desktop in the video', 2),
#  ("what is the color of the man's clothes at the beginning of the video", 2),
#  ('what color is the number in the video', 2),
#  ('where is the remote control', 2),
#  ('what is on the left of the wall', 2),
#  ('what is in front of the child in the video', 2),
#  ('what is the color of the clothes does the person wear while eating in video',
#   2),
#  ("what color is the woman's clothes in the video", 2),
#  ('what color of skirt does the woman in the video wear', 2),
#  ('where does the person enter in the video', 2),
#  ('what color is the blanket in video', 2),
#  ('where is the doll in the video', 2),
#  ('what color is the cartoon character in the video', 2),
#  ('what does the girl hold in hand in the video', 2),
#  ('what is on the shelf in video', 2),
#  ('what is on the sofa in video', 2),
#  ('what did the person in the video open', 2),
#  ('what is the color of the blanket in video', 2),
#  ('is the lamp opening or closed in the video', 2),
#  ('where is the backpack in the video', 2),
#  ('what is in the hand of the man in the video', 2),
#  ("what is on the woman's ear", 2),
#  ('what is hanging on the window in the video', 2),
#  ('what color is the floor', 2),
#  ('what is on the back of the person in the video', 2),
#  ('what does the woman in the video hold in her right hand', 2),
#  ('is the person sitting or standing while eating in the video', 2),
#  ('where is the person at last in the video', 2),
#  ("what is the color of the person's hair", 2),
#  ('what is in the basin in the video', 2),
#  ('what is the hand doing in the video', 2),
#  ('what is the green stuff in video', 2),
#  ('where is the scarf', 2),
#  ('what color is english in the video', 2),
#  ('is the person in the video sitting or squatting', 2),
#  ('where is the refrigerator', 2),
#  ('where does the person lie', 2),
#  ('what is the adult in the video doing', 2),
#  ('what color are the numbers in video', 2),
#  ('what is the person in green doing in the video', 2),
#  ('what does the person have on his left hand', 2),
#  ('where is the phone', 2),
#  ('is the person applauding in the video sitting or standing', 2),
#  ("what color is the girl'hair in video", 2),
#  ('what is the color of the stool', 2),
#  ('what is the color of the bolster in the video', 2),
#  ('where is the coat', 2),
#  ('what color is the roof in the video', 2),
#  ('what is on the window sill', 2),
#  ('where is the kettle', 2),
#  ('what is the computer doing in the video', 2),
#  ('is the cursor in video moving', 2),
#  ('was the man standing or sitting in the end', 2),
#  ('is the person wearing glasses', 2),
#  ('is the curtain in the video open or closed', 2),
#  ('what is the girl in black in video holding in her hand', 2),
#  ('what color is the curtain in the video', 2),
#  ('what is in the hand of the girl in the video', 2),
#  ('what color clothes does the person in the first scene wear', 2),
#  ('what is the little boy in the video doing', 2),
#  ('does the woman in video have straight hair or curly hair', 2),
#  ('what color hair does the woman have in the video', 2),
#  ('what does the person drink', 2),
#  ('where is the washing machine', 2),
#  ('where is the horse in the video', 2),
#  ('what is the person doing with his hands in the video', 2),
#  ('what is the color of the bottle', 2),
#  ('is the person in white standing or sitting in the video', 2),
#  ('what color of clothes does the man squatting in the video wear', 2),
#  ('what is in the hallway', 2),
#  ('what kind of transportation does video have', 2),
#  ('what is the woman with short hair doing', 2),
#  ('what is the color of the closet', 2),
#  ('is the person in the video standing or lying down', 2),
#  ('does the person in video have a beard on their face', 2),
#  ('where is the room in the video', 2),
#  ('is the referee in the video standing or sitting', 2),
#  ('what is on the table of the kitchen', 2),
#  ('what color of the clothes does the cartoon character wear in the video', 2),
#  ('what is the color of the balloon in the video', 2),
#  ('what is on the table in front of the man', 2),
#  ('where is the television in the video', 2),
#  ('is the singing person sitting or standing in the video', 2),
#  ('what is the plane doing in the video', 2),
#  ('what is the men doing in video', 2),
#  ('what is the person in red doing', 2),
#  ('is the person on the stage standing or sitting in the video', 2),
#  ('what is in the dishes', 2),
#  ('what are the athletes in the video doing', 2),
#  ('what is in the box', 2),
#  ('where is the hanger in the video', 2),
#  ('what is in the fridge in the video', 2),
#  ('is the door open or closed in the video', 2),
#  ('what does the person wear in the video', 2),
#  ('where is the boy', 2),
#  ('what is in front of the cabinet', 2),
#  ('is the last person in the video standing or sitting', 2),
#  ('what color is the bowl', 2),
#  ('is the woman in red sitting or standing', 2),
#  ('where is the food', 2),
#  ('what does the woman wear on her face in video', 2),
#  ('what color is the plate in the video', 2),
#  ('where is the picture frame in the video', 2),
#  ('is the woman in the video lying or sitting', 2),
#  ('what is on the door of the refrigerator', 2),
#  ('what is on the sofa in the video', 2),
#  ('what is the person in green clothes doing', 2),
#  ('what is the person with red hair doing', 2),
#  ('what is the person pushing in the video', 2),
#  ('is the animal in the video sitting or standing', 2),
#  ('what is the person wearing a hat doing in the video', 2),
#  ('what is the color of the chair', 2),
#  ('is the character in the video standing or sitting', 2),
#  ('what is the cat doing in the video', 2),
#  ('what is the old man in the video doing', 2),
#  ('what is the color of the pants does the boy in white top wear', 2),
#  ('what is on the roof in the video', 2),
#  ('what is the color of the pants of the man in the video', 2),
#  ('what is on the road in the video', 2),
#  ("what is the color of the woman's hair in the video", 2),
#  ('is the person in the video a man or a woman', 2),
#  ('what color is the ground in the video', 2),
#  ('how many person showed in the video', 2),
#  ('is the child sitting or standing in the video', 2),
#  ('where is the frame', 2),
#  ('what is shown on the screen in the video', 2),
#  ('what color are the shoes', 2),
#  ('where is the clothes in the video', 2),
#  ('what is the shape of the paper in the video', 2),
#  ('is the game character in the video standing or sitting', 2),
#  ('is the man wearing a pair of pants or a skirt', 2),
#  ('what is the host in the video doing', 2),
#  ('where is the box', 2),
#  ('what is man doing in video', 2),
#  ('what is the color of the light in the video', 2),
#  ('where is the mirror in the video hanging', 2),
#  ('where is the calendar', 2),
#  ('is the woman in white standing or sitting in video', 2),
#  ('is the person in the video a boy or a girl', 2),
#  ('is the person in the video sitting or standing while eating', 2),
#  ('what is the person in orange doing in video', 2),
#  ('what color is the plant in the video', 2),
#  ('what color does the man in the video wear', 2),
#  ('what is the last thing in the video', 2),
#  ('what is on the wardrobe', 2),
#  ('what is the picture in video', 2),
#  ('what is the person doing at the beginning of the video', 2),
#  ('is the person with glasses in the video standing or sitting', 2),
#  ('is the person wearing the trousers or shorts in the video', 2),
#  ('is the woman sitting or standing in video', 2),
#  ('does the singing person have long hair or short hair in the video', 2),
#  ('what is the color of the background in the video', 2),
#  ('what does the woman wear around her neck in the video', 2),
#  ('what color pants does the woman wear in the video', 2),
#  ('what color is the pants worn by the person in the video', 2),
#  ('what is on the cabinet in video', 2),
#  ('where is the medicine bottle', 2),
#  ('where is the bowl in the video', 2),
#  ('what appeared in the video', 2),
#  ('what is the animal in video', 2),
#  ("what is in the man's hand in the video", 2),
#  ('is the man in the video sitting or squatting', 2),
#  ('is the person standing or sitting on the stage in the video', 2),
#  ('what is the color of the light', 2),
#  ('is the host in the video standing or sitting', 2),
#  ('is the person with glasses standing or sitting in video', 2),
#  ('is the man standing or sitting in the end', 2),
#  ('what is the color of the curtain', 2),
#  ('which hand of the person in the video holds the food', 2),
#  ('is the person wearing black clothes in the video standing or sitting', 2),
#  ('is the picture in video stationary or moving', 2),
#  ('what color is the sky in the video', 2),
#  ('what is on the vacant lot', 2),
#  ('where does the man in the video put the clothes', 2),
#  ('what is the color of the words in the video', 2),
#  ('what is the person in red doing in the video', 2),
#  ('what does the person in pink doing in the video', 2),
#  ('what is the princess in the video doing', 2),
#  ("what is the color of women's clothes in the video", 2),
#  ('what is the brand of the car', 2),
#  ('what is the color of the boat in the video', 2),
#  ('what is on the beach', 2),
#  ('what is the color of the pan in the video', 2),
#  ('is the person with glasses in the video sitting or standing', 2),
#  ('is the plane flying or stopping', 2),
#  ('is the person in the video walking or sitting', 2),
#  ('what is the person standing in the video doing', 2),
#  ('where is the clock', 2),
#  ('what is the athlete doing in the video', 2),
#  ('what is the color of the hat', 2),
#  ("what is the color of the man's hair", 2),
#  ('what is the monster doing in the video', 2),
#  ('where is the drink', 2),
#  ('where is the broom in the video', 2),
#  ('is the person in the video lying or standing', 2),
#  ('what is the man wearing', 2),
#  ('what does the person have in the video', 2),
#  ('what color is the tie in the video', 2),
#  ('where is the gun in the video', 2),
#  ('what is the person in black doing', 2),
#  ('which hand of the person in the video holds the cup', 2),
#  ("what is the color of women's clothes in video", 2),
#  ("what is the color of the women's clothes in the video", 2),
#  ('what is the person wearing white clothes in the video doing', 2),
#  ('where is the person holding the broom', 2),
#  ('what color is the grass in the video', 2),
#  ('what color is the woman wearing the jacket', 2),
#  ('what does the person hold in the video', 2),
#  ('what color clothes does the man in the video wear', 2),
#  ('what is on the commodity shelf', 2),
#  ('what is in the hand of the woman in the video', 2),
#  ('what color is the candle in the video', 2),
#  ('what color is the font in the video', 2),
#  ('what color clothes does the cartoon character wear in the video', 2),
#  ('what does the man carry on his back in the video', 2),
#  ('where is the game character in the video', 2),
#  ('where is the snake in the video', 2),
#  ('does the person have short hair or long hair in the video', 2),
#  ('where is the decorative painting in the video', 2),
#  ('what color clothes do people in the video wear', 2),
#  ('what is person in video doing', 2),
#  ('is the person sitting or squatting', 2),
#  ('what is on the stand', 2),
#  ('what is the white thing in the video', 2),
#  ('where is the globe in the video', 2),
#  ('what is the dog doing in the video', 2),
#  ('what is the color of the horse in the video', 2),
#  ("what color is the chef's hat in the video", 2),
#  ("what is the color of girl's clothes in video", 2),
#  ('where is the cream in the video', 2),
#  ('is the woman standing or lying in the video', 2),
#  ('are the audience standing or sitting', 2),
#  ('where are the cups in the video', 2),
#  ('where is the cabinet', 2),
#  ('where is the machine in the video', 2),
#  ('what is on the sink', 2),
#  ('is the singing person standing or sitting in the video', 2),
#  ('what is the person standing in video doing', 2),
#  ('where is the adult in the video', 2),
#  ('what is the man in the video holding in his arms', 2),
#  ("what color is the person's hair", 2),
#  ('is the person sitting or standing while drinking water in the video', 2),
#  ('what is on the chair in the video', 2),
#  ('what color is the car', 2),
#  ('what is the color of the hair of the woman in the video', 2),
#  ('is the person wearing the hat in the video sitting or standing', 2),
#  ('what is on the chopping board', 2),
#  ('where is the model in the video', 2),
#  ('is the person in pink in the video sitting or standing', 2),
#  ('what can be seen in video', 2),
#  ('is the man in the video standing or sitting at the end', 2),
#  ('where is the vase', 2),
#  ('what is the color of the stairs in the video', 2),
#  ('what is the color of the hair of the person in blue', 2),
#  ('is the person in white standing or sitting', 2),
#  ("what is the color of the person's pants in video", 2),
#  ('is woman in video standing or sitting', 2),
#  ('what is the person with glasses doing', 2),
#  ('what color clothes is the baby wearing in the video', 2),
#  ('what is the color of the pillows in the video', 2),
#  ('what color is the fence in the video', 2),
#  ('in which hand does the person hold the cellphone in the video', 2),
#  ('what is the color of the shoes in the video', 2),
#  ('what is the person playing in the video', 2),
#  ('where is the boy in video', 2),
#  ('where is the person wearing hat', 2),
#  ('what is the color of the plastic bucket in the video', 2),
#  ('what does the person in the video wear', 2),
#  ('what is the person in blue doing', 2),
#  ('is the person lying or sitting in the video', 2),
#  ('what color is the tire in the video', 2),
#  ('where is the fish in the video', 2),
#  ('what color shorts does the man wear in the video', 2),
#  ('what is the color of the flower in the video', 2),
#  ('what is on the left side of the chair', 2),
#  ('what color is the background in the video', 2),
#  ('what color is the steering wheel in the video', 2),
#  ('which hand of the man in video holds the script', 2),
#  ('what does the person in the video doing', 2),
#  ('what color of clothes does the girl in the video wear', 2),
#  ('what color is the car in video', 2),
#  ('what color is the cat in the video', 2),
#  ('where is the bag in the video', 2),
#  ('where is the orange', 2),
#  ('what is the woman wearing on the head in the video', 2),
#  ('what is the color of the tree in the video', 2),
#  ('where is the lamp in video', 2),
#  ("what is on the girl's head", 2),
#  ('what is the person wearing glasses doing', 2),
#  ('what color is the sofa', 2),
#  ('what is on the couch', 2),
#  ('what color is the english in the video', 2),
#  ('what kind of the jacket does the person wear in the video', 2),
#  ('is the boy standing or sitting', 2),
#  ('what color top does the little girl wear in the video', 2),
#  ('what is the color of the piano in the video', 2),
#  ('what is the color of the pants of the person with glasses', 2),
#  ('what is the person in white doing in video', 2),
#  ('is the phone in the video horizontal or vertical', 2),
#  ('what is the alphabet at the left corner of the video', 2),
#  ('what is the man with glasses doing', 2),
#  ('is the person wearing white clothes in the video long hair or short hair',
#   2),
#  ('what is behind the person standing in video', 2),
#  ('where is the cup in video', 2),
#  ('what color is the glove in the video', 2),
#  ('what is the color of the hat in the video', 2),
#  ('what is the color of the baby carriage in the video', 2),
#  ('what is the women doing in the video', 2),
#  ('what does the person have', 2),
#  ('what is the color of the hearth', 2),
#  ('what is the color of the washing machine in the video', 2),
#  ('where is the man at the beginning of the video', 2),
#  ("what is the color of the man's pants in the video", 2),
#  ('what color are the pants of the person in the video', 2),
#  ('what color is the seat in the video', 2),
#  ('where is the electric fan in the video', 2),
#  ('what is the color of the heart in the video', 1),
#  ('what is color of trousers of man in video', 1),
#  ('how many characters appear in video', 1),
#  ('what is the person holding the broom doing', 1),
#  ('is the person in colorful trousers sitting or standing in the video', 1),
#  ('what color is the hair of the person wearing rose red dress', 1),
#  ('what is the shape of the bricks in the video', 1),
#  ('is the person in the white coat standing or sitting in the video', 1),
#  ('what is the color of the clothes on the bed in the video', 1),
#  ('what instrument is in the video', 1),
#  ('what color is the floor tile in the video', 1),
#  ('where did the person in the video going to', 1),
#  ('what is the color of the pants does the man sitting wear', 1),
#  ('what is in the hands before the person in the video dumps things', 1),
#  ('is the text on the nail polish written in english or chinese in the video',
#   1),
#  ('is the hair-tied person in the video standing or sitting', 1),
#  ('what is the color of the closet which is behind the man', 1),
#  ('what is the person wearing white pants doing', 1),
#  ('what is the round doing in the video', 1),
#  ('where do the people in video play football', 1),
#  ('is the guitar player standing or sitting in the video', 1),
#  ('where does the person put the handbag', 1),
#  ('where is the color paper in the video', 1),
#  ('what is put in the right of the person in the video', 1),
#  ('what is on the left side of the fridge', 1),
#  ('where is the person wearing the hat', 1),
#  ('what is on the corridor', 1),
#  ('is the person in the viedo sitting or standing', 1),
#  ('is the boy with green hair sitting or standing in the video', 1),
#  ('what color is the brand', 1),
#  ('where is the person in red in the video', 1),
#  ('what is the person with white hair in the video doing', 1),
#  ("what is on the man's legs in the video", 1),
#  ('is the person in the last scene standing or sitting', 1),
#  ('what color does the woman wear', 1),
#  ('what kind of the jacket does the person tying hair up wear in the video',
#   1),
#  ('what did the character drive to the river in video', 1),
#  ('what is the person wearing a vest in the video doing', 1),
#  ('which hand of the man holds the bag', 1),
#  ('where is the leopard', 1),
#  ('where does the man in the video put what he has on his hand', 1),
#  ('is the animal appearing in the video a dog or a cat', 1),
#  ('where is the person with golden hair', 1),
#  ('where is the person wearing earrings', 1),
#  ('is the person in video sitting or lying down', 1),
#  ('is the man in red sitting or standing in the video', 1),
#  ("what is color of man's hair in cartoon", 1),
#  ('what is the color of the wooden cabinet in the video', 1),
#  ('which number of the player in the video scored the ball', 1),
#  ('what is on the aisle', 1),
#  ('what is the fish that is moving its mouth', 1),
#  ('where is the camera', 1),
#  ('what type is the yellow car', 1),
#  ('where does the people sit', 1),
#  ('what color is the t-shirt the person wears', 1),
#  ('what color of the team uniform does the person wear in the video', 1),
#  ('where is the two girls dancing together in the video', 1),
#  ('is the man sitting or standing in the cartoon', 1),
#  ('what color are the clothes of the person who sits in the middle in the video',
#   1),
#  ('which season is the model showing in the video', 1),
#  ('is the kid wearing a glasses sitting or standing in the video', 1),
#  ('what does the boy wear on head in the video', 1),
#  ('what is hanging next to the mirror in video', 1),
#  ('what does the person have on his body', 1),
#  ('what is the color of the trousers of the person in a striped shirt in video',
#   1),
#  ('what is the person playing the guitar in the video doing', 1),
#  ('is the athlete in the video standing or sitting', 1),
#  ...]

# %%
[x[0] for x in sort_answer]
# Out:
# ['standing',
#  'sitting',
#  'black',
#  'white',
#  'indoor',
#  'blue',
#  'red',
#  'on table',
#  'in house',
#  'kitchen',
#  'residence',
#  'drinking water',
#  'green',
#  'living room',
#  'glasses',
#  'cup',
#  'yellow',
#  'eating',
#  'short hair',
#  'chair',
#  'clothes',
#  'speaking',
#  'talking',
#  'computer',
#  'bedroom',
#  'lying',
#  'hat',
#  'long hair',
#  'table',
#  'grey',
#  'walking',
#  'book',
#  'in door',
#  'dark blue',
#  'in living room',
#  'on wall',
#  'two',
#  'brown',
#  'gray',
#  'on ground',
#  'purple',
#  'pink',
#  'pillow',
#  'milk white',
#  'in kitchen',
#  'creamy white',
#  'outdoor',
#  'male',
#  'chatting',
#  'in bedroom',
#  'on stairs',
#  'in room',
#  'singing',
#  'inside house',
#  'mirror',
#  'pot',
#  'dancing',
#  'sneezing',
#  'sofa',
#  'light blue',
#  'on bed',
#  'bottle',
#  'room',
#  'cooking',
#  'on sofa',
#  'man',
#  'phone',
#  'bed',
#  'playing computer',
#  'opening door',
#  'cabinet',
#  'orange',
#  'indoors',
#  'desk',
#  'watching tv',
#  'tidying',
#  'bright red',
#  'aterrimus',
#  'car',
#  'three',
#  'in car',
#  'english',
#  'running',
#  'mustache',
#  'playing cell phone',
#  'plate',
#  'cell phone',
#  'bathroom',
#  'on desk',
#  'house',
#  'dark grey',
#  'resting',
#  'dark black',
#  'female',
#  'painting',
#  'shoes',
#  'microphone',
#  'left hand',
#  'yes',
#  'refrigerator',
#  'blanket',
#  'dog',
#  'sleeping',
#  'reading',
#  'furvous',
#  'closet',
#  'bag',
#  'dark green',
#  'towel',
#  'on floor',
#  'on stage',
#  'woman',
#  'on chair',
#  'taking off clothes',
#  'right hand',
#  'lying down',
#  'playing phone',
#  'tv',
#  'door',
#  'closing door',
#  'dark red',
#  'light gray',
#  'clearing up',
#  'reading book',
#  'writing',
#  'sweeping floor',
#  'squatting',
#  'taking things',
#  'box',
#  'tree',
#  'on cabinet',
#  'on shelf',
#  'open',
#  'bowl',
#  'on',
#  'in studio',
#  'light green',
#  'light grey',
#  'corridor',
#  'taking off shoes',
#  'paper',
#  'off-white',
#  'driving',
#  'looking into mirror',
#  'looking in mirror',
#  'studio',
#  'shelf',
#  'crimson',
#  'laptop',
#  'lamp',
#  'broom',
#  'in bathroom',
#  'photo frame',
#  'helmet',
#  'playing games',
#  'guitar',
#  'playing mobile phone',
#  'four',
#  'on road',
#  'toilet',
#  'light yellow',
#  'dark brown',
#  'pouring water',
#  'pure black',
#  'carton',
#  'watch',
#  'grass green',
#  'sky blue',
#  'mouse',
#  'cleaning',
#  'stairs',
#  'beige',
#  'on street',
#  'one',
#  'television',
#  'opening refrigerator',
#  'water cup',
#  'dark gray',
#  'violet',
#  'people',
#  'dark-blue',
#  'curtain',
#  'ring',
#  'looking at computer',
#  'milky white',
#  'washing machine',
#  'food',
#  'switch',
#  'navy blue',
#  'eating things',
#  'pool',
#  'photo',
#  'laughing',
#  'doorway',
#  'cyan',
#  'eating bread',
#  'taking clothes',
#  'camera',
#  'hanging on wall',
#  'cap',
#  'performing',
#  'no',
#  'reading books',
#  'necklace',
#  'eyeglasses',
#  'royal blue',
#  'quilt',
#  'gray white',
#  'playing guitar',
#  'azure',
#  'taking photos',
#  'putting on shoes',
#  'vacuum cleaner',
#  'water',
#  'pen',
#  'light-blue',
#  'drinking',
#  'left',
#  'rectangle',
#  'putting on clothes',
#  'in hands',
#  'rose red',
#  'bucket',
#  'light red',
#  'in cabinet',
#  'in water',
#  'cleaning up',
#  'cartoon',
#  'wearing shoes',
#  'earphone',
#  'carpet',
#  'horizontal',
#  'right',
#  'bread',
#  'turning on light',
#  'light',
#  'taking cup',
#  'fetching things',
#  'mobile phone',
#  'dark purple',
#  'wrestling',
#  'looking for something',
#  'snacks',
#  'exercising',
#  'taking shoes',
#  'silver',
#  'explaining',
#  'window',
#  'jar',
#  'lawn',
#  'light pink',
#  'wearing clothes',
#  'behind door',
#  'smalt',
#  'putting things',
#  'beige white',
#  'in hand',
#  'clock',
#  'golden',
#  'on lawn',
#  'laundry detergent',
#  'curly hair',
#  'gun',
#  'person',
#  'closed',
#  'on washing machine',
#  'stage',
#  'horse',
#  'plastic bag',
#  'remote control',
#  'calling',
#  'tie',
#  'watching computer',
#  'sitting down',
#  'beverage',
#  'public place',
#  'cat',
#  'hearth',
#  'court',
#  'throwing clothes',
#  'paper box',
#  'hanger',
#  'sky-blue',
#  'having rest',
#  'opening',
#  'six',
#  'light white',
#  'light purple',
#  'on stool',
#  'baby blue',
#  'khaki',
#  'in closet',
#  'on door',
#  'throwing pillow',
#  'socket',
#  'stool',
#  'notebook',
#  'poster',
#  'holding pillow',
#  'deep purple',
#  'placing items',
#  'backpack',
#  'atrovirens',
#  'marine blue',
#  'outdoors',
#  'playing basketball',
#  'fighting',
#  'case',
#  'doll',
#  'taking off coat',
#  'lake blue',
#  'knife',
#  'dark yellow',
#  'cloakroom',
#  'on grass',
#  'flower',
#  'in corridor',
#  'dark-red',
#  'lavender',
#  'washing clothes',
#  'curly',
#  'taking photo',
#  'brownish yellow',
#  'posing',
#  'moving',
#  'kneeling',
#  'hands',
#  'shooting',
#  'making call',
#  'couch',
#  'black blue',
#  'azure blue',
#  'taking phone',
#  'keyboard',
#  'taking pillow',
#  'child',
#  'basketball court',
#  'staircase',
#  'steering wheel',
#  'wiping table',
#  'drinking beverage',
#  'ash black',
#  'basket',
#  'cellphone',
#  'auditorium',
#  'looking at mirror',
#  'opening cabinet',
#  'smiling',
#  'jumping',
#  'taking book',
#  'taking something',
#  'round',
#  'taking pictures',
#  'competing',
#  'orange red',
#  'taking medicine',
#  'on cupboard',
#  'newspaper',
#  'spoon',
#  'ball',
#  'square',
#  'vase',
#  'football field',
#  'wall',
#  'light brown',
#  'getting up',
#  'microwave oven',
#  'at table',
#  'taking towel',
#  'skyblue',
#  'toy',
#  'calendar',
#  'in corner',
#  'skirt',
#  'daytime',
#  'wardrobe',
#  'display',
#  'glass',
#  'in game',
#  'rose',
#  'black and white',
#  'watching video',
#  'shirt',
#  'flying',
#  'magazine',
#  'next to car',
#  'pale pink',
#  'climbing stairs',
#  'off white',
#  'grey white',
#  'eating something',
#  'playing',
#  'tv set',
#  'horizontally',
#  'in cupboard',
#  'game scene',
#  'toilets',
#  'on cooktop',
#  'gray black',
#  'modena',
#  'animal',
#  'tan',
#  'turquoise',
#  'making up',
#  'pumpkin',
#  'audience',
#  'clothing',
#  'earphones',
#  'fan',
#  'claybank',
#  'field',
#  'beach',
#  'earrings',
#  'typing',
#  'turning on lights',
#  'looking at phone',
#  'basin',
#  'washing hands',
#  'swimming',
#  'putting away things',
#  'in sky',
#  'pure white',
#  'sheet',
#  'silver grey',
#  'watching videos',
#  'stairwell',
#  'putting cup',
#  'dark-grey',
#  'taking blanket',
#  'kettle',
#  'ocean blue',
#  'game',
#  'stirring',
#  'off',
#  'on court',
#  'making phone call',
#  'seven',
#  'cushion',
#  'taking bag',
#  'gloves',
#  'wiping nose',
#  'corner',
#  'true red',
#  'warehouse',
#  'circle',
#  'stopped',
#  'skiing',
#  'pale green',
#  'on refrigerator',
#  'by river',
#  'storage room',
#  'watching phone',
#  'grey black',
#  'bicycle',
#  'meat',
#  'grass',
#  'closing window',
#  'oven',
#  'playing piano',
#  'interviewing',
#  'tablecloth',
#  'medium yellow',
#  'cloth',
#  'coffee',
#  'lights',
#  'scarf',
#  'grey and white',
#  'having match',
#  'in hallway',
#  'electric fan',
#  'eating food',
#  'frame',
#  'drawing',
#  'going upstairs',
#  'utility room',
#  'pale yellow',
#  'rice white',
#  'table lamp',
#  'taking food',
#  'pan',
#  'plastic bottle',
#  'athlete',
#  'road',
#  'on steps',
#  'five',
#  'changing clothes',
#  'egg',
#  'turning off light',
#  'dressing up',
#  'gymnasium',
#  'big red',
#  'orange yellow',
#  'playing field',
#  'dishes',
#  'drinking milk',
#  'bottle green',
#  'tool',
#  'opening box',
#  'turning off lights',
#  'cartoon character',
#  'light black',
#  'making speech',
#  'playing football',
#  'apron',
#  'trousers',
#  'closing refrigerator',
#  'grayish white',
#  'creamy-white',
#  'wrist watch',
#  'brush',
#  'turning around',
#  'fashion show',
#  'army green',
#  'pure-black',
#  'folding clothes',
#  'going downstairs',
#  'playing game',
#  'introducing car',
#  'blue-black',
#  'faint yellow',
#  'studying',
#  'getting dressed',
#  'mural',
#  'cupboard',
#  'putting down something',
#  'on snow mountain',
#  'folding paper',
#  'laundry room',
#  'in washing room',
#  'corner of wall',
#  'light-grey',
#  'having meal',
#  'turning on computer',
#  'taking selfie',
#  'shovel',
#  'opening closet',
#  'undressing',
#  'in air',
#  'playground',
#  'decorative painting',
#  'handbag',
#  'headset',
#  'in drawer',
#  'in wardrobe',
#  'mop',
#  'garland',
#  'putting clothes',
#  'fresco',
#  'tangerine',
#  'sapphire blue',
#  'electronic guitar',
#  'catwalk show',
#  'driving car',
#  'electric wire',
#  'on carpet',
#  'on window sill',
#  'stroller',
#  'in stairwell',
#  'in refrigerator',
#  'lakeside',
#  'word',
#  'on washbasin',
#  'on hanger',
#  'chicken',
#  'studios',
#  'on screen',
#  'fish',
#  'sunglasses',
#  'standing up',
#  'fruits',
#  'simple',
#  'piano',
#  'riding motorcycle',
#  'putting down cup',
#  'opening cabinet door',
#  'on hearth',
#  'above ground',
#  'earthy yellow',
#  'magenta',
#  'black grey',
#  'in front of table',
#  'stone',
#  'milk-white',
#  'sheets',
#  'brownish red',
#  'on beach',
#  'cleaning window',
#  'can',
#  'sword',
#  'blue and black',
#  'in cup',
#  'light-yellow',
#  'vacuum machine',
#  'banana',
#  'human',
#  'on tv bench',
#  'seat',
#  'stadium',
#  'relaxing',
#  'jacinth',
#  'taking bottle',
#  'introducing',
#  'slivery',
#  'bosom',
#  'next to door',
#  'hugging',
#  'clapping',
#  'vegetables',
#  'putting shoes',
#  'opening window',
#  'light cyan',
#  'putting on coat',
#  'bolster',
#  'watching television',
#  'at corner',
#  'monster',
#  'flashlight',
#  'tidying clothes',
#  'besom',
#  'doing cleaning',
#  'curtains',
#  'screwdriver',
#  'pale blue',
#  'dumbbell',
#  'desk lamp',
#  'wathet',
#  'walking around',
#  'placing clothes',
#  'bowel',
#  'snow mountain',
#  'picking up pillow',
#  'picture',
#  'golden yellow',
#  'lemon yellow',
#  'machine',
#  'pale grey',
#  'boat',
#  'peach red',
#  'throwing things',
#  'taking computer',
#  'bike',
#  'restaurant',
#  'hall',
#  'brown green',
#  'screwing cap',
#  'plant',
#  'sweeping',
#  'forward',
#  'taking rest',
#  'model',
#  'scarlet',
#  'suit',
#  'triangle',
#  'telephone',
#  'gray-black',
#  'pants',
#  'silvery gray',
#  'clapping hands',
#  'glove',
#  'opening refrigerator door',
#  'cooking meal',
#  'in pool',
#  'table tennis',
#  'on runway',
#  'in toilet',
#  'silver gray',
#  'doing chores',
#  'screen',
#  'classroom',
#  'brushing plate',
#  'looking at photo',
#  'hangers',
#  'boy',
#  'stairway',
#  'cleaner',
#  'books',
#  'on tea table',
#  'hair clip',
#  'river',
#  'shampoo',
#  'ivory-white',
#  'back cushion',
#  'dark-black',
#  'turning off computer',
#  'fuchsia',
#  'washroom',
#  'puppy',
#  'national flag',
#  'throwing book',
#  'on closet',
#  'hanging clothes',
#  'on playground',
#  'in pot',
#  'bracelet',
#  'silvery white',
#  'against wall',
#  'golden-yellow',
#  'skeleton',
#  'armrest',
#  'magnet',
#  'earring',
#  'on sea',
#  'plates',
#  'picking up clothes',
#  'blankets',
#  'folding towels',
#  'medal',
#  'filming',
#  'lifting cup',
#  'playing table tennis',
#  'cleaning table',
#  'laboratory',
#  'pea green',
#  'black-blue',
#  'in river',
#  'soft red',
#  'doing some cleaning',
#  'washing cup',
#  'wiping glasses',
#  'sky',
#  'jacket',
#  'in sea',
#  'plastic box',
#  'purple red',
#  'forest',
#  'third',
#  'on snowfield',
#  'repairing',
#  'on shoes',
#  'doing experiment',
#  'rolling',
#  'alpaca',
#  'toothbrush',
#  'fruit',
#  'dining',
#  'vegetable',
#  'selfie stick',
#  'shaking',
#  'hair band',
#  'throwing shoes',
#  'putting food',
#  'in carton',
#  'wing',
#  'amaranth',
#  'on bus',
#  'in front of mirror',
#  'home',
#  'on tv cabinet',
#  'on head',
#  'bookcase',
#  'ring finger',
#  'in washing machine',
#  'fat',
#  'handrail',
#  'on washing sink',
#  'minecraft',
#  'beside sofa',
#  'in box',
#  'brown yellow',
#  'holding dog',
#  'key',
#  'potato',
#  'waving',
#  'broadcasting',
#  'match',
#  'cups',
#  'having beard',
#  'bracers',
#  'putting down clothes',
#  'repairing car',
#  'introducing product',
#  'watching photos',
#  'on carton',
#  'brown-black',
#  'sports center',
#  'operating computer',
#  'fence',
#  'on ice',
#  'taking plates',
#  'drawing curtain',
#  'taking plate',
#  'pushing car',
#  'cleaning mirror',
#  'looking at things',
#  'jasper',
#  'hamster',
#  'brownish black',
#  'rose-bengal',
#  'on chopping board',
#  'screwing bottle cap',
#  'on counter',
#  'pouring laundry detergent',
#  'rabbit',
#  'on plane',
#  'in front of door',
#  'shaking hands',
#  'transparent',
#  'hospital',
#  'stationary',
#  'using vacuum cleaner',
#  'taking broom',
#  'sliver white',
#  'placing cup',
#  'taking out items',
#  'by wall',
#  'cow',
#  'tattoo',
#  'moving chair',
#  'on sport court',
#  'touching hair',
#  'pictures',
#  'vehicle',
#  'on face',
#  'photograph',
#  'blackboard',
#  'sea blue',
#  'on board',
#  'on rope',
#  'putting away stuff',
#  'lying on his stomach',
#  'stirring food',
#  'riding horse',
#  'bbc',
#  'bright-red',
#  'mopping floor',
#  't-shirts',
#  'at stair hall',
#  'eating snacks',
#  'croci',
#  'reseda',
#  'bed sheet',
#  'shorts',
#  'park',
#  'in stairs',
#  'moving boxes',
#  'covering blanket',
#  'looking outside window',
#  'trash can',
#  'beside door',
#  'looking at photos',
#  'in gymnasium',
#  'lobby',
#  'groveling',
#  'in front of closet',
#  'drinking juice',
#  'nodding',
#  'baby',
#  'taking wrench',
#  'snowfield',
#  'english letter',
#  'shelter',
#  'playing video',
#  'watching game',
#  'comic',
#  'near table',
#  'taking books',
#  'chopping board',
#  'racing',
#  'motorcycle',
#  'medicine',
#  'stretching arms',
#  'by sea',
#  'plastic',
#  'hair braiding',
#  'long sleeve',
#  'rugby',
#  'giving speech',
#  'hot',
#  'putting away clothes',
#  'dialog box',
#  'having conversation',
#  'mat',
#  'in cinema',
#  'wiping face',
#  'playing cellphone',
#  'blue white',
#  'playing baseball',
#  'detergent',
#  'ball park',
#  'massaging',
#  'playing ball',
#  'hair',
#  'suburb',
#  'flour',
#  'basketball',
#  'light-green',
#  'oil painting',
#  'black gray',
#  'picking up book',
#  'taking magazine',
#  'wiping hands',
#  'arrow',
#  'baby-blue',
#  'outside house',
#  'holding cup',
#  'seasoning',
#  'sewing machine',
#  'talking on phone',
#  'tibetain blue',
#  'mattress',
#  'at door',
#  'blue purple',
#  'peach',
#  'snake',
#  'washing dishes',
#  '3d',
#  'dessert',
#  'kissing',
#  'peak green',
#  'going up stairs',
#  'purplish red',
#  'looking at cellphone',
#  'card',
#  'doing exercise',
#  'milk',
#  'taking out clothes',
#  'taking box',
#  'folding towel',
#  'seeing information',
#  'closing refrigerator door',
#  'visiting',
#  'closing closet',
#  'monkey',
#  'under stairs',
#  'vermilion',
#  'document',
#  'taking off his clothes',
#  'water bottle',
#  'putting on blanket',
#  'fork',
#  'purplish blue',
#  'leopard',
#  'denim blue',
#  'ash gray',
#  'plastic bags',
#  'glass bottle',
#  'recording',
#  'giving lecture',
#  'umbrella',
#  'hand',
#  'ater',
#  'placing things',
#  'music score',
#  'swimming pool',
#  'rag',
#  'operating phone',
#  'opening computer',
#  'putting towel',
#  'falling down',
#  'balloon',
#  'cage',
#  'saffron',
#  'button',
#  'doing laundry',
#  'paper folding',
#  'ride motorcycle',
#  'in glass bowl',
#  'narrating',
#  'candle',
#  'acting',
#  'looking at camera',
#  'microwave',
#  'reaching out',
#  'reading messages',
#  'cooking things',
#  'statue',
#  'cabinet door',
#  'earth yellow',
#  'boating',
#  'on highway',
#  'subtitle',
#  'number',
#  'bridge',
#  'light-red',
#  'emerald green',
#  'reading newspaper',
#  'waste container',
#  'pigment',
#  'plastic bucket',
#  'vacuum',
#  'washbasin',
#  'boxing',
#  'wiping mirror',
#  'player',
#  'handle',
#  'taking on his coat',
#  'swinging',
#  'pink red',
#  'playing computer games',
#  'black green',
#  'firming',
#  'ruler',
#  'tire',
#  'buff',
#  'water tap',
#  'tidying up things',
#  'tray',
#  'stools',
#  'by road',
#  'cleaning up dust',
#  ...]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
sort_answer
# Out:
# [('standing', 6344),
#  ('sitting', 2440),
#  ('black', 1824),
#  ('white', 1338),
#  ('indoor', 1155),
#  ('blue', 707),
#  ('red', 563),
#  ('on table', 492),
#  ('in house', 450),
#  ('kitchen', 433),
#  ('residence', 384),
#  ('drinking water', 373),
#  ('green', 364),
#  ('living room', 336),
#  ('glasses', 329),
#  ('cup', 304),
#  ('yellow', 297),
#  ('eating', 292),
#  ('short hair', 288),
#  ('chair', 270),
#  ('clothes', 269),
#  ('speaking', 264),
#  ('talking', 263),
#  ('computer', 258),
#  ('bedroom', 256),
#  ('lying', 248),
#  ('hat', 246),
#  ('long hair', 234),
#  ('table', 222),
#  ('grey', 206),
#  ('walking', 204),
#  ('book', 198),
#  ('in door', 195),
#  ('dark blue', 194),
#  ('in living room', 189),
#  ('on wall', 188),
#  ('two', 186),
#  ('brown', 182),
#  ('gray', 175),
#  ('on ground', 167),
#  ('purple', 164),
#  ('pink', 156),
#  ('pillow', 155),
#  ('milk white', 153),
#  ('in kitchen', 152),
#  ('creamy white', 149),
#  ('outdoor', 145),
#  ('male', 142),
#  ('chatting', 139),
#  ('in bedroom', 136),
#  ('on stairs', 131),
#  ('in room', 124),
#  ('singing', 120),
#  ('inside house', 120),
#  ('mirror', 119),
#  ('pot', 114),
#  ('dancing', 114),
#  ('sneezing', 113),
#  ('sofa', 113),
#  ('light blue', 109),
#  ('on bed', 108),
#  ('bottle', 108),
#  ('room', 105),
#  ('cooking', 104),
#  ('on sofa', 104),
#  ('man', 103),
#  ('phone', 102),
#  ('bed', 99),
#  ('playing computer', 97),
#  ('opening door', 97),
#  ('cabinet', 97),
#  ('orange', 97),
#  ('indoors', 95),
#  ('desk', 94),
#  ('watching tv', 93),
#  ('tidying', 91),
#  ('bright red', 90),
#  ('aterrimus', 89),
#  ('car', 89),
#  ('three', 85),
#  ('in car', 84),
#  ('english', 82),
#  ('running', 82),
#  ('mustache', 81),
#  ('playing cell phone', 81),
#  ('plate', 79),
#  ('cell phone', 79),
#  ('bathroom', 79),
#  ('on desk', 78),
#  ('house', 78),
#  ('dark grey', 77),
#  ('resting', 77),
#  ('dark black', 77),
#  ('female', 76),
#  ('painting', 76),
#  ('shoes', 75),
#  ('microphone', 75),
#  ('left hand', 75),
#  ('yes', 75),
#  ('refrigerator', 74),
#  ('blanket', 74),
#  ('dog', 74),
#  ('sleeping', 73),
#  ('reading', 72),
#  ('furvous', 72),
#  ('closet', 72),
#  ('bag', 72),
#  ('dark green', 71),
#  ('towel', 70),
#  ('on floor', 69),
#  ('on stage', 68),
#  ('woman', 67),
#  ('on chair', 67),
#  ('taking off clothes', 67),
#  ('right hand', 66),
#  ('lying down', 65),
#  ('playing phone', 65),
#  ('tv', 65),
#  ('door', 65),
#  ('closing door', 64),
#  ('dark red', 64),
#  ('light gray', 62),
#  ('clearing up', 60),
#  ('reading book', 59),
#  ('writing', 58),
#  ('sweeping floor', 58),
#  ('squatting', 57),
#  ('taking things', 56),
#  ('box', 56),
#  ('tree', 55),
#  ('on cabinet', 54),
#  ('on shelf', 54),
#  ('open', 54),
#  ('bowl', 54),
#  ('on', 54),
#  ('in studio', 54),
#  ('light green', 54),
#  ('light grey', 54),
#  ('corridor', 53),
#  ('taking off shoes', 53),
#  ('paper', 52),
#  ('off-white', 52),
#  ('driving', 51),
#  ('looking into mirror', 51),
#  ('looking in mirror', 50),
#  ('studio', 50),
#  ('shelf', 50),
#  ('crimson', 50),
#  ('laptop', 48),
#  ('lamp', 48),
#  ('broom', 47),
#  ('in bathroom', 47),
#  ('photo frame', 46),
#  ('helmet', 46),
#  ('playing games', 46),
#  ('guitar', 46),
#  ('playing mobile phone', 45),
#  ('four', 45),
#  ('on road', 44),
#  ('toilet', 44),
#  ('light yellow', 44),
#  ('dark brown', 44),
#  ('pouring water', 43),
#  ('pure black', 43),
#  ('carton', 43),
#  ('watch', 43),
#  ('grass green', 42),
#  ('sky blue', 42),
#  ('mouse', 41),
#  ('cleaning', 41),
#  ('stairs', 40),
#  ('beige', 40),
#  ('on street', 39),
#  ('one', 39),
#  ('television', 38),
#  ('opening refrigerator', 38),
#  ('water cup', 38),
#  ('dark gray', 38),
#  ('violet', 37),
#  ('people', 37),
#  ('dark-blue', 37),
#  ('curtain', 37),
#  ('ring', 37),
#  ('looking at computer', 36),
#  ('milky white', 36),
#  ('washing machine', 36),
#  ('food', 36),
#  ('switch', 36),
#  ('navy blue', 35),
#  ('eating things', 35),
#  ('pool', 35),
#  ('photo', 35),
#  ('laughing', 34),
#  ('doorway', 34),
#  ('cyan', 34),
#  ('eating bread', 34),
#  ('taking clothes', 34),
#  ('camera', 34),
#  ('hanging on wall', 33),
#  ('cap', 33),
#  ('performing', 33),
#  ('no', 33),
#  ('reading books', 33),
#  ('necklace', 33),
#  ('eyeglasses', 33),
#  ('royal blue', 32),
#  ('quilt', 32),
#  ('gray white', 32),
#  ('playing guitar', 32),
#  ('azure', 31),
#  ('taking photos', 31),
#  ('putting on shoes', 31),
#  ('vacuum cleaner', 31),
#  ('water', 31),
#  ('pen', 30),
#  ('light-blue', 30),
#  ('drinking', 30),
#  ('left', 30),
#  ('rectangle', 30),
#  ('putting on clothes', 30),
#  ('in hands', 29),
#  ('rose red', 29),
#  ('bucket', 28),
#  ('light red', 28),
#  ('in cabinet', 28),
#  ('in water', 28),
#  ('cleaning up', 28),
#  ('cartoon', 28),
#  ('wearing shoes', 27),
#  ('earphone', 27),
#  ('carpet', 27),
#  ('horizontal', 27),
#  ('right', 27),
#  ('bread', 27),
#  ('turning on light', 27),
#  ('light', 27),
#  ('taking cup', 27),
#  ('fetching things', 26),
#  ('mobile phone', 26),
#  ('dark purple', 26),
#  ('wrestling', 26),
#  ('looking for something', 26),
#  ('snacks', 26),
#  ('exercising', 26),
#  ('taking shoes', 26),
#  ('silver', 26),
#  ('explaining', 26),
#  ('window', 26),
#  ('jar', 26),
#  ('lawn', 25),
#  ('light pink', 25),
#  ('wearing clothes', 25),
#  ('behind door', 25),
#  ('smalt', 25),
#  ('putting things', 25),
#  ('beige white', 25),
#  ('in hand', 25),
#  ('clock', 24),
#  ('golden', 24),
#  ('on lawn', 24),
#  ('laundry detergent', 24),
#  ('curly hair', 24),
#  ('gun', 24),
#  ('person', 24),
#  ('closed', 24),
#  ('on washing machine', 24),
#  ('stage', 24),
#  ('horse', 24),
#  ('plastic bag', 23),
#  ('remote control', 23),
#  ('calling', 23),
#  ('tie', 23),
#  ('watching computer', 23),
#  ('sitting down', 23),
#  ('beverage', 23),
#  ('public place', 23),
#  ('cat', 23),
#  ('hearth', 23),
#  ('court', 23),
#  ('throwing clothes', 22),
#  ('paper box', 22),
#  ('hanger', 22),
#  ('sky-blue', 22),
#  ('having rest', 22),
#  ('opening', 22),
#  ('six', 22),
#  ('light white', 22),
#  ('light purple', 22),
#  ('on stool', 21),
#  ('baby blue', 21),
#  ('khaki', 21),
#  ('in closet', 21),
#  ('on door', 21),
#  ('throwing pillow', 21),
#  ('socket', 21),
#  ('stool', 21),
#  ('notebook', 20),
#  ('poster', 20),
#  ('holding pillow', 20),
#  ('deep purple', 20),
#  ('placing items', 20),
#  ('backpack', 20),
#  ('atrovirens', 20),
#  ('marine blue', 19),
#  ('outdoors', 19),
#  ('playing basketball', 19),
#  ('fighting', 19),
#  ('case', 19),
#  ('doll', 19),
#  ('taking off coat', 19),
#  ('lake blue', 19),
#  ('knife', 19),
#  ('dark yellow', 19),
#  ('cloakroom', 19),
#  ('on grass', 19),
#  ('flower', 19),
#  ('in corridor', 18),
#  ('dark-red', 18),
#  ('lavender', 18),
#  ('washing clothes', 18),
#  ('curly', 18),
#  ('taking photo', 18),
#  ('brownish yellow', 18),
#  ('posing', 18),
#  ('moving', 18),
#  ('kneeling', 18),
#  ('hands', 18),
#  ('shooting', 18),
#  ('making call', 18),
#  ('couch', 18),
#  ('black blue', 18),
#  ('azure blue', 18),
#  ('taking phone', 17),
#  ('keyboard', 17),
#  ('taking pillow', 17),
#  ('child', 17),
#  ('basketball court', 17),
#  ('staircase', 17),
#  ('steering wheel', 17),
#  ('wiping table', 17),
#  ('drinking beverage', 17),
#  ('ash black', 17),
#  ('basket', 17),
#  ('cellphone', 17),
#  ('auditorium', 17),
#  ('looking at mirror', 17),
#  ('opening cabinet', 16),
#  ('smiling', 16),
#  ('jumping', 16),
#  ('taking book', 16),
#  ('taking something', 16),
#  ('round', 16),
#  ('taking pictures', 16),
#  ('competing', 16),
#  ('orange red', 16),
#  ('taking medicine', 16),
#  ('on cupboard', 16),
#  ('newspaper', 16),
#  ('spoon', 16),
#  ('ball', 16),
#  ('square', 16),
#  ('vase', 16),
#  ('football field', 16),
#  ('wall', 16),
#  ('light brown', 16),
#  ('getting up', 16),
#  ('microwave oven', 16),
#  ('at table', 16),
#  ('taking towel', 16),
#  ('skyblue', 16),
#  ('toy', 15),
#  ('calendar', 15),
#  ('in corner', 15),
#  ('skirt', 15),
#  ('daytime', 15),
#  ('wardrobe', 15),
#  ('display', 15),
#  ('glass', 15),
#  ('in game', 15),
#  ('rose', 15),
#  ('black and white', 15),
#  ('watching video', 15),
#  ('shirt', 15),
#  ('flying', 15),
#  ('magazine', 15),
#  ('next to car', 15),
#  ('pale pink', 15),
#  ('climbing stairs', 15),
#  ('off white', 15),
#  ('grey white', 15),
#  ('eating something', 15),
#  ('playing', 15),
#  ('tv set', 15),
#  ('horizontally', 15),
#  ('in cupboard', 15),
#  ('game scene', 15),
#  ('toilets', 15),
#  ('on cooktop', 15),
#  ('gray black', 14),
#  ('modena', 14),
#  ('animal', 14),
#  ('tan', 14),
#  ('turquoise', 14),
#  ('making up', 14),
#  ('pumpkin', 14),
#  ('audience', 14),
#  ('clothing', 14),
#  ('earphones', 14),
#  ('fan', 14),
#  ('claybank', 14),
#  ('field', 14),
#  ('beach', 14),
#  ('earrings', 13),
#  ('typing', 13),
#  ('turning on lights', 13),
#  ('looking at phone', 13),
#  ('basin', 13),
#  ('washing hands', 13),
#  ('swimming', 13),
#  ('putting away things', 13),
#  ('in sky', 13),
#  ('pure white', 13),
#  ('sheet', 13),
#  ('silver grey', 13),
#  ('watching videos', 13),
#  ('stairwell', 13),
#  ('putting cup', 13),
#  ('dark-grey', 13),
#  ('taking blanket', 13),
#  ('kettle', 13),
#  ('ocean blue', 13),
#  ('game', 13),
#  ('stirring', 12),
#  ('off', 12),
#  ('on court', 12),
#  ('making phone call', 12),
#  ('seven', 12),
#  ('cushion', 12),
#  ('taking bag', 12),
#  ('gloves', 12),
#  ('wiping nose', 12),
#  ('corner', 12),
#  ('true red', 12),
#  ('warehouse', 12),
#  ('circle', 12),
#  ('stopped', 12),
#  ('skiing', 12),
#  ('pale green', 12),
#  ('on refrigerator', 12),
#  ('by river', 12),
#  ('storage room', 12),
#  ('watching phone', 12),
#  ('grey black', 12),
#  ('bicycle', 12),
#  ('meat', 12),
#  ('grass', 12),
#  ('closing window', 12),
#  ('oven', 12),
#  ('playing piano', 12),
#  ('interviewing', 12),
#  ('tablecloth', 12),
#  ('medium yellow', 12),
#  ('cloth', 12),
#  ('coffee', 12),
#  ('lights', 12),
#  ('scarf', 12),
#  ('grey and white', 11),
#  ('having match', 11),
#  ('in hallway', 11),
#  ('electric fan', 11),
#  ('eating food', 11),
#  ('frame', 11),
#  ('drawing', 11),
#  ('going upstairs', 11),
#  ('utility room', 11),
#  ('pale yellow', 11),
#  ('rice white', 11),
#  ('table lamp', 11),
#  ('taking food', 11),
#  ('pan', 11),
#  ('plastic bottle', 11),
#  ('athlete', 11),
#  ('road', 11),
#  ('on steps', 11),
#  ('five', 11),
#  ('changing clothes', 11),
#  ('egg', 11),
#  ('turning off light', 11),
#  ('dressing up', 11),
#  ('gymnasium', 11),
#  ('big red', 11),
#  ('orange yellow', 11),
#  ('playing field', 11),
#  ('dishes', 11),
#  ('drinking milk', 11),
#  ('bottle green', 11),
#  ('tool', 11),
#  ('opening box', 11),
#  ('turning off lights', 11),
#  ('cartoon character', 11),
#  ('light black', 11),
#  ('making speech', 11),
#  ('playing football', 10),
#  ('apron', 10),
#  ('trousers', 10),
#  ('closing refrigerator', 10),
#  ('grayish white', 10),
#  ('creamy-white', 10),
#  ('wrist watch', 10),
#  ('brush', 10),
#  ('turning around', 10),
#  ('fashion show', 10),
#  ('army green', 10),
#  ('pure-black', 10),
#  ('folding clothes', 10),
#  ('going downstairs', 10),
#  ('playing game', 10),
#  ('introducing car', 10),
#  ('blue-black', 10),
#  ('faint yellow', 10),
#  ('studying', 10),
#  ('getting dressed', 10),
#  ('mural', 10),
#  ('cupboard', 10),
#  ('putting down something', 10),
#  ('on snow mountain', 10),
#  ('folding paper', 10),
#  ('laundry room', 10),
#  ('in washing room', 10),
#  ('corner of wall', 10),
#  ('light-grey', 10),
#  ('having meal', 10),
#  ('turning on computer', 10),
#  ('taking selfie', 10),
#  ('shovel', 10),
#  ('opening closet', 10),
#  ('undressing', 10),
#  ('in air', 9),
#  ('playground', 9),
#  ('decorative painting', 9),
#  ('handbag', 9),
#  ('headset', 9),
#  ('in drawer', 9),
#  ('in wardrobe', 9),
#  ('mop', 9),
#  ('garland', 9),
#  ('putting clothes', 9),
#  ('fresco', 9),
#  ('tangerine', 9),
#  ('sapphire blue', 9),
#  ('electronic guitar', 9),
#  ('catwalk show', 9),
#  ('driving car', 9),
#  ('electric wire', 9),
#  ('on carpet', 9),
#  ('on window sill', 9),
#  ('stroller', 9),
#  ('in stairwell', 9),
#  ('in refrigerator', 9),
#  ('lakeside', 9),
#  ('word', 9),
#  ('on washbasin', 9),
#  ('on hanger', 9),
#  ('chicken', 9),
#  ('studios', 9),
#  ('on screen', 9),
#  ('fish', 9),
#  ('sunglasses', 9),
#  ('standing up', 9),
#  ('fruits', 9),
#  ('simple', 9),
#  ('piano', 9),
#  ('riding motorcycle', 9),
#  ('putting down cup', 9),
#  ('opening cabinet door', 9),
#  ('on hearth', 9),
#  ('above ground', 9),
#  ('earthy yellow', 9),
#  ('magenta', 9),
#  ('black grey', 9),
#  ('in front of table', 9),
#  ('stone', 9),
#  ('milk-white', 9),
#  ('sheets', 9),
#  ('brownish red', 9),
#  ('on beach', 9),
#  ('cleaning window', 9),
#  ('can', 9),
#  ('sword', 9),
#  ('blue and black', 9),
#  ('in cup', 9),
#  ('light-yellow', 9),
#  ('vacuum machine', 9),
#  ('banana', 9),
#  ('human', 9),
#  ('on tv bench', 9),
#  ('seat', 9),
#  ('stadium', 9),
#  ('relaxing', 9),
#  ('jacinth', 9),
#  ('taking bottle', 9),
#  ('introducing', 9),
#  ('slivery', 8),
#  ('bosom', 8),
#  ('next to door', 8),
#  ('hugging', 8),
#  ('clapping', 8),
#  ('vegetables', 8),
#  ('putting shoes', 8),
#  ('opening window', 8),
#  ('light cyan', 8),
#  ('putting on coat', 8),
#  ('bolster', 8),
#  ('watching television', 8),
#  ('at corner', 8),
#  ('monster', 8),
#  ('flashlight', 8),
#  ('tidying clothes', 8),
#  ('besom', 8),
#  ('doing cleaning', 8),
#  ('curtains', 8),
#  ('screwdriver', 8),
#  ('pale blue', 8),
#  ('dumbbell', 8),
#  ('desk lamp', 8),
#  ('wathet', 8),
#  ('walking around', 8),
#  ('placing clothes', 8),
#  ('bowel', 8),
#  ('snow mountain', 8),
#  ('picking up pillow', 8),
#  ('picture', 8),
#  ('golden yellow', 8),
#  ('lemon yellow', 8),
#  ('machine', 8),
#  ('pale grey', 8),
#  ('boat', 8),
#  ('peach red', 8),
#  ('throwing things', 8),
#  ('taking computer', 8),
#  ('bike', 8),
#  ('restaurant', 8),
#  ('hall', 7),
#  ('brown green', 7),
#  ('screwing cap', 7),
#  ('plant', 7),
#  ('sweeping', 7),
#  ('forward', 7),
#  ('taking rest', 7),
#  ('model', 7),
#  ('scarlet', 7),
#  ('suit', 7),
#  ('triangle', 7),
#  ('telephone', 7),
#  ('gray-black', 7),
#  ('pants', 7),
#  ('silvery gray', 7),
#  ('clapping hands', 7),
#  ('glove', 7),
#  ('opening refrigerator door', 7),
#  ('cooking meal', 7),
#  ('in pool', 7),
#  ('table tennis', 7),
#  ('on runway', 7),
#  ('in toilet', 7),
#  ('silver gray', 7),
#  ('doing chores', 7),
#  ('screen', 7),
#  ('classroom', 7),
#  ('brushing plate', 7),
#  ('looking at photo', 7),
#  ('hangers', 7),
#  ('boy', 7),
#  ('stairway', 7),
#  ('cleaner', 7),
#  ('books', 7),
#  ('on tea table', 7),
#  ('hair clip', 7),
#  ('river', 7),
#  ('shampoo', 7),
#  ('ivory-white', 7),
#  ('back cushion', 7),
#  ('dark-black', 7),
#  ('turning off computer', 7),
#  ('fuchsia', 7),
#  ('washroom', 7),
#  ('puppy', 7),
#  ('national flag', 7),
#  ('throwing book', 7),
#  ('on closet', 7),
#  ('hanging clothes', 7),
#  ('on playground', 7),
#  ('in pot', 7),
#  ('bracelet', 7),
#  ('silvery white', 7),
#  ('against wall', 7),
#  ('golden-yellow', 7),
#  ('skeleton', 7),
#  ('armrest', 7),
#  ('magnet', 7),
#  ('earring', 7),
#  ('on sea', 7),
#  ('plates', 7),
#  ('picking up clothes', 7),
#  ('blankets', 7),
#  ('folding towels', 7),
#  ('medal', 7),
#  ('filming', 7),
#  ('lifting cup', 7),
#  ('playing table tennis', 7),
#  ('cleaning table', 7),
#  ('laboratory', 7),
#  ('pea green', 7),
#  ('black-blue', 7),
#  ('in river', 7),
#  ('soft red', 7),
#  ('doing some cleaning', 7),
#  ('washing cup', 7),
#  ('wiping glasses', 6),
#  ('sky', 6),
#  ('jacket', 6),
#  ('in sea', 6),
#  ('plastic box', 6),
#  ('purple red', 6),
#  ('forest', 6),
#  ('third', 6),
#  ('on snowfield', 6),
#  ('repairing', 6),
#  ('on shoes', 6),
#  ('doing experiment', 6),
#  ('rolling', 6),
#  ('alpaca', 6),
#  ('toothbrush', 6),
#  ('fruit', 6),
#  ('dining', 6),
#  ('vegetable', 6),
#  ('selfie stick', 6),
#  ('shaking', 6),
#  ('hair band', 6),
#  ('throwing shoes', 6),
#  ('putting food', 6),
#  ('in carton', 6),
#  ('wing', 6),
#  ('amaranth', 6),
#  ('on bus', 6),
#  ('in front of mirror', 6),
#  ('home', 6),
#  ('on tv cabinet', 6),
#  ('on head', 6),
#  ('bookcase', 6),
#  ('ring finger', 6),
#  ('in washing machine', 6),
#  ('fat', 6),
#  ('handrail', 6),
#  ('on washing sink', 6),
#  ('minecraft', 6),
#  ('beside sofa', 6),
#  ('in box', 6),
#  ('brown yellow', 6),
#  ('holding dog', 6),
#  ('key', 6),
#  ('potato', 6),
#  ('waving', 6),
#  ('broadcasting', 6),
#  ('match', 6),
#  ('cups', 6),
#  ('having beard', 6),
#  ('bracers', 6),
#  ('putting down clothes', 6),
#  ('repairing car', 6),
#  ('introducing product', 6),
#  ('watching photos', 6),
#  ('on carton', 6),
#  ('brown-black', 6),
#  ('sports center', 6),
#  ('operating computer', 6),
#  ('fence', 6),
#  ('on ice', 6),
#  ('taking plates', 6),
#  ('drawing curtain', 6),
#  ('taking plate', 6),
#  ('pushing car', 6),
#  ('cleaning mirror', 6),
#  ('looking at things', 6),
#  ('jasper', 6),
#  ('hamster', 6),
#  ('brownish black', 6),
#  ('rose-bengal', 6),
#  ('on chopping board', 6),
#  ('screwing bottle cap', 6),
#  ('on counter', 6),
#  ('pouring laundry detergent', 6),
#  ('rabbit', 6),
#  ('on plane', 6),
#  ('in front of door', 6),
#  ('shaking hands', 6),
#  ('transparent', 6),
#  ('hospital', 6),
#  ('stationary', 6),
#  ('using vacuum cleaner', 6),
#  ('taking broom', 6),
#  ('sliver white', 6),
#  ('placing cup', 6),
#  ('taking out items', 6),
#  ('by wall', 6),
#  ('cow', 6),
#  ('tattoo', 6),
#  ('moving chair', 6),
#  ('on sport court', 6),
#  ('touching hair', 6),
#  ('pictures', 6),
#  ('vehicle', 6),
#  ('on face', 6),
#  ('photograph', 6),
#  ('blackboard', 6),
#  ('sea blue', 6),
#  ('on board', 6),
#  ('on rope', 6),
#  ('putting away stuff', 6),
#  ('lying on his stomach', 6),
#  ('stirring food', 6),
#  ('riding horse', 6),
#  ('bbc', 6),
#  ('bright-red', 6),
#  ('mopping floor', 6),
#  ('t-shirts', 6),
#  ('at stair hall', 6),
#  ('eating snacks', 6),
#  ('croci', 6),
#  ('reseda', 6),
#  ('bed sheet', 6),
#  ('shorts', 6),
#  ('park', 6),
#  ('in stairs', 6),
#  ('moving boxes', 6),
#  ('covering blanket', 6),
#  ('looking outside window', 6),
#  ('trash can', 6),
#  ('beside door', 6),
#  ('looking at photos', 6),
#  ('in gymnasium', 6),
#  ('lobby', 6),
#  ('groveling', 6),
#  ('in front of closet', 6),
#  ('drinking juice', 6),
#  ('nodding', 6),
#  ('baby', 6),
#  ('taking wrench', 6),
#  ('snowfield', 6),
#  ('english letter', 6),
#  ('shelter', 6),
#  ('playing video', 6),
#  ('watching game', 6),
#  ('comic', 6),
#  ('near table', 6),
#  ('taking books', 6),
#  ('chopping board', 6),
#  ('racing', 6),
#  ('motorcycle', 6),
#  ('medicine', 6),
#  ('stretching arms', 6),
#  ('by sea', 6),
#  ('plastic', 6),
#  ('hair braiding', 6),
#  ('long sleeve', 6),
#  ('rugby', 6),
#  ('giving speech', 6),
#  ('hot', 6),
#  ('putting away clothes', 6),
#  ('dialog box', 6),
#  ('having conversation', 6),
#  ('mat', 6),
#  ('in cinema', 6),
#  ('wiping face', 6),
#  ('playing cellphone', 6),
#  ('blue white', 6),
#  ('playing baseball', 6),
#  ('detergent', 6),
#  ('ball park', 6),
#  ('massaging', 6),
#  ('playing ball', 6),
#  ('hair', 6),
#  ('suburb', 6),
#  ('flour', 6),
#  ('basketball', 6),
#  ('light-green', 6),
#  ('oil painting', 5),
#  ('black gray', 5),
#  ('picking up book', 5),
#  ('taking magazine', 5),
#  ('wiping hands', 5),
#  ('arrow', 5),
#  ('baby-blue', 5),
#  ('outside house', 5),
#  ('holding cup', 5),
#  ('seasoning', 5),
#  ('sewing machine', 5),
#  ('talking on phone', 5),
#  ('tibetain blue', 5),
#  ('mattress', 5),
#  ('at door', 5),
#  ('blue purple', 5),
#  ('peach', 5),
#  ('snake', 5),
#  ('washing dishes', 5),
#  ('3d', 5),
#  ('dessert', 5),
#  ('kissing', 5),
#  ('peak green', 5),
#  ('going up stairs', 5),
#  ('purplish red', 5),
#  ('looking at cellphone', 5),
#  ('card', 5),
#  ('doing exercise', 5),
#  ('milk', 5),
#  ('taking out clothes', 5),
#  ('taking box', 5),
#  ('folding towel', 5),
#  ('seeing information', 5),
#  ('closing refrigerator door', 5),
#  ('visiting', 5),
#  ('closing closet', 5),
#  ('monkey', 5),
#  ('under stairs', 5),
#  ('vermilion', 5),
#  ('document', 5),
#  ('taking off his clothes', 5),
#  ('water bottle', 5),
#  ('putting on blanket', 5),
#  ('fork', 5),
#  ('purplish blue', 5),
#  ('leopard', 5),
#  ('denim blue', 5),
#  ('ash gray', 5),
#  ('plastic bags', 5),
#  ('glass bottle', 5),
#  ('recording', 5),
#  ('giving lecture', 5),
#  ('umbrella', 5),
#  ('hand', 5),
#  ('ater', 5),
#  ('placing things', 5),
#  ('music score', 5),
#  ('swimming pool', 5),
#  ('rag', 5),
#  ('operating phone', 5),
#  ('opening computer', 5),
#  ('putting towel', 5),
#  ('falling down', 5),
#  ('balloon', 5),
#  ('cage', 5),
#  ('saffron', 5),
#  ('button', 5),
#  ('doing laundry', 5),
#  ('paper folding', 5),
#  ('ride motorcycle', 5),
#  ('in glass bowl', 5),
#  ('narrating', 5),
#  ('candle', 5),
#  ('acting', 5),
#  ('looking at camera', 5),
#  ('microwave', 5),
#  ('reaching out', 5),
#  ('reading messages', 5),
#  ('cooking things', 5),
#  ('statue', 5),
#  ('cabinet door', 5),
#  ('earth yellow', 5),
#  ('boating', 5),
#  ('on highway', 5),
#  ('subtitle', 5),
#  ('number', 5),
#  ('bridge', 5),
#  ('light-red', 5),
#  ('emerald green', 5),
#  ('reading newspaper', 5),
#  ('waste container', 5),
#  ('pigment', 5),
#  ('plastic bucket', 5),
#  ('vacuum', 5),
#  ('washbasin', 5),
#  ('boxing', 5),
#  ('wiping mirror', 5),
#  ('player', 5),
#  ('handle', 5),
#  ('taking on his coat', 5),
#  ('swinging', 5),
#  ('pink red', 5),
#  ('playing computer games', 5),
#  ('black green', 4),
#  ('firming', 4),
#  ('ruler', 4),
#  ('tire', 4),
#  ('buff', 4),
#  ('water tap', 4),
#  ('tidying up things', 4),
#  ('tray', 4),
#  ('stools', 4),
#  ('by road', 4),
#  ('cleaning up dust', 4),
#  ...]

# %%
name = [x[0] for x in sort_answer[0:100]]
num = [x[1] for x in sort_answer[0:100]]
plt.bar(range(len(num)), num,color='rgb',tick_label=name)
plt.title('answer') 
plt.bar(range(len(name)), num,tick_label=name)
plt.xlabel('word name')
plt.ylabel('frequency')
for a,b in enumerate(num):
    plt.text(a, b, '%.0f' % b, ha='center', va= 'bottom',fontsize=9)
plt.show()

# %%
name
# Out:
# ['standing',
#  'sitting',
#  'black',
#  'white',
#  'indoor',
#  'blue',
#  'red',
#  'on table',
#  'in house',
#  'kitchen',
#  'residence',
#  'drinking water',
#  'green',
#  'living room',
#  'glasses',
#  'cup',
#  'yellow',
#  'eating',
#  'short hair',
#  'chair',
#  'clothes',
#  'speaking',
#  'talking',
#  'computer',
#  'bedroom',
#  'lying',
#  'hat',
#  'long hair',
#  'table',
#  'grey',
#  'walking',
#  'book',
#  'in door',
#  'dark blue',
#  'in living room',
#  'on wall',
#  'two',
#  'brown',
#  'gray',
#  'on ground',
#  'purple',
#  'pink',
#  'pillow',
#  'milk white',
#  'in kitchen',
#  'creamy white',
#  'outdoor',
#  'male',
#  'chatting',
#  'in bedroom',
#  'on stairs',
#  'in room',
#  'singing',
#  'inside house',
#  'mirror',
#  'pot',
#  'dancing',
#  'sneezing',
#  'sofa',
#  'light blue',
#  'on bed',
#  'bottle',
#  'room',
#  'cooking',
#  'on sofa',
#  'man',
#  'phone',
#  'bed',
#  'playing computer',
#  'opening door',
#  'cabinet',
#  'orange',
#  'indoors',
#  'desk',
#  'watching tv',
#  'tidying',
#  'bright red',
#  'aterrimus',
#  'car',
#  'three',
#  'in car',
#  'english',
#  'running',
#  'mustache',
#  'playing cell phone',
#  'plate',
#  'cell phone',
#  'bathroom',
#  'on desk',
#  'house',
#  'dark grey',
#  'resting',
#  'dark black',
#  'female',
#  'painting',
#  'shoes',
#  'microphone',
#  'left hand',
#  'yes',
#  'refrigerator']

# %%
num_word_dict_answer_sort=sorted(num_word_dict_answer.items(),key=lambda e:e[1],reverse=True)
num_word_dict_sort=sorted(num_word_dict_question.items(),key=lambda e:e[1],reverse=True)

# %%
num_word_dict_sort
# Out:
# [(8, 3536),
#  (9, 3174),
#  (7, 2790),
#  (10, 1755),
#  (5, 1549),
#  (11, 1089),
#  (6, 852),
#  (12, 759),
#  (4, 481),
#  (13, 426),
#  (14, 112),
#  (15, 60),
#  (16, 24),
#  (17, 9),
#  (3, 5),
#  (18, 2),
#  (2, 1),
#  (19, 1)]

# %%
num_word_dict_answer_sort
# Out:
# [(1, 32978), (2, 14291), (3, 2319), (4, 248), (5, 30), (6, 8), (8, 1)]

# %%
num_word_dict_sort
# Out:
# [(8, 3536),
#  (9, 3174),
#  (7, 2790),
#  (10, 1755),
#  (5, 1549),
#  (11, 1089),
#  (6, 852),
#  (12, 759),
#  (4, 481),
#  (13, 426),
#  (14, 112),
#  (15, 60),
#  (16, 24),
#  (17, 9),
#  (3, 5),
#  (18, 2),
#  (2, 1),
#  (19, 1)]

# %%
name=[x[0] for x in num_word_dict_answer_sort]
num=[x[1] for x in num_word_dict_answer_sort]
plt.title('answer') 
plt.bar(range(len(name)), num,tick_label=name)
plt.xlabel('number of words')
plt.ylabel('number of occurrences')
for a,b in enumerate(num):
    plt.text(a, b, '%.0f' % b, ha='center', va= 'bottom',fontsize=9)
plt.show()

# %%
name
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
num
# Out:
# [32978, 14291, 2319, 248, 30, 8, 1]

# %%
name=[x[0] for x in num_word_dict_sort]
num=[x[1] for x in num_word_dict_sort]
plt.title('question') 
plt.bar(range(len(name)), num,tick_label=name)
plt.xlabel('number of words')
plt.ylabel('number of occurrences')


for a,b in enumerate(num):
    plt.text(a, b, '%.0f' % b, ha='center', va= 'bottom',fontsize=9)
    
plt.show()

# %%
sort_answer
# Out:
# [('standing', 6344),
#  ('sitting', 2440),
#  ('black', 1824),
#  ('white', 1338),
#  ('indoor', 1155),
#  ('blue', 707),
#  ('red', 563),
#  ('on table', 492),
#  ('in house', 450),
#  ('kitchen', 433),
#  ('residence', 384),
#  ('drinking water', 373),
#  ('green', 364),
#  ('living room', 336),
#  ('glasses', 329),
#  ('cup', 304),
#  ('yellow', 297),
#  ('eating', 292),
#  ('short hair', 288),
#  ('chair', 270),
#  ('clothes', 269),
#  ('speaking', 264),
#  ('talking', 263),
#  ('computer', 258),
#  ('bedroom', 256),
#  ('lying', 248),
#  ('hat', 246),
#  ('long hair', 234),
#  ('table', 222),
#  ('grey', 206),
#  ('walking', 204),
#  ('book', 198),
#  ('in door', 195),
#  ('dark blue', 194),
#  ('in living room', 189),
#  ('on wall', 188),
#  ('two', 186),
#  ('brown', 182),
#  ('gray', 175),
#  ('on ground', 167),
#  ('purple', 164),
#  ('pink', 156),
#  ('pillow', 155),
#  ('milk white', 153),
#  ('in kitchen', 152),
#  ('creamy white', 149),
#  ('outdoor', 145),
#  ('male', 142),
#  ('chatting', 139),
#  ('in bedroom', 136),
#  ('on stairs', 131),
#  ('in room', 124),
#  ('singing', 120),
#  ('inside house', 120),
#  ('mirror', 119),
#  ('pot', 114),
#  ('dancing', 114),
#  ('sneezing', 113),
#  ('sofa', 113),
#  ('light blue', 109),
#  ('on bed', 108),
#  ('bottle', 108),
#  ('room', 105),
#  ('cooking', 104),
#  ('on sofa', 104),
#  ('man', 103),
#  ('phone', 102),
#  ('bed', 99),
#  ('playing computer', 97),
#  ('opening door', 97),
#  ('cabinet', 97),
#  ('orange', 97),
#  ('indoors', 95),
#  ('desk', 94),
#  ('watching tv', 93),
#  ('tidying', 91),
#  ('bright red', 90),
#  ('aterrimus', 89),
#  ('car', 89),
#  ('three', 85),
#  ('in car', 84),
#  ('english', 82),
#  ('running', 82),
#  ('mustache', 81),
#  ('playing cell phone', 81),
#  ('plate', 79),
#  ('cell phone', 79),
#  ('bathroom', 79),
#  ('on desk', 78),
#  ('house', 78),
#  ('dark grey', 77),
#  ('resting', 77),
#  ('dark black', 77),
#  ('female', 76),
#  ('painting', 76),
#  ('shoes', 75),
#  ('microphone', 75),
#  ('left hand', 75),
#  ('yes', 75),
#  ('refrigerator', 74),
#  ('blanket', 74),
#  ('dog', 74),
#  ('sleeping', 73),
#  ('reading', 72),
#  ('furvous', 72),
#  ('closet', 72),
#  ('bag', 72),
#  ('dark green', 71),
#  ('towel', 70),
#  ('on floor', 69),
#  ('on stage', 68),
#  ('woman', 67),
#  ('on chair', 67),
#  ('taking off clothes', 67),
#  ('right hand', 66),
#  ('lying down', 65),
#  ('playing phone', 65),
#  ('tv', 65),
#  ('door', 65),
#  ('closing door', 64),
#  ('dark red', 64),
#  ('light gray', 62),
#  ('clearing up', 60),
#  ('reading book', 59),
#  ('writing', 58),
#  ('sweeping floor', 58),
#  ('squatting', 57),
#  ('taking things', 56),
#  ('box', 56),
#  ('tree', 55),
#  ('on cabinet', 54),
#  ('on shelf', 54),
#  ('open', 54),
#  ('bowl', 54),
#  ('on', 54),
#  ('in studio', 54),
#  ('light green', 54),
#  ('light grey', 54),
#  ('corridor', 53),
#  ('taking off shoes', 53),
#  ('paper', 52),
#  ('off-white', 52),
#  ('driving', 51),
#  ('looking into mirror', 51),
#  ('looking in mirror', 50),
#  ('studio', 50),
#  ('shelf', 50),
#  ('crimson', 50),
#  ('laptop', 48),
#  ('lamp', 48),
#  ('broom', 47),
#  ('in bathroom', 47),
#  ('photo frame', 46),
#  ('helmet', 46),
#  ('playing games', 46),
#  ('guitar', 46),
#  ('playing mobile phone', 45),
#  ('four', 45),
#  ('on road', 44),
#  ('toilet', 44),
#  ('light yellow', 44),
#  ('dark brown', 44),
#  ('pouring water', 43),
#  ('pure black', 43),
#  ('carton', 43),
#  ('watch', 43),
#  ('grass green', 42),
#  ('sky blue', 42),
#  ('mouse', 41),
#  ('cleaning', 41),
#  ('stairs', 40),
#  ('beige', 40),
#  ('on street', 39),
#  ('one', 39),
#  ('television', 38),
#  ('opening refrigerator', 38),
#  ('water cup', 38),
#  ('dark gray', 38),
#  ('violet', 37),
#  ('people', 37),
#  ('dark-blue', 37),
#  ('curtain', 37),
#  ('ring', 37),
#  ('looking at computer', 36),
#  ('milky white', 36),
#  ('washing machine', 36),
#  ('food', 36),
#  ('switch', 36),
#  ('navy blue', 35),
#  ('eating things', 35),
#  ('pool', 35),
#  ('photo', 35),
#  ('laughing', 34),
#  ('doorway', 34),
#  ('cyan', 34),
#  ('eating bread', 34),
#  ('taking clothes', 34),
#  ('camera', 34),
#  ('hanging on wall', 33),
#  ('cap', 33),
#  ('performing', 33),
#  ('no', 33),
#  ('reading books', 33),
#  ('necklace', 33),
#  ('eyeglasses', 33),
#  ('royal blue', 32),
#  ('quilt', 32),
#  ('gray white', 32),
#  ('playing guitar', 32),
#  ('azure', 31),
#  ('taking photos', 31),
#  ('putting on shoes', 31),
#  ('vacuum cleaner', 31),
#  ('water', 31),
#  ('pen', 30),
#  ('light-blue', 30),
#  ('drinking', 30),
#  ('left', 30),
#  ('rectangle', 30),
#  ('putting on clothes', 30),
#  ('in hands', 29),
#  ('rose red', 29),
#  ('bucket', 28),
#  ('light red', 28),
#  ('in cabinet', 28),
#  ('in water', 28),
#  ('cleaning up', 28),
#  ('cartoon', 28),
#  ('wearing shoes', 27),
#  ('earphone', 27),
#  ('carpet', 27),
#  ('horizontal', 27),
#  ('right', 27),
#  ('bread', 27),
#  ('turning on light', 27),
#  ('light', 27),
#  ('taking cup', 27),
#  ('fetching things', 26),
#  ('mobile phone', 26),
#  ('dark purple', 26),
#  ('wrestling', 26),
#  ('looking for something', 26),
#  ('snacks', 26),
#  ('exercising', 26),
#  ('taking shoes', 26),
#  ('silver', 26),
#  ('explaining', 26),
#  ('window', 26),
#  ('jar', 26),
#  ('lawn', 25),
#  ('light pink', 25),
#  ('wearing clothes', 25),
#  ('behind door', 25),
#  ('smalt', 25),
#  ('putting things', 25),
#  ('beige white', 25),
#  ('in hand', 25),
#  ('clock', 24),
#  ('golden', 24),
#  ('on lawn', 24),
#  ('laundry detergent', 24),
#  ('curly hair', 24),
#  ('gun', 24),
#  ('person', 24),
#  ('closed', 24),
#  ('on washing machine', 24),
#  ('stage', 24),
#  ('horse', 24),
#  ('plastic bag', 23),
#  ('remote control', 23),
#  ('calling', 23),
#  ('tie', 23),
#  ('watching computer', 23),
#  ('sitting down', 23),
#  ('beverage', 23),
#  ('public place', 23),
#  ('cat', 23),
#  ('hearth', 23),
#  ('court', 23),
#  ('throwing clothes', 22),
#  ('paper box', 22),
#  ('hanger', 22),
#  ('sky-blue', 22),
#  ('having rest', 22),
#  ('opening', 22),
#  ('six', 22),
#  ('light white', 22),
#  ('light purple', 22),
#  ('on stool', 21),
#  ('baby blue', 21),
#  ('khaki', 21),
#  ('in closet', 21),
#  ('on door', 21),
#  ('throwing pillow', 21),
#  ('socket', 21),
#  ('stool', 21),
#  ('notebook', 20),
#  ('poster', 20),
#  ('holding pillow', 20),
#  ('deep purple', 20),
#  ('placing items', 20),
#  ('backpack', 20),
#  ('atrovirens', 20),
#  ('marine blue', 19),
#  ('outdoors', 19),
#  ('playing basketball', 19),
#  ('fighting', 19),
#  ('case', 19),
#  ('doll', 19),
#  ('taking off coat', 19),
#  ('lake blue', 19),
#  ('knife', 19),
#  ('dark yellow', 19),
#  ('cloakroom', 19),
#  ('on grass', 19),
#  ('flower', 19),
#  ('in corridor', 18),
#  ('dark-red', 18),
#  ('lavender', 18),
#  ('washing clothes', 18),
#  ('curly', 18),
#  ('taking photo', 18),
#  ('brownish yellow', 18),
#  ('posing', 18),
#  ('moving', 18),
#  ('kneeling', 18),
#  ('hands', 18),
#  ('shooting', 18),
#  ('making call', 18),
#  ('couch', 18),
#  ('black blue', 18),
#  ('azure blue', 18),
#  ('taking phone', 17),
#  ('keyboard', 17),
#  ('taking pillow', 17),
#  ('child', 17),
#  ('basketball court', 17),
#  ('staircase', 17),
#  ('steering wheel', 17),
#  ('wiping table', 17),
#  ('drinking beverage', 17),
#  ('ash black', 17),
#  ('basket', 17),
#  ('cellphone', 17),
#  ('auditorium', 17),
#  ('looking at mirror', 17),
#  ('opening cabinet', 16),
#  ('smiling', 16),
#  ('jumping', 16),
#  ('taking book', 16),
#  ('taking something', 16),
#  ('round', 16),
#  ('taking pictures', 16),
#  ('competing', 16),
#  ('orange red', 16),
#  ('taking medicine', 16),
#  ('on cupboard', 16),
#  ('newspaper', 16),
#  ('spoon', 16),
#  ('ball', 16),
#  ('square', 16),
#  ('vase', 16),
#  ('football field', 16),
#  ('wall', 16),
#  ('light brown', 16),
#  ('getting up', 16),
#  ('microwave oven', 16),
#  ('at table', 16),
#  ('taking towel', 16),
#  ('skyblue', 16),
#  ('toy', 15),
#  ('calendar', 15),
#  ('in corner', 15),
#  ('skirt', 15),
#  ('daytime', 15),
#  ('wardrobe', 15),
#  ('display', 15),
#  ('glass', 15),
#  ('in game', 15),
#  ('rose', 15),
#  ('black and white', 15),
#  ('watching video', 15),
#  ('shirt', 15),
#  ('flying', 15),
#  ('magazine', 15),
#  ('next to car', 15),
#  ('pale pink', 15),
#  ('climbing stairs', 15),
#  ('off white', 15),
#  ('grey white', 15),
#  ('eating something', 15),
#  ('playing', 15),
#  ('tv set', 15),
#  ('horizontally', 15),
#  ('in cupboard', 15),
#  ('game scene', 15),
#  ('toilets', 15),
#  ('on cooktop', 15),
#  ('gray black', 14),
#  ('modena', 14),
#  ('animal', 14),
#  ('tan', 14),
#  ('turquoise', 14),
#  ('making up', 14),
#  ('pumpkin', 14),
#  ('audience', 14),
#  ('clothing', 14),
#  ('earphones', 14),
#  ('fan', 14),
#  ('claybank', 14),
#  ('field', 14),
#  ('beach', 14),
#  ('earrings', 13),
#  ('typing', 13),
#  ('turning on lights', 13),
#  ('looking at phone', 13),
#  ('basin', 13),
#  ('washing hands', 13),
#  ('swimming', 13),
#  ('putting away things', 13),
#  ('in sky', 13),
#  ('pure white', 13),
#  ('sheet', 13),
#  ('silver grey', 13),
#  ('watching videos', 13),
#  ('stairwell', 13),
#  ('putting cup', 13),
#  ('dark-grey', 13),
#  ('taking blanket', 13),
#  ('kettle', 13),
#  ('ocean blue', 13),
#  ('game', 13),
#  ('stirring', 12),
#  ('off', 12),
#  ('on court', 12),
#  ('making phone call', 12),
#  ('seven', 12),
#  ('cushion', 12),
#  ('taking bag', 12),
#  ('gloves', 12),
#  ('wiping nose', 12),
#  ('corner', 12),
#  ('true red', 12),
#  ('warehouse', 12),
#  ('circle', 12),
#  ('stopped', 12),
#  ('skiing', 12),
#  ('pale green', 12),
#  ('on refrigerator', 12),
#  ('by river', 12),
#  ('storage room', 12),
#  ('watching phone', 12),
#  ('grey black', 12),
#  ('bicycle', 12),
#  ('meat', 12),
#  ('grass', 12),
#  ('closing window', 12),
#  ('oven', 12),
#  ('playing piano', 12),
#  ('interviewing', 12),
#  ('tablecloth', 12),
#  ('medium yellow', 12),
#  ('cloth', 12),
#  ('coffee', 12),
#  ('lights', 12),
#  ('scarf', 12),
#  ('grey and white', 11),
#  ('having match', 11),
#  ('in hallway', 11),
#  ('electric fan', 11),
#  ('eating food', 11),
#  ('frame', 11),
#  ('drawing', 11),
#  ('going upstairs', 11),
#  ('utility room', 11),
#  ('pale yellow', 11),
#  ('rice white', 11),
#  ('table lamp', 11),
#  ('taking food', 11),
#  ('pan', 11),
#  ('plastic bottle', 11),
#  ('athlete', 11),
#  ('road', 11),
#  ('on steps', 11),
#  ('five', 11),
#  ('changing clothes', 11),
#  ('egg', 11),
#  ('turning off light', 11),
#  ('dressing up', 11),
#  ('gymnasium', 11),
#  ('big red', 11),
#  ('orange yellow', 11),
#  ('playing field', 11),
#  ('dishes', 11),
#  ('drinking milk', 11),
#  ('bottle green', 11),
#  ('tool', 11),
#  ('opening box', 11),
#  ('turning off lights', 11),
#  ('cartoon character', 11),
#  ('light black', 11),
#  ('making speech', 11),
#  ('playing football', 10),
#  ('apron', 10),
#  ('trousers', 10),
#  ('closing refrigerator', 10),
#  ('grayish white', 10),
#  ('creamy-white', 10),
#  ('wrist watch', 10),
#  ('brush', 10),
#  ('turning around', 10),
#  ('fashion show', 10),
#  ('army green', 10),
#  ('pure-black', 10),
#  ('folding clothes', 10),
#  ('going downstairs', 10),
#  ('playing game', 10),
#  ('introducing car', 10),
#  ('blue-black', 10),
#  ('faint yellow', 10),
#  ('studying', 10),
#  ('getting dressed', 10),
#  ('mural', 10),
#  ('cupboard', 10),
#  ('putting down something', 10),
#  ('on snow mountain', 10),
#  ('folding paper', 10),
#  ('laundry room', 10),
#  ('in washing room', 10),
#  ('corner of wall', 10),
#  ('light-grey', 10),
#  ('having meal', 10),
#  ('turning on computer', 10),
#  ('taking selfie', 10),
#  ('shovel', 10),
#  ('opening closet', 10),
#  ('undressing', 10),
#  ('in air', 9),
#  ('playground', 9),
#  ('decorative painting', 9),
#  ('handbag', 9),
#  ('headset', 9),
#  ('in drawer', 9),
#  ('in wardrobe', 9),
#  ('mop', 9),
#  ('garland', 9),
#  ('putting clothes', 9),
#  ('fresco', 9),
#  ('tangerine', 9),
#  ('sapphire blue', 9),
#  ('electronic guitar', 9),
#  ('catwalk show', 9),
#  ('driving car', 9),
#  ('electric wire', 9),
#  ('on carpet', 9),
#  ('on window sill', 9),
#  ('stroller', 9),
#  ('in stairwell', 9),
#  ('in refrigerator', 9),
#  ('lakeside', 9),
#  ('word', 9),
#  ('on washbasin', 9),
#  ('on hanger', 9),
#  ('chicken', 9),
#  ('studios', 9),
#  ('on screen', 9),
#  ('fish', 9),
#  ('sunglasses', 9),
#  ('standing up', 9),
#  ('fruits', 9),
#  ('simple', 9),
#  ('piano', 9),
#  ('riding motorcycle', 9),
#  ('putting down cup', 9),
#  ('opening cabinet door', 9),
#  ('on hearth', 9),
#  ('above ground', 9),
#  ('earthy yellow', 9),
#  ('magenta', 9),
#  ('black grey', 9),
#  ('in front of table', 9),
#  ('stone', 9),
#  ('milk-white', 9),
#  ('sheets', 9),
#  ('brownish red', 9),
#  ('on beach', 9),
#  ('cleaning window', 9),
#  ('can', 9),
#  ('sword', 9),
#  ('blue and black', 9),
#  ('in cup', 9),
#  ('light-yellow', 9),
#  ('vacuum machine', 9),
#  ('banana', 9),
#  ('human', 9),
#  ('on tv bench', 9),
#  ('seat', 9),
#  ('stadium', 9),
#  ('relaxing', 9),
#  ('jacinth', 9),
#  ('taking bottle', 9),
#  ('introducing', 9),
#  ('slivery', 8),
#  ('bosom', 8),
#  ('next to door', 8),
#  ('hugging', 8),
#  ('clapping', 8),
#  ('vegetables', 8),
#  ('putting shoes', 8),
#  ('opening window', 8),
#  ('light cyan', 8),
#  ('putting on coat', 8),
#  ('bolster', 8),
#  ('watching television', 8),
#  ('at corner', 8),
#  ('monster', 8),
#  ('flashlight', 8),
#  ('tidying clothes', 8),
#  ('besom', 8),
#  ('doing cleaning', 8),
#  ('curtains', 8),
#  ('screwdriver', 8),
#  ('pale blue', 8),
#  ('dumbbell', 8),
#  ('desk lamp', 8),
#  ('wathet', 8),
#  ('walking around', 8),
#  ('placing clothes', 8),
#  ('bowel', 8),
#  ('snow mountain', 8),
#  ('picking up pillow', 8),
#  ('picture', 8),
#  ('golden yellow', 8),
#  ('lemon yellow', 8),
#  ('machine', 8),
#  ('pale grey', 8),
#  ('boat', 8),
#  ('peach red', 8),
#  ('throwing things', 8),
#  ('taking computer', 8),
#  ('bike', 8),
#  ('restaurant', 8),
#  ('hall', 7),
#  ('brown green', 7),
#  ('screwing cap', 7),
#  ('plant', 7),
#  ('sweeping', 7),
#  ('forward', 7),
#  ('taking rest', 7),
#  ('model', 7),
#  ('scarlet', 7),
#  ('suit', 7),
#  ('triangle', 7),
#  ('telephone', 7),
#  ('gray-black', 7),
#  ('pants', 7),
#  ('silvery gray', 7),
#  ('clapping hands', 7),
#  ('glove', 7),
#  ('opening refrigerator door', 7),
#  ('cooking meal', 7),
#  ('in pool', 7),
#  ('table tennis', 7),
#  ('on runway', 7),
#  ('in toilet', 7),
#  ('silver gray', 7),
#  ('doing chores', 7),
#  ('screen', 7),
#  ('classroom', 7),
#  ('brushing plate', 7),
#  ('looking at photo', 7),
#  ('hangers', 7),
#  ('boy', 7),
#  ('stairway', 7),
#  ('cleaner', 7),
#  ('books', 7),
#  ('on tea table', 7),
#  ('hair clip', 7),
#  ('river', 7),
#  ('shampoo', 7),
#  ('ivory-white', 7),
#  ('back cushion', 7),
#  ('dark-black', 7),
#  ('turning off computer', 7),
#  ('fuchsia', 7),
#  ('washroom', 7),
#  ('puppy', 7),
#  ('national flag', 7),
#  ('throwing book', 7),
#  ('on closet', 7),
#  ('hanging clothes', 7),
#  ('on playground', 7),
#  ('in pot', 7),
#  ('bracelet', 7),
#  ('silvery white', 7),
#  ('against wall', 7),
#  ('golden-yellow', 7),
#  ('skeleton', 7),
#  ('armrest', 7),
#  ('magnet', 7),
#  ('earring', 7),
#  ('on sea', 7),
#  ('plates', 7),
#  ('picking up clothes', 7),
#  ('blankets', 7),
#  ('folding towels', 7),
#  ('medal', 7),
#  ('filming', 7),
#  ('lifting cup', 7),
#  ('playing table tennis', 7),
#  ('cleaning table', 7),
#  ('laboratory', 7),
#  ('pea green', 7),
#  ('black-blue', 7),
#  ('in river', 7),
#  ('soft red', 7),
#  ('doing some cleaning', 7),
#  ('washing cup', 7),
#  ('wiping glasses', 6),
#  ('sky', 6),
#  ('jacket', 6),
#  ('in sea', 6),
#  ('plastic box', 6),
#  ('purple red', 6),
#  ('forest', 6),
#  ('third', 6),
#  ('on snowfield', 6),
#  ('repairing', 6),
#  ('on shoes', 6),
#  ('doing experiment', 6),
#  ('rolling', 6),
#  ('alpaca', 6),
#  ('toothbrush', 6),
#  ('fruit', 6),
#  ('dining', 6),
#  ('vegetable', 6),
#  ('selfie stick', 6),
#  ('shaking', 6),
#  ('hair band', 6),
#  ('throwing shoes', 6),
#  ('putting food', 6),
#  ('in carton', 6),
#  ('wing', 6),
#  ('amaranth', 6),
#  ('on bus', 6),
#  ('in front of mirror', 6),
#  ('home', 6),
#  ('on tv cabinet', 6),
#  ('on head', 6),
#  ('bookcase', 6),
#  ('ring finger', 6),
#  ('in washing machine', 6),
#  ('fat', 6),
#  ('handrail', 6),
#  ('on washing sink', 6),
#  ('minecraft', 6),
#  ('beside sofa', 6),
#  ('in box', 6),
#  ('brown yellow', 6),
#  ('holding dog', 6),
#  ('key', 6),
#  ('potato', 6),
#  ('waving', 6),
#  ('broadcasting', 6),
#  ('match', 6),
#  ('cups', 6),
#  ('having beard', 6),
#  ('bracers', 6),
#  ('putting down clothes', 6),
#  ('repairing car', 6),
#  ('introducing product', 6),
#  ('watching photos', 6),
#  ('on carton', 6),
#  ('brown-black', 6),
#  ('sports center', 6),
#  ('operating computer', 6),
#  ('fence', 6),
#  ('on ice', 6),
#  ('taking plates', 6),
#  ('drawing curtain', 6),
#  ('taking plate', 6),
#  ('pushing car', 6),
#  ('cleaning mirror', 6),
#  ('looking at things', 6),
#  ('jasper', 6),
#  ('hamster', 6),
#  ('brownish black', 6),
#  ('rose-bengal', 6),
#  ('on chopping board', 6),
#  ('screwing bottle cap', 6),
#  ('on counter', 6),
#  ('pouring laundry detergent', 6),
#  ('rabbit', 6),
#  ('on plane', 6),
#  ('in front of door', 6),
#  ('shaking hands', 6),
#  ('transparent', 6),
#  ('hospital', 6),
#  ('stationary', 6),
#  ('using vacuum cleaner', 6),
#  ('taking broom', 6),
#  ('sliver white', 6),
#  ('placing cup', 6),
#  ('taking out items', 6),
#  ('by wall', 6),
#  ('cow', 6),
#  ('tattoo', 6),
#  ('moving chair', 6),
#  ('on sport court', 6),
#  ('touching hair', 6),
#  ('pictures', 6),
#  ('vehicle', 6),
#  ('on face', 6),
#  ('photograph', 6),
#  ('blackboard', 6),
#  ('sea blue', 6),
#  ('on board', 6),
#  ('on rope', 6),
#  ('putting away stuff', 6),
#  ('lying on his stomach', 6),
#  ('stirring food', 6),
#  ('riding horse', 6),
#  ('bbc', 6),
#  ('bright-red', 6),
#  ('mopping floor', 6),
#  ('t-shirts', 6),
#  ('at stair hall', 6),
#  ('eating snacks', 6),
#  ('croci', 6),
#  ('reseda', 6),
#  ('bed sheet', 6),
#  ('shorts', 6),
#  ('park', 6),
#  ('in stairs', 6),
#  ('moving boxes', 6),
#  ('covering blanket', 6),
#  ('looking outside window', 6),
#  ('trash can', 6),
#  ('beside door', 6),
#  ('looking at photos', 6),
#  ('in gymnasium', 6),
#  ('lobby', 6),
#  ('groveling', 6),
#  ('in front of closet', 6),
#  ('drinking juice', 6),
#  ('nodding', 6),
#  ('baby', 6),
#  ('taking wrench', 6),
#  ('snowfield', 6),
#  ('english letter', 6),
#  ('shelter', 6),
#  ('playing video', 6),
#  ('watching game', 6),
#  ('comic', 6),
#  ('near table', 6),
#  ('taking books', 6),
#  ('chopping board', 6),
#  ('racing', 6),
#  ('motorcycle', 6),
#  ('medicine', 6),
#  ('stretching arms', 6),
#  ('by sea', 6),
#  ('plastic', 6),
#  ('hair braiding', 6),
#  ('long sleeve', 6),
#  ('rugby', 6),
#  ('giving speech', 6),
#  ('hot', 6),
#  ('putting away clothes', 6),
#  ('dialog box', 6),
#  ('having conversation', 6),
#  ('mat', 6),
#  ('in cinema', 6),
#  ('wiping face', 6),
#  ('playing cellphone', 6),
#  ('blue white', 6),
#  ('playing baseball', 6),
#  ('detergent', 6),
#  ('ball park', 6),
#  ('massaging', 6),
#  ('playing ball', 6),
#  ('hair', 6),
#  ('suburb', 6),
#  ('flour', 6),
#  ('basketball', 6),
#  ('light-green', 6),
#  ('oil painting', 5),
#  ('black gray', 5),
#  ('picking up book', 5),
#  ('taking magazine', 5),
#  ('wiping hands', 5),
#  ('arrow', 5),
#  ('baby-blue', 5),
#  ('outside house', 5),
#  ('holding cup', 5),
#  ('seasoning', 5),
#  ('sewing machine', 5),
#  ('talking on phone', 5),
#  ('tibetain blue', 5),
#  ('mattress', 5),
#  ('at door', 5),
#  ('blue purple', 5),
#  ('peach', 5),
#  ('snake', 5),
#  ('washing dishes', 5),
#  ('3d', 5),
#  ('dessert', 5),
#  ('kissing', 5),
#  ('peak green', 5),
#  ('going up stairs', 5),
#  ('purplish red', 5),
#  ('looking at cellphone', 5),
#  ('card', 5),
#  ('doing exercise', 5),
#  ('milk', 5),
#  ('taking out clothes', 5),
#  ('taking box', 5),
#  ('folding towel', 5),
#  ('seeing information', 5),
#  ('closing refrigerator door', 5),
#  ('visiting', 5),
#  ('closing closet', 5),
#  ('monkey', 5),
#  ('under stairs', 5),
#  ('vermilion', 5),
#  ('document', 5),
#  ('taking off his clothes', 5),
#  ('water bottle', 5),
#  ('putting on blanket', 5),
#  ('fork', 5),
#  ('purplish blue', 5),
#  ('leopard', 5),
#  ('denim blue', 5),
#  ('ash gray', 5),
#  ('plastic bags', 5),
#  ('glass bottle', 5),
#  ('recording', 5),
#  ('giving lecture', 5),
#  ('umbrella', 5),
#  ('hand', 5),
#  ('ater', 5),
#  ('placing things', 5),
#  ('music score', 5),
#  ('swimming pool', 5),
#  ('rag', 5),
#  ('operating phone', 5),
#  ('opening computer', 5),
#  ('putting towel', 5),
#  ('falling down', 5),
#  ('balloon', 5),
#  ('cage', 5),
#  ('saffron', 5),
#  ('button', 5),
#  ('doing laundry', 5),
#  ('paper folding', 5),
#  ('ride motorcycle', 5),
#  ('in glass bowl', 5),
#  ('narrating', 5),
#  ('candle', 5),
#  ('acting', 5),
#  ('looking at camera', 5),
#  ('microwave', 5),
#  ('reaching out', 5),
#  ('reading messages', 5),
#  ('cooking things', 5),
#  ('statue', 5),
#  ('cabinet door', 5),
#  ('earth yellow', 5),
#  ('boating', 5),
#  ('on highway', 5),
#  ('subtitle', 5),
#  ('number', 5),
#  ('bridge', 5),
#  ('light-red', 5),
#  ('emerald green', 5),
#  ('reading newspaper', 5),
#  ('waste container', 5),
#  ('pigment', 5),
#  ('plastic bucket', 5),
#  ('vacuum', 5),
#  ('washbasin', 5),
#  ('boxing', 5),
#  ('wiping mirror', 5),
#  ('player', 5),
#  ('handle', 5),
#  ('taking on his coat', 5),
#  ('swinging', 5),
#  ('pink red', 5),
#  ('playing computer games', 5),
#  ('black green', 4),
#  ('firming', 4),
#  ('ruler', 4),
#  ('tire', 4),
#  ('buff', 4),
#  ('water tap', 4),
#  ('tidying up things', 4),
#  ('tray', 4),
#  ('stools', 4),
#  ('by road', 4),
#  ('cleaning up dust', 4),
#  ...]
