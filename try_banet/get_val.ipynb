# %%
import sys

# %%
i=0
id=-1
data_list=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["video_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", [])
                elif i % 4 == 0:
                    if word not in data["answer"]:
                        data["answer"].append(word)
                    data_list.append(data)
                    data={}
                    answer=[]
                else:
                    if word not in data["answer"]:
                        data["answer"].append(word)
            else:
                video_id=word

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['kissing'],
#   'id': 6,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['lying'],
#   'id': 7,
#   'question': 'is the person sitting or lying in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['on bed'],
#   'id': 8,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['long hair'],
#   'id': 9,
#   'question': 'does the woman have long hair or short hair in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['white', 'light white', 'pure white'],
#   'id': 10,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['standing', 'sitting'],
#   'id': 11,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['kitchen'],
#   'id': 12,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['drinking water', 'drinking milk'],
#   'id': 13,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['on table'],
#   'id': 14,
#   'question': 'where is the book',
#   'video_name': 'ZJL963'},
#  {'answer': ['third'],
#   'id': 15,
#   'question': 'which layer of the cabinet is the water cup put in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['pure black', 'black', 'dark black'],
#   'id': 16,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['opening cabinet', 'drinking water'],
#   'id': 17,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': ['cabinet'],
#   'id': 18,
#   'question': 'where did the person get the cup',
#   'video_name': 'ZJL1836'},
#  {'answer': ['standing'],
#   'id': 19,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['pink', 'light-pink', 'peach-pink'],
#   'id': 20,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['broadcasting', 'entertainment', 'new'],
#   'id': 21,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['swimsuit'],
#   'id': 22,
#   'question': 'what does the super star wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['in water'],
#   'id': 23,
#   'question': 'where is the superstar in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['standing'],
#   'id': 24,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['tv', 'sofa', 'table'],
#   'id': 25,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': ['white', 'milk white', 'off-white'],
#   'id': 26,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': ['pushing tv button'],
#   'id': 27,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3886'},
#  {'answer': ['in living room', 'indoor', 'in room'],
#   'id': 28,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': ['standing'],
#   'id': 29,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3886'},
#  {'answer': ['book', 'phone', 'computer'],
#   'id': 30,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': ['black', 'white', 'blue'],
#   'id': 31,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': ['taking clothes', 'clearing up', 'playing phone'],
#   'id': 32,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': ['standing'],
#   'id': 33,
#   'question': 'was the man standing or sitting in the end',
#   'video_name': 'ZJL2952'},
#  {'answer': ['in door'],
#   'id': 34,
#   'question': 'where is the man',
#   'video_name': 'ZJL2952'},
#  {'answer': ['brown', 'light brown', 'rustic brown'],
#   'id': 35,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['standing'],
#   'id': 36,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['bathroom'],
#   'id': 37,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['looking at mirror', 'taking off clothes', 'wiping arms'],
#   'id': 38,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['on shelf'],
#   'id': 39,
#   'question': 'where is the towel',
#   'video_name': 'ZJL927'},
#  {'answer': ['schoolbag', 'mobile phone', 'pillow'],
#   'id': 40,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': ['green', 'light green', 'dark green'],
#   'id': 41,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': ['holding pillow'],
#   'id': 42,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3687'},
#  {'answer': ['room'],
#   'id': 43,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': ['sitting'],
#   'id': 44,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3687'},
#  {'answer': ['daytime', 'morning'],
#   'id': 45,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 46,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': ['taking selfie', 'photographing', 'taking photos'],
#   'id': 47,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': ['outdoor', 'suburb', 'in car'],
#   'id': 48,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': ['sitting'],
#   'id': 49,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': ['woman', 'man', 'sofa'],
#   'id': 50,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['beige'],
#   'id': 51,
#   'question': 'what color is the sofa in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['talking'],
#   'id': 52,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['in room'],
#   'id': 53,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['standing', 'sitting'],
#   'id': 54,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': ['black', 'white', 'dark blue'],
#   'id': 55,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['sitting'],
#   'id': 56,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['reading book'],
#   'id': 57,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['kitchen'],
#   'id': 58,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['on table'],
#   'id': 59,
#   'question': 'where is the water bottle in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['photograph', 'cup', 'basket'],
#   'id': 60,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': ['black'],
#   'id': 61,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['drinking water'],
#   'id': 62,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['in stairwell'],
#   'id': 63,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['standing'],
#   'id': 64,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3443'},
#  {'answer': ['closet', 'chair', 'tv'],
#   'id': 65,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': ['black', 'dark black', 'aterrimus'],
#   'id': 66,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': ['opening door', 'putting towel', 'sneezing'],
#   'id': 67,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': ['indoor', 'living room', 'residence'],
#   'id': 68,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': ['standing'],
#   'id': 69,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2146'},
#  {'answer': ['computer'],
#   'id': 70,
#   'question': 'what is on the cabinet in the video',
#   'video_name': 'ZJL578'},
#  {'answer': ['white'],
#   'id': 71,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL578'},
#  {'answer': ['eating things', 'playing computer'],
#   'id': 72,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': ['kitchen'],
#   'id': 73,
#   'question': 'in which room is the woman in the video',
#   'video_name': 'ZJL578'},
#  {'answer': ['standing'],
#   'id': 74,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL578'},
#  {'answer': ['standing'],
#   'id': 75,
#   'question': 'is the person wearing pink in the video standing or sitting',
#   'video_name': 'ZJL2741'},
#  {'answer': ['eating something', 'eating food'],
#   'id': 76,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': ['bedroom'],
#   'id': 77,
#   'question': 'where is the person wearing pink in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': ['bed', 'cabinet', 'mirror'],
#   'id': 78,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': ['white', 'light white', 'gray white'],
#   'id': 79,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': ['green', 'pale green', 'grass green'],
#   'id': 80,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['standing'],
#   'id': 81,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['taking off shoes', 'closing door', 'turn on lights'],
#   'id': 82,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['long hair'],
#   'id': 83,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['pink', 'soft red', 'rose'],
#   'id': 84,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['cup', 'phone', 'clothes'],
#   'id': 85,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': ['brown', 'yellow', 'golden'],
#   'id': 86,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': ['standing'],
#   'id': 87,
#   'question': 'is the man in purple standing or sitting',
#   'video_name': 'ZJL2934'},
#  {'answer': ['in door'],
#   'id': 88,
#   'question': 'where is the man',
#   'video_name': 'ZJL2934'},
#  {'answer': ['shoes'],
#   'id': 89,
#   'question': 'what is on the outside floor',
#   'video_name': 'ZJL2934'},
#  {'answer': ['green', 'grass green', 'pale green'],
#   'id': 90,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['standing'],
#   'id': 91,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['kitchen'],
#   'id': 92,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['making food', 'sweeping floor', 'eating'],
#   'id': 93,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['short hair'],
#   'id': 94,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['cabinet', 'mirror', 'clothes'],
#   'id': 95,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': ['pink', 'magenta', 'burgandy'],
#   'id': 96,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': ['looking at mirror', 'putting on clothes', 'buttoning'],
#   'id': 97,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': ['indoor', 'in room', 'in house'],
#   'id': 98,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': ['standing'],
#   'id': 99,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3944'},
#  {'answer': ['door', 'television', 'curtain'],
#   'id': 100,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': ['yellow', 'khaki', 'brownish yellow'],
#   'id': 101,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': ['watching tv', 'resting', 'sleeping'],
#   'id': 102,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': ['indoors', 'in house', 'in bedroom'],
#   'id': 103,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': ['lying on his stomach'],
#   'id': 104,
#   'question': 'is the person in the video lying on his stomach or sitting',
#   'video_name': 'ZJL4047'},
#  {'answer': ['chair', 'fence', 'book'],
#   'id': 105,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 106,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': ['dancing', 'exercising', 'playing'],
#   'id': 107,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['outdoor', 'yard', 'at door'],
#   'id': 108,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['standing'],
#   'id': 109,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['mustache'],
#   'id': 110,
#   'question': "what is on the person's face in the video",
#   'video_name': 'ZJL651'},
#  {'answer': ['gray', 'black gray', 'neutral gary'],
#   'id': 111,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['eating'],
#   'id': 112,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['staircase'],
#   'id': 113,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['sitting'],
#   'id': 114,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['closet', 'refrigerator', 'pot'],
#   'id': 115,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': ['black', 'dark black', 'aterrimus'],
#   'id': 116,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': ['firing', 'taking things', 'opening refrigerator'],
#   'id': 117,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': ['indoor', 'kitchen', 'residence'],
#   'id': 118,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': ['standing'],
#   'id': 119,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2147'},
#  {'answer': ['icon', 'website', 'people'],
#   'id': 120,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['female'],
#   'id': 121,
#   'question': 'is the person in the video a male or a female',
#   'video_name': 'ZJL1115'},
#  {'answer': ['black'],
#   'id': 122,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['in water'],
#   'id': 123,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['tapping water'],
#   'id': 124,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['music score', 'guitar', 'microphone'],
#   'id': 125,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['purple', 'deep purple', 'purple sauce'],
#   'id': 126,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['singing'],
#   'id': 127,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['on stage'],
#   'id': 128,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['standing'],
#   'id': 129,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['boy', 'girl', 'women'],
#   'id': 130,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['brown', 'tan', 'coffee'],
#   'id': 131,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['interviewing', 'talking', 'narrating'],
#   'id': 132,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['indoor', 'in room', 'interview site'],
#   'id': 133,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['sitting'],
#   'id': 134,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['mustache'],
#   'id': 135,
#   'question': 'what is on the face of the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['white', 'creamy-white', 'ivory-white'],
#   'id': 136,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['setting of pillows'],
#   'id': 137,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['in living room'],
#   'id': 138,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['sitting'],
#   'id': 139,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL3506'},
#  {'answer': ['board', 'sponge', 'brush'],
#   'id': 140,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['yellow', 'light yellow', 'canary yellow'],
#   'id': 141,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['cleaning toy', 'wiping toy', 'cleaning up dust'],
#   'id': 142,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': ['in water', 'in bathtub', 'in bathroom'],
#   'id': 143,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['plastic'],
#   'id': 144,
#   'question': 'what is the material of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['athlete'],
#   'id': 145,
#   'question': 'what is on the track',
#   'video_name': 'ZJL1602'},
#  {'answer': ['yellow'],
#   'id': 146,
#   'question': "what color is the runner's hair",
#   'video_name': 'ZJL1602'},
#  {'answer': ['running'],
#   'id': 147,
#   'question': 'what is the person in yellow hair doing',
#   'video_name': 'ZJL1602'},
#  {'answer': ['on sport court'],
#   'id': 148,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1602'},
#  {'answer': ['standing'],
#   'id': 149,
#   'question': 'is the athlete in the video standing or sitting',
#   'video_name': 'ZJL1602'},
#  {'answer': ['hanging on wall'],
#   'id': 150,
#   'question': 'where is the tv in the video',
#   'video_name': 'ZJL430'},
#  {'answer': ['blue', 'light blue'],
#   'id': 151,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': ['walking'],
#   'id': 152,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL430'},
#  {'answer': ['benches'],
#   'id': 153,
#   'question': 'where is the boy sitting in the video',
#   'video_name': 'ZJL430'},
#  {'answer': ['standing'],
#   'id': 154,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL430'},
#  {'answer': ['plates', 'watches', 'flour'],
#   'id': 155,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['green'],
#   'id': 156,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['taking things', 'pouring things'],
#   'id': 157,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': ['kitchen'],
#   'id': 158,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['standing'],
#   'id': 159,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2863'},
#  {'answer': ['long hair'],
#   'id': 160,
#   'question': 'does the person has long hair or short hair in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['white'],
#   'id': 161,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['washing hands'],
#   'id': 162,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['on cabinet'],
#   'id': 163,
#   'question': 'where is the towel',
#   'video_name': 'ZJL3470'},
#  {'answer': ['standing'],
#   'id': 164,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3470'},
#  {'answer': ['cummerbund'],
#   'id': 165,
#   'question': 'what does the person in video hold',
#   'video_name': 'ZJL2593'},
#  {'answer': ['purple', 'rose red', 'purple red'],
#   'id': 166,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['circle'],
#   'id': 167,
#   'question': 'what is the shape of the decorative ribbon in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['left hand'],
#   'id': 168,
#   'question': 'which hand of the people in video picked up the ribbon',
#   'video_name': 'ZJL2593'},
#  {'answer': ['standing'],
#   'id': 169,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['wheelchair', 'desk', 'chair'],
#   'id': 170,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': ['red'],
#   'id': 171,
#   'question': 'what color clothes does the person sitting on a wheelchair wear',
#   'video_name': 'ZJL842'},
#  {'answer': ['hospital'],
#   'id': 172,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL842'},
#  {'answer': ['talking', 'fetching things'],
#   'id': 173,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': ['standing'],
#   'id': 174,
#   'question': 'is the person wearing white clothes in the video sitting or standing',
#   'video_name': 'ZJL842'},
#  {'answer': ['clothes', 'boxes', 'hangers'],
#   'id': 175,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['indoor', 'in house', 'in bedroom'],
#   'id': 176,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['blue', 'dark blue', 'blue-black'],
#   'id': 177,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['standing'],
#   'id': 178,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3134'},
#  {'answer': ['took stuffs', 'closed wardrobe', 'turned off light'],
#   'id': 179,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': ['cabinet', 'hearth', 'waste container'],
#   'id': 180,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': ['red', 'true red', 'jacinth'],
#   'id': 181,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': ['playing phone', 'watching phone', 'opening refrigerator'],
#   'id': 182,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['indoor', 'kitchen', 'residence'],
#   'id': 183,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['standing'],
#   'id': 184,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['wardrobe', 'clothing', 'hangers'],
#   'id': 185,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['brown', 'gray-black', 'dark gray'],
#   'id': 186,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['displaying boxes', 'cleaning out closet', 'placing boxes'],
#   'id': 187,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['indoor', 'in house', 'in bedroom'],
#   'id': 188,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['standing'],
#   'id': 189,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3144'},
#  {'answer': ['black', 'dark black', 'ash black'],
#   'id': 190,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': ['standing'],
#   'id': 191,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['writing'],
#   'id': 192,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['yellow', 'golden', 'orange'],
#   'id': 193,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['clothes'],
#   'id': 194,
#   'question': 'what is hanging on the wall of video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['close stool', 'tissue', 'shower gel'],
#   'id': 195,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': ['red', 'tangerine', 'scarlet'],
#   'id': 196,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': ['reading books', 'putting down book', 'making machine'],
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': ['toilet'],
#   'id': 198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': ['sitting'],
#   'id': 199,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1874'},
#  {'answer': ['pen', 'round', 'monkey'],
#   'id': 200,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['brown'],
#   'id': 201,
#   'question': 'what color is the round in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['moving'],
#   'id': 202,
#   'question': 'what is the round doing in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['snowfield'],
#   'id': 203,
#   'question': 'where is the monkey in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['six'],
#   'id': 204,
#   'question': 'how many letters are there in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['chair', 'cabinet', 'cup'],
#   'id': 205,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': ['yellow', 'light yellow', 'orange'],
#   'id': 206,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': ['shaking towel', 'putting towel', 'drinking water'],
#   'id': 207,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3896'},
#  {'answer': ['indoor', 'in living room', 'in house'],
#   'id': 208,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3896'},
#  {'answer': ['standing'],
#   'id': 209,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3896'},
#  {'answer': ['straw'],
#   'id': 210,
#   'question': 'what is in the cup in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['on bath crock'],
#   'id': 211,
#   'question': 'where is the cup in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['green', 'apple green', 'emerald green'],
#   'id': 212,
#   'question': 'what color is the wall space in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['taking bath'],
#   'id': 213,
#   'question': 'what is the woman doing in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['lying'],
#   'id': 214,
#   'question': 'is the woman in video standing or lying down',
#   'video_name': 'ZJL2665'},
#  {'answer': ['game scene'],
#   'id': 215,
#   'question': 'what is the scene in the video',
#   'video_name': 'ZJL2252'},
#  {'answer': ['black'],
#   'id': 216,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2252'},
#  {'answer': ['talking', 'playing games', 'wiping mouth'],
#   'id': 217,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2252'},
#  {'answer': ['earphones'],
#   'id': 218,
#   'question': 'what does the person in the video wear on the head',
#   'video_name': 'ZJL2252'},
#  {'answer': ['right hand'],
#   'id': 219,
#   'question': 'which hand does the person in the video use to wipe the mouth',
#   'video_name': 'ZJL2252'},
#  {'answer': ['chair', 'protective hood', 'whistle'],
#   'id': 220,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['black'],
#   'id': 221,
#   'question': 'what color is the trousers worn by the referee in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['watching game'],
#   'id': 222,
#   'question': 'what are the audience in the video doing',
#   'video_name': 'ZJL2817'},
#  {'answer': ['auditorium'],
#   'id': 223,
#   'question': 'where is the audience in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['standing'],
#   'id': 224,
#   'question': 'is the referee in the video sitting or standing',
#   'video_name': 'ZJL2817'},
#  {'answer': ['cartoon'],
#   'id': 225,
#   'question': 'what is on video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['car'],
#   'id': 226,
#   'question': 'what did the character drive to the river in video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['in river'],
#   'id': 227,
#   'question': 'where did the character in video push the car into',
#   'video_name': 'ZJL2596'},
#  {'answer': ['tree', 'lawn'],
#   'id': 228,
#   'question': 'what is on either side of the street in video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['green', 'dark green'],
#   'id': 229,
#   'question': 'what color pants did the big guy in video wear',
#   'video_name': 'ZJL2596'},
#  {'answer': ['necklace'],
#   'id': 230,
#   'question': 'what does the woman wear around her neck in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['black'],
#   'id': 231,
#   'question': 'what color of the clothes does the woman wear in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['dancing', 'running', 'picking flowers'],
#   'id': 232,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['on ground'],
#   'id': 233,
#   'question': 'where is the flower in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['standing'],
#   'id': 234,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['woman', 'child', 'man'],
#   'id': 235,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['pale pink'],
#   'id': 236,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['going to supermarket'],
#   'id': 237,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['next to shelf'],
#   'id': 238,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['standing'],
#   'id': 239,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1499'},
#  {'answer': ['quilt', 'sheets', 'pillow'],
#   'id': 240,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL2204'},
#  {'answer': ['black'],
#   'id': 241,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2204'},
#  {'answer': ['taking cup', 'drinking water', 'drawing curtain'],
#   'id': 242,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2204'},
#  {'answer': ['indoor', 'residence', 'bedroom'],
#   'id': 243,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2204'},
#  {'answer': ['lying'],
#   'id': 244,
#   'question': 'is the person in the video standing or lying',
#   'video_name': 'ZJL2204'},
#  {'answer': ['right hand'],
#   'id': 245,
#   'question': 'in which hand does the person hold the cellphone in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['dark blue'],
#   'id': 246,
#   'question': 'what color of the pants does the person wear in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['making phone call'],
#   'id': 247,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['on stairs'],
#   'id': 248,
#   'question': 'where is the person making a phone call in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['standing', 'sitting'],
#   'id': 249,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['boat'],
#   'id': 250,
#   'question': 'what is in the video',
#   'video_name': 'ZJL268'},
#  {'answer': ['yellow', 'white', 'red'],
#   'id': 251,
#   'question': 'what color is the light in the first scene',
#   'video_name': 'ZJL268'},
#  {'answer': ['visiting'],
#   'id': 252,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL268'},
#  {'answer': ['standing'],
#   'id': 253,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL268'},
#  {'answer': ['exhibition hall'],
#   'id': 254,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL268'},
#  {'answer': ['desk', 'cup', 'camera'],
#   'id': 255,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['gray', 'light gray', 'off white'],
#   'id': 256,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['getting camera', 'walking', 'turning head looking'],
#   'id': 257,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 258,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['standing'],
#   'id': 259,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1066'},
#  {'answer': ['table tennis bat'],
#   'id': 260,
#   'question': 'what is in the hand of the person in the video',
#   'video_name': 'ZJL258'},
#  {'answer': ['black', 'white', 'blue'],
#   'id': 261,
#   'question': 'what color pants does the person in red wear',
#   'video_name': 'ZJL258'},
#  {'answer': ['playing pingpong'],
#   'id': 262,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL258'},
#  {'answer': ['standing'],
#   'id': 263,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL258'},
#  {'answer': ['court', 'cour'],
#   'id': 264,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL258'},
#  {'answer': ['table', 'chair', 'microphone'],
#   'id': 265,
#   'question': 'what is in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['black'],
#   'id': 266,
#   'question': 'what color is the microphone in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['speaking'],
#   'id': 267,
#   'question': 'what is the person wearing purple tie doing in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['before microphone'],
#   'id': 268,
#   'question': 'where is the person with a purple tie in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['standing'],
#   'id': 269,
#   'question': 'is the person wearing the purple tie standing or sitting',
#   'video_name': 'ZJL806'},
#  {'answer': ['person'],
#   'id': 270,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL1549'},
#  {'answer': ['red', 'white', 'grey'],
#   'id': 271,
#   'question': 'what color does the person wear',
#   'video_name': 'ZJL1549'},
#  {'answer': ['sleeping'],
#   'id': 272,
#   'question': 'what is the woman in white doing',
#   'video_name': 'ZJL1549'},
#  {'answer': ['home'],
#   'id': 273,
#   'question': 'where is the woman in white',
#   'video_name': 'ZJL1549'},
#  {'answer': ['standing'],
#   'id': 274,
#   'question': 'is the person in white standing or sitting',
#   'video_name': 'ZJL1549'},
#  {'answer': ['shelf'],
#   'id': 275,
#   'question': 'what is the person pushing over in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['white', 'beige', 'gray white'],
#   'id': 276,
#   'question': 'what is the color of the building in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['fighting'],
#   'id': 277,
#   'question': 'what is the robot doing in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['hat'],
#   'id': 278,
#   'question': 'what is the person wearing on his head in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['standing'],
#   'id': 279,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1752'},
#  {'answer': ['skeleton'],
#   'id': 280,
#   'question': 'what is the white thing in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['dancing'],
#   'id': 281,
#   'question': 'what is the skeleton doing in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['three'],
#   'id': 282,
#   'question': 'how many skulls are in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['in game'],
#   'id': 283,
#   'question': 'where is the skeleton in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['pink', 'pink-red'],
#   'id': 284,
#   'question': "what color is the skull on the man's finger in the video",
#   'video_name': 'ZJL2470'},
#  {'answer': ['guitar'],
#   'id': 285,
#   'question': 'what do the person in the video have in his hand',
#   'video_name': 'ZJL817'},
#  {'answer': ['fifty three', 'five three'],
#   'id': 286,
#   'question': "what is the number on the person's clothes in the video",
#   'video_name': 'ZJL817'},
#  {'answer': ['short sleeves'],
#   'id': 287,
#   'question': "does the person's clothes in the video is short sleeves or long sleeves",
#   'video_name': 'ZJL817'},
#  {'answer': ['playing guitar'],
#   'id': 288,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL817'},
#  {'answer': ['sitting'],
#   'id': 289,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL817'},
#  {'answer': ['knife', 'pot', 'cup'],
#   'id': 290,
#   'question': 'what is on the countertop',
#   'video_name': 'ZJL4258'},
#  {'answer': ['white', 'beige white', 'milk white'],
#   'id': 291,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4258'},
#  {'answer': ['pouring water', 'putting cup', 'taking off shoes'],
#   'id': 292,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4258'},
#  {'answer': ['kitchen', 'indoor', 'in room'],
#   'id': 293,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4258'},
#  {'answer': ['standing'],
#   'id': 294,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4258'},
#  {'answer': ['male'],
#   'id': 295,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['blue'],
#   'id': 296,
#   'question': 'what color is the pants worn by the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['hand standing'],
#   'id': 297,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['indoor'],
#   'id': 298,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['english'],
#   'id': 299,
#   'question': 'is the text in the video english or chinese',
#   'video_name': 'ZJL1196'},
#  {'answer': ['two'],
#   'id': 300,
#   'question': 'how many people appeared in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['navy blue', 'dark blue', 'blue black'],
#   'id': 301,
#   'question': 'what color does the thinner man wear in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['wiping his hair'],
#   'id': 302,
#   'question': 'what is the fat man in the video doing',
#   'video_name': 'ZJL463'},
#  {'answer': ['on ground'],
#   'id': 303,
#   'question': 'where is the broom in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['sitting'],
#   'id': 304,
#   'question': 'are the two men in the video standing or sitting',
#   'video_name': 'ZJL463'},
#  {'answer': ['bottle', 'fruits', 'plastic case'],
#   'id': 305,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 306,
#   'question': 'what is the color of the refrigerator in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['searching refrigerator', 'rotating disc', 'taking plastic case'],
#   'id': 307,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['indoor', 'inside house', 'kitchen'],
#   'id': 308,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['standing'],
#   'id': 309,
#   'question': 'is the person standing or sitting at the beginning of the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['computer', 'table', 'television'],
#   'id': 310,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3029'},
#  {'answer': ['brown', 'dark brown', 'brownish yellow'],
#   'id': 311,
#   'question': "what is the color of the person's hair in the video",
#   'video_name': 'ZJL3029'},
#  {'answer': ['looking at computer', 'watching videos', 'wiping nose'],
#   'id': 312,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3029'},
#  {'answer': ['indoor', 'residence', 'bedroom'],
#   'id': 313,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3029'},
#  {'answer': ['sitting'],
#   'id': 314,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3029'},
#  {'answer': ['left hand'],
#   'id': 315,
#   'question': 'is the person in the video extending the left or right hand',
#   'video_name': 'ZJL1746'},
#  {'answer': ['white'],
#   'id': 316,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL1746'},
#  {'answer': ['reaching out'],
#   'id': 317,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1746'},
#  {'answer': ['short hair'],
#   'id': 318,
#   'question': 'is the person in the video long hair or short hair',
#   'video_name': 'ZJL1746'},
#  {'answer': ['sitting'],
#   'id': 319,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1746'},
#  {'answer': ['two'],
#   'id': 320,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2767'},
#  {'answer': ['eating'],
#   'id': 321,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2767'},
#  {'answer': ['blue', 'gray'],
#   'id': 322,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL2767'},
#  {'answer': ['kitchen'],
#   'id': 323,
#   'question': 'where are the two people in the video',
#   'video_name': 'ZJL2767'},
#  {'answer': ['stools'],
#   'id': 324,
#   'question': 'what is in front of the person wearing pink clothes in the video',
#   'video_name': 'ZJL2767'},
#  {'answer': ['tellurion', 'book', 'vase'],
#   'id': 325,
#   'question': 'what is on the table',
#   'video_name': 'ZJL292'},
#  {'answer': ['green', 'white', 'blue'],
#   'id': 326,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL292'},
#  {'answer': ['talking', 'wearing glasses', 'posing'],
#   'id': 327,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL292'},
#  {'answer': ['standing'],
#   'id': 328,
#   'question': 'is the person in video standing or sitting at the end',
#   'video_name': 'ZJL292'},
#  {'answer': ['room'],
#   'id': 329,
#   'question': 'where is the person in the video at the beginning',
#   'video_name': 'ZJL292'},
#  {'answer': ['bed', 'laptop', 'sheet'],
#   'id': 330,
#   'question': 'what is in the room',
#   'video_name': 'ZJL646'},
#  {'answer': ['black'],
#   'id': 331,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL646'},
#  {'answer': ['eating biscuits'],
#   'id': 332,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL646'},
#  {'answer': ['on table'],
#   'id': 333,
#   'question': 'where is the laptop',
#   'video_name': 'ZJL646'},
#  {'answer': ['sitting'],
#   'id': 334,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL646'},
#  {'answer': ['computer', 'phone', 'mouse'],
#   'id': 335,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3111'},
#  {'answer': ['blue', 'dark-blue', 'black-blue'],
#   'id': 336,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3111'},
#  {'answer': ['watching video', 'playing computer', 'watching movie'],
#   'id': 337,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3111'},
#  {'answer': ['in door', 'in bedroom', 'house'],
#   'id': 338,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3111'},
#  {'answer': ['sitting'],
#   'id': 339,
#   'question': 'is the man sitting or standing in the video',
#   'video_name': 'ZJL3111'},
#  {'answer': ['small tree'],
#   'id': 340,
#   'question': 'what is behind the person in the video',
#   'video_name': 'ZJL2308'},
#  {'answer': ['beige', 'grey', 'beige grey'],
#   'id': 341,
#   'question': 'what color top does the person in the video wear',
#   'video_name': 'ZJL2308'},
#  {'answer': ['talking',
#    'right hand to do operation',
#    'left hand to put right arm'],
#   'id': 342,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2308'},
#  {'answer': ['dumbbell'],
#   'id': 343,
#   'question': 'what did the person in the video take',
#   'video_name': 'ZJL2308'},
#  {'answer': ['sitting'],
#   'id': 344,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2308'},
#  {'answer': ['on grass'],
#   'id': 345,
#   'question': 'where is the animal in video',
#   'video_name': 'ZJL2606'},
#  {'answer': ['alpaca'],
#   'id': 346,
#   'question': 'what is in video',
#   'video_name': 'ZJL2606'},
#  {'answer': ['white', 'black', 'brown'],
#   'id': 347,
#   'question': 'what color does the alpaca in video have',
#   'video_name': 'ZJL2606'},
#  {'answer': ['going ahead'],
#   'id': 348,
#   'question': 'what are the alpacas doing in video',
#   'video_name': 'ZJL2606'},
#  {'answer': ['standing'],
#   'id': 349,
#   'question': 'is the alpaca standing or sitting in video',
#   'video_name': 'ZJL2606'},
#  {'answer': ['close stool', 'hanger', 'mirror'],
#   'id': 350,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL2102'},
#  {'answer': ['purple', 'deep purple', 'purplish black'],
#   'id': 351,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL2102'},
#  {'answer': ['pouring water', 'cleaning close stool', 'cleaning floor'],
#   'id': 352,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2102'},
#  {'answer': ['indoor', 'residence', 'toilet'],
#   'id': 353,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2102'},
#  {'answer': ['standing'],
#   'id': 354,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2102'},
#  {'answer': ['plate', 'bottle', 'glass bowl'],
#   'id': 355,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL1085'},
# ...
#   'video_name': 'ZJL2601'},
#  {'answer': ['mirror', 'socket', 'cup'],
#   'id': 885,
#   'question': 'what is in the room',
#   'video_name': 'ZJL692'},
#  {'answer': ['black'],
#   'id': 886,
#   'question': 'what color of the pants does the person wear in the video',
#   'video_name': 'ZJL692'},
#  {'answer': ['drinking beverage'],
#   'id': 887,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL692'},
#  {'answer': ['on wall'],
#   'id': 888,
#   'question': 'where is the mirror',
#   'video_name': 'ZJL692'},
#  {'answer': ['standing'],
#   'id': 889,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL692'},
#  {'answer': ['sewing machine', 'basin', 'newspaper'],
#   'id': 890,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1027'},
#  {'answer': ['blue', 'smalt', 'marine blue'],
#   'id': 891,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL1027'},
#  {'answer': ['wiping nose', 'getting bag', 'finding things'],
#   'id': 892,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1027'},
#  {'answer': ['indoor', 'inside house', 'in living room'],
#   'id': 893,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1027'},
#  {'answer': ['lying'],
#   'id': 894,
#   'question': 'is the person in the video sitting or lying at first',
#   'video_name': 'ZJL1027'},
#  {'answer': ['hat'],
#   'id': 895,
#   'question': 'what does the woman wear on head in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['white'],
#   'id': 896,
#   'question': 'what color of the clothes does the woman wear in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['speaking'],
#   'id': 897,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['on head'],
#   'id': 898,
#   'question': 'where is the bamboo hat in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['kneeling'],
#   'id': 899,
#   'question': 'is the woman standing or kneeling in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['bottle', 'display', 'doll'],
#   'id': 900,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1101'},
#  {'answer': ['black', 'aterrimus', 'furvous'],
#   'id': 901,
#   'question': 'what color coat does the person wear in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['taking on clothes', 'sitting down', 'folding blanket'],
#   'id': 902,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 903,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['standing'],
#   'id': 904,
#   'question': 'is the person in the video sitting or standing at first',
#   'video_name': 'ZJL1101'},
#  {'answer': ['tabletop'],
#   'id': 905,
#   'question': 'where is the machine in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': ['blue', 'dark blue', 'sky blue'],
#   'id': 906,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': ['introducing product'],
#   'id': 907,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2232'},
#  {'answer': ['machine part'],
#   'id': 908,
#   'question': 'what is in the bag',
#   'video_name': 'ZJL2232'},
#  {'answer': ['standing'],
#   'id': 909,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2232'},
#  {'answer': ['tattoo'],
#   'id': 910,
#   'question': "what is on the woman's arm in the video",
#   'video_name': 'ZJL472'},
#  {'answer': ['blue', 'light blue', 'sky blue'],
#   'id': 911,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL472'},
#  {'answer': ['turning on lights', 'placing items'],
#   'id': 912,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL472'},
#  {'answer': ['drawer'],
#   'id': 913,
#   'question': 'where is the woman in the video putting the clothes',
#   'video_name': 'ZJL472'},
#  {'answer': ['standing'],
#   'id': 914,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL472'},
#  {'answer': ['gray', 'light gray', 'ash black'],
#   'id': 915,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['standing'],
#   'id': 916,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['opening'],
#   'id': 917,
#   'question': 'is the lamp opening or closed in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['carton', 'air fan', 'television'],
#   'id': 918,
#   'question': 'what is in the room',
#   'video_name': 'ZJL1009'},
#  {'answer': ['cleaning up goods', 'picking up things', 'sorting things'],
#   'id': 919,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['blankets'],
#   'id': 920,
#   'question': 'what does the man in the video hold in his right hand',
#   'video_name': 'ZJL459'},
#  {'answer': ['gray', 'light gray'],
#   'id': 921,
#   'question': 'what color do men wear in the video',
#   'video_name': 'ZJL459'},
#  {'answer': ['selfie', 'self-timer'],
#   'id': 922,
#   'question': 'what are the men in the video doing',
#   'video_name': 'ZJL459'},
#  {'answer': ['tie'],
#   'id': 923,
#   'question': 'what is the man wearing on the neck in the video',
#   'video_name': 'ZJL459'},
#  {'answer': ['standing'],
#   'id': 924,
#   'question': 'the man in the video is standing or sitting',
#   'video_name': 'ZJL459'},
#  {'answer': ['glasses'],
#   'id': 925,
#   'question': 'what is on the face of the person wearing purple clothes',
#   'video_name': 'ZJL726'},
#  {'answer': ['gray', 'light grey', 'dark grey'],
#   'id': 926,
#   'question': 'what color is the chair in the video',
#   'video_name': 'ZJL726'},
#  {'answer': ['chatting'],
#   'id': 927,
#   'question': 'what is the person in purple doing',
#   'video_name': 'ZJL726'},
#  {'answer': ['in car'],
#   'id': 928,
#   'question': 'where is the person in purple',
#   'video_name': 'ZJL726'},
#  {'answer': ['sitting'],
#   'id': 929,
#   'question': 'is the person wearing the purple dress standing or sitting',
#   'video_name': 'ZJL726'},
#  {'answer': ['tablecloth', 'white paper', 'electric wire'],
#   'id': 930,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1030'},
#  {'answer': ['blue', 'smalt', 'marine blue'],
#   'id': 931,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['placing box', 'fetching newspaper', 'brush wall'],
#   'id': 932,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 933,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['standing'],
#   'id': 934,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1030'},
#  {'answer': ['curly'],
#   'id': 935,
#   'question': 'is the hair of the man in the video straight or curly',
#   'video_name': 'ZJL611'},
#  {'answer': ['blue', 'dark blue', 'ancient blue'],
#   'id': 936,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL611'},
#  {'answer': ['watching computer', 'writing'],
#   'id': 937,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL611'},
#  {'answer': ['on table'],
#   'id': 938,
#   'question': 'where is the muppet in the video',
#   'video_name': 'ZJL611'},
#  {'answer': ['sitting'],
#   'id': 939,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL611'},
#  {'answer': ['blanket', 'carpet'],
#   'id': 940,
#   'question': 'what is on the sofa in the video',
#   'video_name': 'ZJL1894'},
#  {'answer': ['pure black', 'dark black', 'black'],
#   'id': 941,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1894'},
#  {'answer': ['eating things', 'watching tv', 'drinking water'],
#   'id': 942,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1894'},
#  {'answer': ['on tea table'],
#   'id': 943,
#   'question': 'where does the person in the video take the water cup',
#   'video_name': 'ZJL1894'},
#  {'answer': ['sitting', 'standing'],
#   'id': 944,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1894'},
#  {'answer': ['chair', 'table', 'vacuum cleaner'],
#   'id': 945,
#   'question': 'what is in front of the cabinet',
#   'video_name': 'ZJL3210'},
#  {'answer': ['gray', 'light gray', 'grayish white'],
#   'id': 946,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['doing cleaning', 'putting clothes on', 'cleaning away rubbish'],
#   'id': 947,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['indoor', 'in house', 'in kitchen'],
#   'id': 948,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['standing'],
#   'id': 949,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3210'},
#  {'answer': ['shoes', 'chair', 'table'],
#   'id': 950,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3966'},
#  {'answer': ['yellow', 'grass yellow', 'light yellow'],
#   'id': 951,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3966'},
#  {'answer': ['taking cup', 'drinking water', 'putting down cup'],
#   'id': 952,
#   'question': 'what is the person in white doing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['indoor', 'in living room', 'in house'],
#   'id': 953,
#   'question': 'where is the person in red in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['sitting'],
#   'id': 954,
#   'question': 'is the person in red sitting or standing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['curtain', 'chair', 'table'],
#   'id': 955,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL4059'},
#  {'answer': ['pink', 'flesh color'],
#   'id': 956,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL4059'},
#  {'answer': ['fixing things up', 'drinking water', 'fixing furnitures'],
#   'id': 957,
#   'question': 'what is the person in white doing',
#   'video_name': 'ZJL4059'},
#  {'answer': ['indoors', 'in house', 'in living room'],
#   'id': 958,
#   'question': 'where is the person in white',
#   'video_name': 'ZJL4059'},
#  {'answer': ['standing'],
#   'id': 959,
#   'question': 'is the person in white standing or sitting',
#   'video_name': 'ZJL4059'},
#  {'answer': ['left'],
#   'id': 960,
#   'question': 'which hand of the person in the video holds the clothes when he takes it off',
#   'video_name': 'ZJL349'},
#  {'answer': ['dark green', 'green', 'tibet green'],
#   'id': 961,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL349'},
#  {'answer': ['taking off clothes', 'getting cup'],
#   'id': 962,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL349'},
#  {'answer': ['cup'],
#   'id': 963,
#   'question': 'what does the person have in the right hand',
#   'video_name': 'ZJL349'},
#  {'answer': ['standing'],
#   'id': 964,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL349'},
#  {'answer': ['fan'],
#   'id': 965,
#   'question': 'what is placed on the right side of the person in the video',
#   'video_name': 'ZJL2271'},
#  {'answer': ['grey', 'greyish white', 'light grey'],
#   'id': 966,
#   'question': 'what color top does the person in the video wear',
#   'video_name': 'ZJL2271'},
#  {'answer': ['playing mobile phone'],
#   'id': 967,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2271'},
#  {'answer': ['left hand'],
#   'id': 968,
#   'question': 'which hand of the person in the video puts on the mouth',
#   'video_name': 'ZJL2271'},
#  {'answer': ['sitting'],
#   'id': 969,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2271'},
#  {'answer': ['in room'],
#   'id': 970,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL327'},
#  {'answer': ['blue', 'sky blue', 'ocean blue'],
#   'id': 971,
#   'question': "what color is the person's pants in the video",
#   'video_name': 'ZJL327'},
#  {'answer': ['sleeping', 'lifting his head', 'taking off his pants'],
#   'id': 972,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL327'},
#  {'answer': ['pillow'],
#   'id': 973,
#   'question': "what covers the person's face in the video",
#   'video_name': 'ZJL327'},
#  {'answer': ['sitting'],
#   'id': 974,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL327'},
#  {'answer': ['male'],
#   'id': 975,
#   'question': 'what is the gender of the person with weapon in the video',
#   'video_name': 'ZJL859'},
#  {'answer': ['opening'],
#   'id': 976,
#   'question': 'is the city gate in the video opening or closed',
#   'video_name': 'ZJL859'},
#  {'answer': ['grenade'],
#   'id': 977,
#   'question': 'what is hanging on the waist of the person in the video',
#   'video_name': 'ZJL859'},
#  {'answer': ['scorpion'],
#   'id': 978,
#   'question': 'what animal icon appeared in the video at the beginning',
#   'video_name': 'ZJL859'},
#  {'answer': ['english'],
#   'id': 979,
#   'question': 'is the text in the video written in english or chinese',
#   'video_name': 'ZJL859'},
#  {'answer': ['computer', 'book', 'cup'],
#   'id': 980,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1675'},
#  {'answer': ['red'],
#   'id': 981,
#   'question': 'what is the color of the clothes in the video',
#   'video_name': 'ZJL1675'},
#  {'answer': ['eating'],
#   'id': 982,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1675'},
#  {'answer': ['long hair'],
#   'id': 983,
#   'question': 'is the person in the video long hair or short hair',
#   'video_name': 'ZJL1675'},
#  {'answer': ['sitting'],
#   'id': 984,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1675'},
#  {'answer': ['ball', 'pillar', 'handcart'],
#   'id': 985,
#   'question': 'what is on the floor',
#   'video_name': 'ZJL3380'},
#  {'answer': ['yellow', 'earthy yellow', 'claybank'],
#   'id': 986,
#   'question': 'what is the color of the floor in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['playing games', 'taking exercise', 'exercising'],
#   'id': 987,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['indoor', 'public place', 'gymnasium'],
#   'id': 988,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['standing'],
#   'id': 989,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['laptop', 'remote control', 'mouse'],
#   'id': 990,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1090'},
#  {'answer': ['blue', 'smalt', 'marine blue'],
#   'id': 991,
#   'question': 'what color clothes does the standing person wear in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['entering door', 'watching tv', 'moving chair'],
#   'id': 992,
#   'question': 'what is the standing person doing in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['indoor', 'inside house', 'in bedroom'],
#   'id': 993,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['sitting'],
#   'id': 994,
#   'question': 'is the person holding the phone in the video sitting or standing',
#   'video_name': 'ZJL1090'},
#  {'answer': ['wall painting', 'television', 'socket'],
#   'id': 995,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3473'},
#  {'answer': ['purple', 'modena', 'fuchsia'],
#   'id': 996,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': ['walking'],
#   'id': 997,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': ['on wall'],
#   'id': 998,
#   'question': 'where is the tv',
#   'video_name': 'ZJL3473'},
#  {'answer': ['standing'],
#   'id': 999,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3473'},
#  ...]

# %%
data_list_new=[]
data_new={}
id=-1
for data in data_list:
    for i in range(len(data["answer"])):
        id+=1
        data_new["question"]=data["question"]
        data_new["video_name"]=data["video_name"]
        data_new["id"]=id
        data_new["answer"]=data["answer"][i]
        data_list_new.append(data_new)
        data_new={}

# %%
data_list_new
# Out:
# [{'answer': 'mirror',
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'pool',
#   'id': 1,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'shelf',
#   'id': 2,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'blue',
#   'id': 3,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'dark blue',
#   'id': 4,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'black blue',
#   'id': 5,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'cleaning up',
#   'id': 6,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'wiping mirror',
#   'id': 7,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washing cup',
#   'id': 8,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'indoor',
#   'id': 9,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washroom',
#   'id': 10,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'residence',
#   'id': 11,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'standing',
#   'id': 12,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'white',
#   'id': 13,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'kissing',
#   'id': 14,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'lying',
#   'id': 15,
#   'question': 'is the person sitting or lying in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'on bed',
#   'id': 16,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'long hair',
#   'id': 17,
#   'question': 'does the woman have long hair or short hair in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'white',
#   'id': 18,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'light white',
#   'id': 19,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'pure white',
#   'id': 20,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'standing',
#   'id': 21,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'sitting',
#   'id': 22,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'kitchen',
#   'id': 23,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking water',
#   'id': 24,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking milk',
#   'id': 25,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'on table',
#   'id': 26,
#   'question': 'where is the book',
#   'video_name': 'ZJL963'},
#  {'answer': 'third',
#   'id': 27,
#   'question': 'which layer of the cabinet is the water cup put in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pure black',
#   'id': 28,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'black',
#   'id': 29,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'dark black',
#   'id': 30,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'opening cabinet',
#   'id': 31,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'drinking water',
#   'id': 32,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'cabinet',
#   'id': 33,
#   'question': 'where did the person get the cup',
#   'video_name': 'ZJL1836'},
#  {'answer': 'standing',
#   'id': 34,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pink',
#   'id': 35,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'light-pink',
#   'id': 36,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'peach-pink',
#   'id': 37,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'broadcasting',
#   'id': 38,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'entertainment',
#   'id': 39,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'new',
#   'id': 40,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'swimsuit',
#   'id': 41,
#   'question': 'what does the super star wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'in water',
#   'id': 42,
#   'question': 'where is the superstar in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'standing',
#   'id': 43,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'tv',
#   'id': 44,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'sofa',
#   'id': 45,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'table',
#   'id': 46,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'white',
#   'id': 47,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'milk white',
#   'id': 48,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'off-white',
#   'id': 49,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'pushing tv button',
#   'id': 50,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in living room',
#   'id': 51,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'indoor',
#   'id': 52,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in room',
#   'id': 53,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'standing',
#   'id': 54,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'book',
#   'id': 55,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'phone',
#   'id': 56,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'computer',
#   'id': 57,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'black',
#   'id': 58,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'white',
#   'id': 59,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'blue',
#   'id': 60,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'taking clothes',
#   'id': 61,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'clearing up',
#   'id': 62,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'playing phone',
#   'id': 63,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'standing',
#   'id': 64,
#   'question': 'was the man standing or sitting in the end',
#   'video_name': 'ZJL2952'},
#  {'answer': 'in door',
#   'id': 65,
#   'question': 'where is the man',
#   'video_name': 'ZJL2952'},
#  {'answer': 'brown',
#   'id': 66,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'light brown',
#   'id': 67,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'rustic brown',
#   'id': 68,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'standing',
#   'id': 69,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'bathroom',
#   'id': 70,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'looking at mirror',
#   'id': 71,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'taking off clothes',
#   'id': 72,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'wiping arms',
#   'id': 73,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'on shelf',
#   'id': 74,
#   'question': 'where is the towel',
#   'video_name': 'ZJL927'},
#  {'answer': 'schoolbag',
#   'id': 75,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'mobile phone',
#   'id': 76,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'pillow',
#   'id': 77,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'green',
#   'id': 78,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'light green',
#   'id': 79,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'dark green',
#   'id': 80,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'holding pillow',
#   'id': 81,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'room',
#   'id': 82,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'sitting',
#   'id': 83,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'daytime',
#   'id': 84,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'morning',
#   'id': 85,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'white',
#   'id': 86,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'milk white',
#   'id': 87,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'creamy white',
#   'id': 88,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking selfie',
#   'id': 89,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'photographing',
#   'id': 90,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking photos',
#   'id': 91,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'outdoor',
#   'id': 92,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'suburb',
#   'id': 93,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'in car',
#   'id': 94,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'sitting',
#   'id': 95,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'woman',
#   'id': 96,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'man',
#   'id': 97,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sofa',
#   'id': 98,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'beige',
#   'id': 99,
#   'question': 'what color is the sofa in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'talking',
#   'id': 100,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'in room',
#   'id': 101,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'standing',
#   'id': 102,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sitting',
#   'id': 103,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'black',
#   'id': 104,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'white',
#   'id': 105,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'dark blue',
#   'id': 106,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'sitting',
#   'id': 107,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'reading book',
#   'id': 108,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'kitchen',
#   'id': 109,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'on table',
#   'id': 110,
#   'question': 'where is the water bottle in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'photograph',
#   'id': 111,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'cup',
#   'id': 112,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'basket',
#   'id': 113,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'black',
#   'id': 114,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'drinking water',
#   'id': 115,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'in stairwell',
#   'id': 116,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'standing',
#   'id': 117,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3443'},
#  {'answer': 'closet',
#   'id': 118,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'chair',
#   'id': 119,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'tv',
#   'id': 120,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'black',
#   'id': 121,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'dark black',
#   'id': 122,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'aterrimus',
#   'id': 123,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'opening door',
#   'id': 124,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'putting towel',
#   'id': 125,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'sneezing',
#   'id': 126,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'indoor',
#   'id': 127,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'living room',
#   'id': 128,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'residence',
#   'id': 129,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'standing',
#   'id': 130,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'computer',
#   'id': 131,
#   'question': 'what is on the cabinet in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'white',
#   'id': 132,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL578'},
#  {'answer': 'eating things',
#   'id': 133,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'playing computer',
#   'id': 134,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'kitchen',
#   'id': 135,
#   'question': 'in which room is the woman in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 136,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 137,
#   'question': 'is the person wearing pink in the video standing or sitting',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating something',
#   'id': 138,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating food',
#   'id': 139,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bedroom',
#   'id': 140,
#   'question': 'where is the person wearing pink in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bed',
#   'id': 141,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'cabinet',
#   'id': 142,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'mirror',
#   'id': 143,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'white',
#   'id': 144,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'light white',
#   'id': 145,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'gray white',
#   'id': 146,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'green',
#   'id': 147,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pale green',
#   'id': 148,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'grass green',
#   'id': 149,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'standing',
#   'id': 150,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'taking off shoes',
#   'id': 151,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'closing door',
#   'id': 152,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'turn on lights',
#   'id': 153,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'long hair',
#   'id': 154,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pink',
#   'id': 155,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'soft red',
#   'id': 156,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'rose',
#   'id': 157,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'cup',
#   'id': 158,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'phone',
#   'id': 159,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'clothes',
#   'id': 160,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'brown',
#   'id': 161,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'yellow',
#   'id': 162,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'golden',
#   'id': 163,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'standing',
#   'id': 164,
#   'question': 'is the man in purple standing or sitting',
#   'video_name': 'ZJL2934'},
#  {'answer': 'in door',
#   'id': 165,
#   'question': 'where is the man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'shoes',
#   'id': 166,
#   'question': 'what is on the outside floor',
#   'video_name': 'ZJL2934'},
#  {'answer': 'green',
#   'id': 167,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'grass green',
#   'id': 168,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'pale green',
#   'id': 169,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'standing',
#   'id': 170,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'kitchen',
#   'id': 171,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'making food',
#   'id': 172,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'sweeping floor',
#   'id': 173,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'eating',
#   'id': 174,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'short hair',
#   'id': 175,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'cabinet',
#   'id': 176,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'mirror',
#   'id': 177,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'clothes',
#   'id': 178,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'pink',
#   'id': 179,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'magenta',
#   'id': 180,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'burgandy',
#   'id': 181,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'looking at mirror',
#   'id': 182,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'putting on clothes',
#   'id': 183,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'buttoning',
#   'id': 184,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'indoor',
#   'id': 185,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in room',
#   'id': 186,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in house',
#   'id': 187,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'standing',
#   'id': 188,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'door',
#   'id': 189,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'television',
#   'id': 190,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'curtain',
#   'id': 191,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'yellow',
#   'id': 192,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'khaki',
#   'id': 193,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'brownish yellow',
#   'id': 194,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'watching tv',
#   'id': 195,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'resting',
#   'id': 196,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'sleeping',
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'indoors',
#   'id': 198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in house',
#   'id': 199,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in bedroom',
#   'id': 200,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'lying on his stomach',
#   'id': 201,
#   'question': 'is the person in the video lying on his stomach or sitting',
#   'video_name': 'ZJL4047'},
#  {'answer': 'chair',
#   'id': 202,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'fence',
#   'id': 203,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'book',
#   'id': 204,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'white',
#   'id': 205,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'milk white',
#   'id': 206,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'creamy white',
#   'id': 207,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'dancing',
#   'id': 208,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'exercising',
#   'id': 209,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'playing',
#   'id': 210,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'outdoor',
#   'id': 211,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'yard',
#   'id': 212,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'at door',
#   'id': 213,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'standing',
#   'id': 214,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'mustache',
#   'id': 215,
#   'question': "what is on the person's face in the video",
#   'video_name': 'ZJL651'},
#  {'answer': 'gray',
#   'id': 216,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'black gray',
#   'id': 217,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'neutral gary',
#   'id': 218,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'eating',
#   'id': 219,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'staircase',
#   'id': 220,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'sitting',
#   'id': 221,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'closet',
#   'id': 222,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'refrigerator',
#   'id': 223,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'pot',
#   'id': 224,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'black',
#   'id': 225,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'dark black',
#   'id': 226,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'aterrimus',
#   'id': 227,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'firing',
#   'id': 228,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'taking things',
#   'id': 229,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'opening refrigerator',
#   'id': 230,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'indoor',
#   'id': 231,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'kitchen',
#   'id': 232,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'residence',
#   'id': 233,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'standing',
#   'id': 234,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'icon',
#   'id': 235,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'website',
#   'id': 236,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'people',
#   'id': 237,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'female',
#   'id': 238,
#   'question': 'is the person in the video a male or a female',
#   'video_name': 'ZJL1115'},
#  {'answer': 'black',
#   'id': 239,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'in water',
#   'id': 240,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'tapping water',
#   'id': 241,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'music score',
#   'id': 242,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'guitar',
#   'id': 243,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'microphone',
#   'id': 244,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple',
#   'id': 245,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'deep purple',
#   'id': 246,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple sauce',
#   'id': 247,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'singing',
#   'id': 248,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'on stage',
#   'id': 249,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'standing',
#   'id': 250,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'boy',
#   'id': 251,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'girl',
#   'id': 252,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'women',
#   'id': 253,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'brown',
#   'id': 254,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'tan',
#   'id': 255,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'coffee',
#   'id': 256,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interviewing',
#   'id': 257,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'talking',
#   'id': 258,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'narrating',
#   'id': 259,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'indoor',
#   'id': 260,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'in room',
#   'id': 261,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interview site',
#   'id': 262,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'sitting',
#   'id': 263,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'mustache',
#   'id': 264,
#   'question': 'what is on the face of the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'white',
#   'id': 265,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'creamy-white',
#   'id': 266,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'ivory-white',
#   'id': 267,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'setting of pillows',
#   'id': 268,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'in living room',
#   'id': 269,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'sitting',
#   'id': 270,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL3506'},
#  {'answer': 'board',
#   'id': 271,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'sponge',
#   'id': 272,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'brush',
#   'id': 273,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'yellow',
#   'id': 274,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'light yellow',
#   'id': 275,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'canary yellow',
#   'id': 276,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning toy',
#   'id': 277,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'wiping toy',
#   'id': 278,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning up dust',
#   'id': 279,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in water',
#   'id': 280,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathtub',
#   'id': 281,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathroom',
#   'id': 282,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'plastic',
#   'id': 283,
#   'question': 'what is the material of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'athlete',
#   'id': 284,
#   'question': 'what is on the track',
#   'video_name': 'ZJL1602'},
#  {'answer': 'yellow',
#   'id': 285,
#   'question': "what color is the runner's hair",
#   'video_name': 'ZJL1602'},
#  {'answer': 'running',
#   'id': 286,
#   'question': 'what is the person in yellow hair doing',
#   'video_name': 'ZJL1602'},
#  {'answer': 'on sport court',
#   'id': 287,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1602'},
#  {'answer': 'standing',
#   'id': 288,
#   'question': 'is the athlete in the video standing or sitting',
#   'video_name': 'ZJL1602'},
#  {'answer': 'hanging on wall',
#   'id': 289,
#   'question': 'where is the tv in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'blue',
#   'id': 290,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'light blue',
#   'id': 291,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'walking',
#   'id': 292,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL430'},
#  {'answer': 'benches',
#   'id': 293,
#   'question': 'where is the boy sitting in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'standing',
#   'id': 294,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL430'},
#  {'answer': 'plates',
#   'id': 295,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'watches',
#   'id': 296,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'flour',
#   'id': 297,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'green',
#   'id': 298,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'taking things',
#   'id': 299,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'pouring things',
#   'id': 300,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'kitchen',
#   'id': 301,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'standing',
#   'id': 302,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2863'},
#  {'answer': 'long hair',
#   'id': 303,
#   'question': 'does the person has long hair or short hair in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'white',
#   'id': 304,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'washing hands',
#   'id': 305,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'on cabinet',
#   'id': 306,
#   'question': 'where is the towel',
#   'video_name': 'ZJL3470'},
#  {'answer': 'standing',
#   'id': 307,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3470'},
#  {'answer': 'cummerbund',
#   'id': 308,
#   'question': 'what does the person in video hold',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple',
#   'id': 309,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'rose red',
#   'id': 310,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple red',
#   'id': 311,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'circle',
#   'id': 312,
#   'question': 'what is the shape of the decorative ribbon in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'left hand',
#   'id': 313,
#   'question': 'which hand of the people in video picked up the ribbon',
#   'video_name': 'ZJL2593'},
#  {'answer': 'standing',
#   'id': 314,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'wheelchair',
#   'id': 315,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'desk',
#   'id': 316,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'chair',
#   'id': 317,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'red',
#   'id': 318,
#   'question': 'what color clothes does the person sitting on a wheelchair wear',
#   'video_name': 'ZJL842'},
#  {'answer': 'hospital',
#   'id': 319,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'talking',
#   'id': 320,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'fetching things',
#   'id': 321,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'standing',
#   'id': 322,
#   'question': 'is the person wearing white clothes in the video sitting or standing',
#   'video_name': 'ZJL842'},
#  {'answer': 'clothes',
#   'id': 323,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'boxes',
#   'id': 324,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'hangers',
#   'id': 325,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'indoor',
#   'id': 326,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in house',
#   'id': 327,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in bedroom',
#   'id': 328,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue',
#   'id': 329,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'dark blue',
#   'id': 330,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue-black',
#   'id': 331,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'standing',
#   'id': 332,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3134'},
#  {'answer': 'took stuffs',
#   'id': 333,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'closed wardrobe',
#   'id': 334,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'turned off light',
#   'id': 335,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'cabinet',
#   'id': 336,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'hearth',
#   'id': 337,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'waste container',
#   'id': 338,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'red',
#   'id': 339,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'true red',
#   'id': 340,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'jacinth',
#   'id': 341,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'playing phone',
#   'id': 342,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'watching phone',
#   'id': 343,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'opening refrigerator',
#   'id': 344,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'indoor',
#   'id': 345,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'kitchen',
#   'id': 346,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'residence',
#   'id': 347,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'standing',
#   'id': 348,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'wardrobe',
#   'id': 349,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'clothing',
#   'id': 350,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'hangers',
#   'id': 351,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'brown',
#   'id': 352,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'gray-black',
#   'id': 353,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'dark gray',
#   'id': 354,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'displaying boxes',
#   'id': 355,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'cleaning out closet',
#   'id': 356,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'placing boxes',
#   'id': 357,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'indoor',
#   'id': 358,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in house',
#   'id': 359,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in bedroom',
#   'id': 360,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'standing',
#   'id': 361,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3144'},
#  {'answer': 'black',
#   'id': 362,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'dark black',
#   'id': 363,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'ash black',
#   'id': 364,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'standing',
#   'id': 365,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'writing',
#   'id': 366,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'yellow',
#   'id': 367,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'golden',
#   'id': 368,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'orange',
#   'id': 369,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'clothes',
#   'id': 370,
#   'question': 'what is hanging on the wall of video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'close stool',
#   'id': 371,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tissue',
#   'id': 372,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'shower gel',
#   'id': 373,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'red',
#   'id': 374,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tangerine',
#   'id': 375,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'scarlet',
#   'id': 376,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'reading books',
#   'id': 377,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'putting down book',
#   'id': 378,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'making machine',
#   'id': 379,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'toilet',
#   'id': 380,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'sitting',
#   'id': 381,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1874'},
#  {'answer': 'pen',
#   'id': 382,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'round',
#   'id': 383,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'monkey',
#   'id': 384,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'brown',
#   'id': 385,
#   'question': 'what color is the round in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'moving',
#   'id': 386,
#   'question': 'what is the round doing in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'snowfield',
#   'id': 387,
#   'question': 'where is the monkey in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'six',
#   'id': 388,
#   'question': 'how many letters are there in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'chair',
#   'id': 389,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cabinet',
#   'id': 390,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cup',
#   'id': 391,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'yellow',
#   'id': 392,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'light yellow',
#   'id': 393,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'orange',
#   'id': 394,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'shaking towel',
#   'id': 395,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3896'},
# ...
#   'video_name': 'ZJL2590'},
#  {'answer': 'workbench',
#   'id': 867,
#   'question': 'what is the second picture of video computer on',
#   'video_name': 'ZJL2590'},
#  {'answer': 'female',
#   'id': 868,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'butterfly',
#   'id': 869,
#   'question': 'what is the design of the sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'purple',
#   'id': 870,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'yellow',
#   'id': 871,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'green',
#   'id': 872,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'speaking',
#   'id': 873,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'indoor',
#   'id': 874,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'residence',
#   'id': 875,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'room',
#   'id': 876,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'computer',
#   'id': 877,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'mouse',
#   'id': 878,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'keyboard',
#   'id': 879,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'red',
#   'id': 880,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'orange-red',
#   'id': 881,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'dark-red',
#   'id': 882,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'turning on light',
#   'id': 883,
#   'question': 'what is the person in white doing in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'indoor',
#   'id': 884,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'in house',
#   'id': 885,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'on sofa',
#   'id': 886,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'standing',
#   'id': 887,
#   'question': 'is the person in white standing or sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'door',
#   'id': 888,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'poster',
#   'id': 889,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'light',
#   'id': 890,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'white',
#   'id': 891,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'off-white',
#   'id': 892,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'milk white',
#   'id': 893,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'page turning',
#   'id': 894,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'closing book',
#   'id': 895,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'hugging girl',
#   'id': 896,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'indoor',
#   'id': 897,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in corridor',
#   'id': 898,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in house',
#   'id': 899,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'standing',
#   'id': 900,
#   'question': 'is the man in video sitting or standing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'portrait',
#   'id': 901,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'two',
#   'id': 902,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'white',
#   'id': 903,
#   'question': 'what color is the font in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'right hand',
#   'id': 904,
#   'question': "which hand does the man hold the woman's head in the video",
#   'video_name': 'ZJL2266'},
#  {'answer': 'closing his eyes',
#   'id': 905,
#   'question': 'is the man blinking or closing his eyes in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'laptop',
#   'id': 906,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'table',
#   'id': 907,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tablecloth',
#   'id': 908,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink',
#   'id': 909,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink red',
#   'id': 910,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pale pink',
#   'id': 911,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'playing computer',
#   'id': 912,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'scratching his head',
#   'id': 913,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'turning off computer',
#   'id': 914,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'indoor',
#   'id': 915,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'in house',
#   'id': 916,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'living room',
#   'id': 917,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'sitting',
#   'id': 918,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tv',
#   'id': 919,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'closet',
#   'id': 920,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'lamp',
#   'id': 921,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'white',
#   'id': 922,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'milk white',
#   'id': 923,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'taking rest',
#   'id': 924,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'throwing trash',
#   'id': 925,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'crumbling paper',
#   'id': 926,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'indoor',
#   'id': 927,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in bedroom',
#   'id': 928,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in house',
#   'id': 929,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'sitting',
#   'id': 930,
#   'question': 'is the man sitting or standing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'laundry detergent',
#   'id': 931,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'bottle',
#   'id': 932,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'water bucket',
#   'id': 933,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'black',
#   'id': 934,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'turning on lights',
#   'id': 935,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'opening washing machine',
#   'id': 936,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'taking laundry detergent',
#   'id': 937,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'indoor',
#   'id': 938,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'residence',
#   'id': 939,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'room',
#   'id': 940,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'standing',
#   'id': 941,
#   'question': 'is the person in the video standing or lying',
#   'video_name': 'ZJL2180'},
#  {'answer': 'three',
#   'id': 942,
#   'question': 'how many people are in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'white',
#   'id': 943,
#   'question': 'what is the color of the clothes of the man in video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'drinking coffee',
#   'id': 944,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'on sofa',
#   'id': 945,
#   'question': 'where is the woman who is making a call in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'glasses',
#   'id': 946,
#   'question': "what is on the man's face in the video",
#   'video_name': 'ZJL2412'},
#  {'answer': 'pillow',
#   'id': 947,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'phone',
#   'id': 948,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'computer',
#   'id': 949,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'black',
#   'id': 950,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'white',
#   'id': 951,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'grey',
#   'id': 952,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'playing phone',
#   'id': 953,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'throwing pillow',
#   'id': 954,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'walking',
#   'id': 955,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'standing',
#   'id': 956,
#   'question': 'is the man standing or sitting',
#   'video_name': 'ZJL2908'},
#  {'answer': 'in door',
#   'id': 957,
#   'question': 'where is the man',
#   'video_name': 'ZJL2908'},
#  {'answer': 'book',
#   'id': 958,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'red',
#   'id': 959,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'scarlet',
#   'id': 960,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'bright red',
#   'id': 961,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'chatting',
#   'id': 962,
#   'question': 'what are the men in the video doing',
#   'video_name': 'ZJL528'},
#  {'answer': 'pillow',
#   'id': 963,
#   'question': 'what does the man in the video hold',
#   'video_name': 'ZJL528'},
#  {'answer': 'sitting',
#   'id': 964,
#   'question': 'are the men in the video standing or sitting',
#   'video_name': 'ZJL528'},
#  {'answer': 'dog',
#   'id': 965,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'chair',
#   'id': 966,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'people',
#   'id': 967,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'yellow',
#   'id': 968,
#   'question': 'what color is the slide in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'shower room',
#   'id': 969,
#   'question': 'where did the video last appear',
#   'video_name': 'ZJL1117'},
#  {'answer': 'boy',
#   'id': 970,
#   'question': 'is the person in the video a boy or a girl',
#   'video_name': 'ZJL1117'},
#  {'answer': 'holding dog',
#   'id': 971,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'short hair',
#   'id': 972,
#   'question': 'does the person have long hair or short hair',
#   'video_name': 'ZJL1617'},
#  {'answer': 'glasses',
#   'id': 973,
#   'question': 'what does the person in red wear on his eyes',
#   'video_name': 'ZJL1617'},
#  {'answer': 'blue',
#   'id': 974,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'sapphire blue',
#   'id': 975,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'shorts',
#   'id': 976,
#   'question': 'does the person wear pants or shorts',
#   'video_name': 'ZJL1617'},
#  {'answer': 'standing',
#   'id': 977,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1617'},
#  {'answer': 'snacks',
#   'id': 978,
#   'question': "what is in the girl's hand",
#   'video_name': 'ZJL1603'},
#  {'answer': 'white',
#   'id': 979,
#   'question': "what color are the girl's clothes in the video",
#   'video_name': 'ZJL1603'},
#  {'answer': 'shopping',
#   'id': 980,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1603'},
#  {'answer': 'in supermarket',
#   'id': 981,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1603'},
#  {'answer': 'standing',
#   'id': 982,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1603'},
#  {'answer': 'hat',
#   'id': 983,
#   'question': 'what is the man wearing on the head in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'black',
#   'id': 984,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'indoor',
#   'id': 985,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'by table',
#   'id': 986,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'living room',
#   'id': 987,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'standing',
#   'id': 988,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'wearing clothes',
#   'id': 989,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'picking clothes',
#   'id': 990,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'blue',
#   'id': 991,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'navy blue',
#   'id': 992,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'blue cyan',
#   'id': 993,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'going to table',
#   'id': 994,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'picking up book',
#   'id': 995,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'shaking head',
#   'id': 996,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'standing',
#   'id': 997,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2789'},
#  {'answer': 'living room',
#   'id': 998,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2789'},
#  {'answer': 'hat',
#   'id': 999,
#   'question': 'what is wearing on the head of the person in the video',
#   'video_name': 'ZJL2789'},
#  ...]

# %%
import random
random.shuffle(data_list)

# %%
data_list_train=[]
data_list_val=[]
data_new={}
id=-1
for data in data_list:
    for i in range(len(data["answer"])):
        if id <2999:
            id+=1
            data_new["question"]=data["question"]
            data_new["video_name"]=data["video_name"]
            data_new["id"]=id
            data_new["answer"]=data["answer"][i]
            data_list_val.append(data_new)
            data_new={}
        else:
            id+=1
            data_new["question"]=data["question"]
            data_new["video_name"]=data["video_name"]
            data_new["id"]=id
            data_new["answer"]=data["answer"][i]
            data_list_train.append(data_new)
            data_new={}

# %%
data_list_val
# Out:
# [{'answer': 'displaying camera',
#   'id': 0,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3759'},
#  {'answer': 'standing on chair',
#   'id': 1,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3759'},
#  {'answer': 'leaning against wall',
#   'id': 2,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3759'},
#  {'answer': 'pure black',
#   'id': 3,
#   'question': 'what color of clothes does the person in the video wear',
#   'video_name': 'ZJL1869'},
#  {'answer': 'dark black',
#   'id': 4,
#   'question': 'what color of clothes does the person in the video wear',
#   'video_name': 'ZJL1869'},
#  {'answer': 'black',
#   'id': 5,
#   'question': 'what color of clothes does the person in the video wear',
#   'video_name': 'ZJL1869'},
#  {'answer': 'bathroom',
#   'id': 6,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4237'},
#  {'answer': 'in refrigerator',
#   'id': 7,
#   'question': 'where is the beverage',
#   'video_name': 'ZJL683'},
#  {'answer': 'indoor',
#   'id': 8,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4157'},
#  {'answer': 'residence',
#   'id': 9,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4157'},
#  {'answer': 'doorway',
#   'id': 10,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4157'},
#  {'answer': 'standing',
#   'id': 11,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1883'},
#  {'answer': 'chatting',
#   'id': 12,
#   'question': 'what is the person standing doing in the video',
#   'video_name': 'ZJL1785'},
#  {'answer': 'indoor',
#   'id': 13,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1039'},
#  {'answer': 'house',
#   'id': 14,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1039'},
#  {'answer': 'inside house',
#   'id': 15,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1039'},
#  {'answer': 'opening door',
#   'id': 16,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL13'},
#  {'answer': 'reading book',
#   'id': 17,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL13'},
#  {'answer': 'sweeping floor',
#   'id': 18,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL13'},
#  {'answer': 'red',
#   'id': 19,
#   'question': "what color is the toy ultraman's clothes in the video",
#   'video_name': 'ZJL770'},
#  {'answer': 'indoor',
#   'id': 20,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3016'},
#  {'answer': 'residence',
#   'id': 21,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3016'},
#  {'answer': 'bathroom',
#   'id': 22,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3016'},
#  {'answer': 'toy',
#   'id': 23,
#   'question': 'what is in the video',
#   'video_name': 'ZJL770'},
#  {'answer': 'taking out items',
#   'id': 24,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2101'},
#  {'answer': 'screwing bottle cap',
#   'id': 25,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2101'},
#  {'answer': 'pouring beverage',
#   'id': 26,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2101'},
#  {'answer': 'drinking water',
#   'id': 27,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3999'},
#  {'answer': 'resting',
#   'id': 28,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3999'},
#  {'answer': 'playing computer',
#   'id': 29,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3999'},
#  {'answer': 'kitchen',
#   'id': 30,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2238'},
#  {'answer': 'standing',
#   'id': 31,
#   'question': 'is the man standing or sitting',
#   'video_name': 'ZJL161'},
#  {'answer': 'pouring water',
#   'id': 32,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL4039'},
#  {'answer': 'pouring beverage',
#   'id': 33,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL4039'},
#  {'answer': 'opening refrigerator',
#   'id': 34,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL4039'},
#  {'answer': 'indoor',
#   'id': 35,
#   'question': 'where is the person in the video at the beginning',
#   'video_name': 'ZJL1037'},
#  {'answer': 'house',
#   'id': 36,
#   'question': 'where is the person in the video at the beginning',
#   'video_name': 'ZJL1037'},
#  {'answer': 'staircase',
#   'id': 37,
#   'question': 'where is the person in the video at the beginning',
#   'video_name': 'ZJL1037'},
#  {'answer': 'landed',
#   'id': 38,
#   'question': 'is the plane in the video landed or keep flying in the end',
#   'video_name': 'ZJL815'},
#  {'answer': 'on door',
#   'id': 39,
#   'question': 'where is the hanger',
#   'video_name': 'ZJL3843'},
#  {'answer': 'sitting',
#   'id': 40,
#   'question': 'is the girl standing or sitting in the video',
#   'video_name': 'ZJL1300'},
#  {'answer': 'silk scarf',
#   'id': 41,
#   'question': 'what is on the neck of the person in the video',
#   'video_name': 'ZJL215'},
#  {'answer': 'talking',
#   'id': 42,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3357'},
#  {'answer': 'speaking',
#   'id': 43,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3357'},
#  {'answer': 'performing programs',
#   'id': 44,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3357'},
#  {'answer': 'two',
#   'id': 45,
#   'question': 'how many tvs are there on the table in the video',
#   'video_name': 'ZJL2793'},
#  {'answer': 'gray',
#   'id': 46,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL970'},
#  {'answer': 'dark gray',
#   'id': 47,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL970'},
#  {'answer': 'ash black',
#   'id': 48,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL970'},
#  {'answer': 'pink',
#   'id': 49,
#   'question': "what color is the kid's dress",
#   'video_name': 'ZJL391'},
#  {'answer': 'indoor',
#   'id': 50,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3564'},
#  {'answer': 'kitchen',
#   'id': 51,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3564'},
#  {'answer': 'residence',
#   'id': 52,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3564'},
#  {'answer': 'indoor',
#   'id': 53,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL95'},
#  {'answer': 'in house',
#   'id': 54,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL95'},
#  {'answer': 'in bedroom',
#   'id': 55,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL95'},
#  {'answer': 'bottle',
#   'id': 56,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1013'},
#  {'answer': 'cup',
#   'id': 57,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1013'},
#  {'answer': 'handle',
#   'id': 58,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1013'},
#  {'answer': 'standing',
#   'id': 59,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3967'},
#  {'answer': 'standing',
#   'id': 60,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'on grass',
#   'id': 61,
#   'question': 'where is the animal in video',
#   'video_name': 'ZJL2606'},
#  {'answer': 'yellow',
#   'id': 62,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1653'},
#  {'answer': 'orange',
#   'id': 63,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1653'},
#  {'answer': 'dark yellow',
#   'id': 64,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1653'},
#  {'answer': 'glasses',
#   'id': 65,
#   'question': 'what is on the table',
#   'video_name': 'ZJL962'},
#  {'answer': 'book',
#   'id': 66,
#   'question': 'what is on the table',
#   'video_name': 'ZJL962'},
#  {'answer': 'telephone',
#   'id': 67,
#   'question': 'what is on the table',
#   'video_name': 'ZJL962'},
#  {'answer': 'eating',
#   'id': 68,
#   'question': 'what is the person doing',
#   'video_name': 'ZJL1540'},
#  {'answer': 'on hand',
#   'id': 69,
#   'question': 'where is the book in the video',
#   'video_name': 'ZJL4249'},
#  {'answer': 'walking',
#   'id': 70,
#   'question': 'what is the game character in the video doing',
#   'video_name': 'ZJL740'},
#  {'answer': 'standing',
#   'id': 71,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3433'},
#  {'answer': 'yellow',
#   'id': 72,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL2056'},
#  {'answer': 'khaki',
#   'id': 73,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL2056'},
#  {'answer': 'tan',
#   'id': 74,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL2056'},
#  {'answer': 'lobby',
#   'id': 75,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL247'},
#  {'answer': 'standing',
#   'id': 76,
#   'question': 'is the man standing or sitting',
#   'video_name': 'ZJL2950'},
#  {'answer': 'playing cell phone',
#   'id': 77,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2070'},
#  {'answer': 'drinking water',
#   'id': 78,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2070'},
#  {'answer': 'picking up cup',
#   'id': 79,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2070'},
#  {'answer': 'sitting',
#   'id': 80,
#   'question': 'is the person sitting in the video or standing',
#   'video_name': 'ZJL4184'},
#  {'answer': 'green',
#   'id': 81,
#   'question': 'what color is the pine tree in the video',
#   'video_name': 'ZJL1323'},
#  {'answer': 'bottle green',
#   'id': 82,
#   'question': 'what color is the pine tree in the video',
#   'video_name': 'ZJL1323'},
#  {'answer': 'dark green',
#   'id': 83,
#   'question': 'what color is the pine tree in the video',
#   'video_name': 'ZJL1323'},
#  {'answer': 'beverage',
#   'id': 84,
#   'question': 'what did the woman wearing the vest in the video take',
#   'video_name': 'ZJL2310'},
#  {'answer': 'wiping face',
#   'id': 85,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2734'},
#  {'answer': 'standing',
#   'id': 86,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3792'},
#  {'answer': 'drinking water',
#   'id': 87,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL158'},
#  {'answer': 'tidying',
#   'id': 88,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL158'},
#  {'answer': 'playing cell phone',
#   'id': 89,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL158'},
#  {'answer': 'computer',
#   'id': 90,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3167'},
#  {'answer': 'shoes',
#   'id': 91,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3167'},
#  {'answer': 'vase',
#   'id': 92,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3167'},
#  {'answer': 'white',
#   'id': 93,
#   'question': 'what is the color of the body of machine in the video',
#   'video_name': 'ZJL2862'},
#  {'answer': 'speaking',
#   'id': 94,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3378'},
#  {'answer': 'introducing',
#   'id': 95,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3378'},
#  {'answer': 'explaining',
#   'id': 96,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3378'},
#  {'answer': 'eating',
#   'id': 97,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4279'},
#  {'answer': 'drinking water',
#   'id': 98,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4279'},
#  {'answer': 'putting cup',
#   'id': 99,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4279'},
#  {'answer': 'sitting',
#   'id': 100,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1627'},
#  {'answer': 'male',
#   'id': 101,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1207'},
#  {'answer': 'in door',
#   'id': 102,
#   'question': 'where is the man',
#   'video_name': 'ZJL2980'},
#  {'answer': 'glasses',
#   'id': 103,
#   'question': "what is on the woman's face in the video",
#   'video_name': 'ZJL483'},
#  {'answer': 'lying',
#   'id': 104,
#   'question': 'is the person in the video sitting or lying',
#   'video_name': 'ZJL3292'},
#  {'answer': 'red',
#   'id': 105,
#   'question': 'what color is the cup',
#   'video_name': 'ZJL3487'},
#  {'answer': 'standing',
#   'id': 106,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL665'},
#  {'answer': 'standing',
#   'id': 107,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4253'},
#  {'answer': 'lying',
#   'id': 108,
#   'question': 'is the person in the video sitting or standing after taking medicine',
#   'video_name': 'ZJL3771'},
#  {'answer': 'black',
#   'id': 109,
#   'question': "what is the color of person's clothes in video",
#   'video_name': 'ZJL2685'},
#  {'answer': 'role play',
#   'id': 110,
#   'question': 'what is the child doing in the video',
#   'video_name': 'ZJL1238'},
#  {'answer': 'walking',
#   'id': 111,
#   'question': 'what is the child doing in the video',
#   'video_name': 'ZJL1238'},
#  {'answer': 'running',
#   'id': 112,
#   'question': 'what is the child doing in the video',
#   'video_name': 'ZJL1238'},
#  {'answer': 'dark grey',
#   'id': 113,
#   'question': 'what is the color of the clothes in the video',
#   'video_name': 'ZJL1689'},
#  {'answer': 'horizontal',
#   'id': 114,
#   'question': 'is the text in the video horizontal or vertical',
#   'video_name': 'ZJL1121'},
#  {'answer': 'standing',
#   'id': 115,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL31'},
#  {'answer': 'beach',
#   'id': 116,
#   'question': 'what is in the video',
#   'video_name': 'ZJL812'},
#  {'answer': 'seawater',
#   'id': 117,
#   'question': 'what is in the video',
#   'video_name': 'ZJL812'},
#  {'answer': 'fan',
#   'id': 118,
#   'question': 'what is in the video',
#   'video_name': 'ZJL812'},
#  {'answer': 'black',
#   'id': 119,
#   'question': 'what color is the laptop in the video',
#   'video_name': 'ZJL1157'},
#  {'answer': 'female',
#   'id': 120,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1211'},
#  {'answer': 'standing',
#   'id': 121,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1727'},
#  {'answer': 'grey',
#   'id': 122,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL1513'},
#  {'answer': 'gun',
#   'id': 123,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1340'},
#  {'answer': 'microphone',
#   'id': 124,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1340'},
#  {'answer': 'curtain',
#   'id': 125,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1340'},
#  {'answer': 'carnival',
#   'id': 126,
#   'question': 'where is spongebob in the video',
#   'video_name': 'ZJL1333'},
#  {'answer': 'outdoors',
#   'id': 127,
#   'question': 'where is spongebob in the video',
#   'video_name': 'ZJL1333'},
#  {'answer': 'field',
#   'id': 128,
#   'question': 'where is spongebob in the video',
#   'video_name': 'ZJL1333'},
#  {'answer': 'in basket',
#   'id': 129,
#   'question': 'where is the white kitten in the video',
#   'video_name': 'ZJL1809'},
#  {'answer': 'living room',
#   'id': 130,
#   'question': 'where is the woman in rose red',
#   'video_name': 'ZJL715'},
#  {'answer': 'standing',
#   'id': 131,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3589'},
#  {'answer': 'sofa',
#   'id': 132,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL3577'},
#  {'answer': 'table',
#   'id': 133,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL3577'},
#  {'answer': 'photo',
#   'id': 134,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL3577'},
#  {'answer': 'brown',
#   'id': 135,
#   'question': 'what is the color of the hair of the person in the video',
#   'video_name': 'ZJL3173'},
#  {'answer': 'black',
#   'id': 136,
#   'question': 'what is the color of the hair of the person in the video',
#   'video_name': 'ZJL3173'},
#  {'answer': 'brownish black',
#   'id': 137,
#   'question': 'what is the color of the hair of the person in the video',
#   'video_name': 'ZJL3173'},
#  {'answer': 'pillow',
#   'id': 138,
#   'question': "what is in the women's clothes in the video",
#   'video_name': 'ZJL479'},
#  {'answer': 'orange',
#   'id': 139,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL915'},
#  {'answer': 'tangerine',
#   'id': 140,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL915'},
#  {'answer': 'croci',
#   'id': 141,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL915'},
#  {'answer': 'machinery equipment',
#   'id': 142,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1307'},
#  {'answer': 'long hair',
#   'id': 143,
#   'question': 'is the women in video have short hair or long hair',
#   'video_name': 'ZJL3638'},
#  {'answer': 'folding paper',
#   'id': 144,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1780'},
#  {'answer': 'exhibition hall',
#   'id': 145,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL268'},
#  {'answer': 'standing',
#   'id': 146,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL45'},
#  {'answer': 'indoor',
#   'id': 147,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2383'},
#  {'answer': 'by table',
#   'id': 148,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2383'},
#  {'answer': 'living room',
#   'id': 149,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2383'},
#  {'answer': 'black',
#   'id': 150,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL710'},
#  {'answer': 'sitting',
#   'id': 151,
#   'question': 'is the woman standing or sitting',
#   'video_name': 'ZJL2932'},
#  {'answer': 'cell phone',
#   'id': 152,
#   'question': 'what is the person holding in his hand in the video',
#   'video_name': 'ZJL1699'},
#  {'answer': 'blue',
#   'id': 153,
#   'question': 'what is the color of the person is clothes in the video',
#   'video_name': 'ZJL1807'},
#  {'answer': 'sky blue',
#   'id': 154,
#   'question': 'what is the color of the person is clothes in the video',
#   'video_name': 'ZJL1807'},
#  {'answer': 'lake blue',
#   'id': 155,
#   'question': 'what is the color of the person is clothes in the video',
#   'video_name': 'ZJL1807'},
#  {'answer': 'white',
#   'id': 156,
#   'question': 'what color is the bag in the video',
#   'video_name': 'ZJL2886'},
#  {'answer': 'desk',
#   'id': 157,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3492'},
#  {'answer': 'clothes',
#   'id': 158,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3492'},
#  {'answer': 'book',
#   'id': 159,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3492'},
#  {'answer': 'green',
#   'id': 160,
#   'question': 'what color is the door in the video',
#   'video_name': 'ZJL1162'},
#  {'answer': 'in inn',
#   'id': 161,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1597'},
#  {'answer': 'chair',
#   'id': 162,
#   'question': 'what is the person in video sitting on',
#   'video_name': 'ZJL2567'},
#  {'answer': 'purple',
#   'id': 163,
#   'question': 'what color is the light on the ferris wheel in video',
#   'video_name': 'ZJL1280'},
#  {'answer': 'shoes',
#   'id': 164,
#   'question': 'what is in the closet',
#   'video_name': 'ZJL3875'},
#  {'answer': 'clothes',
#   'id': 165,
#   'question': 'what is in the closet',
#   'video_name': 'ZJL3875'},
#  {'answer': 'hanger',
#   'id': 166,
#   'question': 'what is in the closet',
#   'video_name': 'ZJL3875'},
#  {'answer': 'watching film',
#   'id': 167,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3639'},
#  {'answer': 'eating',
#   'id': 168,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3639'},
#  {'answer': 'writing',
#   'id': 169,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3639'},
#  {'answer': 'drinking water',
#   'id': 170,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2950'},
#  {'answer': 'clearing up',
#   'id': 171,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2950'},
#  {'answer': 'playing phone',
#   'id': 172,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2950'},
#  {'answer': 'shoes',
#   'id': 173,
#   'question': 'what is the wall full of in the video',
#   'video_name': 'ZJL346'},
#  {'answer': 'standing',
#   'id': 174,
#   'question': 'are people standing or sitting in the video',
#   'video_name': 'ZJL727'},
#  {'answer': 'eating',
#   'id': 175,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2354'},
#  {'answer': 'drinking water',
#   'id': 176,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2354'},
#  {'answer': 'indoor',
#   'id': 177,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3897'},
#  {'answer': 'in kitchen',
#   'id': 178,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3897'},
#  {'answer': 'in house',
#   'id': 179,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3897'},
#  {'answer': 'pink',
#   'id': 180,
#   'question': 'what color are the shoes',
#   'video_name': 'ZJL3753'},
#  {'answer': 'magenta',
#   'id': 181,
#   'question': 'what color are the shoes',
#   'video_name': 'ZJL3753'},
#  {'answer': 'red',
#   'id': 182,
#   'question': 'what color are the shoes',
#   'video_name': 'ZJL3753'},
#  {'answer': 'playing computer',
#   'id': 183,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1043'},
#  {'answer': 'getting cup',
#   'id': 184,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1043'},
#  {'answer': 'drinking water',
#   'id': 185,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1043'},
#  {'answer': 'sitting',
#   'id': 186,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3616'},
#  {'answer': 'green',
#   'id': 187,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1321'},
#  {'answer': 'light green',
#   'id': 188,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1321'},
#  {'answer': 'grass green',
#   'id': 189,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1321'},
#  {'answer': 'male',
#   'id': 190,
#   'question': 'what is the gender of the person wrapped in a blanket',
#   'video_name': 'ZJL3162'},
#  {'answer': 'standing',
#   'id': 191,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1723'},
#  {'answer': 'pigment',
#   'id': 192,
#   'question': 'what did the sitting man put on his face',
#   'video_name': 'ZJL2694'},
#  {'answer': 'colour',
#   'id': 193,
#   'question': 'what did the sitting man put on his face',
#   'video_name': 'ZJL2694'},
#  {'answer': 'taking blanket',
#   'id': 194,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2830'},
#  {'answer': 'talking',
#   'id': 195,
#   'question': 'what is the alpaca doing in the picture',
#   'video_name': 'ZJL2680'},
#  {'answer': 'going downstairs',
#   'id': 196,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1868'},
#  {'answer': 'putting computer',
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1868'},
#  {'answer': 'washing his hands',
#   'id': 198,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1868'},
#  {'answer': 'standing',
#   'id': 199,
#   'question': 'is the person in video standing or sitting',
#   'video_name': 'ZJL64'},
#  {'answer': 'going downstairs',
#   'id': 200,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL125'},
#  {'answer': 'tidying',
#   'id': 201,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL125'},
#  {'answer': 'playing cell phone',
#   'id': 202,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL125'},
#  {'answer': 'indoor',
#   'id': 203,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3051'},
#  {'answer': 'residence',
#   'id': 204,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3051'},
#  {'answer': 'wash room',
#   'id': 205,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3051'},
#  {'answer': 'horse',
#   'id': 206,
#   'question': 'what is in the fence in the video',
#   'video_name': 'ZJL1728'},
#  {'answer': 'talking',
#   'id': 207,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1526'},
#  {'answer': 'tidying table',
#   'id': 208,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2073'},
#  {'answer': 'taking out something',
#   'id': 209,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2073'},
#  {'answer': 'tidying items',
#   'id': 210,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2073'},
#  {'answer': 'grey',
#   'id': 211,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3647'},
#  {'answer': 'dark grey',
#   'id': 212,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3647'},
#  {'answer': 'cheering',
#   'id': 213,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1729'},
#  {'answer': 'taking photo',
#   'id': 214,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1729'},
#  {'answer': 'chatting',
#   'id': 215,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1729'},
#  {'answer': 'weight lifting',
#   'id': 216,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL797'},
#  {'answer': 'taking clothes',
#   'id': 217,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3898'},
#  {'answer': 'shaking clothes',
#   'id': 218,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3898'},
#  {'answer': 'putting down clothes',
#   'id': 219,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3898'},
#  {'answer': 'bedroom',
#   'id': 220,
#   'question': 'where is the man',
#   'video_name': 'ZJL131'},
#  {'answer': 'on desktop',
#   'id': 221,
#   'question': 'where is the recycle bin in the video',
#   'video_name': 'ZJL1269'},
#  {'answer': 'standing',
#   'id': 222,
#   'question': 'is the man in video sitting or standing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'water cup',
#   'id': 223,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4116'},
#  {'answer': 'pool',
#   'id': 224,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4116'},
#  {'answer': 'mirror',
#   'id': 225,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4116'},
#  {'answer': 'on desk',
#   'id': 226,
#   'question': 'where is the laptop',
#   'video_name': 'ZJL3434'},
#  {'answer': 'sitting',
#   'id': 227,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL41'},
#  {'answer': 'talking',
#   'id': 228,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL820'},
#  {'answer': 'white',
#   'id': 229,
#   'question': 'what is the color of wall at the beginning of the video',
#   'video_name': 'ZJL3342'},
#  {'answer': 'milk white',
#   'id': 230,
#   'question': 'what is the color of wall at the beginning of the video',
#   'video_name': 'ZJL3342'},
#  {'answer': 'creamy white',
#   'id': 231,
#   'question': 'what is the color of wall at the beginning of the video',
#   'video_name': 'ZJL3342'},
#  {'answer': 'sitting',
#   'id': 232,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3986'},
#  {'answer': 'black',
#   'id': 233,
#   'question': 'what color of the clothes does the woman wear in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': 'standing',
#   'id': 234,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1040'},
#  {'answer': 'climbing stairs',
#   'id': 235,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL301'},
#  {'answer': 'turning on light',
#   'id': 236,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4202'},
#  {'answer': 'tying straps',
#   'id': 237,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4202'},
#  {'answer': 'putting things',
#   'id': 238,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4202'},
#  {'answer': 'right hand',
#   'id': 239,
#   'question': 'which hand does the person wearing glasses in the video use',
#   'video_name': 'ZJL2237'},
#  {'answer': 'on ground',
#   'id': 240,
#   'question': 'where is the pet food container in the video',
#   'video_name': 'ZJL566'},
#  {'answer': 'standing',
#   'id': 241,
#   'question': 'is the person in the video sitting or standing when drinking water',
#   'video_name': 'ZJL2067'},
#  {'answer': 'kneeling',
#   'id': 242,
#   'question': 'is the woman standing or kneeling in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': 'baby stroller',
#   'id': 243,
#   'question': 'what is the object in the video',
#   'video_name': 'ZJL2536'},
#  {'answer': 'baby carriage',
#   'id': 244,
#   'question': 'what is the object in the video',
#   'video_name': 'ZJL2536'},
#  {'answer': 'trolley',
#   'id': 245,
#   'question': 'what is the object in the video',
#   'video_name': 'ZJL2536'},
#  {'answer': 'sitting',
#   'id': 246,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2818'},
#  {'answer': 'table',
#   'id': 247,
#   'question': 'what is on the left of the bed',
#   'video_name': 'ZJL4034'},
#  {'answer': 'television',
#   'id': 248,
#   'question': 'what is on the left of the bed',
#   'video_name': 'ZJL4034'},
#  {'answer': 'bag',
#   'id': 249,
#   'question': 'what is on the left of the bed',
#   'video_name': 'ZJL4034'},
#  {'answer': 'toilet',
#   'id': 250,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL696'},
#  {'answer': 'white',
#   'id': 251,
#   'question': 'what is the color of the floor',
#   'video_name': 'ZJL3814'},
#  {'answer': 'beige white',
#   'id': 252,
#   'question': 'what is the color of the floor',
#   'video_name': 'ZJL3814'},
#  {'answer': 'creamy white',
#   'id': 253,
#   'question': 'what is the color of the floor',
#   'video_name': 'ZJL3814'},
#  {'answer': 'black',
#   'id': 254,
#   'question': 'what color hair does the woman have in the video',
#   'video_name': 'ZJL3457'},
#  {'answer': 'playing video',
#   'id': 255,
#   'question': 'what is the computer in the video doing',
#   'video_name': 'ZJL269'},
#  {'answer': 'black',
#   'id': 256,
#   'question': 'what is the color of the piano in the video',
#   'video_name': 'ZJL1771'},
#  {'answer': 'clothes',
#   'id': 257,
#   'question': 'what is in the room',
#   'video_name': 'ZJL676'},
#  {'answer': 'bed',
#   'id': 258,
#   'question': 'what is in the room',
#   'video_name': 'ZJL676'},
#  {'answer': 'cabinet',
#   'id': 259,
#   'question': 'what is in the room',
#   'video_name': 'ZJL676'},
#  {'answer': 'chair',
#   'id': 260,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3838'},
#  {'answer': 'table',
#   'id': 261,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3838'},
#  {'answer': 'closet',
#   'id': 262,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3838'},
#  {'answer': 'standing',
#   'id': 263,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3928'},
#  {'answer': 'standing',
#   'id': 264,
#   'question': 'is the man in the video sitting or standing',
#   'video_name': 'ZJL1123'},
#  {'answer': 'on ground',
#   'id': 265,
#   'question': 'where is the mirror in the video',
#   'video_name': 'ZJL2316'},
#  {'answer': 'rope',
#   'id': 266,
#   'question': 'what is in the hand of the woman in the video',
#   'video_name': 'ZJL288'},
#  {'answer': 'doing chores',
#   'id': 267,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1633'},
#  {'answer': 'sitting',
#   'id': 268,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1010'},
#  {'answer': 'pool',
#   'id': 269,
#   'question': 'what is in front of the person in the video when he pouring the water',
#   'video_name': 'ZJL3172'},
#  {'answer': 'tap',
#   'id': 270,
#   'question': 'what is in front of the person in the video when he pouring the water',
#   'video_name': 'ZJL3172'},
#  {'answer': 'cleaning cloth',
#   'id': 271,
#   'question': 'what is in front of the person in the video when he pouring the water',
#   'video_name': 'ZJL3172'},
#  {'answer': 'sitting',
#   'id': 272,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL985'},
#  {'answer': 'standing',
#   'id': 273,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3347'},
#  {'answer': 'standing',
#   'id': 274,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3810'},
#  {'answer': 'residence',
#   'id': 275,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2035'},
#  {'answer': 'indoor',
#   'id': 276,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2035'},
#  {'answer': 'toilet',
#   'id': 277,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2035'},
#  {'answer': 'turning on light',
#   'id': 278,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3062'},
#  {'answer': 'collating wardrobe',
#   'id': 279,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3062'},
#  {'answer': 'taking out clothes',
#   'id': 280,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3062'},
#  {'answer': 'standing',
#   'id': 281,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL1725'},
#  {'answer': 'ham',
#   'id': 282,
#   'question': 'what did the person in the video put on the bread',
#   'video_name': 'ZJL2305'},
#  {'answer': 'standing',
#   'id': 283,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1053'},
#  {'answer': 'car',
#   'id': 284,
#   'question': 'what is on the street',
#   'video_name': 'ZJL3422'},
#  {'answer': 'shop',
#   'id': 285,
#   'question': 'what is on the street',
#   'video_name': 'ZJL3422'},
#  {'answer': 'businessman',
#   'id': 286,
#   'question': 'what is on the street',
#   'video_name': 'ZJL3422'},
#  {'answer': 'black',
#   'id': 287,
#   'question': 'what is the color of the clothes in the video',
#   'video_name': 'ZJL1744'},
#  {'answer': 'standing',
#   'id': 288,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1334'},
#  {'answer': 'scarf',
#   'id': 289,
#   'question': 'what is the man wearing on the neck in the video',
#   'video_name': 'ZJL2382'},
#  {'answer': 'cartoon character',
#   'id': 290,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1500'},
#  {'answer': 'drum set',
#   'id': 291,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1500'},
#  {'answer': 'sound',
#   'id': 292,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1500'},
#  {'answer': 'right hand',
#   'id': 293,
#   'question': 'which hand did the person use to hold things',
#   'video_name': 'ZJL1829'},
#  {'answer': 'black',
#   'id': 294,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL711'},
#  {'answer': 'standing',
#   'id': 295,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3509'},
#  {'answer': 'mirror',
#   'id': 296,
#   'question': 'what is on the window',
#   'video_name': 'ZJL3'},
#  {'answer': 'bottle',
#   'id': 297,
#   'question': 'what is on the window',
#   'video_name': 'ZJL3'},
#  {'answer': 'soap box',
#   'id': 298,
#   'question': 'what is on the window',
#   'video_name': 'ZJL3'},
#  {'answer': 'purple',
#   'id': 299,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': 'modena',
#   'id': 300,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': 'fuchsia',
#   'id': 301,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': 'on stairs',
#   'id': 302,
#   'question': 'where is the man in black pants',
#   'video_name': 'ZJL647'},
#  {'answer': 'bottle',
#   'id': 303,
#   'question': 'what is on the table',
#   'video_name': 'ZJL76'},
#  {'answer': 'bowl',
#   'id': 304,
#   'question': 'what is on the table',
#   'video_name': 'ZJL76'},
#  {'answer': 'book',
#   'id': 305,
#   'question': 'what is on the table',
#   'video_name': 'ZJL76'},
#  {'answer': 'standing',
#   'id': 306,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3188'},
#  {'answer': 'green',
#   'id': 307,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2798'},
#  {'answer': 'white',
#   'id': 308,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2798'},
#  {'answer': 'green and white',
#   'id': 309,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2798'},
#  {'answer': 'sitting',
#   'id': 310,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1227'},
#  {'answer': 'in kitchen',
#   'id': 311,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL353'},
#  {'answer': 'sitting on bed',
#   'id': 312,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3753'},
#  {'answer': 'covering with quilt',
#   'id': 313,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3753'},
#  {'answer': 'taking selfie',
#   'id': 314,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3753'},
#  {'answer': 'stirring ingredients',
#   'id': 315,
#   'question': 'what is the first person in the video doing',
#   'video_name': 'ZJL1176'},
#  {'answer': 'pouring ingredients',
#   'id': 316,
#   'question': 'what is the first person in the video doing',
#   'video_name': 'ZJL1176'},
#  {'answer': 'placing pot',
#   'id': 317,
#   'question': 'what is the first person in the video doing',
#   'video_name': 'ZJL1176'},
#  {'answer': 'standing',
#   'id': 318,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3247'},
#  {'answer': 'cooking',
#   'id': 319,
#   'question': 'what is the man wearing orange dress doing',
#   'video_name': 'ZJL3475'},
#  {'answer': 'horizontal',
#   'id': 320,
#   'question': 'is the text in the video horizontal or vertical',
#   'video_name': 'ZJL2845'},
#  {'answer': 'sitting',
#   'id': 321,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3082'},
#  {'answer': 'chair',
#   'id': 322,
#   'question': 'what is in the stand in the video',
#   'video_name': 'ZJL1748'},
#  {'answer': 'people',
#   'id': 323,
#   'question': 'what is in the stand in the video',
#   'video_name': 'ZJL1748'},
#  {'answer': 'billboard',
#   'id': 324,
#   'question': 'what is in the stand in the video',
#   'video_name': 'ZJL1748'},
#  {'answer': 'standing',
#   'id': 325,
#   'question': 'is the person in video sitting or standing bofore putting on a blanket',
#   'video_name': 'ZJL3941'},
#  {'answer': 'lying down',
#   'id': 326,
#   'question': 'is the man in the video sitting or lying down',
#   'video_name': 'ZJL405'},
#  {'answer': 'phone',
#   'id': 327,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3818'},
#  {'answer': 'computer',
#   'id': 328,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3818'},
#  {'answer': 'pen',
#   'id': 329,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3818'},
#  {'answer': 'face-time',
#   'id': 330,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2413'},
#  {'answer': 'holding cup',
#   'id': 331,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3867'},
#  {'answer': 'stretching out hands',
#   'id': 332,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3867'},
#  {'answer': 'drinking water',
#   'id': 333,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3867'},
#  {'answer': 'next to plants',
#   'id': 334,
#   'question': 'where is the staircase',
#   'video_name': 'ZJL739'},
#  {'answer': 'sitting',
#   'id': 335,
#   'question': 'is the person in the video sitting or standing at rest',
#   'video_name': 'ZJL4172'},
#  {'answer': 'standing',
#   'id': 336,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3198'},
#  {'answer': 'machine',
#   'id': 337,
#   'question': 'what is the object in video',
#   'video_name': 'ZJL2646'},
#  {'answer': 'cooking',
#   'id': 338,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3825'},
#  {'answer': 'putting condiment',
#   'id': 339,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3825'},
#  {'answer': 'opening refrigerator',
#   'id': 340,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3825'},
#  {'answer': 'standing',
#   'id': 341,
#   'question': 'is the boy standing or sitting in the video',
#   'video_name': 'ZJL1234'},
#  {'answer': 'mirror',
#   'id': 342,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1075'},
#  {'answer': 'clothes',
#   'id': 343,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1075'},
#  {'answer': 'switch',
#   'id': 344,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1075'},
#  {'answer': 'pure black',
#   'id': 345,
#   'question': 'what color of the pants does the woman wear in the video',
#   'video_name': 'ZJL1860'},
#  {'answer': 'dark black',
#   'id': 346,
#   'question': 'what color of the pants does the woman wear in the video',
#   'video_name': 'ZJL1860'},
#  {'answer': 'black',
#   'id': 347,
#   'question': 'what color of the pants does the woman wear in the video',
#   'video_name': 'ZJL1860'},
#  {'answer': 'hat',
#   'id': 348,
#   'question': 'what does the person wear on head in the video',
#   'video_name': 'ZJL967'},
#  {'answer': 'cabinet',
#   'id': 349,
#   'question': 'what is in the room',
#   'video_name': 'ZJL711'},
#  {'answer': 'plate',
#   'id': 350,
#   'question': 'what is in the room',
#   'video_name': 'ZJL711'},
#  {'answer': 'lights',
#   'id': 351,
#   'question': 'what is in the room',
#   'video_name': 'ZJL711'},
#  {'answer': 'taking clothes',
#   'id': 352,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3926'},
#  {'answer': 'putting on clothes',
#   'id': 353,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3926'},
#  {'answer': 'taking photos',
#   'id': 354,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3926'},
#  {'answer': 'placing stuff',
#   'id': 355,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3793'},
#  {'answer': 'opening refrigerator',
#   'id': 356,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3793'},
#  {'answer': 'closing refrigerator',
#   'id': 357,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3793'},
#  {'answer': 'sitting',
#   'id': 358,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL624'},
#  {'answer': 'desk',
#   'id': 359,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL4173'},
#  {'answer': 'cell phone',
#   'id': 360,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL4173'},
#  {'answer': 'wooden table',
#   'id': 361,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL4173'},
#  {'answer': 'on table',
#   'id': 362,
#   'question': 'where is the speech draft in the video',
#   'video_name': 'ZJL1279'},
#  {'answer': 'making call',
#   'id': 363,
#   'question': 'what is the last person in the video doing',
#   'video_name': 'ZJL2860'},
#  {'answer': 'horse',
#   'id': 364,
#   'question': 'what is in the video',
#   'video_name': 'ZJL743'},
#  {'answer': 'bucket',
#   'id': 365,
#   'question': 'what is in the video',
#   'video_name': 'ZJL743'},
#  {'answer': 'door',
#   'id': 366,
#   'question': 'what is in the video',
#   'video_name': 'ZJL743'},
#  {'answer': 'black',
#   'id': 367,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2933'},
#  {'answer': 'white',
#   'id': 368,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2933'},
#  {'answer': 'green',
#   'id': 369,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2933'},
#  {'answer': 'yes',
#   'id': 370,
#   'question': 'is the person wearing glasses',
#   'video_name': 'ZJL1571'},
#  {'answer': 'electric fan',
#   'id': 371,
#   'question': 'what is on the roof in the video',
#   'video_name': 'ZJL2350'},
#  {'answer': 'book',
#   'id': 372,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL2972'},
#  {'answer': 'phone',
#   'id': 373,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL2972'},
#  {'answer': 'computer',
#   'id': 374,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL2972'},
#  {'answer': 'clapping',
#   'id': 375,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL904'},
#  {'answer': 'talking',
#   'id': 376,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL904'},
#  {'answer': 'cut garlic',
#   'id': 377,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL742'},
#  {'answer': 'cut things',
#   'id': 378,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL742'},
#  {'answer': 'washroom',
#   'id': 379,
#   'question': 'where is the man',
#   'video_name': 'ZJL2898'},
#  {'answer': 'kitchen',
#   'id': 380,
#   'question': 'where is the man',
#   'video_name': 'ZJL2898'},
#  {'answer': 'bedroom',
#   'id': 381,
#   'question': 'where is the man',
#   'video_name': 'ZJL2898'},
#  {'answer': 'sitting',
#   'id': 382,
#   'question': 'is the person in the video sitting or standing at first',
#   'video_name': 'ZJL1034'},
#  {'answer': 'standing',
#   'id': 383,
#   'question': 'is the person taking a picture in the video standing or sitting',
#   'video_name': 'ZJL1792'},
#  {'answer': 'sitting',
#   'id': 384,
#   'question': 'is the man standing or sitting in video',
#   'video_name': 'ZJL2637'},
#  {'answer': 'grey',
#   'id': 385,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3108'},
#  {'answer': 'silvery-gray',
#   'id': 386,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3108'},
#  {'answer': 'light grey',
#   'id': 387,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3108'},
#  {'answer': 'fetching things',
#   'id': 388,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3529'},
#  {'answer': 'grey',
#   'id': 389,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL2'},
#  {'answer': 'dark-grey',
#   'id': 390,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL2'},
#  {'answer': 'light-grey',
#   'id': 391,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL2'},
#  {'answer': 'taking shoes',
#   'id': 392,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1634'},
#  {'answer': 'looking at phone',
#   'id': 393,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1634'},
#  {'answer': 'black',
#   'id': 394,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1614'},
#  {'answer': 'driving car',
#   'id': 395,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL202'},
#  {'answer': 'tidying',
#   'id': 396,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL202'},
# ...
#  {'answer': 'yellow',
#   'id': 868,
#   'question': 'what color is the basin in video',
#   'video_name': 'ZJL3582'},
#  {'answer': 'orange',
#   'id': 869,
#   'question': 'what color is the basin in video',
#   'video_name': 'ZJL3582'},
#  {'answer': 'light yellow',
#   'id': 870,
#   'question': 'what color is the basin in video',
#   'video_name': 'ZJL3582'},
#  {'answer': 'indoors',
#   'id': 871,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in house',
#   'id': 872,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in bedroom',
#   'id': 873,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'sitting',
#   'id': 874,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2655'},
#  {'answer': 'standing',
#   'id': 875,
#   'question': 'is the woman in white standing or sitting in the video',
#   'video_name': 'ZJL2521'},
#  {'answer': 'standing',
#   'id': 876,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3551'},
#  {'answer': 'blue',
#   'id': 877,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2894'},
#  {'answer': 'dark blue',
#   'id': 878,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2894'},
#  {'answer': 'light-blue',
#   'id': 879,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2894'},
#  {'answer': 'kitchen',
#   'id': 880,
#   'question': 'where is the person',
#   'video_name': 'ZJL1551'},
#  {'answer': 'on desk',
#   'id': 881,
#   'question': 'where is the book',
#   'video_name': 'ZJL3451'},
#  {'answer': 'cleaning shoes',
#   'id': 882,
#   'question': 'what is the woman doing',
#   'video_name': 'ZJL2938'},
#  {'answer': 'clearing up',
#   'id': 883,
#   'question': 'what is the woman doing',
#   'video_name': 'ZJL2938'},
#  {'answer': 'walking',
#   'id': 884,
#   'question': 'what is the woman doing',
#   'video_name': 'ZJL2938'},
#  {'answer': 'white',
#   'id': 885,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3304'},
#  {'answer': 'milk white',
#   'id': 886,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3304'},
#  {'answer': 'creamy white',
#   'id': 887,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3304'},
#  {'answer': 'tray',
#   'id': 888,
#   'question': 'what is on the table in the kitchen',
#   'video_name': 'ZJL3200'},
#  {'answer': 'kitchen table',
#   'id': 889,
#   'question': 'what is on the table in the kitchen',
#   'video_name': 'ZJL3200'},
#  {'answer': 'pot',
#   'id': 890,
#   'question': 'what is on the table in the kitchen',
#   'video_name': 'ZJL3200'},
#  {'answer': 'carrying box',
#   'id': 891,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1814'},
#  {'answer': 'turning on lights',
#   'id': 892,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1814'},
#  {'answer': 'opening box',
#   'id': 893,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1814'},
#  {'answer': 'green',
#   'id': 894,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1099'},
#  {'answer': 'grass green',
#   'id': 895,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1099'},
#  {'answer': 'reseda',
#   'id': 896,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1099'},
#  {'answer': 'standing',
#   'id': 897,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1738'},
#  {'answer': 'green',
#   'id': 898,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1463'},
#  {'answer': 'red',
#   'id': 899,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1463'},
#  {'answer': 'white',
#   'id': 900,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1463'},
#  {'answer': 'on stage',
#   'id': 901,
#   'question': 'where is the man in the rompers',
#   'video_name': 'ZJL746'},
#  {'answer': 'black',
#   'id': 902,
#   'question': 'what is the color of the clothes the woman wears',
#   'video_name': 'ZJL2909'},
#  {'answer': 'white',
#   'id': 903,
#   'question': 'what is the color of the clothes the woman wears',
#   'video_name': 'ZJL2909'},
#  {'answer': 'red',
#   'id': 904,
#   'question': 'what is the color of the clothes the woman wears',
#   'video_name': 'ZJL2909'},
#  {'answer': 'knife',
#   'id': 905,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1416'},
#  {'answer': 'sleeve-fish',
#   'id': 906,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1416'},
#  {'answer': 'plate',
#   'id': 907,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1416'},
#  {'answer': 'taking cup',
#   'id': 908,
#   'question': 'what is the person in white doing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': 'drinking water',
#   'id': 909,
#   'question': 'what is the person in white doing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': 'putting down cup',
#   'id': 910,
#   'question': 'what is the person in white doing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': 'kitchen',
#   'id': 911,
#   'question': 'where is the man',
#   'video_name': 'ZJL168'},
#  {'answer': 'in door',
#   'id': 912,
#   'question': 'where are those two people',
#   'video_name': 'ZJL2896'},
#  {'answer': 'hat',
#   'id': 913,
#   'question': 'what is in the video',
#   'video_name': 'ZJL890'},
#  {'answer': 'green plant',
#   'id': 914,
#   'question': 'what is in the video',
#   'video_name': 'ZJL890'},
#  {'answer': 'lawn',
#   'id': 915,
#   'question': 'what is in the video',
#   'video_name': 'ZJL890'},
#  {'answer': 'helmet',
#   'id': 916,
#   'question': 'what is placed in the middle of the crowd in the video',
#   'video_name': 'ZJL2297'},
#  {'answer': 'long hair',
#   'id': 917,
#   'question': 'does the person in the video have long hair or short hair',
#   'video_name': 'ZJL653'},
#  {'answer': 'sitting on sofa',
#   'id': 918,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3760'},
#  {'answer': 'putting carton',
#   'id': 919,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3760'},
#  {'answer': 'taking things',
#   'id': 920,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3760'},
#  {'answer': 'red',
#   'id': 921,
#   'question': 'what color top does the little girl wear in the video',
#   'video_name': 'ZJL2246'},
#  {'answer': 'rose red',
#   'id': 922,
#   'question': 'what color top does the little girl wear in the video',
#   'video_name': 'ZJL2246'},
#  {'answer': 'pink',
#   'id': 923,
#   'question': 'what color top does the little girl wear in the video',
#   'video_name': 'ZJL2246'},
#  {'answer': 'cups',
#   'id': 924,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3252'},
#  {'answer': 'door',
#   'id': 925,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3252'},
#  {'answer': 'watch',
#   'id': 926,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3252'},
#  {'answer': 'daytime',
#   'id': 927,
#   'question': 'what time is it in the video',
#   'video_name': 'ZJL3400'},
#  {'answer': 'morning',
#   'id': 928,
#   'question': 'what time is it in the video',
#   'video_name': 'ZJL3400'},
#  {'answer': 'photograph',
#   'id': 929,
#   'question': 'what is the last thing in the video',
#   'video_name': 'ZJL864'},
#  {'answer': 'gloves',
#   'id': 930,
#   'question': 'what is the singing person wearing in the video',
#   'video_name': 'ZJL2458'},
#  {'answer': 'looking at computer',
#   'id': 931,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4061'},
#  {'answer': 'making phone calls',
#   'id': 932,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4061'},
#  {'answer': 'putting away things',
#   'id': 933,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4061'},
#  {'answer': 'standing',
#   'id': 934,
#   'question': 'is the person in blue sitting or standing in the video',
#   'video_name': 'ZJL3384'},
#  {'answer': 'chair',
#   'id': 935,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2724'},
#  {'answer': 'table',
#   'id': 936,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2724'},
#  {'answer': 'window',
#   'id': 937,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2724'},
#  {'answer': 'stage',
#   'id': 938,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1353'},
#  {'answer': 'indoor',
#   'id': 939,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1353'},
#  {'answer': 'in room',
#   'id': 940,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1353'},
#  {'answer': 'car door',
#   'id': 941,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1144'},
#  {'answer': 'seat',
#   'id': 942,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1144'},
#  {'answer': 'steering wheel',
#   'id': 943,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1144'},
#  {'answer': 'white',
#   'id': 944,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4244'},
#  {'answer': 'beige white',
#   'id': 945,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4244'},
#  {'answer': 'milk white',
#   'id': 946,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4244'},
#  {'answer': 'black',
#   'id': 947,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1360'},
#  {'answer': 'aterrimus',
#   'id': 948,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1360'},
#  {'answer': 'furvous',
#   'id': 949,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1360'},
#  {'answer': 'standing',
#   'id': 950,
#   'question': 'is the man standing or sitting in the video',
#   'video_name': 'ZJL1218'},
#  {'answer': 'standing',
#   'id': 951,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2141'},
#  {'answer': 'taking something',
#   'id': 952,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL265'},
#  {'answer': 'tidying',
#   'id': 953,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL265'},
#  {'answer': 'playing mobile phone',
#   'id': 954,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL265'},
#  {'answer': 'making toy',
#   'id': 955,
#   'question': 'what is the hand doing in the video',
#   'video_name': 'ZJL1502'},
#  {'answer': 'black',
#   'id': 956,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL4225'},
#  {'answer': 'book',
#   'id': 957,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL2346'},
#  {'answer': 'speaking',
#   'id': 958,
#   'question': 'what is the grandmother doing in the video',
#   'video_name': 'ZJL1296'},
#  {'answer': 'performing magic',
#   'id': 959,
#   'question': 'what is the grandmother doing in the video',
#   'video_name': 'ZJL1296'},
#  {'answer': 'white',
#   'id': 960,
#   'question': 'what is the color of th boat in the video',
#   'video_name': 'ZJL2243'},
#  {'answer': 'gray',
#   'id': 961,
#   'question': 'what color is the dress of the person in the video',
#   'video_name': 'ZJL2815'},
#  {'answer': 'table',
#   'id': 962,
#   'question': 'what is on the left side of the chair',
#   'video_name': 'ZJL3573'},
#  {'answer': 'hearth',
#   'id': 963,
#   'question': 'what is on the left side of the chair',
#   'video_name': 'ZJL3573'},
#  {'answer': 'pot',
#   'id': 964,
#   'question': 'what is on the left side of the chair',
#   'video_name': 'ZJL3573'},
#  {'answer': 'singing',
#   'id': 965,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1457'},
#  {'answer': 'talking',
#   'id': 966,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2517'},
#  {'answer': 'having conversation',
#   'id': 967,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2517'},
#  {'answer': 'making interview',
#   'id': 968,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2517'},
#  {'answer': 'watching tv',
#   'id': 969,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1641'},
#  {'answer': 'opening refrigerator',
#   'id': 970,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1641'},
#  {'answer': 'drinking beverage',
#   'id': 971,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1641'},
#  {'answer': 'clothes',
#   'id': 972,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'boxes',
#   'id': 973,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'hangers',
#   'id': 974,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'cyan',
#   'id': 975,
#   'question': 'what is the color of the water bucket',
#   'video_name': 'ZJL3762'},
#  {'answer': 'light cyan',
#   'id': 976,
#   'question': 'what is the color of the water bucket',
#   'video_name': 'ZJL3762'},
#  {'answer': 'green',
#   'id': 977,
#   'question': 'what is the color of the water bucket',
#   'video_name': 'ZJL3762'},
#  {'answer': 'black',
#   'id': 978,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'white',
#   'id': 979,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'grey',
#   'id': 980,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'green',
#   'id': 981,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2961'},
#  {'answer': 'white',
#   'id': 982,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2961'},
#  {'answer': 'blue',
#   'id': 983,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2961'},
#  {'answer': 'kitchen',
#   'id': 984,
#   'question': 'where does the person enter',
#   'video_name': 'ZJL400'},
#  {'answer': 'green',
#   'id': 985,
#   'question': 'what color is the field in the first video',
#   'video_name': 'ZJL2473'},
#  {'answer': 'cyan',
#   'id': 986,
#   'question': 'what color is the field in the first video',
#   'video_name': 'ZJL2473'},
#  {'answer': 'viridis',
#   'id': 987,
#   'question': 'what color is the field in the first video',
#   'video_name': 'ZJL2473'},
#  {'answer': 'picking up towel',
#   'id': 988,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL593'},
#  {'answer': 'sneezing',
#   'id': 989,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL593'},
#  {'answer': 'drinking water',
#   'id': 990,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL593'},
#  {'answer': 'in car',
#   'id': 991,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1192'},
#  {'answer': 'white',
#   'id': 992,
#   'question': 'what color is the dresser in the video',
#   'video_name': 'ZJL1160'},
#  {'answer': 'indoors',
#   'id': 993,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4080'},
#  {'answer': 'in house',
#   'id': 994,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4080'},
#  {'answer': 'in living room',
#   'id': 995,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4080'},
#  {'answer': 'switch',
#   'id': 996,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3817'},
#  {'answer': 'carpet',
#   'id': 997,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3817'},
#  {'answer': 'sofa',
#   'id': 998,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3817'},
#  {'answer': 'in door',
#   'id': 999,
#   'question': 'where is the man',
#   'video_name': 'ZJL2981'},
#  ...]

# %%
data_list_train
# Out:
# [{'answer': 'shooting site',
#   'id': 3000,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1326'},
#  {'answer': 'cup',
#   'id': 3001,
#   'question': 'what does the person have on his left hand',
#   'video_name': 'ZJL342'},
#  {'answer': 'grey',
#   'id': 3002,
#   'question': "what is the color of person's coat in video",
#   'video_name': 'ZJL2600'},
#  {'answer': 'dark grey',
#   'id': 3003,
#   'question': "what is the color of person's coat in video",
#   'video_name': 'ZJL2600'},
#  {'answer': 'purple grey',
#   'id': 3004,
#   'question': "what is the color of person's coat in video",
#   'video_name': 'ZJL2600'},
#  {'answer': 'white',
#   'id': 3005,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL4222'},
#  {'answer': 'talking',
#   'id': 3006,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL865'},
#  {'answer': 'fetching things',
#   'id': 3007,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL865'},
#  {'answer': 'putting things',
#   'id': 3008,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL865'},
#  {'answer': 'dressing his hair',
#   'id': 3009,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3185'},
#  {'answer': 'drinking water',
#   'id': 3010,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3185'},
#  {'answer': 'picking up broom',
#   'id': 3011,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3185'},
#  {'answer': 'yellow',
#   'id': 3012,
#   'question': 'what colour shirt does the goalscorer wear in video',
#   'video_name': 'ZJL2581'},
#  {'answer': 'flower',
#   'id': 3013,
#   'question': 'what is the pattern on the plate in the video',
#   'video_name': 'ZJL2812'},
#  {'answer': 'noodle',
#   'id': 3014,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1322'},
#  {'answer': 'shrimp meat',
#   'id': 3015,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1322'},
#  {'answer': 'plate',
#   'id': 3016,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1322'},
#  {'answer': 'indoors',
#   'id': 3017,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4082'},
#  {'answer': 'in house',
#   'id': 3018,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4082'},
#  {'answer': 'in living room',
#   'id': 3019,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4082'},
#  {'answer': 'indoor',
#   'id': 3020,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washroom',
#   'id': 3021,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'residence',
#   'id': 3022,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'indoor',
#   'id': 3023,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3164'},
#  {'answer': 'in house',
#   'id': 3024,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3164'},
#  {'answer': 'in living room',
#   'id': 3025,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3164'},
#  {'answer': 'on lawn',
#   'id': 3026,
#   'question': 'where is the boy in the video',
#   'video_name': 'ZJL741'},
#  {'answer': 'taking photo',
#   'id': 3027,
#   'question': 'what is the person with glasses doing in the video',
#   'video_name': 'ZJL1811'},
#  {'answer': 'grey',
#   'id': 3028,
#   'question': "what color is the person's pants in the video",
#   'video_name': 'ZJL4065'},
#  {'answer': 'grey and white',
#   'id': 3029,
#   'question': "what color is the person's pants in the video",
#   'video_name': 'ZJL4065'},
#  {'answer': 'silver grey',
#   'id': 3030,
#   'question': "what color is the person's pants in the video",
#   'video_name': 'ZJL4065'},
#  {'answer': 'white',
#   'id': 3031,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL532'},
#  {'answer': 'hat',
#   'id': 3032,
#   'question': 'what is wearing on the head of the person in the video',
#   'video_name': 'ZJL2753'},
#  {'answer': 'brown',
#   'id': 3033,
#   'question': "what color is the sheep's hair in the video",
#   'video_name': 'ZJL2302'},
#  {'answer': 'light brown',
#   'id': 3034,
#   'question': "what color is the sheep's hair in the video",
#   'video_name': 'ZJL2302'},
#  {'answer': 'brown and white',
#   'id': 3035,
#   'question': "what color is the sheep's hair in the video",
#   'video_name': 'ZJL2302'},
#  {'answer': 'show',
#   'id': 3036,
#   'question': 'where is the model in the video',
#   'video_name': 'ZJL782'},
#  {'answer': 'blue',
#   'id': 3037,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': 'dark blue',
#   'id': 3038,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': 'sky blue',
#   'id': 3039,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': 'purple',
#   'id': 3040,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2202'},
#  {'answer': 'dark purple',
#   'id': 3041,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2202'},
#  {'answer': 'light purple',
#   'id': 3042,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2202'},
#  {'answer': 'standing',
#   'id': 3043,
#   'question': 'is the person in video sitting or standing before opening the box',
#   'video_name': 'ZJL3931'},
#  {'answer': 'right hand',
#   'id': 3044,
#   'question': 'is the person in the video reaching out with the right hand or the left hand',
#   'video_name': 'ZJL1747'},
#  {'answer': 'standing',
#   'id': 3045,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1148'},
#  {'answer': 'standing',
#   'id': 3046,
#   'question': 'is the person under the spotlight standing or sitting',
#   'video_name': 'ZJL217'},
#  {'answer': 'blue',
#   'id': 3047,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL959'},
#  {'answer': 'light blue',
#   'id': 3048,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL959'},
#  {'answer': 'azure',
#   'id': 3049,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL959'},
#  {'answer': 'speaking',
#   'id': 3050,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1152'},
#  {'answer': 'walking',
#   'id': 3051,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1152'},
#  {'answer': 'yellow',
#   'id': 3052,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4108'},
#  {'answer': 'light yellow',
#   'id': 3053,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4108'},
#  {'answer': 'black',
#   'id': 3054,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1840'},
#  {'answer': 'standing',
#   'id': 3055,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3439'},
#  {'answer': 'drinking water',
#   'id': 3056,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4001'},
#  {'answer': 'taking napkins',
#   'id': 3057,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4001'},
#  {'answer': 'putting cups',
#   'id': 3058,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4001'},
#  {'answer': 'human',
#   'id': 3059,
#   'question': 'what is on the stool',
#   'video_name': 'ZJL2910'},
#  {'answer': 'pillow',
#   'id': 3060,
#   'question': 'what is on the stool',
#   'video_name': 'ZJL2910'},
#  {'answer': 'computer',
#   'id': 3061,
#   'question': 'what is on the stool',
#   'video_name': 'ZJL2910'},
#  {'answer': 'paper',
#   'id': 3062,
#   'question': 'what is on the door of the refrigerator',
#   'video_name': 'ZJL45'},
#  {'answer': 'magnet',
#   'id': 3063,
#   'question': 'what is on the door of the refrigerator',
#   'video_name': 'ZJL45'},
#  {'answer': 'pictures',
#   'id': 3064,
#   'question': 'what is on the door of the refrigerator',
#   'video_name': 'ZJL45'},
#  {'answer': 'white',
#   'id': 3065,
#   'question': 'what is the color of the clothes does the man wear in video',
#   'video_name': 'ZJL25'},
#  {'answer': 'creamy-white',
#   'id': 3066,
#   'question': 'what is the color of the clothes does the man wear in video',
#   'video_name': 'ZJL25'},
#  {'answer': 'milk-white',
#   'id': 3067,
#   'question': 'what is the color of the clothes does the man wear in video',
#   'video_name': 'ZJL25'},
#  {'answer': 'playing guitar',
#   'id': 3068,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL2685'},
#  {'answer': 'playing',
#   'id': 3069,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL2685'},
#  {'answer': 'crowbar',
#   'id': 3070,
#   'question': 'what is tool is in the game',
#   'video_name': 'ZJL2555'},
#  {'answer': 'cartoon',
#   'id': 3071,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2285'},
#  {'answer': 'in bottom of sea',
#   'id': 3072,
#   'question': 'where is the cartoon character in the video',
#   'video_name': 'ZJL1458'},
#  {'answer': 'sitting',
#   'id': 3073,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1851'},
#  {'answer': 'standing up',
#   'id': 3074,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1851'},
#  {'answer': 'pulling door',
#   'id': 3075,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1851'},
#  {'answer': 'bag',
#   'id': 3076,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL123'},
#  {'answer': 'cell phone',
#   'id': 3077,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL123'},
#  {'answer': 'clothes',
#   'id': 3078,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL123'},
#  {'answer': 'in car',
#   'id': 3079,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL2627'},
#  {'answer': 'bracelet',
#   'id': 3080,
#   'question': 'what is the person wearing the video',
#   'video_name': 'ZJL1768'},
#  {'answer': 'applausing',
#   'id': 3081,
#   'question': 'what is the audience doing',
#   'video_name': 'ZJL1368'},
#  {'answer': 'watching program',
#   'id': 3082,
#   'question': 'what is the audience doing',
#   'video_name': 'ZJL1368'},
#  {'answer': 'enjoying program',
#   'id': 3083,
#   'question': 'what is the audience doing',
#   'video_name': 'ZJL1368'},
#  {'answer': 'short hair',
#   'id': 3084,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL2448'},
#  {'answer': 'chatting',
#   'id': 3085,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1414'},
#  {'answer': 'speaking',
#   'id': 3086,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1414'},
#  {'answer': 'serving food',
#   'id': 3087,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1414'},
#  {'answer': 'looking in mirror',
#   'id': 3088,
#   'question': 'what is the person in short sleeved shirt doing in the video',
#   'video_name': 'ZJL3196'},
#  {'answer': 'speaking',
#   'id': 3089,
#   'question': 'what is the person in short sleeved shirt doing in the video',
#   'video_name': 'ZJL3196'},
#  {'answer': 'having rest',
#   'id': 3090,
#   'question': 'what is the person in short sleeved shirt doing in the video',
#   'video_name': 'ZJL3196'},
#  {'answer': 'standing',
#   'id': 3091,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL695'},
#  {'answer': 'green',
#   'id': 3092,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL531'},
#  {'answer': 'grass green',
#   'id': 3093,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL531'},
#  {'answer': 'light green',
#   'id': 3094,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL531'},
#  {'answer': 'sitting',
#   'id': 3095,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3441'},
#  {'answer': 'microphone',
#   'id': 3096,
#   'question': 'what is on the stage',
#   'video_name': 'ZJL3385'},
#  {'answer': 'acoustics',
#   'id': 3097,
#   'question': 'what is on the stage',
#   'video_name': 'ZJL3385'},
#  {'answer': 'drum set',
#   'id': 3098,
#   'question': 'what is on the stage',
#   'video_name': 'ZJL3385'},
#  {'answer': 'cup',
#   'id': 3099,
#   'question': 'what is on the table',
#   'video_name': 'ZJL44'},
#  {'answer': 'can',
#   'id': 3100,
#   'question': 'what is on the table',
#   'video_name': 'ZJL44'},
#  {'answer': 'plate',
#   'id': 3101,
#   'question': 'what is on the table',
#   'video_name': 'ZJL44'},
#  {'answer': 'tidying',
#   'id': 3102,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2329'},
#  {'answer': 'taking bowel',
#   'id': 3103,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3850'},
#  {'answer': 'sneezing',
#   'id': 3104,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3850'},
#  {'answer': 'rubbing nose',
#   'id': 3105,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3850'},
#  {'answer': 'standing',
#   'id': 3106,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4144'},
#  {'answer': 'blue',
#   'id': 3107,
#   'question': 'what is the color of the dog house in video',
#   'video_name': 'ZJL3406'},
#  {'answer': 'light blue',
#   'id': 3108,
#   'question': 'what is the color of the dog house in video',
#   'video_name': 'ZJL3406'},
#  {'answer': 'azure',
#   'id': 3109,
#   'question': 'what is the color of the dog house in video',
#   'video_name': 'ZJL3406'},
#  {'answer': 'taking pictures',
#   'id': 3110,
#   'question': 'what is the person on the ground doing',
#   'video_name': 'ZJL150'},
#  {'answer': 'tidying',
#   'id': 3111,
#   'question': 'what is the person on the ground doing',
#   'video_name': 'ZJL150'},
#  {'answer': 'playing cell phone',
#   'id': 3112,
#   'question': 'what is the person on the ground doing',
#   'video_name': 'ZJL150'},
#  {'answer': 'kitchen',
#   'id': 3113,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1827'},
#  {'answer': 'looking at phone',
#   'id': 3114,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2190'},
#  {'answer': 'going downstairs',
#   'id': 3115,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2190'},
#  {'answer': 'calling',
#   'id': 3116,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2190'},
#  {'answer': 'black',
#   'id': 3117,
#   'question': 'what is the color of the hat',
#   'video_name': 'ZJL2514'},
#  {'answer': 'pure-black',
#   'id': 3118,
#   'question': 'what is the color of the hat',
#   'video_name': 'ZJL2514'},
#  {'answer': 'drinking water',
#   'id': 3119,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3963'},
#  {'answer': 'putting down cup',
#   'id': 3120,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3963'},
#  {'answer': 'sneezing',
#   'id': 3121,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3963'},
#  {'answer': 'on wall',
#   'id': 3122,
#   'question': 'where is the television in the video',
#   'video_name': 'ZJL524'},
#  {'answer': 'standing',
#   'id': 3123,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3937'},
#  {'answer': 'attending meeting',
#   'id': 3124,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1351'},
#  {'answer': 'debating',
#   'id': 3125,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1351'},
#  {'answer': 'presidential debate',
#   'id': 3126,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1351'},
#  {'answer': 'dark blue',
#   'id': 3127,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL2353'},
#  {'answer': 'hugging pillow',
#   'id': 3128,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2116'},
#  {'answer': 'taking pillow',
#   'id': 3129,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2116'},
#  {'answer': 'throwing pillow',
#   'id': 3130,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2116'},
#  {'answer': 'speaking',
#   'id': 3131,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1421'},
#  {'answer': 'washing machine',
#   'id': 3132,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3734'},
#  {'answer': 'bottle',
#   'id': 3133,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3734'},
#  {'answer': 'basket',
#   'id': 3134,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3734'},
#  {'answer': 'shaking',
#   'id': 3135,
#   'question': 'what is the plane doing in the video',
#   'video_name': 'ZJL2477'},
#  {'answer': 'two',
#   'id': 3136,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2772'},
#  {'answer': 'indoor',
#   'id': 3137,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4112'},
#  {'answer': 'residence',
#   'id': 3138,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4112'},
#  {'answer': 'bathroom',
#   'id': 3139,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4112'},
#  {'answer': 'grey',
#   'id': 3140,
#   'question': 'what color clothes does man wear in the video',
#   'video_name': 'ZJL2362'},
#  {'answer': 'french grey',
#   'id': 3141,
#   'question': 'what color clothes does man wear in the video',
#   'video_name': 'ZJL2362'},
#  {'answer': 'light grey',
#   'id': 3142,
#   'question': 'what color clothes does man wear in the video',
#   'video_name': 'ZJL2362'},
#  {'answer': 'grass',
#   'id': 3143,
#   'question': 'what did the girl wearing the red boots in the video feed the horse',
#   'video_name': 'ZJL2275'},
#  {'answer': 'standing',
#   'id': 3144,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL902'},
#  {'answer': 'washing machine',
#   'id': 3145,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL4016'},
#  {'answer': 'laundry detergent',
#   'id': 3146,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL4016'},
#  {'answer': 'paper box',
#   'id': 3147,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL4016'},
#  {'answer': 'sitting',
#   'id': 3148,
#   'question': 'is the person with a pen in the video standing or sitting',
#   'video_name': 'ZJL389'},
#  {'answer': 'pot',
#   'id': 3149,
#   'question': 'what is in the video',
#   'video_name': 'ZJL874'},
#  {'answer': 'vegetable',
#   'id': 3150,
#   'question': 'what is in the video',
#   'video_name': 'ZJL874'},
#  {'answer': 'bowl',
#   'id': 3151,
#   'question': 'what is in the video',
#   'video_name': 'ZJL874'},
#  {'answer': 'white',
#   'id': 3152,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL24'},
#  {'answer': 'creamy-white',
#   'id': 3153,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL24'},
#  {'answer': 'milk-white',
#   'id': 3154,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL24'},
#  {'answer': 'sitting',
#   'id': 3155,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3786'},
#  {'answer': 'indoor',
#   'id': 3156,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2997'},
#  {'answer': 'residence',
#   'id': 3157,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2997'},
#  {'answer': 'living room',
#   'id': 3158,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2997'},
#  {'answer': 'black',
#   'id': 3159,
#   'question': 'what color pants does the person in the video wear',
#   'video_name': 'ZJL3699'},
#  {'answer': 'watching video',
#   'id': 3160,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3093'},
#  {'answer': 'clearing up clothes',
#   'id': 3161,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3093'},
#  {'answer': 'opening door',
#   'id': 3162,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3093'},
#  {'answer': 'green',
#   'id': 3163,
#   'question': 'what is the color of the trousers does the person wear in video',
#   'video_name': 'ZJL16'},
#  {'answer': 'light green',
#   'id': 3164,
#   'question': 'what is the color of the trousers does the person wear in video',
#   'video_name': 'ZJL16'},
#  {'answer': 'grass green',
#   'id': 3165,
#   'question': 'what is the color of the trousers does the person wear in video',
#   'video_name': 'ZJL16'},
#  {'answer': 'on',
#   'id': 3166,
#   'question': 'is the mobile phone in video on or off',
#   'video_name': 'ZJL2664'},
#  {'answer': 'making bed',
#   'id': 3167,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2155'},
#  {'answer': 'taking things',
#   'id': 3168,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2155'},
#  {'answer': 'turning around',
#   'id': 3169,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2155'},
#  {'answer': 'lying on his stomach',
#   'id': 3170,
#   'question': 'is the person sitting or lying on his stomach in the beginning of the video',
#   'video_name': 'ZJL4070'},
#  {'answer': 'taking towel',
#   'id': 3171,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2140'},
#  {'answer': 'putting on lipsticks',
#   'id': 3172,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2140'},
#  {'answer': 'wiping mirror',
#   'id': 3173,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2140'},
#  {'answer': 'book',
#   'id': 3174,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4145'},
#  {'answer': 'plastic bag',
#   'id': 3175,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4145'},
#  {'answer': 'clothing',
#   'id': 3176,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4145'},
#  {'answer': 'shelf',
#   'id': 3177,
#   'question': 'what is on the wall in the video',
#   'video_name': 'ZJL599'},
#  {'answer': 'gray',
#   'id': 3178,
#   'question': 'what color of the clothes does the man wear in the video',
#   'video_name': 'ZJL1264'},
#  {'answer': 'grey',
#   'id': 3179,
#   'question': "what is the color of man's clothes in video",
#   'video_name': 'ZJL2686'},
#  {'answer': 'light grey',
#   'id': 3180,
#   'question': "what is the color of man's clothes in video",
#   'video_name': 'ZJL2686'},
#  {'answer': 'medium grey',
#   'id': 3181,
#   'question': "what is the color of man's clothes in video",
#   'video_name': 'ZJL2686'},
#  {'answer': 'in kitchen',
#   'id': 3182,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3528'},
#  {'answer': 'pillow',
#   'id': 3183,
#   'question': "what is in the man's hands",
#   'video_name': 'ZJL161'},
#  {'answer': 'cell phone',
#   'id': 3184,
#   'question': "what is in the man's hands",
#   'video_name': 'ZJL161'},
#  {'answer': 'clothes',
#   'id': 3185,
#   'question': "what is in the man's hands",
#   'video_name': 'ZJL161'},
#  {'answer': 'lying down',
#   'id': 3186,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2797'},
#  {'answer': 'resting',
#   'id': 3187,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2797'},
#  {'answer': 'vomiting',
#   'id': 3188,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2797'},
#  {'answer': 'black',
#   'id': 3189,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL566'},
#  {'answer': 'white',
#   'id': 3190,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1584'},
#  {'answer': 'on top',
#   'id': 3191,
#   'question': 'where is the blue fist in the barrel-shape house',
#   'video_name': 'ZJL2519'},
#  {'answer': 'on roof',
#   'id': 3192,
#   'question': 'where is the blue fist in the barrel-shape house',
#   'video_name': 'ZJL2519'},
#  {'answer': 'at top of house',
#   'id': 3193,
#   'question': 'where is the blue fist in the barrel-shape house',
#   'video_name': 'ZJL2519'},
#  {'answer': 'auditorium',
#   'id': 3194,
#   'question': 'where is the audience in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': 'standing',
#   'id': 3195,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4269'},
#  {'answer': 'standing',
#   'id': 3196,
#   'question': 'is the person in short sleeved shirt in the video sitting or standing',
#   'video_name': 'ZJL3196'},
#  {'answer': 'standing',
#   'id': 3197,
#   'question': 'is the person wearing a glasses in the video sitting or standing',
#   'video_name': 'ZJL1179'},
#  {'answer': 'indoor',
#   'id': 3198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3189'},
#  {'answer': 'in house',
#   'id': 3199,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3189'},
#  {'answer': 'in bedroom',
#   'id': 3200,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3189'},
#  {'answer': 'photo',
#   'id': 3201,
#   'question': 'what is on the cabinet',
#   'video_name': 'ZJL64'},
#  {'answer': 'quilt',
#   'id': 3202,
#   'question': 'what is on the cabinet',
#   'video_name': 'ZJL64'},
#  {'answer': 'pendulum table',
#   'id': 3203,
#   'question': 'what is on the cabinet',
#   'video_name': 'ZJL64'},
#  {'answer': 'watching tv',
#   'id': 3204,
#   'question': 'what is the person in red in the video doing',
#   'video_name': 'ZJL1657'},
#  {'answer': 'blue',
#   'id': 3205,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL2042'},
#  {'answer': 'dark blue',
#   'id': 3206,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL2042'},
#  {'answer': 'royal blue',
#   'id': 3207,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL2042'},
#  {'answer': 'next to football field',
#   'id': 3208,
#   'question': 'where is the audience',
#   'video_name': 'ZJL1166'},
#  {'answer': 'on auditorium',
#   'id': 3209,
#   'question': 'where is the audience',
#   'video_name': 'ZJL1166'},
#  {'answer': 'outdoor',
#   'id': 3210,
#   'question': 'where is the audience',
#   'video_name': 'ZJL1166'},
#  {'answer': 'sitting',
#   'id': 3211,
#   'question': 'is the man in the video sitting or standing',
#   'video_name': 'ZJL1448'},
#  {'answer': 'left hand',
#   'id': 3212,
#   'question': 'which hand of the host in the video takes the book',
#   'video_name': 'ZJL2263'},
#  {'answer': 'indoors',
#   'id': 3213,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4001'},
#  {'answer': 'in house',
#   'id': 3214,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4001'},
#  {'answer': 'in kitchen',
#   'id': 3215,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4001'},
#  {'answer': 'coriander',
#   'id': 3216,
#   'question': 'what is on the food in video',
#   'video_name': 'ZJL2582'},
#  {'answer': 'shallot',
#   'id': 3217,
#   'question': 'what is on the food in video',
#   'video_name': 'ZJL2582'},
#  {'answer': 'bean sprout',
#   'id': 3218,
#   'question': 'what is on the food in video',
#   'video_name': 'ZJL2582'},
#  {'answer': 'standing',
#   'id': 3219,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1337'},
#  {'answer': 'standing',
#   'id': 3220,
#   'question': 'is the person holding the bag in the video standing or sitting',
#   'video_name': 'ZJL2276'},
#  {'answer': 'on head',
#   'id': 3221,
#   'question': 'where is the crown in the video',
#   'video_name': 'ZJL1295'},
#  {'answer': 'brown',
#   'id': 3222,
#   'question': 'what color is the roof in the video',
#   'video_name': 'ZJL2871'},
#  {'answer': 'kitchen',
#   'id': 3223,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL917'},
#  {'answer': 'five',
#   'id': 3224,
#   'question': 'what numbers appear in the picture in video',
#   'video_name': 'ZJL2612'},
#  {'answer': 'six',
#   'id': 3225,
#   'question': 'what numbers appear in the picture in video',
#   'video_name': 'ZJL2612'},
#  {'answer': 'red',
#   'id': 3226,
#   'question': "what is the color of the pattern on the girl's hat",
#   'video_name': 'ZJL2520'},
#  {'answer': 'dark-red',
#   'id': 3227,
#   'question': "what is the color of the pattern on the girl's hat",
#   'video_name': 'ZJL2520'},
#  {'answer': 'blue',
#   'id': 3228,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2222'},
#  {'answer': 'sky blue',
#   'id': 3229,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2222'},
#  {'answer': 'ocean blue',
#   'id': 3230,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2222'},
#  {'answer': 'blue',
#   'id': 3231,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3031'},
#  {'answer': 'navy blue',
#   'id': 3232,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3031'},
#  {'answer': 'azure blue',
#   'id': 3233,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3031'},
#  {'answer': 'on hanger',
#   'id': 3234,
#   'question': 'where is the clothes',
#   'video_name': 'ZJL737'},
#  {'answer': 'getting off water',
#   'id': 3235,
#   'question': 'what is the person in the water in video doing',
#   'video_name': 'ZJL2265'},
#  {'answer': 'taking rope',
#   'id': 3236,
#   'question': 'what is the person in the water in video doing',
#   'video_name': 'ZJL2265'},
#  {'answer': 'taking boat',
#   'id': 3237,
#   'question': 'what is the person in the water in video doing',
#   'video_name': 'ZJL2265'},
#  {'answer': 'bowl',
#   'id': 3238,
#   'question': 'what is in the video',
#   'video_name': 'ZJL843'},
#  {'answer': 'spoon',
#   'id': 3239,
#   'question': 'what is in the video',
#   'video_name': 'ZJL843'},
#  {'answer': 'vegetables',
#   'id': 3240,
#   'question': 'what is in the video',
#   'video_name': 'ZJL843'},
#  {'answer': 'drinking water',
#   'id': 3241,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL410'},
#  {'answer': 'looking in mirror',
#   'id': 3242,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL410'},
#  {'answer': 'on table',
#   'id': 3243,
#   'question': 'where is the cup in the video',
#   'video_name': 'ZJL922'},
#  {'answer': 'computer',
#   'id': 3244,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL109'},
#  {'answer': 'cell phone',
#   'id': 3245,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL109'},
#  {'answer': 'clothes',
#   'id': 3246,
#   'question': 'what is in front of the man',
#   'video_name': 'ZJL109'},
#  {'answer': 'kitchen',
#   'id': 3247,
#   'question': 'where is the woman',
#   'video_name': 'ZJL126'},
#  {'answer': 'sitting',
#   'id': 3248,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL865'},
#  {'answer': 'black',
#   'id': 3249,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL351'},
#  {'answer': 'pure black',
#   'id': 3250,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL351'},
#  {'answer': 'dark black',
#   'id': 3251,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL351'},
#  {'answer': 'doing cleaning',
#   'id': 3252,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL483'},
#  {'answer': 'eating',
#   'id': 3253,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3524'},
#  {'answer': 'dark gray',
#   'id': 3254,
#   'question': 'what is the color of the clothes in the video',
#   'video_name': 'ZJL1789'},
#  {'answer': 'yellow',
#   'id': 3255,
#   'question': 'what color is the food in the video',
#   'video_name': 'ZJL2510'},
#  {'answer': 'light-yellow',
#   'id': 3256,
#   'question': 'what color is the food in the video',
#   'video_name': 'ZJL2510'},
#  {'answer': 'beige',
#   'id': 3257,
#   'question': 'what color is the food in the video',
#   'video_name': 'ZJL2510'},
#  {'answer': 'painting',
#   'id': 3258,
#   'question': 'what is on the wall',
#   'video_name': 'ZJL331'},
#  {'answer': 'running',
#   'id': 3259,
#   'question': 'is the car running or stopped in the video',
#   'video_name': 'ZJL1514'},
#  {'answer': 'standing',
#   'id': 3260,
#   'question': 'does the person in the video sit or stand while using the vacuum cleaner',
#   'video_name': 'ZJL4086'},
#  {'answer': 'deskside',
#   'id': 3261,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL286'},
#  {'answer': 'standing',
#   'id': 3262,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL412'},
#  {'answer': 'talking',
#   'id': 3263,
#   'question': 'what is the men doing in video',
#   'video_name': 'ZJL2578'},
#  {'answer': 'grey',
#   'id': 3264,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3706'},
#  {'answer': 'dark grey',
#   'id': 3265,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3706'},
#  {'answer': 'light grey',
#   'id': 3266,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3706'},
#  {'answer': 'sitting',
#   'id': 3267,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3288'},
#  {'answer': 'black',
#   'id': 3268,
#   'question': 'what color dress does the person wear in the video',
#   'video_name': 'ZJL2163'},
#  {'answer': 'wiping desk',
#   'id': 3269,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3100'},
#  {'answer': 'clearing up kitchen',
#   'id': 3270,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3100'},
#  {'answer': 'cleaning up',
#   'id': 3271,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3100'},
#  {'answer': 'standing',
#   'id': 3272,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1641'},
#  {'answer': 'red',
#   'id': 3273,
#   'question': 'is the subtitle red or green in video',
#   'video_name': 'ZJL3352'},
#  {'answer': 'drinking water',
#   'id': 3274,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL362'},
#  {'answer': 'putting away bed',
#   'id': 3275,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL362'},
#  {'answer': 'putting computer in bed',
#   'id': 3276,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL362'},
#  {'answer': 'petting cat',
#   'id': 3277,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3792'},
#  {'answer': 'placing stuff',
#   'id': 3278,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3792'},
#  {'answer': 'opening door',
#   'id': 3279,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3792'},
#  {'answer': 'light',
#   'id': 3280,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1368'},
#  {'answer': 'guitar',
#   'id': 3281,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1368'},
#  {'answer': 'microphone',
#   'id': 3282,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1368'},
#  {'answer': 'glasses',
#   'id': 3283,
#   'question': "what is wearing on the woman's face in the video",
#   'video_name': 'ZJL438'},
#  {'answer': 'standing',
#   'id': 3284,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2830'},
#  {'answer': 'fighting',
#   'id': 3285,
#   'question': 'what is the person on the square in the video doing',
#   'video_name': 'ZJL2270'},
#  {'answer': 'by sea',
#   'id': 3286,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1523'},
#  {'answer': 'black',
#   'id': 3287,
#   'question': 'what is the color of the cat in the video',
#   'video_name': 'ZJL527'},
#  {'answer': 'black',
#   'id': 3288,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1592'},
#  {'answer': 'white',
#   'id': 3289,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1592'},
#  {'answer': 'blue',
#   'id': 3290,
#   'question': "what color are the person's clothes in the video",
#   'video_name': 'ZJL1592'},
#  {'answer': 'on table',
#   'id': 3291,
#   'question': 'where is the book',
#   'video_name': 'ZJL633'},
#  {'answer': 'male',
#   'id': 3292,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL876'},
#  {'answer': 'looking into mirror',
#   'id': 3293,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3505'},
#  {'answer': 'standing',
#   'id': 3294,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL2454'},
#  {'answer': 'standing',
#   'id': 3295,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4170'},
#  {'answer': 'corridor',
#   'id': 3296,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2770'},
#  {'answer': 'standing',
#   'id': 3297,
#   'question': 'is the man sitting or standing in the video',
#   'video_name': 'ZJL3126'},
#  {'answer': 'taking off coat',
#   'id': 3298,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2383'},
#  {'answer': 'walking',
#   'id': 3299,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3699'},
#  {'answer': 'taking pillow',
#   'id': 3300,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3699'},
#  {'answer': 'stepping on pillow',
#   'id': 3301,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3699'},
#  {'answer': 'eating',
#   'id': 3302,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL951'},
#  {'answer': 'no',
#   'id': 3303,
#   'question': 'is the girl wearing a necklace',
#   'video_name': 'ZJL1579'},
#  {'answer': 'male',
#   'id': 3304,
#   'question': 'is it a man or a woman who is turning a somersault in the video',
#   'video_name': 'ZJL1147'},
#  {'answer': 'taking cup',
#   'id': 3305,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2138'},
#  {'answer': 'drinking water',
#   'id': 3306,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2138'},
#  {'answer': 'eating',
#   'id': 3307,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2138'},
#  {'answer': 'drinking water',
#   'id': 3308,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1842'},
#  {'answer': 'opening refrigerator',
#   'id': 3309,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1842'},
#  {'answer': 'leaving kitchen',
#   'id': 3310,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1842'},
#  {'answer': 'sitting',
#   'id': 3311,
#   'question': 'is the person standing or sitting in the beginning of the video',
#   'video_name': 'ZJL4084'},
#  {'answer': 'black',
#   'id': 3312,
#   'question': 'what color coat does the person wear in the video',
#   'video_name': 'ZJL3459'},
#  {'answer': 'cleaning',
#   'id': 3313,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2332'},
#  {'answer': 'microphone',
#   'id': 3314,
#   'question': 'what does the bespectacled black man in video hold',
#   'video_name': 'ZJL2699'},
#  {'answer': 'standing',
#   'id': 3315,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1575'},
#  {'answer': 'kitchen',
#   'id': 3316,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3710'},
#  {'answer': 'black',
#   'id': 3317,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2373'},
#  {'answer': 'screen',
#   'id': 3318,
#   'question': 'what is at the back of the man in the video',
#   'video_name': 'ZJL2518'},
#  {'answer': 'viewing screen',
#   'id': 3319,
#   'question': 'what is at the back of the man in the video',
#   'video_name': 'ZJL2518'},
#  {'answer': 'led screen',
#   'id': 3320,
#   'question': 'what is at the back of the man in the video',
#   'video_name': 'ZJL2518'},
#  {'answer': 'plate',
#   'id': 3321,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1608'},
#  {'answer': 'food',
#   'id': 3322,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1608'},
#  {'answer': 'sauce',
#   'id': 3323,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1608'},
#  {'answer': 'standing',
#   'id': 3324,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3209'},
#  {'answer': 'black',
#   'id': 3325,
#   'question': 'what color does the woman wear',
#   'video_name': 'ZJL398'},
#  {'answer': 'pure black',
#   'id': 3326,
#   'question': 'what color does the woman wear',
#   'video_name': 'ZJL398'},
#  {'answer': 'dark black',
#   'id': 3327,
#   'question': 'what color does the woman wear',
#   'video_name': 'ZJL398'},
#  {'answer': 'white',
#   'id': 3328,
#   'question': 'what color is the door',
#   'video_name': 'ZJL2735'},
#  {'answer': 'light white',
#   'id': 3329,
#   'question': 'what color is the door',
#   'video_name': 'ZJL2735'},
#  {'answer': 'beige',
#   'id': 3330,
#   'question': 'what color is the door',
#   'video_name': 'ZJL2735'},
#  {'answer': 'black',
#   'id': 3331,
#   'question': "what is the color of the woman's hair",
#   'video_name': 'ZJL113'},
#  {'answer': 'golden',
#   'id': 3332,
#   'question': "what is the color of the woman's hair",
#   'video_name': 'ZJL113'},
#  {'answer': 'brown',
#   'id': 3333,
#   'question': "what is the color of the woman's hair",
#   'video_name': 'ZJL113'},
#  {'answer': 'throwing things',
#   'id': 3334,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2135'},
#  {'answer': 'moving things',
#   'id': 3335,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2135'},
#  {'answer': 'taking things',
#   'id': 3336,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2135'},
#  {'answer': 'in front of table',
#   'id': 3337,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL721'},
#  {'answer': 'playing computer',
#   'id': 3338,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3119'},
#  {'answer': 'reading book',
#   'id': 3339,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3119'},
#  {'answer': 'writing',
#   'id': 3340,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3119'},
#  {'answer': 'putting clothes',
#   'id': 3341,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3697'},
#  {'answer': 'opening closet',
#   'id': 3342,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3697'},
#  {'answer': 'taking facial mask',
#   'id': 3343,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3697'},
#  {'answer': 'on table',
#   'id': 3344,
#   'question': 'where is the microphone in the video',
#   'video_name': 'ZJL1745'},
#  {'answer': 'standing',
#   'id': 3345,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2833'},
#  {'answer': 'white',
#   'id': 3346,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2173'},
#  {'answer': 'milky white',
#   'id': 3347,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2173'},
#  {'answer': 'off-white',
#   'id': 3348,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2173'},
#  {'answer': 'taking pot salad',
#   'id': 3349,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2762'},
#  {'answer': 'dressing',
#   'id': 3350,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2762'},
#  {'answer': 'cooking',
#   'id': 3351,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2762'},
#  {'answer': 'putting on clothes',
#   'id': 3352,
#   'question': 'what is the person in white clothes doing',
#   'video_name': 'ZJL2064'},
#  {'answer': 'tidying clothes',
#   'id': 3353,
#   'question': 'what is the person in white clothes doing',
#   'video_name': 'ZJL2064'},
#  {'answer': 'buttoning button',
#   'id': 3354,
#   'question': 'what is the person in white clothes doing',
#   'video_name': 'ZJL2064'},
#  {'answer': 'alarm clock',
#   'id': 3355,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3723'},
#  {'answer': 'lamp',
#   'id': 3356,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3723'},
#  {'answer': 'book',
#   'id': 3357,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3723'},
#  {'answer': 'black',
#   'id': 3358,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL1708'},
#  {'answer': 'climbing stairs',
#   'id': 3359,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1065'},
#  {'answer': 'getting bag',
#   'id': 3360,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1065'},
#  {'answer': 'walking down stairs',
#   'id': 3361,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1065'},
#  {'answer': 'cleaner',
#   'id': 3362,
#   'question': 'what is on the right side of the table',
#   'video_name': 'ZJL3552'},
#  {'answer': 'table',
#   'id': 3363,
#   'question': 'what is on the right side of the table',
#   'video_name': 'ZJL3552'},
#  {'answer': 'cabinet',
#   'id': 3364,
#   'question': 'what is on the right side of the table',
#   'video_name': 'ZJL3552'},
#  {'answer': 'house',
#   'id': 3365,
#   'question': 'what is in the video',
#   'video_name': 'ZJL736'},
#  {'answer': 'hat',
#   'id': 3366,
#   'question': 'what is in the video',
#   'video_name': 'ZJL736'},
#  {'answer': 'stick',
#   'id': 3367,
#   'question': 'what is in the video',
#   'video_name': 'ZJL736'},
#  {'answer': 'white',
#   'id': 3368,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL1563'},
#  {'answer': 'black',
#   'id': 3369,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL1563'},
#  {'answer': 'blue',
#   'id': 3370,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL1563'},
#  {'answer': 'corridor',
#   'id': 3371,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2775'},
#  {'answer': 'touching grass',
#   'id': 3372,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1756'},
#  {'answer': 'black',
#   'id': 3373,
#   'question': "what color is the man's hair in the video",
#   'video_name': 'ZJL1286'},
#  {'answer': 'collating wardrobe',
#   'id': 3374,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3023'},
#  {'answer': 'placing clothing',
#   'id': 3375,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3023'},
#  {'answer': 'taking out clothes',
#   'id': 3376,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3023'},
#  {'answer': 'standing',
#   'id': 3377,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL248'},
#  {'answer': 'on bed',
#   'id': 3378,
#   'question': 'where is the man',
#   'video_name': 'ZJL2967'},
#  {'answer': 'hat',
#   'id': 3379,
#   'question': "what is on the man's head in the video",
#   'video_name': 'ZJL497'},
#  {'answer': 'standing',
#   'id': 3380,
#   'question': 'is the man in the video is standing or sitting',
#   'video_name': 'ZJL439'},
#  {'answer': 'in bedroom',
#   'id': 3381,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL3518'},
#  {'answer': 'microphone',
#   'id': 3382,
#   'question': 'what is in the person is hand in the video',
#   'video_name': 'ZJL1770'},
#  {'answer': 'bolster',
#   'id': 3383,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3309'},
#  {'answer': 'dog',
#   'id': 3384,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3309'},
#  {'answer': 'cellphone',
#   'id': 3385,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3309'},
#  {'answer': 'speaking',
#   'id': 3386,
#   'question': 'what is the person wearing a hat doing in the video',
#   'video_name': 'ZJL798'},
#  {'answer': 'recording',
#   'id': 3387,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL299'},
#  {'answer': 'on chair',
#   'id': 3388,
#   'question': 'where is the computer',
#   'video_name': 'ZJL4243'},
#  {'answer': 'black',
#   'id': 3389,
#   'question': 'what color of the coat does the person wear in the video',
# ...
#   'id': 3866,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL63'},
#  {'answer': 'indoor',
#   'id': 3867,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL898'},
#  {'answer': 'room',
#   'id': 3868,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL898'},
#  {'answer': 'house',
#   'id': 3869,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL898'},
#  {'answer': 'white',
#   'id': 3870,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL4022'},
#  {'answer': 'standing',
#   'id': 3871,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2248'},
#  {'answer': 'doing homework',
#   'id': 3872,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2388'},
#  {'answer': 'resting',
#   'id': 3873,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2388'},
#  {'answer': 'playing computer',
#   'id': 3874,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL171'},
#  {'answer': 'tidying',
#   'id': 3875,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL171'},
#  {'answer': 'playing cell phone',
#   'id': 3876,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL171'},
#  {'answer': 'laptop',
#   'id': 3877,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1358'},
#  {'answer': 'glass',
#   'id': 3878,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1358'},
#  {'answer': 'water bottle',
#   'id': 3879,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1358'},
#  {'answer': 'guitar',
#   'id': 3880,
#   'question': 'what do the person in the video have in his hand',
#   'video_name': 'ZJL817'},
#  {'answer': 'sitting',
#   'id': 3881,
#   'question': 'is the woman in the video lying or sitting',
#   'video_name': 'ZJL570'},
#  {'answer': 'indoors',
#   'id': 3882,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4084'},
#  {'answer': 'in house',
#   'id': 3883,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4084'},
#  {'answer': 'in bedroom',
#   'id': 3884,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4084'},
#  {'answer': 'drinking water',
#   'id': 3885,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3265'},
#  {'answer': 'taking bolster',
#   'id': 3886,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3265'},
#  {'answer': 'holding bolster',
#   'id': 3887,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3265'},
#  {'answer': 'fountain',
#   'id': 3888,
#   'question': 'what is behind the person in the video',
#   'video_name': 'ZJL2258'},
#  {'answer': 'pool',
#   'id': 3889,
#   'question': 'what is behind the person in the video',
#   'video_name': 'ZJL2258'},
#  {'answer': 'indoor',
#   'id': 3890,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2167'},
#  {'answer': 'residence',
#   'id': 3891,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2167'},
#  {'answer': 'room',
#   'id': 3892,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2167'},
#  {'answer': 'food',
#   'id': 3893,
#   'question': 'what is on the table',
#   'video_name': 'ZJL2811'},
#  {'answer': 'standing',
#   'id': 3894,
#   'question': 'is the person in video standing or sitting',
#   'video_name': 'ZJL79'},
#  {'answer': 'pink',
#   'id': 3895,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'fleshed-color',
#   'id': 3896,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'pink-red',
#   'id': 3897,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'bathroom',
#   'id': 3898,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL989'},
#  {'answer': 'toilet',
#   'id': 3899,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL989'},
#  {'answer': 'watching photos',
#   'id': 3900,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL814'},
#  {'answer': 'hat',
#   'id': 3901,
#   'question': 'what is on the person is head in the video',
#   'video_name': 'ZJL1663'},
#  {'answer': 'yellow',
#   'id': 3902,
#   'question': 'what color is the leopard in the video',
#   'video_name': 'ZJL1472'},
#  {'answer': 'birdcage',
#   'id': 3903,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3365'},
#  {'answer': 'air conditioner',
#   'id': 3904,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3365'},
#  {'answer': 'chair',
#   'id': 3905,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3365'},
#  {'answer': 'standing',
#   'id': 3906,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4105'},
#  {'answer': 'one',
#   'id': 3907,
#   'question': 'how many choppers in the video',
#   'video_name': 'ZJL1724'},
#  {'answer': 'sitting',
#   'id': 3908,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1539'},
#  {'answer': 'standing',
#   'id': 3909,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2074'},
#  {'answer': 'sitting',
#   'id': 3910,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1007'},
#  {'answer': 'green',
#   'id': 3911,
#   'question': 'what color does the person wear',
#   'video_name': 'ZJL380'},
#  {'answer': 'dark green',
#   'id': 3912,
#   'question': 'what color does the person wear',
#   'video_name': 'ZJL380'},
#  {'answer': 'green and white',
#   'id': 3913,
#   'question': 'what color does the person wear',
#   'video_name': 'ZJL380'},
#  {'answer': 'indoor',
#   'id': 3914,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3580'},
#  {'answer': 'utility room',
#   'id': 3915,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3580'},
#  {'answer': 'residence',
#   'id': 3916,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3580'},
#  {'answer': 'barbershop',
#   'id': 3917,
#   'question': 'where is the animal in the video',
#   'video_name': 'ZJL1122'},
#  {'answer': 'shaking hands',
#   'id': 3918,
#   'question': 'what is the person in red doing',
#   'video_name': 'ZJL3007'},
#  {'answer': 'punching',
#   'id': 3919,
#   'question': 'what is the person in red doing',
#   'video_name': 'ZJL3007'},
#  {'answer': 'throwing things',
#   'id': 3920,
#   'question': 'what is the person in red doing',
#   'video_name': 'ZJL3007'},
#  {'answer': 'chair',
#   'id': 3921,
#   'question': 'what is in front of the cabinet',
#   'video_name': 'ZJL3568'},
#  {'answer': 'curtain',
#   'id': 3922,
#   'question': 'what is in front of the cabinet',
#   'video_name': 'ZJL3568'},
#  {'answer': 'shelf',
#   'id': 3923,
#   'question': 'what is in front of the cabinet',
#   'video_name': 'ZJL3568'},
#  {'answer': 'brown',
#   'id': 3924,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1826'},
#  {'answer': 'sixteen',
#   'id': 3925,
#   'question': "how many square can form one side of the rubik's cube",
#   'video_name': 'ZJL2432'},
#  {'answer': 'one six',
#   'id': 3926,
#   'question': "how many square can form one side of the rubik's cube",
#   'video_name': 'ZJL2432'},
#  {'answer': 'bag',
#   'id': 3927,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1312'},
#  {'answer': 'snacks',
#   'id': 3928,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1312'},
#  {'answer': 'mess tin',
#   'id': 3929,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1312'},
#  {'answer': 'in kitchen',
#   'id': 3930,
#   'question': 'where is the man wearing orange dress',
#   'video_name': 'ZJL3475'},
#  {'answer': 'basketball park',
#   'id': 3931,
#   'question': 'where is man in video',
#   'video_name': 'ZJL2557'},
#  {'answer': 'gymnasium',
#   'id': 3932,
#   'question': 'where is man in video',
#   'video_name': 'ZJL2557'},
#  {'answer': 'basketball stadium',
#   'id': 3933,
#   'question': 'where is man in video',
#   'video_name': 'ZJL2557'},
#  {'answer': 'eating bread',
#   'id': 3934,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2188'},
#  {'answer': 'drinking water',
#   'id': 3935,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2188'},
#  {'answer': 'opening carton',
#   'id': 3936,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2188'},
#  {'answer': 'black',
#   'id': 3937,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3593'},
#  {'answer': 'dark black',
#   'id': 3938,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3593'},
#  {'answer': 'grey black',
#   'id': 3939,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3593'},
#  {'answer': 'black',
#   'id': 3940,
#   'question': "what is the color of the yellow-haired men's clothes in the video",
#   'video_name': 'ZJL1805'},
#  {'answer': 'helmet',
#   'id': 3941,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL3048'},
#  {'answer': 'carton',
#   'id': 3942,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL3048'},
#  {'answer': 'armrest',
#   'id': 3943,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL3048'},
#  {'answer': 'living room',
#   'id': 3944,
#   'question': 'where is the woman',
#   'video_name': 'ZJL143'},
#  {'answer': 'sweeping floor',
#   'id': 3945,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2733'},
#  {'answer': 'water balle',
#   'id': 3946,
#   'question': 'what sports have appeared in video',
#   'video_name': 'ZJL2704'},
#  {'answer': 'synchronized swimming',
#   'id': 3947,
#   'question': 'what sports have appeared in video',
#   'video_name': 'ZJL2704'},
#  {'answer': 'reading',
#   'id': 3948,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL119'},
#  {'answer': 'playing and fighting',
#   'id': 3949,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL119'},
#  {'answer': 'playing cell phone',
#   'id': 3950,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL119'},
#  {'answer': 'hearth',
#   'id': 3951,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3125'},
#  {'answer': 'shelter',
#   'id': 3952,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3125'},
#  {'answer': 'can',
#   'id': 3953,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL3125'},
#  {'answer': 'eating',
#   'id': 3954,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL667'},
#  {'answer': 'covering with cover',
#   'id': 3955,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2239'},
#  {'answer': 'talking',
#   'id': 3956,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2239'},
#  {'answer': 'taking bowl',
#   'id': 3957,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2239'},
#  {'answer': 'headless',
#   'id': 3958,
#   'question': 'does the crystal skull have head or not',
#   'video_name': 'ZJL2543'},
#  {'answer': 'standing',
#   'id': 3959,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL313'},
#  {'answer': 'taking out clothes',
#   'id': 3960,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2076'},
#  {'answer': 'picking up clothes',
#   'id': 3961,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2076'},
#  {'answer': 'putting on clothes',
#   'id': 3962,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2076'},
#  {'answer': 'drawing paper',
#   'id': 3963,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3375'},
#  {'answer': 'pen',
#   'id': 3964,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3375'},
#  {'answer': 'hands',
#   'id': 3965,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3375'},
#  {'answer': 'sitting',
#   'id': 3966,
#   'question': 'is the man in the video standing or sitting at the beginning',
#   'video_name': 'ZJL417'},
#  {'answer': 'watching tv',
#   'id': 3967,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL184'},
#  {'answer': 'tidying',
#   'id': 3968,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL184'},
#  {'answer': 'playing cell phone',
#   'id': 3969,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL184'},
#  {'answer': 'rubbing head',
#   'id': 3970,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2161'},
#  {'answer': 'taking book',
#   'id': 3971,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2161'},
#  {'answer': 'flipping through book',
#   'id': 3972,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2161'},
#  {'answer': 'installing bulb',
#   'id': 3973,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4026'},
#  {'answer': 'moving chairs',
#   'id': 3974,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4026'},
#  {'answer': 'fixing up things',
#   'id': 3975,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4026'},
#  {'answer': 'positive',
#   'id': 3976,
#   'question': 'is the machine in video positive or negative',
#   'video_name': 'ZJL2646'},
#  {'answer': 'books',
#   'id': 3977,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3217'},
#  {'answer': 'teacups',
#   'id': 3978,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3217'},
#  {'answer': 'wires',
#   'id': 3979,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3217'},
#  {'answer': 'light green',
#   'id': 3980,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2398'},
#  {'answer': 'green',
#   'id': 3981,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2398'},
#  {'answer': 'carpet',
#   'id': 3982,
#   'question': 'what is in the room',
#   'video_name': 'ZJL767'},
#  {'answer': 'chair',
#   'id': 3983,
#   'question': 'what is in the room',
#   'video_name': 'ZJL767'},
#  {'answer': 'cabinet',
#   'id': 3984,
#   'question': 'what is in the room',
#   'video_name': 'ZJL767'},
#  {'answer': 'blue',
#   'id': 3985,
#   'question': 'what color is the background of the picture in video',
#   'video_name': 'ZJL2653'},
#  {'answer': 'skyblue',
#   'id': 3986,
#   'question': 'what color is the background of the picture in video',
#   'video_name': 'ZJL2653'},
#  {'answer': 'short hair',
#   'id': 3987,
#   'question': 'is the man in the video long hair or short hair',
#   'video_name': 'ZJL480'},
#  {'answer': 'pot',
#   'id': 3988,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3192'},
#  {'answer': 'microwave oven',
#   'id': 3989,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3192'},
#  {'answer': 'kitchen table',
#   'id': 3990,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3192'},
#  {'answer': 'indoor',
#   'id': 3991,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'in house',
#   'id': 3992,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'in bedroom',
#   'id': 3993,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3209'},
#  {'answer': 'lamp',
#   'id': 3994,
#   'question': 'what does the person turn on in the video',
#   'video_name': 'ZJL998'},
#  {'answer': 'yellow',
#   'id': 3995,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL4218'},
#  {'answer': 'curved',
#   'id': 3996,
#   'question': 'is the pipe in video straight or curved',
#   'video_name': 'ZJL2646'},
#  {'answer': 'taking something',
#   'id': 3997,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3658'},
#  {'answer': 'putting back cabinet',
#   'id': 3998,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3658'},
#  {'answer': 'sneezing',
#   'id': 3999,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3658'},
#  ...]

# %%
import json

# %%
with open("./new_data/data_val_answer_separation.json","w") as f:
    json.dump(data_list_val,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
with open("./new_data/data_train_answer_separation.json","w") as f:
    json.dump(data_list_train,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
len(data_list_val)
# Out:
# 3000

# %%
i=0
id=-1
data_list=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["video_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", [])
                elif i % 4 == 0:
                    data["answer"].append(word)
                    data_list.append(data)
                    data={}
                    answer=[]
                else:
                    data["answer"].append(word)
            else:
                video_id=word

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3540'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['kissing', 'kissing', 'kissing'],
#   'id': 6,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['lying', 'lying', 'lying'],
#   'id': 7,
#   'question': 'is the person sitting or lying in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['on bed', 'on bed', 'on bed'],
#   'id': 8,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['long hair', 'long hair', 'long hair'],
#   'id': 9,
#   'question': 'does the woman have long hair or short hair in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': ['white', 'light white', 'pure white'],
#   'id': 10,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['standing', 'sitting', 'sitting'],
#   'id': 11,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['kitchen', 'kitchen', 'kitchen'],
#   'id': 12,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['drinking water', 'drinking milk', 'drinking water'],
#   'id': 13,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': ['on table', 'on table', 'on table'],
#   'id': 14,
#   'question': 'where is the book',
#   'video_name': 'ZJL963'},
#  {'answer': ['third', 'third', 'third'],
#   'id': 15,
#   'question': 'which layer of the cabinet is the water cup put in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['pure black', 'black', 'dark black'],
#   'id': 16,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['opening cabinet', 'drinking water', 'drinking water'],
#   'id': 17,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': ['cabinet', 'cabinet', 'cabinet'],
#   'id': 18,
#   'question': 'where did the person get the cup',
#   'video_name': 'ZJL1836'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 19,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': ['pink', 'light-pink', 'peach-pink'],
#   'id': 20,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['broadcasting', 'entertainment', 'new'],
#   'id': 21,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['swimsuit', 'swimsuit', 'swimsuit'],
#   'id': 22,
#   'question': 'what does the super star wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['in water', 'in water', 'in water'],
#   'id': 23,
#   'question': 'where is the superstar in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 24,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': ['tv', 'sofa', 'table'],
#   'id': 25,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': ['white', 'milk white', 'off-white'],
#   'id': 26,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': ['pushing tv button', 'pushing tv button', 'pushing tv button'],
#   'id': 27,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3886'},
#  {'answer': ['in living room', 'indoor', 'in room'],
#   'id': 28,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 29,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3886'},
#  {'answer': ['book', 'phone', 'computer'],
#   'id': 30,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': ['black', 'white', 'blue'],
#   'id': 31,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': ['taking clothes', 'clearing up', 'playing phone'],
#   'id': 32,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 33,
#   'question': 'was the man standing or sitting in the end',
#   'video_name': 'ZJL2952'},
#  {'answer': ['in door', 'in door', 'in door'],
#   'id': 34,
#   'question': 'where is the man',
#   'video_name': 'ZJL2952'},
#  {'answer': ['brown', 'light brown', 'rustic brown'],
#   'id': 35,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 36,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['bathroom', 'bathroom', 'bathroom'],
#   'id': 37,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['looking at mirror', 'taking off clothes', 'wiping arms'],
#   'id': 38,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': ['on shelf', 'on shelf', 'on shelf'],
#   'id': 39,
#   'question': 'where is the towel',
#   'video_name': 'ZJL927'},
#  {'answer': ['schoolbag', 'mobile phone', 'pillow'],
#   'id': 40,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': ['green', 'light green', 'dark green'],
#   'id': 41,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': ['holding pillow', 'holding pillow', 'holding pillow'],
#   'id': 42,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3687'},
#  {'answer': ['room', 'room', 'room'],
#   'id': 43,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 44,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3687'},
#  {'answer': ['daytime', 'morning', 'daytime'],
#   'id': 45,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 46,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': ['taking selfie', 'photographing', 'taking photos'],
#   'id': 47,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': ['outdoor', 'suburb', 'in car'],
#   'id': 48,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 49,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': ['woman', 'man', 'sofa'],
#   'id': 50,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['beige', 'beige', 'beige'],
#   'id': 51,
#   'question': 'what color is the sofa in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['talking', 'talking', 'talking'],
#   'id': 52,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['in room', 'in room', 'in room'],
#   'id': 53,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': ['standing', 'sitting', 'standing'],
#   'id': 54,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': ['black', 'white', 'dark blue'],
#   'id': 55,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 56,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['reading book', 'reading book', 'reading book'],
#   'id': 57,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['kitchen', 'kitchen', 'kitchen'],
#   'id': 58,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['on table', 'on table', 'on table'],
#   'id': 59,
#   'question': 'where is the water bottle in the video',
#   'video_name': 'ZJL984'},
#  {'answer': ['photograph', 'cup', 'basket'],
#   'id': 60,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 61,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['drinking water', 'drinking water', 'drinking water'],
#   'id': 62,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['in stairwell', 'in stairwell', 'in stairwell'],
#   'id': 63,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 64,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3443'},
#  {'answer': ['closet', 'chair', 'tv'],
#   'id': 65,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': ['black', 'dark black', 'aterrimus'],
#   'id': 66,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': ['opening door', 'putting towel', 'sneezing'],
#   'id': 67,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': ['indoor', 'living room', 'residence'],
#   'id': 68,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 69,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2146'},
#  {'answer': ['computer', 'computer', 'computer'],
#   'id': 70,
#   'question': 'what is on the cabinet in the video',
#   'video_name': 'ZJL578'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 71,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL578'},
#  {'answer': ['eating things', 'playing computer', 'eating things'],
#   'id': 72,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': ['kitchen', 'kitchen', 'kitchen'],
#   'id': 73,
#   'question': 'in which room is the woman in the video',
#   'video_name': 'ZJL578'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 74,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL578'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 75,
#   'question': 'is the person wearing pink in the video standing or sitting',
#   'video_name': 'ZJL2741'},
#  {'answer': ['eating something', 'eating food', 'eating food'],
#   'id': 76,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': ['bedroom', 'bedroom', 'bedroom'],
#   'id': 77,
#   'question': 'where is the person wearing pink in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': ['bed', 'cabinet', 'mirror'],
#   'id': 78,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': ['white', 'light white', 'gray white'],
#   'id': 79,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': ['green', 'pale green', 'grass green'],
#   'id': 80,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 81,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['taking off shoes', 'closing door', 'turn on lights'],
#   'id': 82,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['long hair', 'long hair', 'long hair'],
#   'id': 83,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['pink', 'soft red', 'rose'],
#   'id': 84,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': ['cup', 'phone', 'clothes'],
#   'id': 85,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': ['brown', 'yellow', 'golden'],
#   'id': 86,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 87,
#   'question': 'is the man in purple standing or sitting',
#   'video_name': 'ZJL2934'},
#  {'answer': ['in door', 'in door', 'in door'],
#   'id': 88,
#   'question': 'where is the man',
#   'video_name': 'ZJL2934'},
#  {'answer': ['shoes', 'shoes', 'shoes'],
#   'id': 89,
#   'question': 'what is on the outside floor',
#   'video_name': 'ZJL2934'},
#  {'answer': ['green', 'grass green', 'pale green'],
#   'id': 90,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 91,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['kitchen', 'kitchen', 'kitchen'],
#   'id': 92,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['making food', 'sweeping floor', 'eating'],
#   'id': 93,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['short hair', 'short hair', 'short hair'],
#   'id': 94,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL995'},
#  {'answer': ['cabinet', 'mirror', 'clothes'],
#   'id': 95,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': ['pink', 'magenta', 'burgandy'],
#   'id': 96,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': ['looking at mirror', 'putting on clothes', 'buttoning'],
#   'id': 97,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': ['indoor', 'in room', 'in house'],
#   'id': 98,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 99,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3944'},
#  {'answer': ['door', 'television', 'curtain'],
#   'id': 100,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': ['yellow', 'khaki', 'brownish yellow'],
#   'id': 101,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': ['watching tv', 'resting', 'sleeping'],
#   'id': 102,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': ['indoors', 'in house', 'in bedroom'],
#   'id': 103,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': ['lying on his stomach',
#    'lying on his stomach',
#    'lying on his stomach'],
#   'id': 104,
#   'question': 'is the person in the video lying on his stomach or sitting',
#   'video_name': 'ZJL4047'},
#  {'answer': ['chair', 'fence', 'book'],
#   'id': 105,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 106,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': ['dancing', 'exercising', 'playing'],
#   'id': 107,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['outdoor', 'yard', 'at door'],
#   'id': 108,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 109,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': ['mustache', 'mustache', 'mustache'],
#   'id': 110,
#   'question': "what is on the person's face in the video",
#   'video_name': 'ZJL651'},
#  {'answer': ['gray', 'black gray', 'neutral gary'],
#   'id': 111,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['eating', 'eating', 'eating'],
#   'id': 112,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['staircase', 'staircase', 'staircase'],
#   'id': 113,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 114,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': ['closet', 'refrigerator', 'pot'],
#   'id': 115,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': ['black', 'dark black', 'aterrimus'],
#   'id': 116,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': ['firing', 'taking things', 'opening refrigerator'],
#   'id': 117,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': ['indoor', 'kitchen', 'residence'],
#   'id': 118,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 119,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2147'},
#  {'answer': ['icon', 'website', 'people'],
#   'id': 120,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['female', 'female', 'female'],
#   'id': 121,
#   'question': 'is the person in the video a male or a female',
#   'video_name': 'ZJL1115'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 122,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['in water', 'in water', 'in water'],
#   'id': 123,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['tapping water', 'tapping water', 'tapping water'],
#   'id': 124,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': ['music score', 'guitar', 'microphone'],
#   'id': 125,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['purple', 'deep purple', 'purple sauce'],
#   'id': 126,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['singing', 'singing', 'singing'],
#   'id': 127,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['on stage', 'on stage', 'on stage'],
#   'id': 128,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 129,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL783'},
#  {'answer': ['boy', 'girl', 'women'],
#   'id': 130,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['brown', 'tan', 'coffee'],
#   'id': 131,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['interviewing', 'talking', 'narrating'],
#   'id': 132,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['indoor', 'in room', 'interview site'],
#   'id': 133,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 134,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': ['mustache', 'mustache', 'mustache'],
#   'id': 135,
#   'question': 'what is on the face of the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['white', 'creamy-white', 'ivory-white'],
#   'id': 136,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['setting of pillows', 'setting of pillows', 'setting of pillows'],
#   'id': 137,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['in living room', 'in living room', 'in living room'],
#   'id': 138,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 139,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL3506'},
#  {'answer': ['board', 'sponge', 'brush'],
#   'id': 140,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['yellow', 'light yellow', 'canary yellow'],
#   'id': 141,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['cleaning toy', 'wiping toy', 'cleaning up dust'],
#   'id': 142,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': ['in water', 'in bathtub', 'in bathroom'],
#   'id': 143,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['plastic', 'plastic', 'plastic'],
#   'id': 144,
#   'question': 'what is the material of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': ['athlete', 'athlete', 'athlete'],
#   'id': 145,
#   'question': 'what is on the track',
#   'video_name': 'ZJL1602'},
#  {'answer': ['yellow', 'yellow', 'yellow'],
#   'id': 146,
#   'question': "what color is the runner's hair",
#   'video_name': 'ZJL1602'},
#  {'answer': ['running', 'running', 'running'],
#   'id': 147,
#   'question': 'what is the person in yellow hair doing',
#   'video_name': 'ZJL1602'},
#  {'answer': ['on sport court', 'on sport court', 'on sport court'],
#   'id': 148,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1602'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 149,
#   'question': 'is the athlete in the video standing or sitting',
#   'video_name': 'ZJL1602'},
#  {'answer': ['hanging on wall', 'hanging on wall', 'hanging on wall'],
#   'id': 150,
#   'question': 'where is the tv in the video',
#   'video_name': 'ZJL430'},
#  {'answer': ['blue', 'light blue', 'light blue'],
#   'id': 151,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': ['walking', 'walking', 'walking'],
#   'id': 152,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL430'},
#  {'answer': ['benches', 'benches', 'benches'],
#   'id': 153,
#   'question': 'where is the boy sitting in the video',
#   'video_name': 'ZJL430'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 154,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL430'},
#  {'answer': ['plates', 'watches', 'flour'],
#   'id': 155,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['green', 'green', 'green'],
#   'id': 156,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['taking things', 'pouring things', 'taking things'],
#   'id': 157,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': ['kitchen', 'kitchen', 'kitchen'],
#   'id': 158,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 159,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2863'},
#  {'answer': ['long hair', 'long hair', 'long hair'],
#   'id': 160,
#   'question': 'does the person has long hair or short hair in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 161,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['washing hands', 'washing hands', 'washing hands'],
#   'id': 162,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': ['on cabinet', 'on cabinet', 'on cabinet'],
#   'id': 163,
#   'question': 'where is the towel',
#   'video_name': 'ZJL3470'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 164,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3470'},
#  {'answer': ['cummerbund', 'cummerbund', 'cummerbund'],
#   'id': 165,
#   'question': 'what does the person in video hold',
#   'video_name': 'ZJL2593'},
#  {'answer': ['purple', 'rose red', 'purple red'],
#   'id': 166,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['circle', 'circle', 'circle'],
#   'id': 167,
#   'question': 'what is the shape of the decorative ribbon in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['left hand', 'left hand', 'left hand'],
#   'id': 168,
#   'question': 'which hand of the people in video picked up the ribbon',
#   'video_name': 'ZJL2593'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 169,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2593'},
#  {'answer': ['wheelchair', 'desk', 'chair'],
#   'id': 170,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': ['red', 'red', 'red'],
#   'id': 171,
#   'question': 'what color clothes does the person sitting on a wheelchair wear',
#   'video_name': 'ZJL842'},
#  {'answer': ['hospital', 'hospital', 'hospital'],
#   'id': 172,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL842'},
#  {'answer': ['talking', 'fetching things', 'talking'],
#   'id': 173,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 174,
#   'question': 'is the person wearing white clothes in the video sitting or standing',
#   'video_name': 'ZJL842'},
#  {'answer': ['clothes', 'boxes', 'hangers'],
#   'id': 175,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['indoor', 'in house', 'in bedroom'],
#   'id': 176,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['blue', 'dark blue', 'blue-black'],
#   'id': 177,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 178,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3134'},
#  {'answer': ['took stuffs', 'closed wardrobe', 'turned off light'],
#   'id': 179,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': ['cabinet', 'hearth', 'waste container'],
#   'id': 180,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': ['red', 'true red', 'jacinth'],
#   'id': 181,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': ['playing phone', 'watching phone', 'opening refrigerator'],
#   'id': 182,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['indoor', 'kitchen', 'residence'],
#   'id': 183,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 184,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3546'},
#  {'answer': ['wardrobe', 'clothing', 'hangers'],
#   'id': 185,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['brown', 'gray-black', 'dark gray'],
#   'id': 186,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['displaying boxes', 'cleaning out closet', 'placing boxes'],
#   'id': 187,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['indoor', 'in house', 'in bedroom'],
#   'id': 188,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 189,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3144'},
#  {'answer': ['black', 'dark black', 'ash black'],
#   'id': 190,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 191,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['writing', 'writing', 'writing'],
#   'id': 192,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['yellow', 'golden', 'orange'],
#   'id': 193,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['clothes', 'clothes', 'clothes'],
#   'id': 194,
#   'question': 'what is hanging on the wall of video',
#   'video_name': 'ZJL3633'},
#  {'answer': ['close stool', 'tissue', 'shower gel'],
#   'id': 195,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': ['red', 'tangerine', 'scarlet'],
#   'id': 196,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': ['reading books', 'putting down book', 'making machine'],
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': ['toilet', 'toilet', 'toilet'],
#   'id': 198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 199,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1874'},
#  {'answer': ['pen', 'round', 'monkey'],
#   'id': 200,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['brown', 'brown', 'brown'],
#   'id': 201,
#   'question': 'what color is the round in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['moving', 'moving', 'moving'],
#   'id': 202,
#   'question': 'what is the round doing in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['snowfield', 'snowfield', 'snowfield'],
#   'id': 203,
#   'question': 'where is the monkey in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['six', 'six', 'six'],
#   'id': 204,
#   'question': 'how many letters are there in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': ['chair', 'cabinet', 'cup'],
#   'id': 205,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': ['yellow', 'light yellow', 'orange'],
#   'id': 206,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': ['shaking towel', 'putting towel', 'drinking water'],
#   'id': 207,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3896'},
#  {'answer': ['indoor', 'in living room', 'in house'],
#   'id': 208,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3896'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 209,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3896'},
#  {'answer': ['straw', 'straw', 'straw'],
#   'id': 210,
#   'question': 'what is in the cup in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['on bath crock', 'on bath crock', 'on bath crock'],
#   'id': 211,
#   'question': 'where is the cup in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['green', 'apple green', 'emerald green'],
#   'id': 212,
#   'question': 'what color is the wall space in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['taking bath', 'taking bath', 'taking bath'],
#   'id': 213,
#   'question': 'what is the woman doing in video',
#   'video_name': 'ZJL2665'},
#  {'answer': ['lying', 'lying', 'lying'],
#   'id': 214,
#   'question': 'is the woman in video standing or lying down',
#   'video_name': 'ZJL2665'},
#  {'answer': ['game scene', 'game scene', 'game scene'],
#   'id': 215,
#   'question': 'what is the scene in the video',
#   'video_name': 'ZJL2252'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 216,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2252'},
#  {'answer': ['talking', 'playing games', 'wiping mouth'],
#   'id': 217,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2252'},
#  {'answer': ['earphones', 'earphones', 'earphones'],
#   'id': 218,
#   'question': 'what does the person in the video wear on the head',
#   'video_name': 'ZJL2252'},
#  {'answer': ['right hand', 'right hand', 'right hand'],
#   'id': 219,
#   'question': 'which hand does the person in the video use to wipe the mouth',
#   'video_name': 'ZJL2252'},
#  {'answer': ['chair', 'protective hood', 'whistle'],
#   'id': 220,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 221,
#   'question': 'what color is the trousers worn by the referee in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['watching game', 'watching game', 'watching game'],
#   'id': 222,
#   'question': 'what are the audience in the video doing',
#   'video_name': 'ZJL2817'},
#  {'answer': ['auditorium', 'auditorium', 'auditorium'],
#   'id': 223,
#   'question': 'where is the audience in the video',
#   'video_name': 'ZJL2817'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 224,
#   'question': 'is the referee in the video sitting or standing',
#   'video_name': 'ZJL2817'},
#  {'answer': ['cartoon', 'cartoon', 'cartoon'],
#   'id': 225,
#   'question': 'what is on video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['car', 'car', 'car'],
#   'id': 226,
#   'question': 'what did the character drive to the river in video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['in river', 'in river', 'in river'],
#   'id': 227,
#   'question': 'where did the character in video push the car into',
#   'video_name': 'ZJL2596'},
#  {'answer': ['tree', 'tree', 'lawn'],
#   'id': 228,
#   'question': 'what is on either side of the street in video',
#   'video_name': 'ZJL2596'},
#  {'answer': ['green', 'dark green', 'dark green'],
#   'id': 229,
#   'question': 'what color pants did the big guy in video wear',
#   'video_name': 'ZJL2596'},
#  {'answer': ['necklace', 'necklace', 'necklace'],
#   'id': 230,
#   'question': 'what does the woman wear around her neck in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 231,
#   'question': 'what color of the clothes does the woman wear in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['dancing', 'running', 'picking flowers'],
#   'id': 232,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['on ground', 'on ground', 'on ground'],
#   'id': 233,
#   'question': 'where is the flower in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 234,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL1217'},
#  {'answer': ['woman', 'child', 'man'],
#   'id': 235,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['pale pink', 'pale pink', 'pale pink'],
#   'id': 236,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['going to supermarket',
#    'going to supermarket',
#    'going to supermarket'],
#   'id': 237,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['next to shelf', 'next to shelf', 'next to shelf'],
#   'id': 238,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1499'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 239,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1499'},
#  {'answer': ['quilt', 'sheets', 'pillow'],
#   'id': 240,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL2204'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 241,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2204'},
#  {'answer': ['taking cup', 'drinking water', 'drawing curtain'],
#   'id': 242,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2204'},
#  {'answer': ['indoor', 'residence', 'bedroom'],
#   'id': 243,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2204'},
#  {'answer': ['lying', 'lying', 'lying'],
#   'id': 244,
#   'question': 'is the person in the video standing or lying',
#   'video_name': 'ZJL2204'},
#  {'answer': ['right hand', 'right hand', 'right hand'],
#   'id': 245,
#   'question': 'in which hand does the person hold the cellphone in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['dark blue', 'dark blue', 'dark blue'],
#   'id': 246,
#   'question': 'what color of the pants does the person wear in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['making phone call', 'making phone call', 'making phone call'],
#   'id': 247,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['on stairs', 'on stairs', 'on stairs'],
#   'id': 248,
#   'question': 'where is the person making a phone call in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['standing', 'sitting', 'standing'],
#   'id': 249,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1813'},
#  {'answer': ['boat', 'boat', 'boat'],
#   'id': 250,
#   'question': 'what is in the video',
#   'video_name': 'ZJL268'},
#  {'answer': ['yellow', 'white', 'red'],
#   'id': 251,
#   'question': 'what color is the light in the first scene',
#   'video_name': 'ZJL268'},
#  {'answer': ['visiting', 'visiting', 'visiting'],
#   'id': 252,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL268'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 253,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL268'},
#  {'answer': ['exhibition hall', 'exhibition hall', 'exhibition hall'],
#   'id': 254,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL268'},
#  {'answer': ['desk', 'cup', 'camera'],
#   'id': 255,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['gray', 'light gray', 'off white'],
#   'id': 256,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['getting camera', 'walking', 'turning head looking'],
#   'id': 257,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 258,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1066'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 259,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1066'},
#  {'answer': ['table tennis bat', 'table tennis bat', 'table tennis bat'],
#   'id': 260,
#   'question': 'what is in the hand of the person in the video',
#   'video_name': 'ZJL258'},
#  {'answer': ['black', 'white', 'blue'],
#   'id': 261,
#   'question': 'what color pants does the person in red wear',
#   'video_name': 'ZJL258'},
#  {'answer': ['playing pingpong', 'playing pingpong', 'playing pingpong'],
#   'id': 262,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL258'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 263,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL258'},
#  {'answer': ['court', 'court', 'cour'],
#   'id': 264,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL258'},
#  {'answer': ['table', 'chair', 'microphone'],
#   'id': 265,
#   'question': 'what is in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 266,
#   'question': 'what color is the microphone in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['speaking', 'speaking', 'speaking'],
#   'id': 267,
#   'question': 'what is the person wearing purple tie doing in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['before microphone', 'before microphone', 'before microphone'],
#   'id': 268,
#   'question': 'where is the person with a purple tie in the video',
#   'video_name': 'ZJL806'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 269,
#   'question': 'is the person wearing the purple tie standing or sitting',
#   'video_name': 'ZJL806'},
#  {'answer': ['person', 'person', 'person'],
#   'id': 270,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL1549'},
#  {'answer': ['red', 'white', 'grey'],
#   'id': 271,
#   'question': 'what color does the person wear',
#   'video_name': 'ZJL1549'},
#  {'answer': ['sleeping', 'sleeping', 'sleeping'],
#   'id': 272,
#   'question': 'what is the woman in white doing',
#   'video_name': 'ZJL1549'},
#  {'answer': ['home', 'home', 'home'],
#   'id': 273,
#   'question': 'where is the woman in white',
#   'video_name': 'ZJL1549'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 274,
#   'question': 'is the person in white standing or sitting',
#   'video_name': 'ZJL1549'},
#  {'answer': ['shelf', 'shelf', 'shelf'],
#   'id': 275,
#   'question': 'what is the person pushing over in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['white', 'beige', 'gray white'],
#   'id': 276,
#   'question': 'what is the color of the building in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['fighting', 'fighting', 'fighting'],
#   'id': 277,
#   'question': 'what is the robot doing in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['hat', 'hat', 'hat'],
#   'id': 278,
#   'question': 'what is the person wearing on his head in the video',
#   'video_name': 'ZJL1752'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 279,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1752'},
#  {'answer': ['skeleton', 'skeleton', 'skeleton'],
#   'id': 280,
#   'question': 'what is the white thing in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['dancing', 'dancing', 'dancing'],
#   'id': 281,
#   'question': 'what is the skeleton doing in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['three', 'three', 'three'],
#   'id': 282,
#   'question': 'how many skulls are in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['in game', 'in game', 'in game'],
#   'id': 283,
#   'question': 'where is the skeleton in the video',
#   'video_name': 'ZJL2470'},
#  {'answer': ['pink', 'pink', 'pink-red'],
#   'id': 284,
#   'question': "what color is the skull on the man's finger in the video",
#   'video_name': 'ZJL2470'},
#  {'answer': ['guitar', 'guitar', 'guitar'],
#   'id': 285,
#   'question': 'what do the person in the video have in his hand',
#   'video_name': 'ZJL817'},
#  {'answer': ['fifty three', 'five three', 'fifty three'],
#   'id': 286,
#   'question': "what is the number on the person's clothes in the video",
#   'video_name': 'ZJL817'},
#  {'answer': ['short sleeves', 'short sleeves', 'short sleeves'],
#   'id': 287,
#   'question': "does the person's clothes in the video is short sleeves or long sleeves",
#   'video_name': 'ZJL817'},
#  {'answer': ['playing guitar', 'playing guitar', 'playing guitar'],
#   'id': 288,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL817'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 289,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL817'},
#  {'answer': ['knife', 'pot', 'cup'],
#   'id': 290,
#   'question': 'what is on the countertop',
#   'video_name': 'ZJL4258'},
#  {'answer': ['white', 'beige white', 'milk white'],
#   'id': 291,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4258'},
#  {'answer': ['pouring water', 'putting cup', 'taking off shoes'],
#   'id': 292,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4258'},
#  {'answer': ['kitchen', 'indoor', 'in room'],
#   'id': 293,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4258'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 294,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4258'},
#  {'answer': ['male', 'male', 'male'],
#   'id': 295,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['blue', 'blue', 'blue'],
#   'id': 296,
#   'question': 'what color is the pants worn by the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['hand standing', 'hand standing', 'hand standing'],
#   'id': 297,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['indoor', 'indoor', 'indoor'],
#   'id': 298,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1196'},
#  {'answer': ['english', 'english', 'english'],
#   'id': 299,
#   'question': 'is the text in the video english or chinese',
#   'video_name': 'ZJL1196'},
#  {'answer': ['two', 'two', 'two'],
#   'id': 300,
#   'question': 'how many people appeared in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['navy blue', 'dark blue', 'blue black'],
#   'id': 301,
#   'question': 'what color does the thinner man wear in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['wiping his hair', 'wiping his hair', 'wiping his hair'],
#   'id': 302,
#   'question': 'what is the fat man in the video doing',
#   'video_name': 'ZJL463'},
#  {'answer': ['on ground', 'on ground', 'on ground'],
#   'id': 303,
#   'question': 'where is the broom in the video',
#   'video_name': 'ZJL463'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 304,
#   'question': 'are the two men in the video standing or sitting',
#   'video_name': 'ZJL463'},
#  {'answer': ['bottle', 'fruits', 'plastic case'],
#   'id': 305,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['white', 'milk white', 'creamy white'],
#   'id': 306,
#   'question': 'what is the color of the refrigerator in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['searching refrigerator', 'rotating disc', 'taking plastic case'],
#   'id': 307,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['indoor', 'inside house', 'kitchen'],
#   'id': 308,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 309,
#   'question': 'is the person standing or sitting at the beginning of the video',
#   'video_name': 'ZJL1381'},
#  {'answer': ['computer', 'table', 'television'],
#   'id': 310,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3029'},
#  {'answer': ['brown', 'dark brown', 'brownish yellow'],
#   'id': 311,
#   'question': "what is the color of the person's hair in the video",
#   'video_name': 'ZJL3029'},
#  {'answer': ['looking at computer', 'watching videos', 'wiping nose'],
#   'id': 312,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3029'},
#  {'answer': ['indoor', 'residence', 'bedroom'],
#   'id': 313,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3029'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 314,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3029'},
#  {'answer': ['left hand', 'left hand', 'left hand'],
#   'id': 315,
#   'question': 'is the person in the video extending the left or right hand',
#   'video_name': 'ZJL1746'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 316,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL1746'},
#  {'answer': ['reaching out', 'reaching out', 'reaching out'],
#   'id': 317,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1746'},
#  {'answer': ['short hair', 'short hair', 'short hair'],
#   'id': 318,
#   'question': 'is the person in the video long hair or short hair',
#   'video_name': 'ZJL1746'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 319,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1746'},
#  {'answer': ['two', 'two', 'two'],
#   'id': 320,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2767'},
#  {'answer': ['eating', 'eating', 'eating'],
#   'id': 321,
# ...
#   'video_name': 'ZJL1027'},
#  {'answer': ['hat', 'hat', 'hat'],
#   'id': 895,
#   'question': 'what does the woman wear on head in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 896,
#   'question': 'what color of the clothes does the woman wear in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['speaking', 'speaking', 'speaking'],
#   'id': 897,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['on head', 'on head', 'on head'],
#   'id': 898,
#   'question': 'where is the bamboo hat in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['kneeling', 'kneeling', 'kneeling'],
#   'id': 899,
#   'question': 'is the woman standing or kneeling in the video',
#   'video_name': 'ZJL1245'},
#  {'answer': ['bottle', 'display', 'doll'],
#   'id': 900,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1101'},
#  {'answer': ['black', 'aterrimus', 'furvous'],
#   'id': 901,
#   'question': 'what color coat does the person wear in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['taking on clothes', 'sitting down', 'folding blanket'],
#   'id': 902,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 903,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1101'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 904,
#   'question': 'is the person in the video sitting or standing at first',
#   'video_name': 'ZJL1101'},
#  {'answer': ['tabletop', 'tabletop', 'tabletop'],
#   'id': 905,
#   'question': 'where is the machine in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': ['blue', 'dark blue', 'sky blue'],
#   'id': 906,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2232'},
#  {'answer': ['introducing product',
#    'introducing product',
#    'introducing product'],
#   'id': 907,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2232'},
#  {'answer': ['machine part', 'machine part', 'machine part'],
#   'id': 908,
#   'question': 'what is in the bag',
#   'video_name': 'ZJL2232'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 909,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2232'},
#  {'answer': ['tattoo', 'tattoo', 'tattoo'],
#   'id': 910,
#   'question': "what is on the woman's arm in the video",
#   'video_name': 'ZJL472'},
#  {'answer': ['blue', 'light blue', 'sky blue'],
#   'id': 911,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL472'},
#  {'answer': ['turning on lights', 'placing items', 'placing items'],
#   'id': 912,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL472'},
#  {'answer': ['drawer', 'drawer', 'drawer'],
#   'id': 913,
#   'question': 'where is the woman in the video putting the clothes',
#   'video_name': 'ZJL472'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 914,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL472'},
#  {'answer': ['gray', 'light gray', 'ash black'],
#   'id': 915,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 916,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['opening', 'opening', 'opening'],
#   'id': 917,
#   'question': 'is the lamp opening or closed in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['carton', 'air fan', 'television'],
#   'id': 918,
#   'question': 'what is in the room',
#   'video_name': 'ZJL1009'},
#  {'answer': ['cleaning up goods', 'picking up things', 'sorting things'],
#   'id': 919,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1009'},
#  {'answer': ['blankets', 'blankets', 'blankets'],
#   'id': 920,
#   'question': 'what does the man in the video hold in his right hand',
#   'video_name': 'ZJL459'},
#  {'answer': ['gray', 'light gray', 'light gray'],
#   'id': 921,
#   'question': 'what color do men wear in the video',
#   'video_name': 'ZJL459'},
#  {'answer': ['selfie', 'selfie', 'self-timer'],
#   'id': 922,
#   'question': 'what are the men in the video doing',
#   'video_name': 'ZJL459'},
#  {'answer': ['tie', 'tie', 'tie'],
#   'id': 923,
#   'question': 'what is the man wearing on the neck in the video',
#   'video_name': 'ZJL459'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 924,
#   'question': 'the man in the video is standing or sitting',
#   'video_name': 'ZJL459'},
#  {'answer': ['glasses', 'glasses', 'glasses'],
#   'id': 925,
#   'question': 'what is on the face of the person wearing purple clothes',
#   'video_name': 'ZJL726'},
#  {'answer': ['gray', 'light grey', 'dark grey'],
#   'id': 926,
#   'question': 'what color is the chair in the video',
#   'video_name': 'ZJL726'},
#  {'answer': ['chatting', 'chatting', 'chatting'],
#   'id': 927,
#   'question': 'what is the person in purple doing',
#   'video_name': 'ZJL726'},
#  {'answer': ['in car', 'in car', 'in car'],
#   'id': 928,
#   'question': 'where is the person in purple',
#   'video_name': 'ZJL726'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 929,
#   'question': 'is the person wearing the purple dress standing or sitting',
#   'video_name': 'ZJL726'},
#  {'answer': ['tablecloth', 'white paper', 'electric wire'],
#   'id': 930,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1030'},
#  {'answer': ['blue', 'smalt', 'marine blue'],
#   'id': 931,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['placing box', 'fetching newspaper', 'brush wall'],
#   'id': 932,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['indoor', 'house', 'inside house'],
#   'id': 933,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1030'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 934,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1030'},
#  {'answer': ['curly', 'curly', 'curly'],
#   'id': 935,
#   'question': 'is the hair of the man in the video straight or curly',
#   'video_name': 'ZJL611'},
#  {'answer': ['blue', 'dark blue', 'ancient blue'],
#   'id': 936,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL611'},
#  {'answer': ['watching computer', 'writing', 'writing'],
#   'id': 937,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL611'},
#  {'answer': ['on table', 'on table', 'on table'],
#   'id': 938,
#   'question': 'where is the muppet in the video',
#   'video_name': 'ZJL611'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 939,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL611'},
#  {'answer': ['blanket', 'carpet', 'blanket'],
#   'id': 940,
#   'question': 'what is on the sofa in the video',
#   'video_name': 'ZJL1894'},
#  {'answer': ['pure black', 'dark black', 'black'],
#   'id': 941,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1894'},
#  {'answer': ['eating things', 'watching tv', 'drinking water'],
#   'id': 942,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1894'},
#  {'answer': ['on tea table', 'on tea table', 'on tea table'],
#   'id': 943,
#   'question': 'where does the person in the video take the water cup',
#   'video_name': 'ZJL1894'},
#  {'answer': ['sitting', 'standing', 'standing'],
#   'id': 944,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1894'},
#  {'answer': ['chair', 'table', 'vacuum cleaner'],
#   'id': 945,
#   'question': 'what is in front of the cabinet',
#   'video_name': 'ZJL3210'},
#  {'answer': ['gray', 'light gray', 'grayish white'],
#   'id': 946,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['doing cleaning', 'putting clothes on', 'cleaning away rubbish'],
#   'id': 947,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['indoor', 'in house', 'in kitchen'],
#   'id': 948,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3210'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 949,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3210'},
#  {'answer': ['shoes', 'chair', 'table'],
#   'id': 950,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3966'},
#  {'answer': ['yellow', 'grass yellow', 'light yellow'],
#   'id': 951,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3966'},
#  {'answer': ['taking cup', 'drinking water', 'putting down cup'],
#   'id': 952,
#   'question': 'what is the person in white doing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['indoor', 'in living room', 'in house'],
#   'id': 953,
#   'question': 'where is the person in red in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 954,
#   'question': 'is the person in red sitting or standing in video',
#   'video_name': 'ZJL3966'},
#  {'answer': ['curtain', 'chair', 'table'],
#   'id': 955,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL4059'},
#  {'answer': ['pink', 'flesh color', 'pink'],
#   'id': 956,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL4059'},
#  {'answer': ['fixing things up', 'drinking water', 'fixing furnitures'],
#   'id': 957,
#   'question': 'what is the person in white doing',
#   'video_name': 'ZJL4059'},
#  {'answer': ['indoors', 'in house', 'in living room'],
#   'id': 958,
#   'question': 'where is the person in white',
#   'video_name': 'ZJL4059'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 959,
#   'question': 'is the person in white standing or sitting',
#   'video_name': 'ZJL4059'},
#  {'answer': ['left', 'left', 'left'],
#   'id': 960,
#   'question': 'which hand of the person in the video holds the clothes when he takes it off',
#   'video_name': 'ZJL349'},
#  {'answer': ['dark green', 'green', 'tibet green'],
#   'id': 961,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL349'},
#  {'answer': ['taking off clothes', 'getting cup', 'getting cup'],
#   'id': 962,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL349'},
#  {'answer': ['cup', 'cup', 'cup'],
#   'id': 963,
#   'question': 'what does the person have in the right hand',
#   'video_name': 'ZJL349'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 964,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL349'},
#  {'answer': ['fan', 'fan', 'fan'],
#   'id': 965,
#   'question': 'what is placed on the right side of the person in the video',
#   'video_name': 'ZJL2271'},
#  {'answer': ['grey', 'greyish white', 'light grey'],
#   'id': 966,
#   'question': 'what color top does the person in the video wear',
#   'video_name': 'ZJL2271'},
#  {'answer': ['playing mobile phone',
#    'playing mobile phone',
#    'playing mobile phone'],
#   'id': 967,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2271'},
#  {'answer': ['left hand', 'left hand', 'left hand'],
#   'id': 968,
#   'question': 'which hand of the person in the video puts on the mouth',
#   'video_name': 'ZJL2271'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 969,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2271'},
#  {'answer': ['in room', 'in room', 'in room'],
#   'id': 970,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL327'},
#  {'answer': ['blue', 'sky blue', 'ocean blue'],
#   'id': 971,
#   'question': "what color is the person's pants in the video",
#   'video_name': 'ZJL327'},
#  {'answer': ['sleeping', 'lifting his head', 'taking off his pants'],
#   'id': 972,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL327'},
#  {'answer': ['pillow', 'pillow', 'pillow'],
#   'id': 973,
#   'question': "what covers the person's face in the video",
#   'video_name': 'ZJL327'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 974,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL327'},
#  {'answer': ['male', 'male', 'male'],
#   'id': 975,
#   'question': 'what is the gender of the person with weapon in the video',
#   'video_name': 'ZJL859'},
#  {'answer': ['opening', 'opening', 'opening'],
#   'id': 976,
#   'question': 'is the city gate in the video opening or closed',
#   'video_name': 'ZJL859'},
#  {'answer': ['grenade', 'grenade', 'grenade'],
#   'id': 977,
#   'question': 'what is hanging on the waist of the person in the video',
#   'video_name': 'ZJL859'},
#  {'answer': ['scorpion', 'scorpion', 'scorpion'],
#   'id': 978,
#   'question': 'what animal icon appeared in the video at the beginning',
#   'video_name': 'ZJL859'},
#  {'answer': ['english', 'english', 'english'],
#   'id': 979,
#   'question': 'is the text in the video written in english or chinese',
#   'video_name': 'ZJL859'},
#  {'answer': ['computer', 'book', 'cup'],
#   'id': 980,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL1675'},
#  {'answer': ['red', 'red', 'red'],
#   'id': 981,
#   'question': 'what is the color of the clothes in the video',
#   'video_name': 'ZJL1675'},
#  {'answer': ['eating', 'eating', 'eating'],
#   'id': 982,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1675'},
#  {'answer': ['long hair', 'long hair', 'long hair'],
#   'id': 983,
#   'question': 'is the person in the video long hair or short hair',
#   'video_name': 'ZJL1675'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 984,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1675'},
#  {'answer': ['ball', 'pillar', 'handcart'],
#   'id': 985,
#   'question': 'what is on the floor',
#   'video_name': 'ZJL3380'},
#  {'answer': ['yellow', 'earthy yellow', 'claybank'],
#   'id': 986,
#   'question': 'what is the color of the floor in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['playing games', 'taking exercise', 'exercising'],
#   'id': 987,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['indoor', 'public place', 'gymnasium'],
#   'id': 988,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 989,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3380'},
#  {'answer': ['laptop', 'remote control', 'mouse'],
#   'id': 990,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1090'},
#  {'answer': ['blue', 'smalt', 'marine blue'],
#   'id': 991,
#   'question': 'what color clothes does the standing person wear in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['entering door', 'watching tv', 'moving chair'],
#   'id': 992,
#   'question': 'what is the standing person doing in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['indoor', 'inside house', 'in bedroom'],
#   'id': 993,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1090'},
#  {'answer': ['sitting', 'sitting', 'sitting'],
#   'id': 994,
#   'question': 'is the person holding the phone in the video sitting or standing',
#   'video_name': 'ZJL1090'},
#  {'answer': ['wall painting', 'television', 'socket'],
#   'id': 995,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3473'},
#  {'answer': ['purple', 'modena', 'fuchsia'],
#   'id': 996,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': ['walking', 'walking', 'walking'],
#   'id': 997,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3473'},
#  {'answer': ['on wall', 'on wall', 'on wall'],
#   'id': 998,
#   'question': 'where is the tv',
#   'video_name': 'ZJL3473'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 999,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3473'},
#  ...]

# %% [markdown]
# data_t = [i["video_name"] for i in data_list_train_no]
# data_v = [i["video_name"] for i in data_list_val_no]
# len(set(data_t) & set(data_v))

# %%
data_list_val_no=data_list[0:3000]
data_list_train_no=data_list[3000:]

# %%
len(data_list_val_no)
# Out:
# 3000

# %%
with open("./new_data/data_val.json","w") as f:
    json.dump(data_list_val_no,f)
    print("加载入文件完成...")
with open("./new_data/data_train.json","w") as f:
    json.dump(data_list_train_no,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...
# 加载入文件完成...

# %%
i=0
id=-1
data_test=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/test.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["video_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", "")
                elif i % 4 == 0:
                    #data["answer"].append(word)
                    data_test.append(data)
                    data={}
#                     #answer=[]
#                 else:
#                     #data["answer"].append(word)
            else:
                video_id=word

# %%
data_test
# Out:
# [{'answer': '',
#   'id': 0,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 1,
#   'question': 'what color pants does the referee wear in the video',
#   'video_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 2,
#   'question': 'what is the person in the middle of the video doing',
#   'video_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 3,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 4,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'video_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 5,
#   'question': 'what is on the table',
#   'video_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 6,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 7,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 8,
#   'question': 'where is the cup',
#   'video_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 9,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 10,
#   'question': 'what is in the room',
#   'video_name': 'ZJL669'},
#  {'answer': '',
#   'id': 11,
#   'question': 'what color of the pants does the person wear in the video',
#   'video_name': 'ZJL669'},
#  {'answer': '',
#   'id': 12,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL669'},
#  {'answer': '',
#   'id': 13,
#   'question': 'where is the photo frame',
#   'video_name': 'ZJL669'},
#  {'answer': '',
#   'id': 14,
#   'question': 'is the person standing or lying in the video',
#   'video_name': 'ZJL669'},
#  {'answer': '',
#   'id': 15,
#   'question': 'what is in front of the person in video',
#   'video_name': 'ZJL4179'},
#  {'answer': '',
#   'id': 16,
#   'question': 'what color are the pants in the video',
#   'video_name': 'ZJL4179'},
#  {'answer': '',
#   'id': 17,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4179'},
#  {'answer': '',
#   'id': 18,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4179'},
#  {'answer': '',
#   'id': 19,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4179'},
#  {'answer': '',
#   'id': 20,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL2342'},
#  {'answer': '',
#   'id': 21,
#   'question': 'what color clothes does the man wear in the video',
#   'video_name': 'ZJL2342'},
#  {'answer': '',
#   'id': 22,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2342'},
#  {'answer': '',
#   'id': 23,
#   'question': 'where are the shoes in the video',
#   'video_name': 'ZJL2342'},
#  {'answer': '',
#   'id': 24,
#   'question': 'is the man in the video sitting or standing',
#   'video_name': 'ZJL2342'},
#  {'answer': '',
#   'id': 25,
#   'question': 'is the man in the video long hair or short hair',
#   'video_name': 'ZJL470'},
#  {'answer': '',
#   'id': 26,
#   'question': 'what color is the curtain in the video',
#   'video_name': 'ZJL470'},
#  {'answer': '',
#   'id': 27,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL470'},
#  {'answer': '',
#   'id': 28,
#   'question': 'where is the water glass in the video',
#   'video_name': 'ZJL470'},
#  {'answer': '',
#   'id': 29,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL470'},
#  {'answer': '',
#   'id': 30,
#   'question': 'what is inside the sea in video',
#   'video_name': 'ZJL1793'},
#  {'answer': '',
#   'id': 31,
#   'question': 'what is the color of the yacht in the video',
#   'video_name': 'ZJL1793'},
#  {'answer': '',
#   'id': 32,
#   'question': 'does the yacht in the video start or stop',
#   'video_name': 'ZJL1793'},
#  {'answer': '',
#   'id': 33,
#   'question': 'is a tree or a flower by the lake in the video',
#   'video_name': 'ZJL1793'},
#  {'answer': '',
#   'id': 34,
#   'question': 'what is by the lake in the video',
#   'video_name': 'ZJL1793'},
#  {'answer': '',
#   'id': 35,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1174'},
#  {'answer': '',
#   'id': 36,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1174'},
#  {'answer': '',
#   'id': 37,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1174'},
#  {'answer': '',
#   'id': 38,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1174'},
#  {'answer': '',
#   'id': 39,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1174'},
#  {'answer': '',
#   'id': 40,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL2752'},
#  {'answer': '',
#   'id': 41,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2752'},
#  {'answer': '',
#   'id': 42,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2752'},
#  {'answer': '',
#   'id': 43,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2752'},
#  {'answer': '',
#   'id': 44,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2752'},
#  {'answer': '',
#   'id': 45,
#   'question': 'what does the woman wear around her neck in the video',
#   'video_name': 'ZJL1219'},
#  {'answer': '',
#   'id': 46,
#   'question': 'what color is the man is hair in the video',
#   'video_name': 'ZJL1219'},
#  {'answer': '',
#   'id': 47,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1219'},
#  {'answer': '',
#   'id': 48,
#   'question': 'where is the man lying on in the video',
#   'video_name': 'ZJL1219'},
#  {'answer': '',
#   'id': 49,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL1219'},
#  {'answer': '',
#   'id': 50,
#   'question': 'what is on the chair in the video',
#   'video_name': 'ZJL462'},
#  {'answer': '',
#   'id': 51,
#   'question': 'what color does the man in the video wear',
#   'video_name': 'ZJL462'},
#  {'answer': '',
#   'id': 52,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL462'},
#  {'answer': '',
#   'id': 53,
#   'question': 'where are the clothes hanging in the video',
#   'video_name': 'ZJL462'},
#  {'answer': '',
#   'id': 54,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL462'},
#  {'answer': '',
#   'id': 55,
#   'question': 'how many people are in the video',
#   'video_name': 'ZJL2430'},
#  {'answer': '',
#   'id': 56,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2430'},
#  {'answer': '',
#   'id': 57,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL2430'},
#  {'answer': '',
#   'id': 58,
#   'question': 'what did the person become in the end of the video',
#   'video_name': 'ZJL2430'},
#  {'answer': '',
#   'id': 59,
#   'question': 'where is the bear in the video',
#   'video_name': 'ZJL2430'},
#  {'answer': '',
#   'id': 60,
#   'question': 'what is on the grass in the video',
#   'video_name': 'ZJL1730'},
#  {'answer': '',
#   'id': 61,
#   'question': 'what is the color of the cow in the video',
#   'video_name': 'ZJL1730'},
#  {'answer': '',
#   'id': 62,
#   'question': 'what is the cow in the video doing',
#   'video_name': 'ZJL1730'},
#  {'answer': '',
#   'id': 63,
#   'question': 'what is the person wearing on his head in the video',
#   'video_name': 'ZJL1730'},
#  {'answer': '',
#   'id': 64,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1730'},
#  {'answer': '',
#   'id': 65,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL3539'},
#  {'answer': '',
#   'id': 66,
#   'question': 'what is the color of the cup in video',
#   'video_name': 'ZJL3539'},
#  {'answer': '',
#   'id': 67,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3539'},
#  {'answer': '',
#   'id': 68,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3539'},
#  {'answer': '',
#   'id': 69,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3539'},
#  {'answer': '',
#   'id': 70,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2437'},
#  {'answer': '',
#   'id': 71,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2437'},
#  {'answer': '',
#   'id': 72,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL2437'},
#  {'answer': '',
#   'id': 73,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2437'},
#  {'answer': '',
#   'id': 74,
#   'question': "what is on the person's neck in the video",
#   'video_name': 'ZJL2437'},
#  {'answer': '',
#   'id': 75,
#   'question': 'which person in the video is playing the computer',
#   'video_name': 'ZJL1885'},
#  {'answer': '',
#   'id': 76,
#   'question': 'what color of upper outer garment does the child in the video wear',
#   'video_name': 'ZJL1885'},
#  {'answer': '',
#   'id': 77,
#   'question': 'what is the child in the video doing',
#   'video_name': 'ZJL1885'},
#  {'answer': '',
#   'id': 78,
#   'question': 'where is the computer in the video',
#   'video_name': 'ZJL1885'},
#  {'answer': '',
#   'id': 79,
#   'question': 'is the child in the video sitting or standing',
#   'video_name': 'ZJL1885'},
#  {'answer': '',
#   'id': 80,
#   'question': 'what are the man holding in the video',
#   'video_name': 'ZJL433'},
#  {'answer': '',
#   'id': 81,
#   'question': 'what color does the man wear in the video',
#   'video_name': 'ZJL433'},
#  {'answer': '',
#   'id': 82,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL433'},
#  {'answer': '',
#   'id': 83,
#   'question': 'where is the bottle in the video',
#   'video_name': 'ZJL433'},
#  {'answer': '',
#   'id': 84,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL433'},
#  {'answer': '',
#   'id': 85,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3316'},
#  {'answer': '',
#   'id': 86,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3316'},
#  {'answer': '',
#   'id': 87,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3316'},
#  {'answer': '',
#   'id': 88,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3316'},
#  {'answer': '',
#   'id': 89,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3316'},
#  {'answer': '',
#   'id': 90,
#   'question': 'what is on the floor',
#   'video_name': 'ZJL2043'},
#  {'answer': '',
#   'id': 91,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL2043'},
#  {'answer': '',
#   'id': 92,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2043'},
#  {'answer': '',
#   'id': 93,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2043'},
#  {'answer': '',
#   'id': 94,
#   'question': 'is the person in the video sitting or standing at the beginning',
#   'video_name': 'ZJL2043'},
#  {'answer': '',
#   'id': 95,
#   'question': 'what is on the face of the person in the video',
#   'video_name': 'ZJL3519'},
#  {'answer': '',
#   'id': 96,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3519'},
#  {'answer': '',
#   'id': 97,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3519'},
#  {'answer': '',
#   'id': 98,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3519'},
#  {'answer': '',
#   'id': 99,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3519'},
#  {'answer': '',
#   'id': 100,
#   'question': 'what is on the table',
#   'video_name': 'ZJL1567'},
#  {'answer': '',
#   'id': 101,
#   'question': "what color is the person's clothes in the video",
#   'video_name': 'ZJL1567'},
#  {'answer': '',
#   'id': 102,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1567'},
#  {'answer': '',
#   'id': 103,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1567'},
#  {'answer': '',
#   'id': 104,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1567'},
#  {'answer': '',
#   'id': 105,
#   'question': 'what is in front of the door in the video',
#   'video_name': 'ZJL4097'},
#  {'answer': '',
#   'id': 106,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL4097'},
#  {'answer': '',
#   'id': 107,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4097'},
#  {'answer': '',
#   'id': 108,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4097'},
#  {'answer': '',
#   'id': 109,
#   'question': 'is the person sitting in the video resting or lying',
#   'video_name': 'ZJL4097'},
#  {'answer': '',
#   'id': 110,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL2737'},
#  {'answer': '',
#   'id': 111,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2737'},
#  {'answer': '',
#   'id': 112,
#   'question': 'what is on the face of the person in the video',
#   'video_name': 'ZJL2737'},
#  {'answer': '',
#   'id': 113,
#   'question': 'where is the computer in the video',
#   'video_name': 'ZJL2737'},
#  {'answer': '',
#   'id': 114,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2737'},
#  {'answer': '',
#   'id': 115,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3823'},
#  {'answer': '',
#   'id': 116,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL3823'},
#  {'answer': '',
#   'id': 117,
#   'question': 'what is the man doing while standing in the video',
#   'video_name': 'ZJL3823'},
#  {'answer': '',
#   'id': 118,
#   'question': 'where is the cup',
#   'video_name': 'ZJL3823'},
#  {'answer': '',
#   'id': 119,
#   'question': 'is the person sitting or standing while eating in the video',
#   'video_name': 'ZJL3823'},
#  {'answer': '',
#   'id': 120,
#   'question': 'what vehicle is in the video',
#   'video_name': 'ZJL1233'},
#  {'answer': '',
#   'id': 121,
#   'question': 'what color of the clothes does the man wear in the video',
#   'video_name': 'ZJL1233'},
#  {'answer': '',
#   'id': 122,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1233'},
#  {'answer': '',
#   'id': 123,
#   'question': 'where is the high speed railway in the video',
#   'video_name': 'ZJL1233'},
#  {'answer': '',
#   'id': 124,
#   'question': 'is the man standing or sitting in the video',
#   'video_name': 'ZJL1233'},
#  {'answer': '',
#   'id': 125,
#   'question': 'what is on the left of the video',
#   'video_name': 'ZJL279'},
#  {'answer': '',
#   'id': 126,
#   'question': 'what color pants does the boy wear in the video',
#   'video_name': 'ZJL279'},
#  {'answer': '',
#   'id': 127,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL279'},
#  {'answer': '',
#   'id': 128,
#   'question': 'are the audience standing or sitting',
#   'video_name': 'ZJL279'},
#  {'answer': '',
#   'id': 129,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL279'},
#  {'answer': '',
#   'id': 130,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1134'},
#  {'answer': '',
#   'id': 131,
#   'question': 'what color is the hat in the video',
#   'video_name': 'ZJL1134'},
#  {'answer': '',
#   'id': 132,
#   'question': 'what is the person with a pen in the video doing',
#   'video_name': 'ZJL1134'},
#  {'answer': '',
#   'id': 133,
#   'question': 'where is the balloon in the video',
#   'video_name': 'ZJL1134'},
#  {'answer': '',
#   'id': 134,
#   'question': 'did the person with the pen end up sitting or standing',
#   'video_name': 'ZJL1134'},
#  {'answer': '',
#   'id': 135,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3344'},
#  {'answer': '',
#   'id': 136,
#   'question': 'what is the color of spoon in the video',
#   'video_name': 'ZJL3344'},
#  {'answer': '',
#   'id': 137,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3344'},
#  {'answer': '',
#   'id': 138,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3344'},
#  {'answer': '',
#   'id': 139,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3344'},
#  {'answer': '',
#   'id': 140,
#   'question': 'what is in the room',
#   'video_name': 'ZJL691'},
#  {'answer': '',
#   'id': 141,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL691'},
#  {'answer': '',
#   'id': 142,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL691'},
#  {'answer': '',
#   'id': 143,
#   'question': 'where is the book',
#   'video_name': 'ZJL691'},
#  {'answer': '',
#   'id': 144,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL691'},
#  {'answer': '',
#   'id': 145,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL514'},
#  {'answer': '',
#   'id': 146,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL514'},
#  {'answer': '',
#   'id': 147,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL514'},
#  {'answer': '',
#   'id': 148,
#   'question': 'where is the chair in the video',
#   'video_name': 'ZJL514'},
#  {'answer': '',
#   'id': 149,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL514'},
#  {'answer': '',
#   'id': 150,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL871'},
#  {'answer': '',
#   'id': 151,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL871'},
#  {'answer': '',
#   'id': 152,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL871'},
#  {'answer': '',
#   'id': 153,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL871'},
#  {'answer': '',
#   'id': 154,
#   'question': 'what is on the wall in the video',
#   'video_name': 'ZJL871'},
#  {'answer': '',
#   'id': 155,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL2727'},
#  {'answer': '',
#   'id': 156,
#   'question': 'what color clothes does the woman in the video wear',
#   'video_name': 'ZJL2727'},
#  {'answer': '',
#   'id': 157,
#   'question': 'where is thewoman in the video',
#   'video_name': 'ZJL2727'},
#  {'answer': '',
#   'id': 158,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2727'},
#  {'answer': '',
#   'id': 159,
#   'question': 'is the person in the video short hair or long hair',
#   'video_name': 'ZJL2727'},
#  {'answer': '',
#   'id': 160,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL486'},
#  {'answer': '',
#   'id': 161,
#   'question': 'what color is the trash can in the video',
#   'video_name': 'ZJL486'},
#  {'answer': '',
#   'id': 162,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL486'},
#  {'answer': '',
#   'id': 163,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL486'},
#  {'answer': '',
#   'id': 164,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL486'},
#  {'answer': '',
#   'id': 165,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1171'},
#  {'answer': '',
#   'id': 166,
#   'question': 'what color is the cloak in the video',
#   'video_name': 'ZJL1171'},
#  {'answer': '',
#   'id': 167,
#   'question': 'is the hawk in the video on land or in the air',
#   'video_name': 'ZJL1171'},
#  {'answer': '',
#   'id': 168,
#   'question': 'what is the person wearing the cloak in the video doing',
#   'video_name': 'ZJL1171'},
#  {'answer': '',
#   'id': 169,
#   'question': 'is the person wearing a cloak in the video sitting or standing',
#   'video_name': 'ZJL1171'},
#  {'answer': '',
#   'id': 170,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL602'},
#  {'answer': '',
#   'id': 171,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL602'},
#  {'answer': '',
#   'id': 172,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL602'},
#  {'answer': '',
#   'id': 173,
#   'question': 'where is the case',
#   'video_name': 'ZJL602'},
#  {'answer': '',
#   'id': 174,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL602'},
#  {'answer': '',
#   'id': 175,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1485'},
#  {'answer': '',
#   'id': 176,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL1485'},
#  {'answer': '',
#   'id': 177,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1485'},
#  {'answer': '',
#   'id': 178,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1485'},
#  {'answer': '',
#   'id': 179,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1485'},
#  {'answer': '',
#   'id': 180,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2877'},
#  {'answer': '',
#   'id': 181,
#   'question': 'what color is the door in the video',
#   'video_name': 'ZJL2877'},
#  {'answer': '',
#   'id': 182,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2877'},
#  {'answer': '',
#   'id': 183,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2877'},
#  {'answer': '',
#   'id': 184,
#   'question': 'is the book in the video placed vertically or horizontally',
#   'video_name': 'ZJL2877'},
#  {'answer': '',
#   'id': 185,
#   'question': "is the man's hair in the video white or black",
#   'video_name': 'ZJL2348'},
#  {'answer': '',
#   'id': 186,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL2348'},
#  {'answer': '',
#   'id': 187,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2348'},
#  {'answer': '',
#   'id': 188,
#   'question': 'what does the man in video wear on his face',
#   'video_name': 'ZJL2348'},
#  {'answer': '',
#   'id': 189,
#   'question': 'is the man in the video sitting or standing',
#   'video_name': 'ZJL2348'},
#  {'answer': '',
#   'id': 190,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3856'},
#  {'answer': '',
#   'id': 191,
#   'question': 'what is the color of the bed sheet',
#   'video_name': 'ZJL3856'},
#  {'answer': '',
#   'id': 192,
#   'question': 'what is the man in red doing in the video',
#   'video_name': 'ZJL3856'},
#  {'answer': '',
#   'id': 193,
#   'question': 'where is the mouse',
#   'video_name': 'ZJL3856'},
#  {'answer': '',
#   'id': 194,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3856'},
#  {'answer': '',
#   'id': 195,
#   'question': 'what is in the room',
#   'video_name': 'ZJL659'},
#  {'answer': '',
#   'id': 196,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL659'},
#  {'answer': '',
#   'id': 197,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL659'},
#  {'answer': '',
#   'id': 198,
#   'question': 'where is the laundry detergent',
#   'video_name': 'ZJL659'},
#  {'answer': '',
#   'id': 199,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL659'},
#  {'answer': '',
#   'id': 200,
#   'question': 'what is in front of the door',
#   'video_name': 'ZJL2028'},
#  {'answer': '',
#   'id': 201,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL2028'},
#  {'answer': '',
#   'id': 202,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2028'},
#  {'answer': '',
#   'id': 203,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2028'},
#  {'answer': '',
#   'id': 204,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2028'},
#  {'answer': '',
#   'id': 205,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2126'},
#  {'answer': '',
#   'id': 206,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL2126'},
#  {'answer': '',
#   'id': 207,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2126'},
#  {'answer': '',
#   'id': 208,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2126'},
#  {'answer': '',
#   'id': 209,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2126'},
#  {'answer': '',
#   'id': 210,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2361'},
#  {'answer': '',
#   'id': 211,
#   'question': 'what color clothes does the woman wear in the video',
#   'video_name': 'ZJL2361'},
#  {'answer': '',
#   'id': 212,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2361'},
#  {'answer': '',
#   'id': 213,
#   'question': 'what does the person in video wear on their faces',
#   'video_name': 'ZJL2361'},
#  {'answer': '',
#   'id': 214,
#   'question': 'what does the person in the video hold in the hand',
#   'video_name': 'ZJL2361'},
#  {'answer': '',
#   'id': 215,
#   'question': 'what is in the room',
#   'video_name': 'ZJL707'},
#  {'answer': '',
#   'id': 216,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL707'},
#  {'answer': '',
#   'id': 217,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL707'},
#  {'answer': '',
#   'id': 218,
#   'question': 'where is the laptop',
#   'video_name': 'ZJL707'},
#  {'answer': '',
#   'id': 219,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL707'},
#  {'answer': '',
#   'id': 220,
#   'question': 'what does the person take',
#   'video_name': 'ZJL375'},
#  {'answer': '',
#   'id': 221,
#   'question': 'what is the color of the clothes the person is wearing',
#   'video_name': 'ZJL375'},
#  {'answer': '',
#   'id': 222,
#   'question': 'what is the person doing',
#   'video_name': 'ZJL375'},
#  {'answer': '',
#   'id': 223,
#   'question': 'where is the person',
#   'video_name': 'ZJL375'},
#  {'answer': '',
#   'id': 224,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL375'},
#  {'answer': '',
#   'id': 225,
#   'question': 'what is on the face of the man having white hair',
#   'video_name': 'ZJL3514'},
#  {'answer': '',
#   'id': 226,
#   'question': 'what color coat does the person having white hair wear',
#   'video_name': 'ZJL3514'},
#  {'answer': '',
#   'id': 227,
#   'question': 'what is the man having white hair doing',
#   'video_name': 'ZJL3514'},
#  {'answer': '',
#   'id': 228,
#   'question': 'where is the microwave oven',
#   'video_name': 'ZJL3514'},
#  {'answer': '',
#   'id': 229,
#   'question': 'is the person having white hair standing or sitting',
#   'video_name': 'ZJL3514'},
#  {'answer': '',
#   'id': 230,
#   'question': 'what is in the room',
#   'video_name': 'ZJL712'},
#  {'answer': '',
#   'id': 231,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL712'},
#  {'answer': '',
#   'id': 232,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL712'},
#  {'answer': '',
#   'id': 233,
#   'question': 'where is the calendar',
#   'video_name': 'ZJL712'},
#  {'answer': '',
#   'id': 234,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL712'},
#  {'answer': '',
#   'id': 235,
#   'question': 'what is on the sofa',
#   'video_name': 'ZJL61'},
#  {'answer': '',
#   'id': 236,
#   'question': "what is the color of the person's trousers in video",
#   'video_name': 'ZJL61'},
#  {'answer': '',
#   'id': 237,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL61'},
#  {'answer': '',
#   'id': 238,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL61'},
#  {'answer': '',
#   'id': 239,
#   'question': 'is the person in video standing or sitting',
#   'video_name': 'ZJL61'},
#  {'answer': '',
#   'id': 240,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL862'},
#  {'answer': '',
#   'id': 241,
#   'question': 'what color is the box in the video',
#   'video_name': 'ZJL862'},
#  {'answer': '',
#   'id': 242,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL862'},
#  {'answer': '',
#   'id': 243,
#   'question': 'what is in the box in the video',
#   'video_name': 'ZJL862'},
#  {'answer': '',
#   'id': 244,
#   'question': 'what did the person do after fetching the gloves in the video',
#   'video_name': 'ZJL862'},
#  {'answer': '',
#   'id': 245,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL3227'},
#  {'answer': '',
#   'id': 246,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3227'},
#  {'answer': '',
#   'id': 247,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3227'},
#  {'answer': '',
#   'id': 248,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3227'},
#  {'answer': '',
#   'id': 249,
#   'question': 'is the person in the video sitting or standing at the beginning',
#   'video_name': 'ZJL3227'},
#  {'answer': '',
#   'id': 250,
#   'question': 'what is behind the person in the video',
#   'video_name': 'ZJL4146'},
#  {'answer': '',
#   'id': 251,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL4146'},
#  {'answer': '',
#   'id': 252,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4146'},
#  {'answer': '',
#   'id': 253,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4146'},
#  {'answer': '',
#   'id': 254,
#   'question': 'is the person in the video lying or standing',
#   'video_name': 'ZJL4146'},
#  {'answer': '',
#   'id': 255,
#   'question': 'what is on the cooktop in the kitchen',
#   'video_name': 'ZJL2162'},
#  {'answer': '',
#   'id': 256,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2162'},
#  {'answer': '',
#   'id': 257,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2162'},
#  {'answer': '',
#   'id': 258,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2162'},
#  {'answer': '',
#   'id': 259,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2162'},
#  {'answer': '',
#   'id': 260,
#   'question': 'what sports equipment is in the video',
#   'video_name': 'ZJL1278'},
#  {'answer': '',
#   'id': 261,
#   'question': 'what color of the team uniform does the person wear in the video',
#   'video_name': 'ZJL1278'},
#  {'answer': '',
#   'id': 262,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1278'},
#  {'answer': '',
#   'id': 263,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1278'},
#  {'answer': '',
#   'id': 264,
#   'question': 'is the team member standing or sitting in the video',
#   'video_name': 'ZJL1278'},
#  {'answer': '',
#   'id': 265,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1446'},
#  {'answer': '',
#   'id': 266,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL1446'},
#  {'answer': '',
#   'id': 267,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1446'},
#  {'answer': '',
#   'id': 268,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL1446'},
#  {'answer': '',
#   'id': 269,
#   'question': 'is the man in the video sitting or standing',
#   'video_name': 'ZJL1446'},
#  {'answer': '',
#   'id': 270,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3887'},
#  {'answer': '',
#   'id': 271,
#   'question': 'what color is the computer',
#   'video_name': 'ZJL3887'},
#  {'answer': '',
#   'id': 272,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3887'},
#  {'answer': '',
#   'id': 273,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3887'},
#  {'answer': '',
#   'id': 274,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3887'},
#  {'answer': '',
#   'id': 275,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3246'},
#  {'answer': '',
#   'id': 276,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3246'},
#  {'answer': '',
#   'id': 277,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3246'},
#  {'answer': '',
#   'id': 278,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3246'},
#  {'answer': '',
#   'id': 279,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3246'},
#  {'answer': '',
#   'id': 280,
#   'question': 'what is in the closet',
#   'video_name': 'ZJL36'},
#  {'answer': '',
#   'id': 281,
#   'question': 'what is the color of the clothes does the person wear in video',
#   'video_name': 'ZJL36'},
#  {'answer': '',
#   'id': 282,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL36'},
#  {'answer': '',
#   'id': 283,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL36'},
#  {'answer': '',
#   'id': 284,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL36'},
#  {'answer': '',
#   'id': 285,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2145'},
#  {'answer': '',
#   'id': 286,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2145'},
#  {'answer': '',
#   'id': 287,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2145'},
#  {'answer': '',
#   'id': 288,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2145'},
#  {'answer': '',
#   'id': 289,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2145'},
#  {'answer': '',
#   'id': 290,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1505'},
#  {'answer': '',
#   'id': 291,
#   'question': 'what color is the dog in the video',
#   'video_name': 'ZJL1505'},
#  {'answer': '',
#   'id': 292,
#   'question': 'what is the dog doing in the video',
#   'video_name': 'ZJL1505'},
#  {'answer': '',
#   'id': 293,
#   'question': 'where is the dog in the video',
#   'video_name': 'ZJL1505'},
#  {'answer': '',
#   'id': 294,
#   'question': 'is the dog in the video sitting or standing',
#   'video_name': 'ZJL1505'},
#  {'answer': '',
#   'id': 295,
#   'question': 'what is in the bathroom',
#   'video_name': 'ZJL2119'},
#  {'answer': '',
#   'id': 296,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2119'},
#  {'answer': '',
#   'id': 297,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2119'},
#  {'answer': '',
#   'id': 298,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2119'},
#  {'answer': '',
#   'id': 299,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2119'},
#  {'answer': '',
#   'id': 300,
#   'question': 'what is in the corner in the video',
#   'video_name': 'ZJL1898'},
#  {'answer': '',
#   'id': 301,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1898'},
#  {'answer': '',
#   'id': 302,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1898'},
#  {'answer': '',
#   'id': 303,
#   'question': 'where does the person in the video take the case',
#   'video_name': 'ZJL1898'},
#  {'answer': '',
#   'id': 304,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1898'},
#  {'answer': '',
#   'id': 305,
#   'question': 'what is in front of the window',
#   'video_name': 'ZJL3333'},
#  {'answer': '',
#   'id': 306,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL3333'},
#  {'answer': '',
#   'id': 307,
#   'question': 'what is on the tv',
#   'video_name': 'ZJL3333'},
#  {'answer': '',
#   'id': 308,
#   'question': 'where is the television in the video',
#   'video_name': 'ZJL3333'},
#  {'answer': '',
#   'id': 309,
#   'question': 'what time is it in the video',
#   'video_name': 'ZJL3333'},
#  {'answer': '',
#   'id': 310,
#   'question': 'where does the person in the video sit on',
#   'video_name': 'ZJL1863'},
#  {'answer': '',
#   'id': 311,
#   'question': 'what color of clothes does the person in the video wear',
#   'video_name': 'ZJL1863'},
#  {'answer': '',
#   'id': 312,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1863'},
#  {'answer': '',
#   'id': 313,
#   'question': 'where does the person in the video take the water cup',
#   'video_name': 'ZJL1863'},
#  {'answer': '',
#   'id': 314,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL1863'},
#  {'answer': '',
#   'id': 315,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL2719'},
#  {'answer': '',
#   'id': 316,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2719'},
#  {'answer': '',
#   'id': 317,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL2719'},
#  {'answer': '',
#   'id': 318,
#   'question': 'what color clothes is the man in the video wear',
#   'video_name': 'ZJL2719'},
#  {'answer': '',
#   'id': 319,
#   'question': 'what is in the chair in the video',
#   'video_name': 'ZJL2719'},
#  {'answer': '',
#   'id': 320,
#   'question': 'what is on the wall',
#   'video_name': 'ZJL3774'},
#  {'answer': '',
#   'id': 321,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL3774'},
#  {'answer': '',
#   'id': 322,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3774'},
#  {'answer': '',
#   'id': 323,
#   'question': 'where is the cup',
#   'video_name': 'ZJL3774'},
#  {'answer': '',
#   'id': 324,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3774'},
#  {'answer': '',
#   'id': 325,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL2376'},
#  {'answer': '',
#   'id': 326,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2376'},
#  {'answer': '',
#   'id': 327,
#   'question': 'where does the person put the clothes in the video',
#   'video_name': 'ZJL2376'},
#  {'answer': '',
#   'id': 328,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2376'},
#  {'answer': '',
#   'id': 329,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2376'},
#  {'answer': '',
#   'id': 330,
#   'question': 'where is the woman wearing a hat in the video',
#   'video_name': 'ZJL2298'},
#  {'answer': '',
#   'id': 331,
#   'question': 'what color clothes does the woman with hat wear in the video',
#   'video_name': 'ZJL2298'},
#  {'answer': '',
#   'id': 332,
#   'question': 'what is the woman wearing a hat in the video doing',
#   'video_name': 'ZJL2298'},
#  {'answer': '',
#   'id': 333,
#   'question': 'how many people in the video are performing on the stage',
#   'video_name': 'ZJL2298'},
#  {'answer': '',
#   'id': 334,
#   'question': 'is the person wearing hat standing or sitting in the video',
#   'video_name': 'ZJL2298'},
#  {'answer': '',
#   'id': 335,
#   'question': 'what is on the cabinet door',
#   'video_name': 'ZJL4265'},
#  {'answer': '',
#   'id': 336,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4265'},
#  {'answer': '',
#   'id': 337,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4265'},
#  {'answer': '',
#   'id': 338,
#   'question': 'where is the schoolbag',
#   'video_name': 'ZJL4265'},
#  {'answer': '',
#   'id': 339,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4265'},
#  {'answer': '',
#   'id': 340,
#   'question': 'what does the man wear on head in the video',
#   'video_name': 'ZJL1221'},
#  {'answer': '',
#   'id': 341,
#   'question': 'what color of the pants does the man wear in the video',
#   'video_name': 'ZJL1221'},
#  {'answer': '',
#   'id': 342,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1221'},
#  {'answer': '',
#   'id': 343,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL1221'},
#  {'answer': '',
#   'id': 344,
#   'question': 'is the man standing or sitting in the video',
#   'video_name': 'ZJL1221'},
#  {'answer': '',
#   'id': 345,
#   'question': 'what is on the ground',
#   'video_name': 'ZJL2172'},
#  {'answer': '',
#   'id': 346,
#   'question': 'what color pants does the person pickin up things wear in the video',
#   'video_name': 'ZJL2172'},
#  {'answer': '',
#   'id': 347,
#   'question': 'what is the person wearing blue pants in the video doing',
#   'video_name': 'ZJL2172'},
#  {'answer': '',
#   'id': 348,
#   'question': 'where is the person carrying the carton in the video',
#   'video_name': 'ZJL2172'},
#  {'answer': '',
#   'id': 349,
#   'question': 'is the person carrying the carton in the video standing or lying',
#   'video_name': 'ZJL2172'},
#  {'answer': '',
#   'id': 350,
#   'question': 'what is in the room',
#   'video_name': 'ZJL638'},
#  {'answer': '',
#   'id': 351,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL638'},
#  {'answer': '',
#   'id': 352,
#   'question': 'what is the person in black pants doing',
#   'video_name': 'ZJL638'},
#  {'answer': '',
#   'id': 353,
#   'question': 'where is the person in black pants',
#   'video_name': 'ZJL638'},
#  {'answer': '',
#   'id': 354,
#   'question': 'is the person in black pants sitting or standing',
#   'video_name': 'ZJL638'},
#  {'answer': '',
#   'id': 355,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1146'},
#  {'answer': '',
#   'id': 356,
#   'question': 'what is the athlete doing in the video',
#   'video_name': 'ZJL1146'},
#  {'answer': '',
#   'id': 357,
#   'question': 'where is the athlete in the video',
#   'video_name': 'ZJL1146'},
#  {'answer': '',
#   'id': 358,
#   'question': 'what was the last shot the player made in the video',
#   'video_name': 'ZJL1146'},
#  {'answer': '',
#   'id': 359,
#   'question': 'is the referee sitting or standing in the video',
#   'video_name': 'ZJL1146'},
#  {'answer': '',
#   'id': 360,
#   'question': 'what is on the table',
#   'video_name': 'ZJL3220'},
#  {'answer': '',
#   'id': 361,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3220'},
#  {'answer': '',
#   'id': 362,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3220'},
#  {'answer': '',
#   'id': 363,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3220'},
#  {'answer': '',
#   'id': 364,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3220'},
#  {'answer': '',
#   'id': 365,
#   'question': 'what can you see in video',
#   'video_name': 'ZJL1412'},
#  {'answer': '',
#   'id': 366,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL1412'},
#  {'answer': '',
#   'id': 367,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1412'},
#  {'answer': '',
#   'id': 368,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1412'},
#  {'answer': '',
#   'id': 369,
#   'question': 'is the woman sitting or standing in the video',
#   'video_name': 'ZJL1412'},
#  {'answer': '',
#   'id': 370,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1091'},
#  {'answer': '',
#   'id': 371,
#   'question': 'what color clothes does the person running out in the video wear',
#   'video_name': 'ZJL1091'},
#  {'answer': '',
#   'id': 372,
#   'question': 'what is the person in the room doing',
#   'video_name': 'ZJL1091'},
#  {'answer': '',
#   'id': 373,
#   'question': 'where is the person eating in the video',
#   'video_name': 'ZJL1091'},
#  {'answer': '',
#   'id': 374,
#   'question': 'is the person eating in the video sitting or standing',
#   'video_name': 'ZJL1091'},
#  {'answer': '',
#   'id': 375,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3668'},
#  {'answer': '',
#   'id': 376,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3668'},
#  {'answer': '',
#   'id': 377,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3668'},
#  {'answer': '',
#   'id': 378,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3668'},
#  {'answer': '',
#   'id': 379,
#   'question': "what is the person's hair like in video",
#   'video_name': 'ZJL3668'},
#  {'answer': '',
#   'id': 380,
#   'question': 'where did the person in the video park the motorcycle',
#   'video_name': 'ZJL2301'},
#  {'answer': '',
#   'id': 381,
#   'question': 'what color top does the woman wear in the video',
#   'video_name': 'ZJL2301'},
#  {'answer': '',
#   'id': 382,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL2301'},
#  {'answer': '',
#   'id': 383,
#   'question': 'where is the child in the video playing',
#   'video_name': 'ZJL2301'},
#  {'answer': '',
#   'id': 384,
#   'question': 'which hand does the woman in the video keep moving',
#   'video_name': 'ZJL2301'},
#  {'answer': '',
#   'id': 385,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1530'},
#  {'answer': '',
#   'id': 386,
#   'question': 'what is the color of the car',
#   'video_name': 'ZJL1530'},
#  {'answer': '',
#   'id': 387,
#   'question': 'what is the person doing',
#   'video_name': 'ZJL1530'},
#  {'answer': '',
#   'id': 388,
#   'question': 'where is the car',
#   'video_name': 'ZJL1530'},
#  {'answer': '',
#   'id': 389,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1530'},
#  {'answer': '',
#   'id': 390,
#   'question': 'what is on the table-board',
#   'video_name': 'ZJL74'},
#  {'answer': '',
#   'id': 391,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL74'},
#  {'answer': '',
#   'id': 392,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL74'},
#  {'answer': '',
#   'id': 393,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL74'},
#  {'answer': '',
#   'id': 394,
#   'question': 'is the person in video standing or sitting',
#   'video_name': 'ZJL74'},
#  {'answer': '',
#   'id': 395,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL2041'},
#  {'answer': '',
#   'id': 396,
#   'question': 'what is the color of the clothes of the person in the video at the beginning',
#   'video_name': 'ZJL2041'},
#  {'answer': '',
#   'id': 397,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2041'},
#  {'answer': '',
#   'id': 398,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2041'},
#  {'answer': '',
#   'id': 399,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2041'},
#  {'answer': '',
#   'id': 400,
#   'question': 'in which hand of the person in the video is carrying a bag',
#   'video_name': 'ZJL1838'},
#  {'answer': '',
#   'id': 401,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1838'},
#  {'answer': '',
#   'id': 402,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1838'},
#  {'answer': '',
#   'id': 403,
#   'question': 'which hand of the person in the video is making the towel',
#   'video_name': 'ZJL1838'},
#  {'answer': '',
#   'id': 404,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1838'},
#  {'answer': '',
#   'id': 405,
#   'question': 'what is on the washing machine',
#   'video_name': 'ZJL4256'},
#  {'answer': '',
#   'id': 406,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4256'},
#  {'answer': '',
#   'id': 407,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4256'},
#  {'answer': '',
#   'id': 408,
#   'question': 'where is the washing machine',
#   'video_name': 'ZJL4256'},
#  {'answer': '',
#   'id': 409,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4256'},
#  {'answer': '',
#   'id': 410,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1203'},
#  {'answer': '',
#   'id': 411,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1203'},
#  {'answer': '',
#   'id': 412,
#   'question': 'what color is the bowl in the video',
#   'video_name': 'ZJL1203'},
#  {'answer': '',
#   'id': 413,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1203'},
#  {'answer': '',
#   'id': 414,
#   'question': 'what is hanging on the wall in the video',
#   'video_name': 'ZJL1203'},
#  {'answer': '',
#   'id': 415,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2859'},
#  {'answer': '',
#   'id': 416,
#   'question': 'what color is the dress of the short-haired person talking in the video',
#   'video_name': 'ZJL2859'},
#  {'answer': '',
#   'id': 417,
#   'question': 'what is the person wearing pink jackets in the video doing',
#   'video_name': 'ZJL2859'},
#  {'answer': '',
#   'id': 418,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2859'},
#  {'answer': '',
#   'id': 419,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2859'},
#  {'answer': '',
#   'id': 420,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL592'},
# ...
#  {'answer': '',
#   'id': 862,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL476'},
#  {'answer': '',
#   'id': 863,
#   'question': 'where does the man in the video put the cup',
#   'video_name': 'ZJL476'},
#  {'answer': '',
#   'id': 864,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL476'},
#  {'answer': '',
#   'id': 865,
#   'question': 'what does the person in the video hold',
#   'video_name': 'ZJL1878'},
#  {'answer': '',
#   'id': 866,
#   'question': 'what color of overcoat does the person in the video wear',
#   'video_name': 'ZJL1878'},
#  {'answer': '',
#   'id': 867,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1878'},
#  {'answer': '',
#   'id': 868,
#   'question': 'where does the person in the video put the water cup',
#   'video_name': 'ZJL1878'},
#  {'answer': '',
#   'id': 869,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1878'},
#  {'answer': '',
#   'id': 870,
#   'question': 'what is on the table',
#   'video_name': 'ZJL4242'},
#  {'answer': '',
#   'id': 871,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL4242'},
#  {'answer': '',
#   'id': 872,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4242'},
#  {'answer': '',
#   'id': 873,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4242'},
#  {'answer': '',
#   'id': 874,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4242'},
#  {'answer': '',
#   'id': 875,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1365'},
#  {'answer': '',
#   'id': 876,
#   'question': 'what color is the pool in the video',
#   'video_name': 'ZJL1365'},
#  {'answer': '',
#   'id': 877,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1365'},
#  {'answer': '',
#   'id': 878,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1365'},
#  {'answer': '',
#   'id': 879,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1365'},
#  {'answer': '',
#   'id': 880,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL2069'},
#  {'answer': '',
#   'id': 881,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL2069'},
#  {'answer': '',
#   'id': 882,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2069'},
#  {'answer': '',
#   'id': 883,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2069'},
#  {'answer': '',
#   'id': 884,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2069'},
#  {'answer': '',
#   'id': 885,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3670'},
#  {'answer': '',
#   'id': 886,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3670'},
#  {'answer': '',
#   'id': 887,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3670'},
#  {'answer': '',
#   'id': 888,
#   'question': 'what does the person in video have in his hand',
#   'video_name': 'ZJL3670'},
#  {'answer': '',
#   'id': 889,
#   'question': 'what is hanging on the door in video',
#   'video_name': 'ZJL3670'},
#  {'answer': '',
#   'id': 890,
#   'question': 'what kind of musical instruments is in the video',
#   'video_name': 'ZJL2576'},
#  {'answer': '',
#   'id': 891,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL2576'},
#  {'answer': '',
#   'id': 892,
#   'question': 'what is the peorson in video sitting on',
#   'video_name': 'ZJL2576'},
#  {'answer': '',
#   'id': 893,
#   'question': 'what is in front of people in video',
#   'video_name': 'ZJL2576'},
#  {'answer': '',
#   'id': 894,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2576'},
#  {'answer': '',
#   'id': 895,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3437'},
#  {'answer': '',
#   'id': 896,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3437'},
#  {'answer': '',
#   'id': 897,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3437'},
#  {'answer': '',
#   'id': 898,
#   'question': 'where is the cup',
#   'video_name': 'ZJL3437'},
#  {'answer': '',
#   'id': 899,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3437'},
#  {'answer': '',
#   'id': 900,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3294'},
#  {'answer': '',
#   'id': 901,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL3294'},
#  {'answer': '',
#   'id': 902,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3294'},
#  {'answer': '',
#   'id': 903,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3294'},
#  {'answer': '',
#   'id': 904,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3294'},
#  {'answer': '',
#   'id': 905,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL4159'},
#  {'answer': '',
#   'id': 906,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL4159'},
#  {'answer': '',
#   'id': 907,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4159'},
#  {'answer': '',
#   'id': 908,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4159'},
#  {'answer': '',
#   'id': 909,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL4159'},
#  {'answer': '',
#   'id': 910,
#   'question': 'what does the boy wear around his neck in the video',
#   'video_name': 'ZJL1262'},
#  {'answer': '',
#   'id': 911,
#   'question': "what color is the boy's hair in the video",
#   'video_name': 'ZJL1262'},
#  {'answer': '',
#   'id': 912,
#   'question': 'what is the boy doing in the video',
#   'video_name': 'ZJL1262'},
#  {'answer': '',
#   'id': 913,
#   'question': 'where is the alarm clock in the video',
#   'video_name': 'ZJL1262'},
#  {'answer': '',
#   'id': 914,
#   'question': 'is the boy standing or sitting in the video',
#   'video_name': 'ZJL1262'},
#  {'answer': '',
#   'id': 915,
#   'question': 'what is in the video',
#   'video_name': 'ZJL907'},
#  {'answer': '',
#   'id': 916,
#   'question': 'what is the color of the clothes worn by the person singing in the middle of the video',
#   'video_name': 'ZJL907'},
#  {'answer': '',
#   'id': 917,
#   'question': 'what is the man holding the microphone doing in the video',
#   'video_name': 'ZJL907'},
#  {'answer': '',
#   'id': 918,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL907'},
#  {'answer': '',
#   'id': 919,
#   'question': 'is the person singing in the video sitting or standing',
#   'video_name': 'ZJL907'},
#  {'answer': '',
#   'id': 920,
#   'question': 'what does the man wear on head in the video',
#   'video_name': 'ZJL1266'},
#  {'answer': '',
#   'id': 921,
#   'question': 'what color of the clothes does the man wear in the video',
#   'video_name': 'ZJL1266'},
#  {'answer': '',
#   'id': 922,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL1266'},
#  {'answer': '',
#   'id': 923,
#   'question': 'where is the food in the video',
#   'video_name': 'ZJL1266'},
#  {'answer': '',
#   'id': 924,
#   'question': 'is the man standing or sitting in the video',
#   'video_name': 'ZJL1266'},
#  {'answer': '',
#   'id': 925,
#   'question': 'what is in the closet',
#   'video_name': 'ZJL3853'},
#  {'answer': '',
#   'id': 926,
#   'question': 'what is the color of the wall',
#   'video_name': 'ZJL3853'},
#  {'answer': '',
#   'id': 927,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3853'},
#  {'answer': '',
#   'id': 928,
#   'question': 'where is the apron',
#   'video_name': 'ZJL3853'},
#  {'answer': '',
#   'id': 929,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3853'},
#  {'answer': '',
#   'id': 930,
#   'question': 'does the man in the video have long or short hair',
#   'video_name': 'ZJL585'},
#  {'answer': '',
#   'id': 931,
#   'question': 'what color of clothes does the man in the video wear',
#   'video_name': 'ZJL585'},
#  {'answer': '',
#   'id': 932,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL585'},
#  {'answer': '',
#   'id': 933,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL585'},
#  {'answer': '',
#   'id': 934,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL585'},
#  {'answer': '',
#   'id': 935,
#   'question': 'what is in the video',
#   'video_name': 'ZJL828'},
#  {'answer': '',
#   'id': 936,
#   'question': 'what is the font color of the passage in the video',
#   'video_name': 'ZJL828'},
#  {'answer': '',
#   'id': 937,
#   'question': 'where did the passage in the video come from',
#   'video_name': 'ZJL828'},
#  {'answer': '',
#   'id': 938,
#   'question': 'what month does the passage written in the video',
#   'video_name': 'ZJL828'},
#  {'answer': '',
#   'id': 939,
#   'question': 'is the passage written in english or chinese in the video',
#   'video_name': 'ZJL828'},
#  {'answer': '',
#   'id': 940,
#   'question': 'what does the man in the video hold in his hand',
#   'video_name': 'ZJL2397'},
#  {'answer': '',
#   'id': 941,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2397'},
#  {'answer': '',
#   'id': 942,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2397'},
#  {'answer': '',
#   'id': 943,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2397'},
#  {'answer': '',
#   'id': 944,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2397'},
#  {'answer': '',
#   'id': 945,
#   'question': 'what is in the hand of the person in black dress',
#   'video_name': 'ZJL1630'},
#  {'answer': '',
#   'id': 946,
#   'question': 'what color are the clothes of the person with yellow hair in the video',
#   'video_name': 'ZJL1630'},
#  {'answer': '',
#   'id': 947,
#   'question': 'what is the person in red in the video doing',
#   'video_name': 'ZJL1630'},
#  {'answer': '',
#   'id': 948,
#   'question': 'does the person have long hair or short hair',
#   'video_name': 'ZJL1630'},
#  {'answer': '',
#   'id': 949,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1630'},
#  {'answer': '',
#   'id': 950,
#   'question': 'what color clothes does the person in the video wear',
#   'video_name': 'ZJL2740'},
#  {'answer': '',
#   'id': 951,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2740'},
#  {'answer': '',
#   'id': 952,
#   'question': 'what does the person in the video hold',
#   'video_name': 'ZJL2740'},
#  {'answer': '',
#   'id': 953,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2740'},
#  {'answer': '',
#   'id': 954,
#   'question': 'where does the water cup come out of the video',
#   'video_name': 'ZJL2740'},
#  {'answer': '',
#   'id': 955,
#   'question': 'what is above the water tap in video',
#   'video_name': 'ZJL3597'},
#  {'answer': '',
#   'id': 956,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3597'},
#  {'answer': '',
#   'id': 957,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3597'},
#  {'answer': '',
#   'id': 958,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3597'},
#  {'answer': '',
#   'id': 959,
#   'question': 'what does the person in video wear on his head',
#   'video_name': 'ZJL3597'},
#  {'answer': '',
#   'id': 960,
#   'question': 'what does the white-haired man in video hold',
#   'video_name': 'ZJL2677'},
#  {'answer': '',
#   'id': 961,
#   'question': 'what color is the lighting in video',
#   'video_name': 'ZJL2677'},
#  {'answer': '',
#   'id': 962,
#   'question': 'what are the people doing in video',
#   'video_name': 'ZJL2677'},
#  {'answer': '',
#   'id': 963,
#   'question': 'where is the old man with white hair standing',
#   'video_name': 'ZJL2677'},
#  {'answer': '',
#   'id': 964,
#   'question': 'is the man play the piano standing or sitting',
#   'video_name': 'ZJL2677'},
#  {'answer': '',
#   'id': 965,
#   'question': 'what is on the ground in the video',
#   'video_name': 'ZJL1776'},
#  {'answer': '',
#   'id': 966,
#   'question': 'what is the color of the carton in the video',
#   'video_name': 'ZJL1776'},
#  {'answer': '',
#   'id': 967,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1776'},
#  {'answer': '',
#   'id': 968,
#   'question': 'is the person in the video holding things in the left hand or in the right hand',
#   'video_name': 'ZJL1776'},
#  {'answer': '',
#   'id': 969,
#   'question': 'is the carton in the video standing or standing upside down',
#   'video_name': 'ZJL1776'},
#  {'answer': '',
#   'id': 970,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3588'},
#  {'answer': '',
#   'id': 971,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3588'},
#  {'answer': '',
#   'id': 972,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3588'},
#  {'answer': '',
#   'id': 973,
#   'question': 'what is the person in video holding',
#   'video_name': 'ZJL3588'},
#  {'answer': '',
#   'id': 974,
#   'question': 'what is the color of the wall in video',
#   'video_name': 'ZJL3588'},
#  {'answer': '',
#   'id': 975,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3935'},
#  {'answer': '',
#   'id': 976,
#   'question': "what color is the person's coat in video",
#   'video_name': 'ZJL3935'},
#  {'answer': '',
#   'id': 977,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3935'},
#  {'answer': '',
#   'id': 978,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3935'},
#  {'answer': '',
#   'id': 979,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3935'},
#  {'answer': '',
#   'id': 980,
#   'question': 'what is on the left of the person in the video',
#   'video_name': 'ZJL2103'},
#  {'answer': '',
#   'id': 981,
#   'question': 'what is the color of the wall in the video',
#   'video_name': 'ZJL2103'},
#  {'answer': '',
#   'id': 982,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2103'},
#  {'answer': '',
#   'id': 983,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2103'},
#  {'answer': '',
#   'id': 984,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2103'},
#  {'answer': '',
#   'id': 985,
#   'question': 'what is in the hand of the woman in the video',
#   'video_name': 'ZJL285'},
#  {'answer': '',
#   'id': 986,
#   'question': 'what color is the car in the video',
#   'video_name': 'ZJL285'},
#  {'answer': '',
#   'id': 987,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL285'},
#  {'answer': '',
#   'id': 988,
#   'question': 'is the car in the video parked or driving',
#   'video_name': 'ZJL285'},
#  {'answer': '',
#   'id': 989,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL285'},
#  {'answer': '',
#   'id': 990,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1405'},
#  {'answer': '',
#   'id': 991,
#   'question': 'what is the color of the car at the beginning of the video',
#   'video_name': 'ZJL1405'},
#  {'answer': '',
#   'id': 992,
#   'question': 'what is the car doing in the video',
#   'video_name': 'ZJL1405'},
#  {'answer': '',
#   'id': 993,
#   'question': 'where is the car in the video',
#   'video_name': 'ZJL1405'},
#  {'answer': '',
#   'id': 994,
#   'question': 'is the car driving or stopping at the beginning of the video',
#   'video_name': 'ZJL1405'},
#  {'answer': '',
#   'id': 995,
#   'question': 'what is in the video',
#   'video_name': 'ZJL912'},
#  {'answer': '',
#   'id': 996,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL912'},
#  {'answer': '',
#   'id': 997,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL912'},
#  {'answer': '',
#   'id': 998,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL912'},
#  {'answer': '',
#   'id': 999,
#   'question': 'is the person in red riding on a bicycle or standing on a bicycle',
#   'video_name': 'ZJL912'},
#  ...]

# %%
#new_dict = json.loads(data_list)
with open("./new_data/data_test.json","w") as f:
    json.dump(data_list,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
with open("/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt") as f:
    fs = f.readlines()

# %%
random.shuffle(fs)

# %%
random.shuffle(video_n = [i.split(",")[0] for i in fs]
# Out:
#   File "<ipython-input-24-ffb2a64d7526>", line 1
#     random.shuffle(video_n = [i.split(",")[0] for i in fs]
#                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
len(set(video_n))

# %%
data_list_new
# Out:
# [{'answer': 'mirror',
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'pool',
#   'id': 1,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'shelf',
#   'id': 2,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'blue',
#   'id': 3,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'dark blue',
#   'id': 4,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'black blue',
#   'id': 5,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'cleaning up',
#   'id': 6,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'wiping mirror',
#   'id': 7,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washing cup',
#   'id': 8,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'indoor',
#   'id': 9,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washroom',
#   'id': 10,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'residence',
#   'id': 11,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'standing',
#   'id': 12,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'white',
#   'id': 13,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'kissing',
#   'id': 14,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'lying',
#   'id': 15,
#   'question': 'is the person sitting or lying in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'on bed',
#   'id': 16,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'long hair',
#   'id': 17,
#   'question': 'does the woman have long hair or short hair in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'white',
#   'id': 18,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'light white',
#   'id': 19,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'pure white',
#   'id': 20,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'standing',
#   'id': 21,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'sitting',
#   'id': 22,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'kitchen',
#   'id': 23,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking water',
#   'id': 24,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking milk',
#   'id': 25,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'on table',
#   'id': 26,
#   'question': 'where is the book',
#   'video_name': 'ZJL963'},
#  {'answer': 'third',
#   'id': 27,
#   'question': 'which layer of the cabinet is the water cup put in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pure black',
#   'id': 28,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'black',
#   'id': 29,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'dark black',
#   'id': 30,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'opening cabinet',
#   'id': 31,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'drinking water',
#   'id': 32,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'cabinet',
#   'id': 33,
#   'question': 'where did the person get the cup',
#   'video_name': 'ZJL1836'},
#  {'answer': 'standing',
#   'id': 34,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pink',
#   'id': 35,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'light-pink',
#   'id': 36,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'peach-pink',
#   'id': 37,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'broadcasting',
#   'id': 38,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'entertainment',
#   'id': 39,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'new',
#   'id': 40,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'swimsuit',
#   'id': 41,
#   'question': 'what does the super star wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'in water',
#   'id': 42,
#   'question': 'where is the superstar in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'standing',
#   'id': 43,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'tv',
#   'id': 44,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'sofa',
#   'id': 45,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'table',
#   'id': 46,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'white',
#   'id': 47,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'milk white',
#   'id': 48,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'off-white',
#   'id': 49,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'pushing tv button',
#   'id': 50,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in living room',
#   'id': 51,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'indoor',
#   'id': 52,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in room',
#   'id': 53,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'standing',
#   'id': 54,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'book',
#   'id': 55,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'phone',
#   'id': 56,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'computer',
#   'id': 57,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'black',
#   'id': 58,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'white',
#   'id': 59,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'blue',
#   'id': 60,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'taking clothes',
#   'id': 61,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'clearing up',
#   'id': 62,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'playing phone',
#   'id': 63,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'standing',
#   'id': 64,
#   'question': 'was the man standing or sitting in the end',
#   'video_name': 'ZJL2952'},
#  {'answer': 'in door',
#   'id': 65,
#   'question': 'where is the man',
#   'video_name': 'ZJL2952'},
#  {'answer': 'brown',
#   'id': 66,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'light brown',
#   'id': 67,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'rustic brown',
#   'id': 68,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'standing',
#   'id': 69,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'bathroom',
#   'id': 70,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'looking at mirror',
#   'id': 71,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'taking off clothes',
#   'id': 72,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'wiping arms',
#   'id': 73,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'on shelf',
#   'id': 74,
#   'question': 'where is the towel',
#   'video_name': 'ZJL927'},
#  {'answer': 'schoolbag',
#   'id': 75,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'mobile phone',
#   'id': 76,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'pillow',
#   'id': 77,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'green',
#   'id': 78,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'light green',
#   'id': 79,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'dark green',
#   'id': 80,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'holding pillow',
#   'id': 81,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'room',
#   'id': 82,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'sitting',
#   'id': 83,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'daytime',
#   'id': 84,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'morning',
#   'id': 85,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'white',
#   'id': 86,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'milk white',
#   'id': 87,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'creamy white',
#   'id': 88,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking selfie',
#   'id': 89,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'photographing',
#   'id': 90,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking photos',
#   'id': 91,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'outdoor',
#   'id': 92,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'suburb',
#   'id': 93,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'in car',
#   'id': 94,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'sitting',
#   'id': 95,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'woman',
#   'id': 96,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'man',
#   'id': 97,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sofa',
#   'id': 98,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'beige',
#   'id': 99,
#   'question': 'what color is the sofa in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'talking',
#   'id': 100,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'in room',
#   'id': 101,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'standing',
#   'id': 102,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sitting',
#   'id': 103,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'black',
#   'id': 104,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'white',
#   'id': 105,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'dark blue',
#   'id': 106,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'sitting',
#   'id': 107,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'reading book',
#   'id': 108,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'kitchen',
#   'id': 109,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'on table',
#   'id': 110,
#   'question': 'where is the water bottle in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'photograph',
#   'id': 111,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'cup',
#   'id': 112,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'basket',
#   'id': 113,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'black',
#   'id': 114,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'drinking water',
#   'id': 115,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'in stairwell',
#   'id': 116,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'standing',
#   'id': 117,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3443'},
#  {'answer': 'closet',
#   'id': 118,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'chair',
#   'id': 119,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'tv',
#   'id': 120,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'black',
#   'id': 121,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'dark black',
#   'id': 122,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'aterrimus',
#   'id': 123,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'opening door',
#   'id': 124,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'putting towel',
#   'id': 125,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'sneezing',
#   'id': 126,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'indoor',
#   'id': 127,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'living room',
#   'id': 128,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'residence',
#   'id': 129,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'standing',
#   'id': 130,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'computer',
#   'id': 131,
#   'question': 'what is on the cabinet in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'white',
#   'id': 132,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL578'},
#  {'answer': 'eating things',
#   'id': 133,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'playing computer',
#   'id': 134,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'kitchen',
#   'id': 135,
#   'question': 'in which room is the woman in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 136,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 137,
#   'question': 'is the person wearing pink in the video standing or sitting',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating something',
#   'id': 138,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating food',
#   'id': 139,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bedroom',
#   'id': 140,
#   'question': 'where is the person wearing pink in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bed',
#   'id': 141,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'cabinet',
#   'id': 142,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'mirror',
#   'id': 143,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'white',
#   'id': 144,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'light white',
#   'id': 145,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'gray white',
#   'id': 146,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'green',
#   'id': 147,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pale green',
#   'id': 148,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'grass green',
#   'id': 149,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'standing',
#   'id': 150,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'taking off shoes',
#   'id': 151,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'closing door',
#   'id': 152,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'turn on lights',
#   'id': 153,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'long hair',
#   'id': 154,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pink',
#   'id': 155,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'soft red',
#   'id': 156,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'rose',
#   'id': 157,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'cup',
#   'id': 158,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'phone',
#   'id': 159,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'clothes',
#   'id': 160,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'brown',
#   'id': 161,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'yellow',
#   'id': 162,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'golden',
#   'id': 163,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'standing',
#   'id': 164,
#   'question': 'is the man in purple standing or sitting',
#   'video_name': 'ZJL2934'},
#  {'answer': 'in door',
#   'id': 165,
#   'question': 'where is the man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'shoes',
#   'id': 166,
#   'question': 'what is on the outside floor',
#   'video_name': 'ZJL2934'},
#  {'answer': 'green',
#   'id': 167,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'grass green',
#   'id': 168,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'pale green',
#   'id': 169,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'standing',
#   'id': 170,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'kitchen',
#   'id': 171,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'making food',
#   'id': 172,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'sweeping floor',
#   'id': 173,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'eating',
#   'id': 174,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'short hair',
#   'id': 175,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'cabinet',
#   'id': 176,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'mirror',
#   'id': 177,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'clothes',
#   'id': 178,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'pink',
#   'id': 179,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'magenta',
#   'id': 180,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'burgandy',
#   'id': 181,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'looking at mirror',
#   'id': 182,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'putting on clothes',
#   'id': 183,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'buttoning',
#   'id': 184,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'indoor',
#   'id': 185,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in room',
#   'id': 186,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in house',
#   'id': 187,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'standing',
#   'id': 188,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'door',
#   'id': 189,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'television',
#   'id': 190,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'curtain',
#   'id': 191,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'yellow',
#   'id': 192,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'khaki',
#   'id': 193,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'brownish yellow',
#   'id': 194,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'watching tv',
#   'id': 195,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'resting',
#   'id': 196,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'sleeping',
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'indoors',
#   'id': 198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in house',
#   'id': 199,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in bedroom',
#   'id': 200,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'lying on his stomach',
#   'id': 201,
#   'question': 'is the person in the video lying on his stomach or sitting',
#   'video_name': 'ZJL4047'},
#  {'answer': 'chair',
#   'id': 202,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'fence',
#   'id': 203,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'book',
#   'id': 204,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'white',
#   'id': 205,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'milk white',
#   'id': 206,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'creamy white',
#   'id': 207,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'dancing',
#   'id': 208,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'exercising',
#   'id': 209,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'playing',
#   'id': 210,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'outdoor',
#   'id': 211,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'yard',
#   'id': 212,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'at door',
#   'id': 213,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'standing',
#   'id': 214,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'mustache',
#   'id': 215,
#   'question': "what is on the person's face in the video",
#   'video_name': 'ZJL651'},
#  {'answer': 'gray',
#   'id': 216,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'black gray',
#   'id': 217,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'neutral gary',
#   'id': 218,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'eating',
#   'id': 219,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'staircase',
#   'id': 220,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'sitting',
#   'id': 221,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'closet',
#   'id': 222,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'refrigerator',
#   'id': 223,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'pot',
#   'id': 224,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'black',
#   'id': 225,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'dark black',
#   'id': 226,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'aterrimus',
#   'id': 227,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'firing',
#   'id': 228,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'taking things',
#   'id': 229,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'opening refrigerator',
#   'id': 230,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'indoor',
#   'id': 231,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'kitchen',
#   'id': 232,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'residence',
#   'id': 233,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'standing',
#   'id': 234,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'icon',
#   'id': 235,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'website',
#   'id': 236,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'people',
#   'id': 237,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'female',
#   'id': 238,
#   'question': 'is the person in the video a male or a female',
#   'video_name': 'ZJL1115'},
#  {'answer': 'black',
#   'id': 239,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'in water',
#   'id': 240,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'tapping water',
#   'id': 241,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'music score',
#   'id': 242,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'guitar',
#   'id': 243,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'microphone',
#   'id': 244,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple',
#   'id': 245,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'deep purple',
#   'id': 246,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple sauce',
#   'id': 247,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'singing',
#   'id': 248,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'on stage',
#   'id': 249,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'standing',
#   'id': 250,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'boy',
#   'id': 251,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'girl',
#   'id': 252,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'women',
#   'id': 253,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'brown',
#   'id': 254,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'tan',
#   'id': 255,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'coffee',
#   'id': 256,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interviewing',
#   'id': 257,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'talking',
#   'id': 258,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'narrating',
#   'id': 259,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'indoor',
#   'id': 260,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'in room',
#   'id': 261,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interview site',
#   'id': 262,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'sitting',
#   'id': 263,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'mustache',
#   'id': 264,
#   'question': 'what is on the face of the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'white',
#   'id': 265,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'creamy-white',
#   'id': 266,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'ivory-white',
#   'id': 267,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'setting of pillows',
#   'id': 268,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'in living room',
#   'id': 269,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'sitting',
#   'id': 270,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL3506'},
#  {'answer': 'board',
#   'id': 271,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'sponge',
#   'id': 272,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'brush',
#   'id': 273,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'yellow',
#   'id': 274,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'light yellow',
#   'id': 275,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'canary yellow',
#   'id': 276,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning toy',
#   'id': 277,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'wiping toy',
#   'id': 278,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning up dust',
#   'id': 279,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in water',
#   'id': 280,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathtub',
#   'id': 281,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathroom',
#   'id': 282,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'plastic',
#   'id': 283,
#   'question': 'what is the material of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'athlete',
#   'id': 284,
#   'question': 'what is on the track',
#   'video_name': 'ZJL1602'},
#  {'answer': 'yellow',
#   'id': 285,
#   'question': "what color is the runner's hair",
#   'video_name': 'ZJL1602'},
#  {'answer': 'running',
#   'id': 286,
#   'question': 'what is the person in yellow hair doing',
#   'video_name': 'ZJL1602'},
#  {'answer': 'on sport court',
#   'id': 287,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1602'},
#  {'answer': 'standing',
#   'id': 288,
#   'question': 'is the athlete in the video standing or sitting',
#   'video_name': 'ZJL1602'},
#  {'answer': 'hanging on wall',
#   'id': 289,
#   'question': 'where is the tv in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'blue',
#   'id': 290,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'light blue',
#   'id': 291,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'walking',
#   'id': 292,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL430'},
#  {'answer': 'benches',
#   'id': 293,
#   'question': 'where is the boy sitting in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'standing',
#   'id': 294,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL430'},
#  {'answer': 'plates',
#   'id': 295,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'watches',
#   'id': 296,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'flour',
#   'id': 297,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'green',
#   'id': 298,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'taking things',
#   'id': 299,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'pouring things',
#   'id': 300,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'kitchen',
#   'id': 301,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'standing',
#   'id': 302,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2863'},
#  {'answer': 'long hair',
#   'id': 303,
#   'question': 'does the person has long hair or short hair in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'white',
#   'id': 304,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'washing hands',
#   'id': 305,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'on cabinet',
#   'id': 306,
#   'question': 'where is the towel',
#   'video_name': 'ZJL3470'},
#  {'answer': 'standing',
#   'id': 307,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3470'},
#  {'answer': 'cummerbund',
#   'id': 308,
#   'question': 'what does the person in video hold',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple',
#   'id': 309,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'rose red',
#   'id': 310,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple red',
#   'id': 311,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'circle',
#   'id': 312,
#   'question': 'what is the shape of the decorative ribbon in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'left hand',
#   'id': 313,
#   'question': 'which hand of the people in video picked up the ribbon',
#   'video_name': 'ZJL2593'},
#  {'answer': 'standing',
#   'id': 314,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'wheelchair',
#   'id': 315,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'desk',
#   'id': 316,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'chair',
#   'id': 317,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'red',
#   'id': 318,
#   'question': 'what color clothes does the person sitting on a wheelchair wear',
#   'video_name': 'ZJL842'},
#  {'answer': 'hospital',
#   'id': 319,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'talking',
#   'id': 320,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'fetching things',
#   'id': 321,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'standing',
#   'id': 322,
#   'question': 'is the person wearing white clothes in the video sitting or standing',
#   'video_name': 'ZJL842'},
#  {'answer': 'clothes',
#   'id': 323,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'boxes',
#   'id': 324,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'hangers',
#   'id': 325,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'indoor',
#   'id': 326,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in house',
#   'id': 327,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in bedroom',
#   'id': 328,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue',
#   'id': 329,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'dark blue',
#   'id': 330,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue-black',
#   'id': 331,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'standing',
#   'id': 332,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3134'},
#  {'answer': 'took stuffs',
#   'id': 333,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'closed wardrobe',
#   'id': 334,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'turned off light',
#   'id': 335,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'cabinet',
#   'id': 336,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'hearth',
#   'id': 337,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'waste container',
#   'id': 338,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'red',
#   'id': 339,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'true red',
#   'id': 340,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'jacinth',
#   'id': 341,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'playing phone',
#   'id': 342,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'watching phone',
#   'id': 343,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'opening refrigerator',
#   'id': 344,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'indoor',
#   'id': 345,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'kitchen',
#   'id': 346,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'residence',
#   'id': 347,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'standing',
#   'id': 348,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'wardrobe',
#   'id': 349,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'clothing',
#   'id': 350,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'hangers',
#   'id': 351,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'brown',
#   'id': 352,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'gray-black',
#   'id': 353,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'dark gray',
#   'id': 354,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'displaying boxes',
#   'id': 355,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'cleaning out closet',
#   'id': 356,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'placing boxes',
#   'id': 357,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'indoor',
#   'id': 358,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in house',
#   'id': 359,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in bedroom',
#   'id': 360,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'standing',
#   'id': 361,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3144'},
#  {'answer': 'black',
#   'id': 362,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'dark black',
#   'id': 363,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'ash black',
#   'id': 364,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'standing',
#   'id': 365,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'writing',
#   'id': 366,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'yellow',
#   'id': 367,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'golden',
#   'id': 368,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'orange',
#   'id': 369,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'clothes',
#   'id': 370,
#   'question': 'what is hanging on the wall of video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'close stool',
#   'id': 371,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tissue',
#   'id': 372,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'shower gel',
#   'id': 373,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'red',
#   'id': 374,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tangerine',
#   'id': 375,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'scarlet',
#   'id': 376,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'reading books',
#   'id': 377,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'putting down book',
#   'id': 378,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'making machine',
#   'id': 379,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'toilet',
#   'id': 380,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'sitting',
#   'id': 381,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1874'},
#  {'answer': 'pen',
#   'id': 382,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'round',
#   'id': 383,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'monkey',
#   'id': 384,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'brown',
#   'id': 385,
#   'question': 'what color is the round in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'moving',
#   'id': 386,
#   'question': 'what is the round doing in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'snowfield',
#   'id': 387,
#   'question': 'where is the monkey in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'six',
#   'id': 388,
#   'question': 'how many letters are there in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'chair',
#   'id': 389,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cabinet',
#   'id': 390,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cup',
#   'id': 391,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'yellow',
#   'id': 392,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'light yellow',
#   'id': 393,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'orange',
#   'id': 394,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'shaking towel',
#   'id': 395,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3896'},
# ...
#   'video_name': 'ZJL2590'},
#  {'answer': 'workbench',
#   'id': 867,
#   'question': 'what is the second picture of video computer on',
#   'video_name': 'ZJL2590'},
#  {'answer': 'female',
#   'id': 868,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'butterfly',
#   'id': 869,
#   'question': 'what is the design of the sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'purple',
#   'id': 870,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'yellow',
#   'id': 871,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'green',
#   'id': 872,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'speaking',
#   'id': 873,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'indoor',
#   'id': 874,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'residence',
#   'id': 875,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'room',
#   'id': 876,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'computer',
#   'id': 877,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'mouse',
#   'id': 878,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'keyboard',
#   'id': 879,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'red',
#   'id': 880,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'orange-red',
#   'id': 881,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'dark-red',
#   'id': 882,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'turning on light',
#   'id': 883,
#   'question': 'what is the person in white doing in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'indoor',
#   'id': 884,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'in house',
#   'id': 885,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'on sofa',
#   'id': 886,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'standing',
#   'id': 887,
#   'question': 'is the person in white standing or sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'door',
#   'id': 888,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'poster',
#   'id': 889,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'light',
#   'id': 890,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'white',
#   'id': 891,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'off-white',
#   'id': 892,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'milk white',
#   'id': 893,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'page turning',
#   'id': 894,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'closing book',
#   'id': 895,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'hugging girl',
#   'id': 896,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'indoor',
#   'id': 897,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in corridor',
#   'id': 898,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in house',
#   'id': 899,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'standing',
#   'id': 900,
#   'question': 'is the man in video sitting or standing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'portrait',
#   'id': 901,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'two',
#   'id': 902,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'white',
#   'id': 903,
#   'question': 'what color is the font in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'right hand',
#   'id': 904,
#   'question': "which hand does the man hold the woman's head in the video",
#   'video_name': 'ZJL2266'},
#  {'answer': 'closing his eyes',
#   'id': 905,
#   'question': 'is the man blinking or closing his eyes in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'laptop',
#   'id': 906,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'table',
#   'id': 907,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tablecloth',
#   'id': 908,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink',
#   'id': 909,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink red',
#   'id': 910,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pale pink',
#   'id': 911,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'playing computer',
#   'id': 912,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'scratching his head',
#   'id': 913,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'turning off computer',
#   'id': 914,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'indoor',
#   'id': 915,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'in house',
#   'id': 916,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'living room',
#   'id': 917,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'sitting',
#   'id': 918,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tv',
#   'id': 919,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'closet',
#   'id': 920,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'lamp',
#   'id': 921,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'white',
#   'id': 922,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'milk white',
#   'id': 923,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'taking rest',
#   'id': 924,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'throwing trash',
#   'id': 925,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'crumbling paper',
#   'id': 926,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'indoor',
#   'id': 927,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in bedroom',
#   'id': 928,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in house',
#   'id': 929,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'sitting',
#   'id': 930,
#   'question': 'is the man sitting or standing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'laundry detergent',
#   'id': 931,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'bottle',
#   'id': 932,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'water bucket',
#   'id': 933,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'black',
#   'id': 934,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'turning on lights',
#   'id': 935,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'opening washing machine',
#   'id': 936,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'taking laundry detergent',
#   'id': 937,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'indoor',
#   'id': 938,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'residence',
#   'id': 939,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'room',
#   'id': 940,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'standing',
#   'id': 941,
#   'question': 'is the person in the video standing or lying',
#   'video_name': 'ZJL2180'},
#  {'answer': 'three',
#   'id': 942,
#   'question': 'how many people are in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'white',
#   'id': 943,
#   'question': 'what is the color of the clothes of the man in video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'drinking coffee',
#   'id': 944,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'on sofa',
#   'id': 945,
#   'question': 'where is the woman who is making a call in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'glasses',
#   'id': 946,
#   'question': "what is on the man's face in the video",
#   'video_name': 'ZJL2412'},
#  {'answer': 'pillow',
#   'id': 947,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'phone',
#   'id': 948,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'computer',
#   'id': 949,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'black',
#   'id': 950,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'white',
#   'id': 951,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'grey',
#   'id': 952,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'playing phone',
#   'id': 953,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'throwing pillow',
#   'id': 954,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'walking',
#   'id': 955,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'standing',
#   'id': 956,
#   'question': 'is the man standing or sitting',
#   'video_name': 'ZJL2908'},
#  {'answer': 'in door',
#   'id': 957,
#   'question': 'where is the man',
#   'video_name': 'ZJL2908'},
#  {'answer': 'book',
#   'id': 958,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'red',
#   'id': 959,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'scarlet',
#   'id': 960,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'bright red',
#   'id': 961,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'chatting',
#   'id': 962,
#   'question': 'what are the men in the video doing',
#   'video_name': 'ZJL528'},
#  {'answer': 'pillow',
#   'id': 963,
#   'question': 'what does the man in the video hold',
#   'video_name': 'ZJL528'},
#  {'answer': 'sitting',
#   'id': 964,
#   'question': 'are the men in the video standing or sitting',
#   'video_name': 'ZJL528'},
#  {'answer': 'dog',
#   'id': 965,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'chair',
#   'id': 966,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'people',
#   'id': 967,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'yellow',
#   'id': 968,
#   'question': 'what color is the slide in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'shower room',
#   'id': 969,
#   'question': 'where did the video last appear',
#   'video_name': 'ZJL1117'},
#  {'answer': 'boy',
#   'id': 970,
#   'question': 'is the person in the video a boy or a girl',
#   'video_name': 'ZJL1117'},
#  {'answer': 'holding dog',
#   'id': 971,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'short hair',
#   'id': 972,
#   'question': 'does the person have long hair or short hair',
#   'video_name': 'ZJL1617'},
#  {'answer': 'glasses',
#   'id': 973,
#   'question': 'what does the person in red wear on his eyes',
#   'video_name': 'ZJL1617'},
#  {'answer': 'blue',
#   'id': 974,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'sapphire blue',
#   'id': 975,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'shorts',
#   'id': 976,
#   'question': 'does the person wear pants or shorts',
#   'video_name': 'ZJL1617'},
#  {'answer': 'standing',
#   'id': 977,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1617'},
#  {'answer': 'snacks',
#   'id': 978,
#   'question': "what is in the girl's hand",
#   'video_name': 'ZJL1603'},
#  {'answer': 'white',
#   'id': 979,
#   'question': "what color are the girl's clothes in the video",
#   'video_name': 'ZJL1603'},
#  {'answer': 'shopping',
#   'id': 980,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1603'},
#  {'answer': 'in supermarket',
#   'id': 981,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1603'},
#  {'answer': 'standing',
#   'id': 982,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1603'},
#  {'answer': 'hat',
#   'id': 983,
#   'question': 'what is the man wearing on the head in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'black',
#   'id': 984,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'indoor',
#   'id': 985,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'by table',
#   'id': 986,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'living room',
#   'id': 987,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'standing',
#   'id': 988,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'wearing clothes',
#   'id': 989,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'picking clothes',
#   'id': 990,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'blue',
#   'id': 991,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'navy blue',
#   'id': 992,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'blue cyan',
#   'id': 993,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'going to table',
#   'id': 994,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'picking up book',
#   'id': 995,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'shaking head',
#   'id': 996,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'standing',
#   'id': 997,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2789'},
#  {'answer': 'living room',
#   'id': 998,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2789'},
#  {'answer': 'hat',
#   'id': 999,
#   'question': 'what is wearing on the head of the person in the video',
#   'video_name': 'ZJL2789'},
#  ...]

# %%
len(data_list_new)
# Out:
# 31061

# %%
data_list_new
# Out:
# [{'answer': 'mirror',
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'pool',
#   'id': 1,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'shelf',
#   'id': 2,
#   'question': 'what is in front of the chair',
#   'video_name': 'ZJL3540'},
#  {'answer': 'blue',
#   'id': 3,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'dark blue',
#   'id': 4,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'black blue',
#   'id': 5,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3540'},
#  {'answer': 'cleaning up',
#   'id': 6,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'wiping mirror',
#   'id': 7,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washing cup',
#   'id': 8,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'indoor',
#   'id': 9,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'washroom',
#   'id': 10,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'residence',
#   'id': 11,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'standing',
#   'id': 12,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3540'},
#  {'answer': 'white',
#   'id': 13,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'kissing',
#   'id': 14,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'lying',
#   'id': 15,
#   'question': 'is the person sitting or lying in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'on bed',
#   'id': 16,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'long hair',
#   'id': 17,
#   'question': 'does the woman have long hair or short hair in the video',
#   'video_name': 'ZJL2495'},
#  {'answer': 'white',
#   'id': 18,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'light white',
#   'id': 19,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'pure white',
#   'id': 20,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'standing',
#   'id': 21,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'sitting',
#   'id': 22,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'kitchen',
#   'id': 23,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking water',
#   'id': 24,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'drinking milk',
#   'id': 25,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL963'},
#  {'answer': 'on table',
#   'id': 26,
#   'question': 'where is the book',
#   'video_name': 'ZJL963'},
#  {'answer': 'third',
#   'id': 27,
#   'question': 'which layer of the cabinet is the water cup put in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pure black',
#   'id': 28,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'black',
#   'id': 29,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'dark black',
#   'id': 30,
#   'question': 'what color of the jacket does the person wear in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'opening cabinet',
#   'id': 31,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'drinking water',
#   'id': 32,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1836'},
#  {'answer': 'cabinet',
#   'id': 33,
#   'question': 'where did the person get the cup',
#   'video_name': 'ZJL1836'},
#  {'answer': 'standing',
#   'id': 34,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL1836'},
#  {'answer': 'pink',
#   'id': 35,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'light-pink',
#   'id': 36,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'peach-pink',
#   'id': 37,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'broadcasting',
#   'id': 38,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'entertainment',
#   'id': 39,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'new',
#   'id': 40,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'swimsuit',
#   'id': 41,
#   'question': 'what does the super star wear in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'in water',
#   'id': 42,
#   'question': 'where is the superstar in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'standing',
#   'id': 43,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL2487'},
#  {'answer': 'tv',
#   'id': 44,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'sofa',
#   'id': 45,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'table',
#   'id': 46,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3886'},
#  {'answer': 'white',
#   'id': 47,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'milk white',
#   'id': 48,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'off-white',
#   'id': 49,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3886'},
#  {'answer': 'pushing tv button',
#   'id': 50,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in living room',
#   'id': 51,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'indoor',
#   'id': 52,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'in room',
#   'id': 53,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3886'},
#  {'answer': 'standing',
#   'id': 54,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3886'},
#  {'answer': 'book',
#   'id': 55,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'phone',
#   'id': 56,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'computer',
#   'id': 57,
#   'question': 'what is on the desk',
#   'video_name': 'ZJL2952'},
#  {'answer': 'black',
#   'id': 58,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'white',
#   'id': 59,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'blue',
#   'id': 60,
#   'question': 'what is the color of the trousers the man wears',
#   'video_name': 'ZJL2952'},
#  {'answer': 'taking clothes',
#   'id': 61,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'clearing up',
#   'id': 62,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'playing phone',
#   'id': 63,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2952'},
#  {'answer': 'standing',
#   'id': 64,
#   'question': 'was the man standing or sitting in the end',
#   'video_name': 'ZJL2952'},
#  {'answer': 'in door',
#   'id': 65,
#   'question': 'where is the man',
#   'video_name': 'ZJL2952'},
#  {'answer': 'brown',
#   'id': 66,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'light brown',
#   'id': 67,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'rustic brown',
#   'id': 68,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'standing',
#   'id': 69,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'bathroom',
#   'id': 70,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'looking at mirror',
#   'id': 71,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'taking off clothes',
#   'id': 72,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'wiping arms',
#   'id': 73,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL927'},
#  {'answer': 'on shelf',
#   'id': 74,
#   'question': 'where is the towel',
#   'video_name': 'ZJL927'},
#  {'answer': 'schoolbag',
#   'id': 75,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'mobile phone',
#   'id': 76,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'pillow',
#   'id': 77,
#   'question': 'what is on the bed',
#   'video_name': 'ZJL3687'},
#  {'answer': 'green',
#   'id': 78,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'light green',
#   'id': 79,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'dark green',
#   'id': 80,
#   'question': 'what color does the person wear in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'holding pillow',
#   'id': 81,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'room',
#   'id': 82,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3687'},
#  {'answer': 'sitting',
#   'id': 83,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3687'},
#  {'answer': 'daytime',
#   'id': 84,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'morning',
#   'id': 85,
#   'question': 'when was video filmed',
#   'video_name': 'ZJL3405'},
#  {'answer': 'white',
#   'id': 86,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'milk white',
#   'id': 87,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'creamy white',
#   'id': 88,
#   'question': 'what is the color of the car for the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking selfie',
#   'id': 89,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'photographing',
#   'id': 90,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'taking photos',
#   'id': 91,
#   'question': 'what is the person in red doing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'outdoor',
#   'id': 92,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'suburb',
#   'id': 93,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'in car',
#   'id': 94,
#   'question': 'where is the person in red',
#   'video_name': 'ZJL3405'},
#  {'answer': 'sitting',
#   'id': 95,
#   'question': 'is the person in red sitting or standing in the video',
#   'video_name': 'ZJL3405'},
#  {'answer': 'woman',
#   'id': 96,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'man',
#   'id': 97,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sofa',
#   'id': 98,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'beige',
#   'id': 99,
#   'question': 'what color is the sofa in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'talking',
#   'id': 100,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'in room',
#   'id': 101,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL1492'},
#  {'answer': 'standing',
#   'id': 102,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'sitting',
#   'id': 103,
#   'question': 'is the woman in the video sitting or standing',
#   'video_name': 'ZJL1492'},
#  {'answer': 'black',
#   'id': 104,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'white',
#   'id': 105,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'dark blue',
#   'id': 106,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'sitting',
#   'id': 107,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'reading book',
#   'id': 108,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'kitchen',
#   'id': 109,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'on table',
#   'id': 110,
#   'question': 'where is the water bottle in the video',
#   'video_name': 'ZJL984'},
#  {'answer': 'photograph',
#   'id': 111,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'cup',
#   'id': 112,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'basket',
#   'id': 113,
#   'question': 'what is on the staircase',
#   'video_name': 'ZJL3443'},
#  {'answer': 'black',
#   'id': 114,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'drinking water',
#   'id': 115,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'in stairwell',
#   'id': 116,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3443'},
#  {'answer': 'standing',
#   'id': 117,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3443'},
#  {'answer': 'closet',
#   'id': 118,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'chair',
#   'id': 119,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'tv',
#   'id': 120,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL2146'},
#  {'answer': 'black',
#   'id': 121,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'dark black',
#   'id': 122,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'aterrimus',
#   'id': 123,
#   'question': 'what color pants does the person wear in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'opening door',
#   'id': 124,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'putting towel',
#   'id': 125,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'sneezing',
#   'id': 126,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'indoor',
#   'id': 127,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'living room',
#   'id': 128,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'residence',
#   'id': 129,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2146'},
#  {'answer': 'standing',
#   'id': 130,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2146'},
#  {'answer': 'computer',
#   'id': 131,
#   'question': 'what is on the cabinet in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'white',
#   'id': 132,
#   'question': 'what color of clothes does the woman in the video wear',
#   'video_name': 'ZJL578'},
#  {'answer': 'eating things',
#   'id': 133,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'playing computer',
#   'id': 134,
#   'question': 'what is the woman in the video doing',
#   'video_name': 'ZJL578'},
#  {'answer': 'kitchen',
#   'id': 135,
#   'question': 'in which room is the woman in the video',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 136,
#   'question': 'is the woman in the video standing or sitting',
#   'video_name': 'ZJL578'},
#  {'answer': 'standing',
#   'id': 137,
#   'question': 'is the person wearing pink in the video standing or sitting',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating something',
#   'id': 138,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'eating food',
#   'id': 139,
#   'question': 'what is the person wearing pink in the video doing',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bedroom',
#   'id': 140,
#   'question': 'where is the person wearing pink in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'bed',
#   'id': 141,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'cabinet',
#   'id': 142,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'mirror',
#   'id': 143,
#   'question': 'what is in the room',
#   'video_name': 'ZJL2741'},
#  {'answer': 'white',
#   'id': 144,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'light white',
#   'id': 145,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'gray white',
#   'id': 146,
#   'question': 'what color is the wall in the video',
#   'video_name': 'ZJL2741'},
#  {'answer': 'green',
#   'id': 147,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pale green',
#   'id': 148,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'grass green',
#   'id': 149,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'standing',
#   'id': 150,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'taking off shoes',
#   'id': 151,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'closing door',
#   'id': 152,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'turn on lights',
#   'id': 153,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'long hair',
#   'id': 154,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'pink',
#   'id': 155,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'soft red',
#   'id': 156,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'rose',
#   'id': 157,
#   'question': 'what is the color of the shoes in the video',
#   'video_name': 'ZJL921'},
#  {'answer': 'cup',
#   'id': 158,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'phone',
#   'id': 159,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'clothes',
#   'id': 160,
#   'question': "what is in the man in purple's hand",
#   'video_name': 'ZJL2934'},
#  {'answer': 'brown',
#   'id': 161,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'yellow',
#   'id': 162,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'golden',
#   'id': 163,
#   'question': 'what is the color of the trousers of the sitting man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'standing',
#   'id': 164,
#   'question': 'is the man in purple standing or sitting',
#   'video_name': 'ZJL2934'},
#  {'answer': 'in door',
#   'id': 165,
#   'question': 'where is the man',
#   'video_name': 'ZJL2934'},
#  {'answer': 'shoes',
#   'id': 166,
#   'question': 'what is on the outside floor',
#   'video_name': 'ZJL2934'},
#  {'answer': 'green',
#   'id': 167,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'grass green',
#   'id': 168,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'pale green',
#   'id': 169,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'standing',
#   'id': 170,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'kitchen',
#   'id': 171,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'making food',
#   'id': 172,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'sweeping floor',
#   'id': 173,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'eating',
#   'id': 174,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'short hair',
#   'id': 175,
#   'question': 'does the person have long hair or short hair in the video',
#   'video_name': 'ZJL995'},
#  {'answer': 'cabinet',
#   'id': 176,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'mirror',
#   'id': 177,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'clothes',
#   'id': 178,
#   'question': 'what is in the room',
#   'video_name': 'ZJL3944'},
#  {'answer': 'pink',
#   'id': 179,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'magenta',
#   'id': 180,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'burgandy',
#   'id': 181,
#   'question': 'what color is the cabinet',
#   'video_name': 'ZJL3944'},
#  {'answer': 'looking at mirror',
#   'id': 182,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'putting on clothes',
#   'id': 183,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'buttoning',
#   'id': 184,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'indoor',
#   'id': 185,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in room',
#   'id': 186,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'in house',
#   'id': 187,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3944'},
#  {'answer': 'standing',
#   'id': 188,
#   'question': 'is the person in video sitting or standing',
#   'video_name': 'ZJL3944'},
#  {'answer': 'door',
#   'id': 189,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'television',
#   'id': 190,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'curtain',
#   'id': 191,
#   'question': 'what is on the right of the bed',
#   'video_name': 'ZJL4047'},
#  {'answer': 'yellow',
#   'id': 192,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'khaki',
#   'id': 193,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'brownish yellow',
#   'id': 194,
#   'question': 'what is the color of the door in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'watching tv',
#   'id': 195,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'resting',
#   'id': 196,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'sleeping',
#   'id': 197,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL4047'},
#  {'answer': 'indoors',
#   'id': 198,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in house',
#   'id': 199,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'in bedroom',
#   'id': 200,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL4047'},
#  {'answer': 'lying on his stomach',
#   'id': 201,
#   'question': 'is the person in the video lying on his stomach or sitting',
#   'video_name': 'ZJL4047'},
#  {'answer': 'chair',
#   'id': 202,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'fence',
#   'id': 203,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'book',
#   'id': 204,
#   'question': 'what is in front of the wall',
#   'video_name': 'ZJL3428'},
#  {'answer': 'white',
#   'id': 205,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'milk white',
#   'id': 206,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'creamy white',
#   'id': 207,
#   'question': "what is the color of the person's clothes in the video",
#   'video_name': 'ZJL3428'},
#  {'answer': 'dancing',
#   'id': 208,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'exercising',
#   'id': 209,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'playing',
#   'id': 210,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'outdoor',
#   'id': 211,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'yard',
#   'id': 212,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'at door',
#   'id': 213,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'standing',
#   'id': 214,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3428'},
#  {'answer': 'mustache',
#   'id': 215,
#   'question': "what is on the person's face in the video",
#   'video_name': 'ZJL651'},
#  {'answer': 'gray',
#   'id': 216,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'black gray',
#   'id': 217,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'neutral gary',
#   'id': 218,
#   'question': 'what color of the clothes does the person wear in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'eating',
#   'id': 219,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'staircase',
#   'id': 220,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'sitting',
#   'id': 221,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL651'},
#  {'answer': 'closet',
#   'id': 222,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'refrigerator',
#   'id': 223,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'pot',
#   'id': 224,
#   'question': 'what is in the kitchen',
#   'video_name': 'ZJL2147'},
#  {'answer': 'black',
#   'id': 225,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'dark black',
#   'id': 226,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'aterrimus',
#   'id': 227,
#   'question': 'what color top does the person wear in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'firing',
#   'id': 228,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'taking things',
#   'id': 229,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'opening refrigerator',
#   'id': 230,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'indoor',
#   'id': 231,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'kitchen',
#   'id': 232,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'residence',
#   'id': 233,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2147'},
#  {'answer': 'standing',
#   'id': 234,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2147'},
#  {'answer': 'icon',
#   'id': 235,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'website',
#   'id': 236,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'people',
#   'id': 237,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'female',
#   'id': 238,
#   'question': 'is the person in the video a male or a female',
#   'video_name': 'ZJL1115'},
#  {'answer': 'black',
#   'id': 239,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'in water',
#   'id': 240,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'tapping water',
#   'id': 241,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1115'},
#  {'answer': 'music score',
#   'id': 242,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'guitar',
#   'id': 243,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'microphone',
#   'id': 244,
#   'question': 'what is in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple',
#   'id': 245,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'deep purple',
#   'id': 246,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'purple sauce',
#   'id': 247,
#   'question': 'what color skirt is the women wearing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'singing',
#   'id': 248,
#   'question': 'what is the woman doing in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'on stage',
#   'id': 249,
#   'question': 'where is the woman in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'standing',
#   'id': 250,
#   'question': 'is the woman standing or sitting in the video',
#   'video_name': 'ZJL783'},
#  {'answer': 'boy',
#   'id': 251,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'girl',
#   'id': 252,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'women',
#   'id': 253,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'brown',
#   'id': 254,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'tan',
#   'id': 255,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'coffee',
#   'id': 256,
#   'question': 'what color clothes does the girl wear in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interviewing',
#   'id': 257,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'talking',
#   'id': 258,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'narrating',
#   'id': 259,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'indoor',
#   'id': 260,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'in room',
#   'id': 261,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'interview site',
#   'id': 262,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'sitting',
#   'id': 263,
#   'question': 'is the person standing or sitting in the video',
#   'video_name': 'ZJL1348'},
#  {'answer': 'mustache',
#   'id': 264,
#   'question': 'what is on the face of the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'white',
#   'id': 265,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'creamy-white',
#   'id': 266,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'ivory-white',
#   'id': 267,
#   'question': 'what color pants does the man wear in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'setting of pillows',
#   'id': 268,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'in living room',
#   'id': 269,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3506'},
#  {'answer': 'sitting',
#   'id': 270,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL3506'},
#  {'answer': 'board',
#   'id': 271,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'sponge',
#   'id': 272,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'brush',
#   'id': 273,
#   'question': 'what is in front of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'yellow',
#   'id': 274,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'light yellow',
#   'id': 275,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'canary yellow',
#   'id': 276,
#   'question': 'what is the color of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning toy',
#   'id': 277,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'wiping toy',
#   'id': 278,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'cleaning up dust',
#   'id': 279,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in water',
#   'id': 280,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathtub',
#   'id': 281,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'in bathroom',
#   'id': 282,
#   'question': 'where is the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'plastic',
#   'id': 283,
#   'question': 'what is the material of the toy in the video',
#   'video_name': 'ZJL3083'},
#  {'answer': 'athlete',
#   'id': 284,
#   'question': 'what is on the track',
#   'video_name': 'ZJL1602'},
#  {'answer': 'yellow',
#   'id': 285,
#   'question': "what color is the runner's hair",
#   'video_name': 'ZJL1602'},
#  {'answer': 'running',
#   'id': 286,
#   'question': 'what is the person in yellow hair doing',
#   'video_name': 'ZJL1602'},
#  {'answer': 'on sport court',
#   'id': 287,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1602'},
#  {'answer': 'standing',
#   'id': 288,
#   'question': 'is the athlete in the video standing or sitting',
#   'video_name': 'ZJL1602'},
#  {'answer': 'hanging on wall',
#   'id': 289,
#   'question': 'where is the tv in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'blue',
#   'id': 290,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'light blue',
#   'id': 291,
#   'question': 'what color does the man standing in the video wear',
#   'video_name': 'ZJL430'},
#  {'answer': 'walking',
#   'id': 292,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL430'},
#  {'answer': 'benches',
#   'id': 293,
#   'question': 'where is the boy sitting in the video',
#   'video_name': 'ZJL430'},
#  {'answer': 'standing',
#   'id': 294,
#   'question': 'is the man in the video standing or sitting',
#   'video_name': 'ZJL430'},
#  {'answer': 'plates',
#   'id': 295,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'watches',
#   'id': 296,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'flour',
#   'id': 297,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'green',
#   'id': 298,
#   'question': 'what color is the clothes worn by the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'taking things',
#   'id': 299,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'pouring things',
#   'id': 300,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2863'},
#  {'answer': 'kitchen',
#   'id': 301,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2863'},
#  {'answer': 'standing',
#   'id': 302,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2863'},
#  {'answer': 'long hair',
#   'id': 303,
#   'question': 'does the person has long hair or short hair in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'white',
#   'id': 304,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'washing hands',
#   'id': 305,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3470'},
#  {'answer': 'on cabinet',
#   'id': 306,
#   'question': 'where is the towel',
#   'video_name': 'ZJL3470'},
#  {'answer': 'standing',
#   'id': 307,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL3470'},
#  {'answer': 'cummerbund',
#   'id': 308,
#   'question': 'what does the person in video hold',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple',
#   'id': 309,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'rose red',
#   'id': 310,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'purple red',
#   'id': 311,
#   'question': 'what color is the cummerbund in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'circle',
#   'id': 312,
#   'question': 'what is the shape of the decorative ribbon in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'left hand',
#   'id': 313,
#   'question': 'which hand of the people in video picked up the ribbon',
#   'video_name': 'ZJL2593'},
#  {'answer': 'standing',
#   'id': 314,
#   'question': 'is the person standing or sitting in video',
#   'video_name': 'ZJL2593'},
#  {'answer': 'wheelchair',
#   'id': 315,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'desk',
#   'id': 316,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'chair',
#   'id': 317,
#   'question': 'what is in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'red',
#   'id': 318,
#   'question': 'what color clothes does the person sitting on a wheelchair wear',
#   'video_name': 'ZJL842'},
#  {'answer': 'hospital',
#   'id': 319,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL842'},
#  {'answer': 'talking',
#   'id': 320,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'fetching things',
#   'id': 321,
#   'question': 'what is the person wearing white clothes in the video doing',
#   'video_name': 'ZJL842'},
#  {'answer': 'standing',
#   'id': 322,
#   'question': 'is the person wearing white clothes in the video sitting or standing',
#   'video_name': 'ZJL842'},
#  {'answer': 'clothes',
#   'id': 323,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'boxes',
#   'id': 324,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'hangers',
#   'id': 325,
#   'question': 'what is in the cabinet in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'indoor',
#   'id': 326,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in house',
#   'id': 327,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'in bedroom',
#   'id': 328,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue',
#   'id': 329,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'dark blue',
#   'id': 330,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'blue-black',
#   'id': 331,
#   'question': 'what is the color of the pants of the person in the video',
#   'video_name': 'ZJL3134'},
#  {'answer': 'standing',
#   'id': 332,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3134'},
#  {'answer': 'took stuffs',
#   'id': 333,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'closed wardrobe',
#   'id': 334,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'turned off light',
#   'id': 335,
#   'question': 'what did the person in the video do before going out',
#   'video_name': 'ZJL3134'},
#  {'answer': 'cabinet',
#   'id': 336,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'hearth',
#   'id': 337,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'waste container',
#   'id': 338,
#   'question': 'what is in front of the fridge',
#   'video_name': 'ZJL3546'},
#  {'answer': 'red',
#   'id': 339,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'true red',
#   'id': 340,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'jacinth',
#   'id': 341,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3546'},
#  {'answer': 'playing phone',
#   'id': 342,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'watching phone',
#   'id': 343,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'opening refrigerator',
#   'id': 344,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'indoor',
#   'id': 345,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'kitchen',
#   'id': 346,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'residence',
#   'id': 347,
#   'question': 'where is the person in video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'standing',
#   'id': 348,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3546'},
#  {'answer': 'wardrobe',
#   'id': 349,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'clothing',
#   'id': 350,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'hangers',
#   'id': 351,
#   'question': 'what is in front of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'brown',
#   'id': 352,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'gray-black',
#   'id': 353,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'dark gray',
#   'id': 354,
#   'question': 'what is the color of the clothes of the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'displaying boxes',
#   'id': 355,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'cleaning out closet',
#   'id': 356,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'placing boxes',
#   'id': 357,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'indoor',
#   'id': 358,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in house',
#   'id': 359,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'in bedroom',
#   'id': 360,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3144'},
#  {'answer': 'standing',
#   'id': 361,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL3144'},
#  {'answer': 'black',
#   'id': 362,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'dark black',
#   'id': 363,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'ash black',
#   'id': 364,
#   'question': "what is the color of the person's clothes in video",
#   'video_name': 'ZJL3633'},
#  {'answer': 'standing',
#   'id': 365,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'writing',
#   'id': 366,
#   'question': 'what is the person doing in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'yellow',
#   'id': 367,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'golden',
#   'id': 368,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'orange',
#   'id': 369,
#   'question': 'what color is the pen in video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'clothes',
#   'id': 370,
#   'question': 'what is hanging on the wall of video',
#   'video_name': 'ZJL3633'},
#  {'answer': 'close stool',
#   'id': 371,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tissue',
#   'id': 372,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'shower gel',
#   'id': 373,
#   'question': 'what is on the right of the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'red',
#   'id': 374,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'tangerine',
#   'id': 375,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'scarlet',
#   'id': 376,
#   'question': 'what color of upper outer garment does the person in the video wear',
#   'video_name': 'ZJL1874'},
#  {'answer': 'reading books',
#   'id': 377,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'putting down book',
#   'id': 378,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'making machine',
#   'id': 379,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1874'},
#  {'answer': 'toilet',
#   'id': 380,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1874'},
#  {'answer': 'sitting',
#   'id': 381,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1874'},
#  {'answer': 'pen',
#   'id': 382,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'round',
#   'id': 383,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'monkey',
#   'id': 384,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'brown',
#   'id': 385,
#   'question': 'what color is the round in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'moving',
#   'id': 386,
#   'question': 'what is the round doing in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'snowfield',
#   'id': 387,
#   'question': 'where is the monkey in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'six',
#   'id': 388,
#   'question': 'how many letters are there in the video',
#   'video_name': 'ZJL1503'},
#  {'answer': 'chair',
#   'id': 389,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cabinet',
#   'id': 390,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'cup',
#   'id': 391,
#   'question': 'what is in the living room',
#   'video_name': 'ZJL3896'},
#  {'answer': 'yellow',
#   'id': 392,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'light yellow',
#   'id': 393,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'orange',
#   'id': 394,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3896'},
#  {'answer': 'shaking towel',
#   'id': 395,
#   'question': 'what is the person in video doing',
#   'video_name': 'ZJL3896'},
# ...
#   'video_name': 'ZJL2590'},
#  {'answer': 'workbench',
#   'id': 867,
#   'question': 'what is the second picture of video computer on',
#   'video_name': 'ZJL2590'},
#  {'answer': 'female',
#   'id': 868,
#   'question': 'what is the gender of the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'butterfly',
#   'id': 869,
#   'question': 'what is the design of the sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'purple',
#   'id': 870,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'yellow',
#   'id': 871,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'green',
#   'id': 872,
#   'question': 'what color is the butterfly sticker in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'speaking',
#   'id': 873,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'indoor',
#   'id': 874,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'residence',
#   'id': 875,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'room',
#   'id': 876,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1136'},
#  {'answer': 'computer',
#   'id': 877,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'mouse',
#   'id': 878,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'keyboard',
#   'id': 879,
#   'question': 'what is on the table',
#   'video_name': 'ZJL7'},
#  {'answer': 'red',
#   'id': 880,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'orange-red',
#   'id': 881,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'dark-red',
#   'id': 882,
#   'question': 'what is the color of the clothes does the sitting person wear in video',
#   'video_name': 'ZJL7'},
#  {'answer': 'turning on light',
#   'id': 883,
#   'question': 'what is the person in white doing in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'indoor',
#   'id': 884,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'in house',
#   'id': 885,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'on sofa',
#   'id': 886,
#   'question': 'where is the person sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'standing',
#   'id': 887,
#   'question': 'is the person in white standing or sitting in the video',
#   'video_name': 'ZJL7'},
#  {'answer': 'door',
#   'id': 888,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'poster',
#   'id': 889,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'light',
#   'id': 890,
#   'question': 'what is in the corridor',
#   'video_name': 'ZJL3962'},
#  {'answer': 'white',
#   'id': 891,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'off-white',
#   'id': 892,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'milk white',
#   'id': 893,
#   'question': 'what color is the wall',
#   'video_name': 'ZJL3962'},
#  {'answer': 'page turning',
#   'id': 894,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'closing book',
#   'id': 895,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'hugging girl',
#   'id': 896,
#   'question': 'what is the man in video doing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'indoor',
#   'id': 897,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in corridor',
#   'id': 898,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'in house',
#   'id': 899,
#   'question': 'where is the man in video',
#   'video_name': 'ZJL3962'},
#  {'answer': 'standing',
#   'id': 900,
#   'question': 'is the man in video sitting or standing',
#   'video_name': 'ZJL3962'},
#  {'answer': 'portrait',
#   'id': 901,
#   'question': 'what is in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'two',
#   'id': 902,
#   'question': 'how many people are there in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'white',
#   'id': 903,
#   'question': 'what color is the font in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'right hand',
#   'id': 904,
#   'question': "which hand does the man hold the woman's head in the video",
#   'video_name': 'ZJL2266'},
#  {'answer': 'closing his eyes',
#   'id': 905,
#   'question': 'is the man blinking or closing his eyes in the video',
#   'video_name': 'ZJL2266'},
#  {'answer': 'laptop',
#   'id': 906,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'table',
#   'id': 907,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tablecloth',
#   'id': 908,
#   'question': 'what can you see in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink',
#   'id': 909,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pink red',
#   'id': 910,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'pale pink',
#   'id': 911,
#   'question': 'what color is the tablecloth in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'playing computer',
#   'id': 912,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'scratching his head',
#   'id': 913,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'turning off computer',
#   'id': 914,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL3320'},
#  {'answer': 'indoor',
#   'id': 915,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'in house',
#   'id': 916,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'living room',
#   'id': 917,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'sitting',
#   'id': 918,
#   'question': 'is the person sitting or standing in the video',
#   'video_name': 'ZJL3320'},
#  {'answer': 'tv',
#   'id': 919,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'closet',
#   'id': 920,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'lamp',
#   'id': 921,
#   'question': 'what is at the right side the bed',
#   'video_name': 'ZJL3094'},
#  {'answer': 'white',
#   'id': 922,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'milk white',
#   'id': 923,
#   'question': 'what is the color of the clothes the man wears in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'taking rest',
#   'id': 924,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'throwing trash',
#   'id': 925,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'crumbling paper',
#   'id': 926,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'indoor',
#   'id': 927,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in bedroom',
#   'id': 928,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'in house',
#   'id': 929,
#   'question': 'where is the man in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'sitting',
#   'id': 930,
#   'question': 'is the man sitting or standing in the video',
#   'video_name': 'ZJL3094'},
#  {'answer': 'laundry detergent',
#   'id': 931,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'bottle',
#   'id': 932,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'water bucket',
#   'id': 933,
#   'question': 'what is on the storage rack',
#   'video_name': 'ZJL2180'},
#  {'answer': 'black',
#   'id': 934,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'turning on lights',
#   'id': 935,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'opening washing machine',
#   'id': 936,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'taking laundry detergent',
#   'id': 937,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2180'},
#  {'answer': 'indoor',
#   'id': 938,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'residence',
#   'id': 939,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'room',
#   'id': 940,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2180'},
#  {'answer': 'standing',
#   'id': 941,
#   'question': 'is the person in the video standing or lying',
#   'video_name': 'ZJL2180'},
#  {'answer': 'three',
#   'id': 942,
#   'question': 'how many people are in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'white',
#   'id': 943,
#   'question': 'what is the color of the clothes of the man in video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'drinking coffee',
#   'id': 944,
#   'question': 'what is the man doing in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'on sofa',
#   'id': 945,
#   'question': 'where is the woman who is making a call in the video',
#   'video_name': 'ZJL2412'},
#  {'answer': 'glasses',
#   'id': 946,
#   'question': "what is on the man's face in the video",
#   'video_name': 'ZJL2412'},
#  {'answer': 'pillow',
#   'id': 947,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'phone',
#   'id': 948,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'computer',
#   'id': 949,
#   'question': "what is in the man's hand",
#   'video_name': 'ZJL2908'},
#  {'answer': 'black',
#   'id': 950,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'white',
#   'id': 951,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'grey',
#   'id': 952,
#   'question': 'what is the color of the clothes the man wears',
#   'video_name': 'ZJL2908'},
#  {'answer': 'playing phone',
#   'id': 953,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'throwing pillow',
#   'id': 954,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'walking',
#   'id': 955,
#   'question': 'what is the man doing',
#   'video_name': 'ZJL2908'},
#  {'answer': 'standing',
#   'id': 956,
#   'question': 'is the man standing or sitting',
#   'video_name': 'ZJL2908'},
#  {'answer': 'in door',
#   'id': 957,
#   'question': 'where is the man',
#   'video_name': 'ZJL2908'},
#  {'answer': 'book',
#   'id': 958,
#   'question': 'what is on the table in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'red',
#   'id': 959,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'scarlet',
#   'id': 960,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'bright red',
#   'id': 961,
#   'question': 'what is the color of the curtain in the video',
#   'video_name': 'ZJL528'},
#  {'answer': 'chatting',
#   'id': 962,
#   'question': 'what are the men in the video doing',
#   'video_name': 'ZJL528'},
#  {'answer': 'pillow',
#   'id': 963,
#   'question': 'what does the man in the video hold',
#   'video_name': 'ZJL528'},
#  {'answer': 'sitting',
#   'id': 964,
#   'question': 'are the men in the video standing or sitting',
#   'video_name': 'ZJL528'},
#  {'answer': 'dog',
#   'id': 965,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'chair',
#   'id': 966,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'people',
#   'id': 967,
#   'question': 'what is in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'yellow',
#   'id': 968,
#   'question': 'what color is the slide in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'shower room',
#   'id': 969,
#   'question': 'where did the video last appear',
#   'video_name': 'ZJL1117'},
#  {'answer': 'boy',
#   'id': 970,
#   'question': 'is the person in the video a boy or a girl',
#   'video_name': 'ZJL1117'},
#  {'answer': 'holding dog',
#   'id': 971,
#   'question': 'what is the person doing in the video',
#   'video_name': 'ZJL1117'},
#  {'answer': 'short hair',
#   'id': 972,
#   'question': 'does the person have long hair or short hair',
#   'video_name': 'ZJL1617'},
#  {'answer': 'glasses',
#   'id': 973,
#   'question': 'what does the person in red wear on his eyes',
#   'video_name': 'ZJL1617'},
#  {'answer': 'blue',
#   'id': 974,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'sapphire blue',
#   'id': 975,
#   'question': "what color is the person's drinking bottle",
#   'video_name': 'ZJL1617'},
#  {'answer': 'shorts',
#   'id': 976,
#   'question': 'does the person wear pants or shorts',
#   'video_name': 'ZJL1617'},
#  {'answer': 'standing',
#   'id': 977,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1617'},
#  {'answer': 'snacks',
#   'id': 978,
#   'question': "what is in the girl's hand",
#   'video_name': 'ZJL1603'},
#  {'answer': 'white',
#   'id': 979,
#   'question': "what color are the girl's clothes in the video",
#   'video_name': 'ZJL1603'},
#  {'answer': 'shopping',
#   'id': 980,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL1603'},
#  {'answer': 'in supermarket',
#   'id': 981,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL1603'},
#  {'answer': 'standing',
#   'id': 982,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL1603'},
#  {'answer': 'hat',
#   'id': 983,
#   'question': 'what is the man wearing on the head in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'black',
#   'id': 984,
#   'question': 'what color clothes does the person wear in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'indoor',
#   'id': 985,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'by table',
#   'id': 986,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'living room',
#   'id': 987,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2384'},
#  {'answer': 'standing',
#   'id': 988,
#   'question': 'is the person in the video sitting or standing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'wearing clothes',
#   'id': 989,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'picking clothes',
#   'id': 990,
#   'question': 'what is the man in the video doing',
#   'video_name': 'ZJL2384'},
#  {'answer': 'blue',
#   'id': 991,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'navy blue',
#   'id': 992,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'blue cyan',
#   'id': 993,
#   'question': 'what color clothes does person in the video wear',
#   'video_name': 'ZJL2789'},
#  {'answer': 'going to table',
#   'id': 994,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'picking up book',
#   'id': 995,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'shaking head',
#   'id': 996,
#   'question': 'what is the person in the video doing',
#   'video_name': 'ZJL2789'},
#  {'answer': 'standing',
#   'id': 997,
#   'question': 'is the person in the video standing or sitting',
#   'video_name': 'ZJL2789'},
#  {'answer': 'living room',
#   'id': 998,
#   'question': 'where is the person in the video',
#   'video_name': 'ZJL2789'},
#  {'answer': 'hat',
#   'id': 999,
#   'question': 'what is wearing on the head of the person in the video',
#   'video_name': 'ZJL2789'},
#  ...]

# %%
contain_standing=[]
for data in data_list_new:
    if data["answer"]=='standing':
        if "standing" not in data["question"]:
            contain_standing.append(data["question"])

# %%
contain_standing
# Out:
# ['what is the woman in black doing',
#  'what is the person doing in the video',
#  'is the singing woman or sitting in the video',
#  'what is in front of the wall',
#  'does the person in the video sit or stand while using the vacuum cleaner']
