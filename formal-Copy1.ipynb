# %%
import sys

# %%
i=0
id=-1
data_list=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", [])
                elif i % 4 == 0:
                    data["answer"].append(word)
                    data_list.append(data)
                    data={}
                    answer=[]
                else:
                    data["answer"].append(word)
            else:
                video_id=word

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'vedio_name': 'ZJL2495'},
#  {'answer': ['kissing', 'kissing', 'kissing'],
#   'id': 6,
# ...

# %%
len(data_list)
# Out:
# 16625

# %%
i=0
id=-1
data_list=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/train_raw.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", [])
                elif i % 4 == 0:
                    if word not in data["answer"]:
                        data["answer"].append(word)
                    data_list.append(data)
                    data={}
                    answer=[]
                else:
                    if word not in data["answer"]:
                        data["answer"].append(word)
            else:
                video_id=word

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'vedio_name': 'ZJL2495'},
#  {'answer': ['kissing'],
#   'id': 6,
#   'question': 'what is the person doing in the video',
# ...

# %%
for i in data_list[1]["answer"]:
    print(i)
# Out:
# blue
# dark blue
# black blue

# %%
data_test
# Out:
# [{'answer': ['0', '0', '0'],
#   'id': 1,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 2,
#   'question': 'what color pants does the referee wear in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 3,
#   'question': 'what is the person in the middle of the video doing',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 4,
#   'question': 'where is the person in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 5,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 6,
#   'question': 'what is on the table',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0', '0', '0'],
#   'id': 7,
#   'question': 'what is the color of the wall',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0', '0', '0'],
#   'id': 8,
# ...

# %%
data_list_new=[]
data_new={}
id=-1
for data in data_list:
    for i in range(len(data["answer"])):
        id+=1
        data_new["question"]=data["question"]
        data_new["vedio_name"]=data["vedio_name"]
        data_new["id"]=id
        data_new["answer"]=data["answer"][i]
        data_list_new.append(data_new)
        data_new={}

# %%
data_list_new
# Out:
# [{'answer': 'mirror',
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'pool',
#   'id': 1,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'shelf',
#   'id': 2,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'blue',
#   'id': 3,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'dark blue',
#   'id': 4,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'black blue',
#   'id': 5,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'cleaning up',
#   'id': 6,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'wiping mirror',
#   'id': 7,
#   'question': 'what is the person doing in video',
# ...

# %%
len(data_list_new)
# Out:
# 31061

# %% [markdown]
# import json
# #new_dict = json.loads(data_list)
# with open("./data/data_train_answer_separation.json","w") as f:
#     json.dump(data_list_new,f)
#     print("加载入文件完成...")

# %%
i=0
id=-1
data_test=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/test.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", "")
                elif i % 4 == 0:
                    #data["answer"].append(word)
                    data_test.append(data)
                    data={}
#                     #answer=[]
#                 else:
#                     #data["answer"].append(word)
            else:
                video_id=word

# %%
i=0
id=-1
data_test=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/test.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", "[]")
                elif i % 4 == 0:
                    if word not in data["answer"]:
                        data["answer"].append(word)
                    data_test.append(data)
                    data={}
                    answer=[]
                else:
                    if word not in data["answer"]:
                        data["answer"].append(word)
            else:
                video_id=word
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-56eb85ca0a4e> in <module>()
#      26                 else:
#      27                     if word not in data["answer"]:
# ---> 28                         data["answer"].append(word)
#      29             else:
#      30                 video_id=word
#
# AttributeError: 'str' object has no attribute 'append'

# %%
data_test
# Out:
# [{'answer': ['0'],
#   'id': 0,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0'],
#   'id': 1,
#   'question': 'what color pants does the referee wear in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0'],
#   'id': 2,
#   'question': 'what is the person in the middle of the video doing',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0'],
#   'id': 3,
#   'question': 'where is the person in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0'],
#   'id': 4,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0'],
#   'id': 5,
#   'question': 'what is on the table',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0'],
#   'id': 6,
#   'question': 'what is the color of the wall',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0'],
#   'id': 7,
#   'question': 'what is the man in the video doing',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0'],
# ...

# %%
len(data_test)
# Out:
# 4170

# %%
data_test
# Out:
# [{'answer': ['0', '0', '0'],
#   'id': 1,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 2,
#   'question': 'what color pants does the referee wear in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 3,
#   'question': 'what is the person in the middle of the video doing',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 4,
#   'question': 'where is the person in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 5,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'vedio_name': 'ZJL1330'},
#  {'answer': ['0', '0', '0'],
#   'id': 6,
#   'question': 'what is on the table',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0', '0', '0'],
#   'id': 7,
#   'question': 'what is the color of the wall',
#   'vedio_name': 'ZJL4209'},
#  {'answer': ['0', '0', '0'],
#   'id': 8,
# ...

# %%
len(data_list_new)
# Out:
# 31061

# %%
import random

# %%
resultList=random.sample(range(0,len(data_list_new)),4100); # sample(x,y)函数的作用是从序列x中，随机选择y个不重复的元素。上面的方法写了那么多，其实Python一句话就完成了。
print(resultList)# 打印结果
# Out:
# [1503, 3290, 30661, 18772, 4886, 2832, 30983, 20238, 27198, 2652, 4777, 3690, 2689, 28203, 30409, 23613, 873, 26132, 4748, 19286, 23733, 698, 4011, 3278, 15237, 6616, 17977, 1991, 19075, 30318, 24594, 6471, 23479, 28091, 8239, 23867, 18686, 12822, 13688, 8657, 23193, 24071, 8578, 30080, 14143, 8478, 30249, 26303, 15030, 26832, 4092, 6790, 27229, 24982, 15044, 26542, 2111, 22638, 9307, 20263, 28512, 27196, 22730, 8865, 28583, 8064, 25594, 17102, 23123, 2011, 2572, 2352, 18513, 5368, 14098, 30154, 19807, 26057, 10367, 19038, 10249, 24881, 926, 20283, 1714, 8528, 7245, 245, 12372, 11451, 5149, 25276, 30210, 28958, 5188, 27555, 9069, 10480, 3260, 24897, 16616, 13501, 15637, 5002, 25033, 30361, 6494, 6723, 8559, 29932, 20530, 20038, 5258, 26732, 8830, 5113, 22325, 15628, 15709, 9298, 16402, 16663, 5818, 19138, 18037, 20863, 25958, 9163, 1700, 10344, 19828, 2286, 10207, 3114, 16580, 5139, 139, 22531, 20293, 3342, 24266, 12615, 4486, 19723, 5135, 3852, 21809, 26477, 14536, 5059, 30418, 1984
# ...

# %%
data_train_val=[]
for i in resultList:
    data_train_val.append(data_list_new[i])

# %%
data_train_val
# Out:
# [{'answer': 'resting',
#   'id': 1504,
#   'question': 'what is the person in the video doing',
#   'vedio_name': 'ZJL2055'},
#  {'answer': 'opening refrigerator door',
#   'id': 3291,
#   'question': 'what is the person in video doing',
#   'vedio_name': 'ZJL85'},
#  {'answer': 'towel',
#   'id': 30662,
#   'question': 'what is on the bed',
#   'vedio_name': 'ZJL4230'},
#  {'answer': 'baby blue',
#   'id': 18773,
#   'question': 'what color does the person wear in the video',
#   'vedio_name': 'ZJL3728'},
#  {'answer': 'black',
#   'id': 4887,
#   'question': 'what is the color of the clothes the man wears',
#   'vedio_name': 'ZJL2977'},
#  {'answer': 'observing photo frame',
#   'id': 2833,
#   'question': 'what is the person in the video doing',
#   'vedio_name': 'ZJL4128'},
#  {'answer': 'folding towels',
#   'id': 30984,
#   'question': 'what is the people in the video doing',
#   'vedio_name': 'ZJL3682'},
#  {'answer': 'at evening',
#   'id': 20239,
# ...

# %%
#new_dict = json.loads(data_list)
with open("./data/data_train_val_answer_separation.json","w") as f:
    json.dump(data_train_val,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
import random

# %%
resultList=random.sample(range(0,len(data_list)),4100); # sample(x,y)函数的作用是从序列x中，随机选择y个不重复的元素。上面的方法写了那么多，其实Python一句话就完成了。
#print(resultList)# 打印结果
data_val=[]
for i in resultList:
    data_val.append(data_list[i])

# %%
data_val
# Out:
# [{'answer': ['bed', 'pillow', 'quilt'],
#   'id': 16535,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1319'},
#  {'answer': ['tire', 'parts', 'wood'],
#   'id': 10825,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL2887'},
#  {'answer': ['laundry detergent', 'laundry detergent', 'laundry detergent'],
#   'id': 3405,
#   'question': 'what is on the washing machine',
#   'vedio_name': 'ZJL4188'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 1649,
#   'question': 'is the person in the video sitting or standing',
#   'vedio_name': 'ZJL3708'},
#  {'answer': ['moving forward', 'moving forward', 'moving forward'],
#   'id': 10017,
#   'question': 'what is the person in the video doing',
#   'vedio_name': 'ZJL2302'},
#  {'answer': ['dancing', 'running', 'picking flowers'],
#   'id': 232,
#   'question': 'what is the woman doing in the video',
#   'vedio_name': 'ZJL1217'},
#  {'answer': ['black', 'black', 'black'],
#   'id': 9061,
# ...

# %%
resultList
# Out:
# [948,
#  14159,
#  8870,
#  2636,
#  2537,
#  8403,
#  8083,
#  14554,
#  9843,
#  12384,
#  15318,
#  1367,
#  6937,
#  7425,
#  3205,
#  15194,
#  12270,
#  15929,
#  6374,
#  8600,
#  9033,
#  4155,
#  4659,
#  7131,
#  6268,
#  2653,
#  12565,
#  15910,
#  4593,
#  6920,
#  3486,
#  12761,
#  9444,
#  4350,
#  12517,
#  326,
#  5455,
#  7962,
#  942,
#  16596,
#  3315,
#  9704,
#  13247,
#  12093,
#  13530,
#  7536,
#  15541,
#  10372,
#  6465,
#  13021,
#  16542,
#  4180,
#  405,
#  9481,
#  7454,
#  6774,
#  2953,
#  11151,
#  9418,
#  1944,
#  626,
#  240,
#  12135,
#  4251,
#  3577,
#  8058,
#  9909,
#  15161,
#  15753,
#  7707,
#  3054,
#  16319,
#  9369,
#  7884,
#  12883,
#  478,
#  13269,
#  12283,
#  391,
#  9948,
#  14465,
#  11896,
#  5686,
#  7819,
#  8437,
#  9037,
#  5222,
#  2283,
#  7751,
#  13573,
#  13088,
#  6382,
#  12667,
#  1709,
#  249,
#  6645,
#  16010,
#  13541,
#  2522,
#  888,
#  15802,
#  340,
#  3296,
#  12099,
#  6627,
#  11878,
#  484,
#  594,
# ...

# %%
len(data_val)
# Out:
# 4100

# %%
import json

# %%
#new_dict = json.loads(data_list)
with open("./new_data/data_train.json","w") as f:
    json.dump(data_list,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'vedio_name': 'ZJL2495'},
#  {'answer': ['kissing'],
#   'id': 6,
#   'question': 'what is the person doing in the video',
# ...

# %%
i=0
id=-1
data_test=[]
data = {}
answer_list=[]

with open('/disk/private-data/yy/TianChi/VQADatasetA_20180815/test.txt','r') as f:
    for line in f.readlines():
        line=line.strip('\n')
        words = line.split(',')
        for word in words:
            if word[0:3]!="ZJL" and word!='':
                i+=1
                if i % 4==1:
                    id+=1
                    data["question"]=word
                    data["vedio_name"]=video_id
                    data["id"]=id
                    data.setdefault("answer", "")
                elif i % 4 == 0:
                    #data["answer"].append(word)
                    data_test.append(data)
                    data={}
                    #answer=[]
                #else:
                    #data["answer"].append(word)
            else:
                video_id=word

# %%
data_test
# Out:
# [{'answer': '',
#   'id': 0,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 1,
#   'question': 'what color pants does the referee wear in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 2,
#   'question': 'what is the person in the middle of the video doing',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 3,
#   'question': 'where is the person in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 4,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 5,
#   'question': 'what is on the table',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 6,
#   'question': 'what is the color of the wall',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 7,
#   'question': 'what is the man in the video doing',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 8,
# ...

# %%
with open("./new_data/data_train.json","w") as f:
    json.dump(data_list,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
with open("./new_data/data_train_answer_separation.json","w") as f:
    json.dump(data_list_new,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
data_list_new
# Out:
# [{'answer': 'mirror',
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'pool',
#   'id': 1,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'shelf',
#   'id': 2,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'blue',
#   'id': 3,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'dark blue',
#   'id': 4,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'black blue',
#   'id': 5,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'cleaning up',
#   'id': 6,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': 'wiping mirror',
#   'id': 7,
#   'question': 'what is the person doing in video',
# ...

# %%
with open("./new_data/data_test.json","w") as f:
    json.dump(data_test,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
data_test
# Out:
# [{'answer': '',
#   'id': 0,
#   'question': 'what is in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 1,
#   'question': 'what color pants does the referee wear in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 2,
#   'question': 'what is the person in the middle of the video doing',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 3,
#   'question': 'where is the person in the video',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 4,
#   'question': 'is the person wearing the blue in the video standing or kneeling',
#   'vedio_name': 'ZJL1330'},
#  {'answer': '',
#   'id': 5,
#   'question': 'what is on the table',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 6,
#   'question': 'what is the color of the wall',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 7,
#   'question': 'what is the man in the video doing',
#   'vedio_name': 'ZJL4209'},
#  {'answer': '',
#   'id': 8,
# ...

# %%
data_list
# Out:
# [{'answer': ['mirror', 'pool', 'shelf'],
#   'id': 0,
#   'question': 'what is in front of the chair',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['blue', 'dark blue', 'black blue'],
#   'id': 1,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['cleaning up', 'wiping mirror', 'washing cup'],
#   'id': 2,
#   'question': 'what is the person doing in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['indoor', 'washroom', 'residence'],
#   'id': 3,
#   'question': 'where is the person in video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['standing', 'standing', 'standing'],
#   'id': 4,
#   'question': 'is the person sitting or standing in the video',
#   'vedio_name': 'ZJL3540'},
#  {'answer': ['white', 'white', 'white'],
#   'id': 5,
#   'question': 'what is the color of the clothes of the woman in the video',
#   'vedio_name': 'ZJL2495'},
#  {'answer': ['kissing', 'kissing', 'kissing'],
#   'id': 6,
# ...

# %%
with open("./new_data/data_train_val.json","w") as f:
    json.dump(data_list,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...

# %%
data_val
# Out:
# [{'answer': 'on table',
#   'id': 14914,
#   'question': 'where is the towel in the video',
#   'vedio_name': 'ZJL940'},
#  {'answer': 'true red',
#   'id': 340,
#   'question': "what is the color of the person's clothes in video",
#   'vedio_name': 'ZJL3546'},
#  {'answer': 'standing',
#   'id': 8146,
#   'question': 'is the person in the video standing or sitting',
#   'vedio_name': 'ZJL225'},
#  {'answer': 'computer',
#   'id': 10422,
#   'question': 'what is in front of the person in the video',
#   'vedio_name': 'ZJL2095'},
#  {'answer': 'dark red',
#   'id': 27507,
#   'question': "what is the color of the man's clothes in the video",
#   'vedio_name': 'ZJL3064'},
#  {'answer': 'black',
#   'id': 16781,
#   'question': 'what is the color of the clothes does the man wear',
#   'vedio_name': 'ZJL120'},
#  {'answer': 'white',
#   'id': 19999,
#   'question': 'what color is the wall',
#   'vedio_name': 'ZJL2713'},
#  {'answer': 'mannequin',
#   'id': 19679,
# ...

# %%
with open("./new_data/data_train_answer_separation.json","w") as f:
    json.dump(data_val,f)
    print("加载入文件完成...")
# Out:
# 加载入文件完成...
